# %% [markdown]
# ### Subject: MA5851 - Data Science Master Class I
# ### Author: Hendrik A. Dreyer
# ### Due Date: 3 December 2019
#
# #### This file contains the step to processing the Hacker News stories were posted during August 2019

# %%
import os

script_dir = os.getcwd()  #<-- absolute dir the script is in
rel_path = "..\data\hacker_news_post_process_2019.csv"
abs_file_path = os.path.join(script_dir, rel_path)

#Load the post process data from Assessment 3 into a pandas dataframe
import pandas as pd

# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv(abs_file_path) 

# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0        id                                         link_title  \
# 0         750  20624576  Turning a MacBook into a Touchscreen with $1 o...
# 1         690  20643052          The Lonely Work of Moderating Hacker News
# 2         241  20783006                                Introducing nushell
# 3          61  20826618  Google just deleted my nearly 10-year-old free...
# 4         540  20679133                               Ebola Is Now Curable
#
#                  web_link  points
# 0    www.anishathalye.com    1724
# 1       www.newyorker.com    1663
# 2  www.jonathanturner.org    1477
# 3              medium.com    1400
# 4           www.wired.com    1232

# %%
#Shape of the loaded post-procssed data
data.shape
# Out:
# (930, 5)

# %%
#Initiate spark
import findspark
findspark.init()

# %%
#Import the neccessary libs
from pyspark import SparkContext
from pyspark.sql.types import *
from pyspark.sql import SparkSession

# %%
#Create a spark session
spark = SparkSession.builder.master('local[4]').appName('HN_Media_Titles').getOrCreate()

# %%
#Specify a structure onto which the RDD will be framed
schema = StructType([
    StructField("idx",          IntegerType(), True),
    StructField("id",           StringType(),  True),
    StructField("link_title",   StringType(),  True),
    StructField("web_link",     StringType(),  True),
    StructField("points",       IntegerType(), True)])

# %%
# Set the relative path to the pst process csv file
spark_file_path = abs_file_path

#Format the csv file for RDD ingestion
data = spark.read.format("org.apache.spark.csv")\
                        .option("delimiter",",")\
                        .schema(schema)\
                        .option("mode", "PERMISSIVE")\
                        .option("inferSchema", "True")\
                        .csv(spark_file_path)

# %%
#Have a quick peak
data.show()
# Out:
# +----+--------+--------------------+--------------------+------+
# | idx|      id|          link_title|            web_link|points|
# +----+--------+--------------------+--------------------+------+
# |null|    null|                null|                null|  null|
# | 750|20624576|Turning a MacBook...|www.anishathalye.com|  1724|
# | 690|20643052|The Lonely Work o...|   www.newyorker.com|  1663|
# | 241|20783006| Introducing nushell|www.jonathanturne...|  1477|
# |  61|20826618|Google just delet...|          medium.com|  1400|
# | 540|20679133|Ebola Is Now Curable|       www.wired.com|  1232|
# | 780|20610839|All the best engi...|          medium.com|  1230|
# | 360|20739629|I Miss Microsoft ...|   www.hanselman.com|  1198|
# | 660|20653453|Alan Kay's answer...|       www.quora.com|  1181|
# | 362|20740179|Information opera...|    blog.twitter.com|  1116|
# | 785|20610395|Terminating Servi...|new.blog.cloudfla...|  1098|
# | 120|20794937|What happens when...|         twitter.com|  1041|
# | 363|20734384|How to Build Good...|      www.csc.gov.sg|  1016|
# | 570|20676904|NULL license plat...|     knrs.iheart.com|   999|
# | 630|20662232|What Does a Coder...|   nsaphra.github.io|   986|
# | 753|20625232|Yelp Is Replacing...|        www.vice.com|   953|
# | 450|20713283|Japanese anime st...|     www.blender.org|   937|
# | 240|20779964|Deconstructing Go...|freedom-to-tinker...|   918|
# | 480|20706702|      Cloudflare S-1|         www.sec.gov|   915|
# | 781|20616055|8chan goes dark a...|    www.theverge.com|   910|
# +----+--------+--------------------+--------------------+------+
# only showing top 20 rows

# %%
#Filter the link_title field and place int an RDD
link_title_rdd = data.select("link_title").rdd.flatMap(lambda x: x)

# %%
link_title_rdd.collect()
# Out:
# ['link_title',
#  'Turning a MacBook into a Touchscreen with $1 of Hardware (2018)',
#  'The Lonely Work of Moderating Hacker News',
#  'Introducing nushell',
#  'Google just deleted my nearly 10-year-old free and open-source Android app',
#  'Ebola Is Now Curable',
#  'All the best engineering advice I stole from non-technical people',
#  'I Miss Microsoft Encarta',
#  "Alan Kay's answer to ‘what are some forgotten books programmers should read?’",
#  'Information operations directed at Hong Kong',
#  'Terminating Service for 8Chan',
#  'What happens when you launch Google Chrome for the first time?',
#  'How to Build Good Software',
#  'NULL license plate not such a bright idea',
#  "What Does a Coder Do If They Can't Type?",
#  'Yelp Is Replacing Restaurants’ Phone Numbers So Grubhub Can Take a Cut',
#  'Japanese anime studio Khara moving to Blender',
#  'Deconstructing Google’s excuses on tracking protection',
#  'Cloudflare S-1',
#  '8chan goes dark after hardware provider discontinues service',
#  'Please Add RSS Support to Your Site',
#  'No More Cheap Shipping for Chinese Sellers',
#  'Python Is Eating the World',
#  'Verizon to Sell Tumblr to Automattic',
#  'Tasty Seaweed Reduces Cows’ Methane Emissions by 99%',
#  'Hy',
#  'Things I Learnt from a Senior Software Engineer',
#  'WeWTF',
#  'Linux Journal Ceases Publication: An Awkward Goodbye',
#  'AMD lands Google, Twitter as customers with newest server chip',
#  'US Navy will replace touchscreen with mechanical controls on its destroyers',
#  'Standard Ebooks: Free public-domain ebooks, carefully produced',
#  'Why is modern web development so complicated?',
#  'A man who destroyed his multimillion dollar company in 10 seconds (2018)',
#  'OpenDrop: An Open Source AirDrop Implementation',
#  'A deep dive into iOS Exploit chains found in the wild',
#  'Software Architecture Guide',
#  'Sites using Facebook ‘Like’ button liable for data, EU court rules',
#  "Insect 'apocalypse' in U.S. driven by 50x increase in toxic pesticides: study",
#  'Apple Confirms $1M Reward for Anyone Who Can Hack an iPhone',
#  'Why All of Our Games Look Like Crap',
#  'Tech Interview Handbook',
#  'Fewer Than Half of Google Searches Now Result in a Click',
#  'Ugly Gerry – Font created from congressional districts',
#  'Why has examine.com disappeared from search results?',
#  'A Walk in Hong Kong',
#  'John Carmack on the Joe Rogan Experience [video]',
#  'The Baseline Interpreter: A Faster JavaScript Interpreter in Firefox 70',
#  'Google Doesn’t Want Staff Debating Politics at Work Anymore',
#  'Build Your Own Text Editor',
#  "I've reproduced 130 research papers about “predicting the stock market”",
#  'Ask HN: How Do You Read?',
#  'How to build a plugin system on the web and also sleep well at night',
#  'Europe is edging towards making post-car cities a reality',
#  'New York City Neighbors Build Cheaper Way to Connect to Web',
#  'GitHub Actions now supports CI/CD, free for public repositories',
#  'Consume less, create more',
#  'Living Near Trees, Not Just Green Space, Improves Wellbeing',
#  'Kerbal Space Program 2',
#  'MacBook Pro Keyboard Drives Me Crazy',
#  'Why I Turned Down an AWS Job Offer',
#  'Facebook has been granted patent on shadow banning',
#  "The Linux kernel's inability to gracefully handle low memory pressure",
#  'Show HN: CLI tool for saving web pages as a single file',
#  'Start Your Own ISP',
#  "Every productivity thought I've ever had, as concisely as possible",
#  "Preindustrial workers worked fewer hours than today's (2009)",
#  'Milky Way’s Black Hole Just Flared, Growing 75 Times as Bright for a Few Hours',
#  'Amazon has proven unable or unwilling to effectively police third-party sellers',
#  'Rails 6.0',
#  'Ha-ha wall',
#  'Speaking to yourself in the third person makes you wiser',
#  'IBM Open-Sources Power Chip Instruction Set',
#  'Apple expands parts access to more independent repair businesses',
#  'Paged Out – a new experimental magazine about programming',
#  "Let's build houses for people, not cars",
#  'We Have Ruined Childhood',
#  "Decrement carbon: Stripe's negative emissions commitment",
#  '16M Americans will vote on hackable paperless machines',
#  'Home Chip Fab',
#  'Google and Mozilla are failing to support browser extension developers',
#  "A mathematician's way of converting miles to kilometers",
#  'There is no evil like reCAPTCHA',
#  'Kaspersky AV injected unique ID allowing sites to track users in incognito mode',
#  'Who Owns Huawei?',
#  'The Horror of Microsoft Teams',
#  'Hundreds of extreme self-citing scientists revealed in new database',
#  'Regex for Noobs – An Illustrated Guide',
#  'Apple will soon treat online web tracking the same as a security vulnerability',
#  'The IT Guy vs. the Con Artist',
#  'Death Note: L, Anonymity and Eluding Entropy (2017)',
#  'AMD Rome Second Generation EPYC Review: 2x 64-core Benchmarked',
#  'Amazon Is a Monopoly',
#  'Time anxiety: is it too late?',
#  'WTF – A personal information dashboard for your terminal',
#  'Scientists Discover a Cure for the Deadliest Strain of Tuberculosis',
#  'Show HN: Divjoy – React Codebase and UI Generator',
#  'Proteins That May Restore Damaged Sound-Detecting Cells in the Ear',
#  '15 states are trying to make the electoral college obselete',
#  'Banned C standard library functions in Git source code',
#  'Pronunciations for hexadecimal numbers (1968)',
#  'Turbo, an Improved Rainbow Colormap for Visualization',
#  "From Mac to Linux – the setup I've grown to love",
#  'Time to Get Serious about Tick-Borne Diseases',
#  'Pentagon testing mass surveillance balloons across the US',
#  'Useless Windows 10 Features',
#  'Some Obscure C Features',
#  'Mercedes-Benz pre-safe sound',
#  'TSV Utilities: Command line tools for large, tabular data files',
#  'Psytrance Guide',
#  "Researcher banned on Valve's bug bounty program publishes second Steam 0-day",
#  'Why do developers at Google consider Agile development to be nonsense? (2016)',
#  'Planet: Imaging the entire Earth every day',
#  'Software made me loathe my car',
#  'Dqlite – High-Availability SQLite',
#  'CutiePi – All-in-one Raspberry Pi tablet',
#  "Knuth on Huang's Sensitivity Proof: “I've got the proof down to one page” [pdf]",
#  'Supercentenarians are concentrated into regions with no birth certificates',
#  'Anthony Levandowski Charged with Theft of Trade Secrets',
#  'exFAT in the Linux kernel',
#  'Speed matters: Why working quickly is more important than it seems (2015)',
#  'Programmers: Before you turn 40, get a plan B (2009)',
#  'Information Theory for Intelligent People (2018) [pdf]',
#  'I completed Ultimate Go, took good notes and commented directly on source code',
#  'A Guide to Recording 660FPS Video on a $6 Raspberry Pi Camera',
#  'Super Mario 64 has been decompiled',
#  'YAML: Probably not so great after all',
#  'Rust Language Cheat Sheet',
#  'Thoughts on Rust bloat',
#  'Google Chrome Incognito Mode Can Still Be Detected',
#  'Rules for Intuitive UX',
#  'iTerm2 3.3',
#  'Datadog S-1',
#  'The not so hidden cost of sharing code between iOS and Android',
#  'Show HN: Chart.xkcd – Xkcd-styled chart library',
#  'Tell HN: Danny Cohen Has Died',
#  'Down the Rabbit-Hole',
#  'Three Kinds of Good Tech Debt',
#  'Facebook scans system libraries on Android and uploads them to their server',
#  'Uber Posts $5.2B Loss and Slowest Ever Growth Rate',
#  'The Fully Remote Attack Surface of the iPhone',
#  'Google to Offer a Best Price Guarantee on Certain Flights',
#  'NPM Bans Terminal Ads',
#  'The Architecture of Open Source Applications',
#  'People love working remotely',
#  'Berlin’s Popular Shopping Streets Will Go Car-Free',
#  'Toni Morrison Has Died',
#  'Sourcehut welcomes Bitbucket refugees',
#  'AI startup claims to automate app making but actually just uses humans',
#  'Ask HN: Recommended resources to learn the Linux kernel and OS theory?',
#  'Steam Windows Client Local Privilege Escalation 0day',
#  'Hong Kong ISP Association’s Statement on Selective Blocking of Internet Services',
#  'I wasn’t getting hired as a data scientist, so I sought data on who is',
#  'Juul, Philip Morris Sued Under Racketeer Act for Targeting Kids',
#  'VMware Acquires Carbon Black for $2.1B and Pivotal for $2.7B',
#  'Zen 2 Missives – AMD now delivering efficiencies that are double that of Intel',
#  'Write your own Excel in F# (2018)',
#  'Performance Matters',
#  'Is Perl 6 Being Renamed?',
#  'People Simply Empty Out (1986)',
#  'Black Hat: GDPR privacy law exploited to reveal personal data',
#  'Show HN: I trained a deep learning model to build sites for me',
#  'WebKit Tracking Prevention Policy',
#  'Removing Coordinated Inauthentic Behavior from China',
#  'Calculus For The People',
#  'Anxiety Looks Different in Men',
#  'Yield Curves Invert in U.S., U.K',
#  'Amazon offered ‘Amazon’s Choice’ to vendors who bought ads and lowered prices',
#  'CyberChef – Cyber Swiss Army Knife',
#  'Rust 1.37.0',
#  "A Boeing Code Leak Exposes Security Flaws Deep in a 787's Guts",
#  'Ask HN: Best resources to gain math intuition?',
#  'Mozilla takes action to protect users in Kazakhstan',
#  'Anime4K: Real time high quality video upscaling',
#  'Wine on Windows 10',
#  'Building a distributed time-series database on PostgreSQL',
#  'Xfce 4.14',
#  'Most startup theory is ex-post, therefore bs',
#  'Lessons from Stripe',
#  'Show HN: Wave-based non-line-of-sight computational imaging in Julia',
#  '‘They Get Fired All the Time. And They Have No Idea Why’',
#  '9th Circuit says users can sue Facebook over unlawful use of facial recognition',
#  'Linux kernel drivers in Rust might become an option in the future',
#  'MoviePass Worked Out Great',
#  'A Beginner’s Introduction to Python Web Frameworks (2018)',
#  'Ask HN: Who is hiring? (August 2019)',
#  'Show HN: Data Structures and Algorithms in JavaScript',
#  'Await in Rust',
#  'Cool but obscure X11 tools',
#  'Elsevier threatens others for linking to Sci-Hub but does so itself',
#  'Group sex app leaks locations, pics and personal details',
#  'Apple Is Locking iPhone Batteries to Discourage Repair',
#  '“I would like to maintain the floppy driver”',
#  'Fracking in North America could be partly to blame for methane spike – study',
#  'Flawed Algorithms Are Grading Millions of Students’ Essays',
#  '35 Over 35',
#  'U.S. Designates China as Currency Manipulator',
#  'Sunsetting Mercurial Support in Bitbucket',
#  'Open letter from an Android developer to the Google Play team',
#  'Cue – A language for defining, generating, and validating data',
#  'How Rust optimizes async/await',
#  'One City Saved $5M by Routing School Buses with an Algorithm',
#  'Async-std: an async port of the Rust standard library',
#  'RegExr',
#  'The Art of Warez [video]',
#  'Get your work recognized: write a brag document',
#  'One job, many roles: The different skills needed to be a successful CTO',
#  'Productivity and the Workweek (2000)',
#  'Nigerian Teens Are Making Sci-Fi Shorts with Slick Visual Effects',
#  'The most frequent 777 characters give 90% coverage of Kanji in the wild',
#  'Contributing to the Mozilla code base',
#  'The Lost Art of Lacing Cable (2018)',
#  'Martini: Real-Time Terrain Mesh Generator',
#  'The Impact of Meditating Every Day',
#  'Software was eating the world – now landlords are eating everything',
#  'IBM has released the Power Architecture instruction set to the Linux Foundation',
#  "Plastics: What's Recyclable, What Becomes Trash and Why",
#  'Uber, losing billions, freezes engineering hires',
#  'IRS budget cuts cost $34.3B in lost revenue from big business',
#  'Calculus Is Deeply Irrational',
#  'Every Noise at Once',
#  'AT&T employees were bribed to install phone unlocking malware on company network',
#  'The Problem at Yale Is Not Free Speech',
#  'Silk',
#  'Beyond Meat and KFC partner to test fried plant-based ‘chicken’',
#  'The We Company S-1',
#  'How to return to the flow faster',
#  'The Paxos Algorithm, or How to Win a Turing Award',
#  'Attorney General Barr and Encryption',
#  'Making email more modern with JMAP',
#  'FFmpeg 4.2',
#  'WebAssembly Interface Types: Interoperate with All the Things',
#  'Roblox hits 100M monthly active users, bigger than Minecraft',
#  'Words that do Handstands',
#  'How Men’s Bodies Change When They Become Fathers',
#  'Misconfigured Jira instances exposed data of hundreds of Fortune 500 companies',
#  'Companies Use Borrowed Billions to Buy Back Stock, Not to Invest',
#  'NY State alleges ExxonMobil knew risks of climate change and defrauded investors',
#  'New React DevTools',
#  'WeWork Gets Tax Rebate Meant for Its Small-Business Tenants',
#  'Administration Using the Full Power of the Surveillance State on Whistleblowers',
#  'A book from Alan Turing and a mysterious piece of paper',
#  'How to get your first ten customers (2013)',
#  'Does the Amazon provide 20% of our oxygen?',
#  'Uber proposes policy that would pay drivers a minimum wage of $21 per hour',
#  'The Most Dangerous Writing App',
#  'Why Did China Just Devalue the Yuan? How Trade Works with Free-Floating Currency',
#  'Arend: Theorem Prover Based on Homotopy Type Theory by JetBrains',
#  'BlazingSQL is Now Open Source',
#  'Key Negotiation of Bluetooth Attack',
#  'On-Device, Real-Time Hand Tracking with MediaPipe',
#  'Dirty tricks 6502 programmers use',
#  'Insured price $2,758, cash price $521',
#  'Germans Grow Frustrated with Their Slow-Poke Internet',
#  'Building a Raspberry Pi 3B+ full keyboard handheld',
#  'Show HN: Saag as a Service – macronutrient-portioned Indian spinach curry',
#  'Social exclusion fuels extremism in young men',
#  'CamScanner, a malicious Android app with more than 100M downloads in Google Play',
#  "Moscow's blockchain voting system cracked a month before election",
#  'Anna Karenina Principle',
#  'QEMU VM Escape',
#  'Inflated Bond Ratings Helped Spur the Financial Crisis. They’re Back',
#  'Medieval people bathed regularly',
#  'Devilution – A web port of the original Diablo game',
#  'Cooling a house without air conditioning',
#  '3.8M-year-old skull of an early ape-like human ancestor discovered in Ethiopia',
#  'Huawei Technicians Helped African Governments Spy on Political Opponents',
#  'TypeScript 3.6',
#  'The answer to “Will you mentor me?” is no (2010)',
#  'How to Measure Indoor Air Quality with a Raspberry Pi, RuuviTags and PMS7003',
#  'WeWork Isn’t a Tech Company',
#  "Why Const Doesn't Make C Code Faster",
#  'Verified by Twilio',
#  'Python vs. Rust for Neural Networks',
#  'Big Coal Plants Begin to Close',
#  'Aussie ISV buys ads to wake up Google support',
#  'The Feynman Lectures on Physics: Algebra (1963)',
#  'Coinbase: Responding to Firefox 0-days in the wild',
#  'Gamedev Tutorial: Trigonometry Basics – Sine and Cosine',
#  'Secretly Public Domain: Most books published in the US before 1964',
#  'Show HN: ClojureScript pixel game engine with Blender live-reloading',
#  'Lisp is not based on the Lambda Calculus',
#  'Alphabet overtakes Apple to become most cash-rich company',
#  'Rice University researchers propose a way to boost solar efficiency',
#  'Using Backblaze B2 and Cloudflare Workers for free image hosting',
#  "The worst sales promotion in history: Hoover's free flight fiasco",
#  'The Door Problem of Combat Design',
#  'Wikipedia Is Now a Brave Verified Publisher',
#  'Google Plans to Deprecate FTP URL Support in Chrome',
#  'Killing a process and all of its descendants',
#  'Show HN: I created Postwoman, an online, open-source API request builder',
#  'The Many Possibilities of iMessage File Vulnerability',
#  'The design of littlefs: A fail-safe filesystem designed for microcontrollers',
#  "Ask HN: What's the best setup for ad blocking and tracker blocking?",
#  'Rabbit Holes: The Secret to Technical Expertise',
#  'Show HN: I made a CRM system to make sales fun',
#  'Syslog: Complete System Administrator Guide',
#  'My Sudden Trip to Hell',
#  'Why does all life use the same 20 amino acids?',
#  'Toshiba Introduces New Tiny NVMe SSD Form Factor',
#  'John Carmack on Parallel Implementations (2018)',
#  'GNU Radio 3.8',
#  'Ask HN: How do you handle logging?',
#  'The GitHub registry public beta is live',
#  'A practical guide to CSS transitions and animations',
#  'U.S. Farmers Stung by Tariffs Now Face a $3.5B Corn Loss',
#  'Facebook Hit by Apple’s Crackdown on Messaging Feature',
#  'Privacy Sandbox – Open standards to enhance privacy on the web',
#  'Transformers from Scratch',
#  'We Made Amiga, They Fucked It Up (2015)',
#  'Memory Management in Python',
#  'Die With Me – A chat app you can only use when you have less than 5% battery',
#  'Now Bigger Than eBay, Shopify Sets Its Sights on Amazon',
#  "Let's Build a Video Card",
#  'Pastel: A command-line tool to generate, analyze, convert and manipulate colors',
#  'Pagemap: A mini map for your website',
#  'Minify Your SVGs',
#  'Yubico launches its dual USB-C and Lightning two-factor security key',
#  'A Bloomberg reporter’s account of trying to get back his name and credit rating',
#  'Opioid crisis: Johnson and Johnson hit by landmark ruling',
#  'Big Pharma is using faux generics to keep drug prices high, critics say',
#  "Tokyo's audiophile venues (2016)",
#  'Japan surpasses China as largest foreign holder of US Treasurys',
#  'Statement on the Purpose of a Corporation',
#  'Spying on HTTPS',
#  "Why doesn't mathematics collapse, though humans often make mistakes in proofs?",
#  'Hackers ship their exploits directly to their target’s mailroom',
#  'Major book publishers sue Amazon’s Audible over new speech-to-text feature',
#  'Hacking the Sonos IKEA Symfonisk into a High Quality Speaker Amp',
#  'Kubernetes Security Assessment [pdf]',
#  '“Culture fit” is a two way street (2018)',
#  'What Happens When You ACH a Dead Person?',
#  'Google search takes 7 seconds on certain queries',
#  'Go Module Mirror and Checksum Database Launched',
#  'High levels of oestrogens in the womb linked to autism',
#  'Alone in the Dark',
#  'The fungus that devastates the Cavendish banana has now arrived in Latin America',
#  'Metal shards from Boeing 787 taking off over Rome rain down on people below',
#  'The “terrible” 3 cent MCU – a short survey of sub $0.10 microcontrollers',
#  'The Order of the JSON',
#  'In effect, Seattle is decriminalizing the use of hard drugs',
#  'FAA Bans Recalled Apple Laptops from Flights',
#  'Salsify – A New Architecture for Real-time Internet Video',
#  'Walmart sues Tesla over fires at stores fitted with its solar panels',
#  'Danish bank launches negative interest rate mortgage',
#  'Open-source firmware',
#  'Technical Vision for Qt 6',
#  'Show HN: Yack – Community Browser for Hacker News, Reddit, YouTube and More',
#  'A dream of an ultimate OS (1995)',
#  'A Primer on Bézier Curves (2013)',
#  'Bontrager’s WaveCel material more effective at preventing concussions than MIPS',
#  'The Death of Social Reciprocity in the Era of Digital Distraction',
#  'Amazon wants to control third-party sellers’ product pricing',
#  'PartiQL: One query language for all your data',
#  "A bug I wish I hadn't caught",
#  'A mobile phone that respects your freedom [video]',
#  'Cloud Run Button: Click-to-deploy your Git repos to GCP',
#  'My Home Lab Server with 20 Cores / 40 Threads and 128 GB Memory',
#  'GCC null pointer check removed',
#  "In the US, it's cheaper to build and operate wind farms than buy fossil fuels",
#  'WiringPi – deprecated',
#  'Credit cards have a privacy problem',
#  'Starbucks, monetary superpower',
#  'Building ages in the Netherlands',
#  'Huawei Seeks Independence from the US with RISC-V and Ascend Chips',
#  'Black Hat Talk About ‘Time AI’ Causes Uproar, Is Deleted by Conference',
#  'The hypersane are among us, if only we are prepared to look',
#  'Why I like Clojure',
#  'Cybersecurity Pros Name Their Price as Hacker Attacks Swell',
#  'GCP to introduce an additional charge for publicly addressed VM instances',
#  'YouTube shuts down music companies’ use of manual copyright claims',
#  'Poetry: Dependency Management for Python',
#  'Protocols, Not Platforms: A Technological Approach to Free Speech',
#  'Artichoke – A Ruby made with Rust',
#  'Apollo Guidance Computer switching power supply works after 50 years',
#  'Monads as a Programming Pattern',
#  'Denial of H1-B visas to India’s largest IT services exporters at all-time high',
#  'Show HN: Zero-Config Documentation Websites for Python',
#  'Show HN: We track Reddit, Google trends, Twitter, etc. to find trending topics',
#  'Advice to my younger self: become allergic to the churn',
#  'Show HN: Sourcery – get a free, self-updating website',
#  'Show HN: Lunch Money, a personal budgeting tool with multi-currency support',
#  'New Life Found That Lives Off Electricity (2016)',
#  'Cerebras Systems unveils a 1.2T transistor chip for AI',
#  'Software architects should be involved in earliest system engineering activities',
#  'Using TypeScript with React',
#  'BMW unveils car sprayed with Vantablack',
#  'We shouldn’t take peer review as the ‘gold standard’',
#  'Launch HN: SannTek (YC S19) – Breathalyzer for Cannabis',
#  'The Myth of Consumer-Grade Security',
#  'Nvidia CEO says Google is the only customer building its own silicon at scale',
#  'Racket: Lisp for Learning',
#  'Ask HN: How to be less argumentative online?',
#  'Insurance Companies Are Paying Cops to Investigate Their Own Customers',
#  'Stand Out as a Speaker',
#  'Creeping normality',
#  'NASA said to be investigating first allegation of a crime in space',
#  'Germany for First Time Sells 30-Year Bonds Offering Negative Yields',
#  'America’s elderly seem more screen-obsessed than the young',
#  'Alarming surge in drug-resistant HIV uncovered',
#  'Levenshtein Distance',
#  'Punpedia – The Online Encyclopedia of Puns',
#  'Legit-Looking iPhone Lightning Cables Will Hijack Your Computer',
#  'Open Startups List',
#  'The first solar road has turned out to be a disappointing failure',
#  'Facial recognition: School ID checks lead to GDPR fine',
#  'Twitter confesses to more adtech leaks',
#  'What has to happen with Unix virtual memory when you have no swap space',
#  'Elon Musk Gambled Tesla to Save SolarCity',
#  'How the new open-source typeface used by GitHub and Mozilla came to be',
#  'Splunk acquires cloud monitoring service SignalFx for $1.05B',
#  'Swap, swap, swap, and bad places to work',
#  'Interviews with programming language creators (2010) [pdf]',
#  'Activision Blizzard has moved billions of dollars of profit into tax havens',
#  'How to Make Billions of Dollars Reducing Loneliness',
#  'Seashells – Pipe output from command-line programs to the web in real time',
#  "WeWork IPO Shows It's the Most Magical Unicorn",
#  'Experimental USAF space plane breaks record for orbital spaceflight',
#  'What I Do as a DevOps Consultant',
#  'Making containers safer',
#  'The Erlang Rationale',
#  'Apple suspends Siri response grading in response to privacy concerns',
#  'The Tragedy of UCS-2',
#  'Crispr pioneer among University of California researchers boycotting Elsevier',
#  '‘No One Saw a Thing’: When a Midwest Town Banded Together to Kill the Town Bully',
#  'What Makes a Good Conversation?',
#  'Ruffle – An Adobe Flash Player Written in Rust Compiled to WebAssembly',
#  'Hedonometer',
#  'GitHub Supports Web Authentication (WebAuthn) for Security Keys',
#  'Twelve LaTeX packages to get your paper accepted (2017)',
#  'A Manager’s Guide to Kubernetes Adoption',
#  'Typed Properties in PHP 7.4',
#  'A Readable Specification of TLS 1.3',
#  'Who Owns Your Wireless Service? Crooks Do',
#  'Feds ordered Google location dragnet to solve Wisconsin bank robbery',
#  'Things to Know About GNU Readline',
#  'Mortgage Market Reopens to Risky Borrowers',
#  'Recognizing the signs of disruption in our urban habitat',
#  'Acute Effects of Electronic Cigarette Aerosol Inhalation on Vascular Function',
#  'NOAA Data Confirms July Was Hottest Month Ever Recorded',
#  'JavaScript: The Modern Parts',
#  'Google Warns Developers That All New Android Apps Require 3 Days for Approval',
#  'Rust GUI ecosystem overview',
#  'How Does Esperanto Sound?',
#  'How Command and Conquer: Tiberian Sun punished the computers of the day [video]',
#  'What’s the difference between statistics and machine learning?',
#  'Dropbox no longer follows symlinks to items outside of your Dropbox account',
#  'Climate change made European heatwave up to 3°C hotter',
#  'Unison File Synchronizer',
#  'Michael Cicconetti',
#  'OpenGPT-2: We Replicated GPT-2 Because You Can Too',
#  'Practical Tips for Facelifting a Tech Resume',
#  'Natural Language Processing: The Age of Transformers',
#  'The Portuguese Bank Note Crisis of 1925',
#  'California farmers are planting solar panels as water supplies dry up',
#  'YouTube Said to Be Fined Up to $200M for Children’s Privacy Violations',
#  'Microsoft Is Killing ePub Support in Edge Classic',
#  'Ask HN: Configuration Management for Personal Computer?',
#  'Intel and Rust: The Future of Systems Programming [video]',
#  'From 30 to 230 Docker containers per host',
#  'Wireless Carrier Throttling of Online Video Is Pervasive: Study',
#  'How do black holes destroy information and why is that a problem?',
#  'Waypipe: GSoC Project Complete',
#  'Launch HN: Quirk (YC S19) – Open-Source Cognitive Behavioral Therapy',
#  "Boeing's Crashes Expose Systemic Failings",
#  'Goldman Sachs is spending $100M to shave milliseconds off stock trades',
#  'Bad Times in Tech? Not If You’re a Startup Serving Other Startups',
#  'Why did Turbo Pascal apps fail with a division-by-zero on faster systems?',
#  'Show HN: StoryTime – Create stories about your code instead of documentation',
#  'One of the greatest science fiction magazines is now available online (2017)',
#  'Nixery: Transparently build and serve containers using Nix',
#  'Most internet service providers are gone – Sonic has survived and thrived',
#  'Where do interrupts happen?',
#  'On-disk format robustness requirements for new filesystems',
#  'Giving up on Julia (2016)',
#  'The Ethics of Web Performance',
#  'Keeping Tesla Roadsters Alive Is Serious Work',
#  'Oracle directors give blessing to shareholder lawsuit against Larry Ellison',
#  'LF: Fully Decentralized Fully Replicated Key/Value Store',
#  'A Quarter of Humanity Faces Looming Water Crises',
#  'PacVim – PacVim is a game that teaches you vim commands',
#  'Why Does Infrastructure Cost So Much?',
#  'Laws of Showrunning (2016) [pdf]',
#  'Possible detection of a black hole with a mass that was thought to be impossible',
#  'Launch HN: Dex (YC S19) – personal CRM that reminds you to keep in touch',
#  "A Buddhist monk confronts Japan's suicide culture (2013)",
#  'The flawed three-cueing system for teaching reading',
#  'Home 3D metal printing: first results',
#  'São Paulo’s Outdoor Advertising Ban (2016)',
#  'Google Forcing Nest Cameras’ Visual Indicator Light To Be On',
#  'The Flawed Reasoning Behind the Replication Crisis',
#  'Sugar: Open-source software learning platform for children',
#  'Open Location Code: An Open Source Standard for Addresses',
#  "'It's crazy': Chase forgiving all debt owed by its Canada credit card customers",
#  'Computer Science Illustrated (2014)',
#  'Parsing JSON Is a Minefield (2018)',
#  'I found an easter egg from 1977',
#  'The interviewer skills ladder for high growth companies',
#  'Show HN: Tailwind.run – An Online Playground for Tailwind CSS',
#  'What to do once you admit that decentralization never seems to work (2018)',
#  'Hundreds of exposed Amazon cloud backups found leaking sensitive data',
#  'Removing One Maine Dam 20 Years Ago Changed Everything',
#  'Nonplanar Printing',
#  "Why didn't the Romans contribute much to mathematics?",
#  'Bulk Data Structures C++',
#  'Exploring Weight Agnostic Neural Networks',
#  'Have You Ever Tried to Sell a Diamond? (1982)',
#  'Big O Notation – Using not-boring math to measure code’s efficiency',
#  'Cisco is making it more difficult to use used hardware',
#  'How shrinkflation is playing havoc with economists’ models',
#  'Rotten Apple: Right to Repair Roundup',
#  'Tumblr',
#  'DoorDash Buying Caviar from Square for $410M',
#  'Daniel Radcliffe and the Art of the Fact-Check (2018)',
#  'Svalbard is as close as you can get to a place with open borders',
#  'Dyson Tree',
#  'How I finally won my name from domain resellers after nine years of waiting',
#  "FBI tells lawmakers it can't access Dayton gunman's phone",
#  'Children of a Thailand tribe who see with clarity beneath the waves (2016)',
#  'Franky Zapata: Flyboarding Frenchman crosses English Channel',
#  'Dignity',
#  'Teen Hacker Finds Bugs in School Software That Exposed Millions of Records',
#  'A Pissed-Off Tutorial for Google Wave (2010) [video]',
#  'I Took a Pay Cut for a More Meaningful Job',
#  'IBM Stops Buybacks to Pay for Red Hat',
#  'Parallelism in PostgreSQL',
#  'Tech backlash has come to Stanford',
#  'Google’s rivals opt out of search engine auction, calling it ‘anti-competitive’',
#  'Peloton S-1',
#  'Why a mock doesn’t work',
#  'Patterns on goods designed to trigger Automated License Plate Readers',
#  'Show HN: TeXnique – A LaTeX Typesetting Game',
#  'Upmem Puts CPUs Inside Memory to Allow Applications to Run 20 Times Faster',
#  'More Fires Now Burning in Angola, Congo Than Amazon',
#  'Telegram introduces feature to prevent users from texting too often in a group',
#  'Somehow I Became Respectable',
#  'How to become a great impostor',
#  "Seattle's 'microtransit' experiment drives people to light rail",
#  'Basic Electron Framework Exploitation',
#  'Helsinki Central Library chosen as the best new public library',
#  'SpaceX Smallsat Rideshare Program',
#  'Personal Website for Programmers',
#  'Startups from Y Combinator’s S19 Demo Day 1',
#  'Highlights from Git 2.23',
#  'Show HN: YouTube Decade – The most-viewed videos posted 10 years ago',
#  'Standard JS: npm install funding',
#  'Mapped: The world’s coal power plants',
#  'Kept alive with tubes for nearly 17 years',
#  'Lessons we learned when debugging a scaling problem',
#  'P++ idea: FAQ',
#  'Show HN: Scarf – Platform to help open-source developers monetize their work',
#  'Old Paris Is No More',
#  "Spacebook: AGI's near Real-Time satellite viewer",
#  'The Path to Dijkstra’s Handwriting (2013)',
#  'Ted Chiang: Realist of a Larger Reality',
#  'Escape rooms are big business',
#  'Alcohol Belts of Europe',
#  'Dependent Haskell Is the Future (2018)',
#  'North American versus European distribution systems (2011)',
#  "Social share buttons that don't allow the social sites to track your users",
#  'Nutrient deficiencies in rice grown under higher carbon dioxide',
#  'The body is the missing link for truly intelligent machines (2017)',
#  'Electric motor design claims remarkable improvements',
#  'Living Off the Land in Linux',
#  'No Son of Mine Is Going to Be a Benthamite',
#  'Extended Validation Certificates Are Really Dead',
#  "The Mobility Trap: Why We'll Never Fix Congestion by Speeding Up Traffic",
#  'Static Type Checking in Common Lisp',
#  'Interslavic Language',
#  'Startups from Y Combinator’s S19 Demo Day 2',
#  'Announcing Notqmail',
#  'Why the French love to say no',
#  'Theories of Error Back-Propagation in the Brain',
#  'Black Beekeepers Are Transforming Detroit’s Vacant Lots into Bee Farms (2018)',
#  'GPT-2: 6-Month Follow-Up',
#  'Crossword Panic of 1944',
#  'Libspng – C library for reading and writing PNG files',
#  "Kegan's Theory of the Evolution of Consciousness",
#  'Hospital checklists are meant to save lives, so why do they often fail?',
#  'Understanding SAT by Implementing a Simple SAT Solver in Python (2014)',
#  'A deep dive into Linux namespaces, part 4',
#  'Chemists make first-ever ring of pure carbon',
#  'Datacenter Locations Driven by 19th Century Politics',
#  'Uber Is Biggest Loser as SoftBank Counts IPO Returns',
#  'Using bacteria to make self-healing cement',
#  'Better Encrypted Group Chat',
#  'Exploring Mathematics with Matplotlib and Python',
#  "Moravec's Paradox",
#  'Vibration-minimizing motion retargeting for robotic characters',
#  'Website Builder Webflow (YC S13) Went from Near Bankruptcy to $72M Series A',
#  'Swiss Post Suspends Drone Delivery Service After Second Crash',
#  'Do-It-Yourself OpenJDK Garbage Collector',
#  "Patagonia's Philosopher King (2016)",
#  'J can look like APL or English',
#  "Julia's Release Process",
#  'Math in Data Science',
#  'Getting Real About Distributed System Reliability (2012)',
#  "Don't forget randomness is still just a hypothesis (2006)",
#  'History of the broken vertical bar, being the ¦ form of |',
#  'Show HN: I Built a “Google Alerts” for Hacker News',
#  'TV detector van',
#  'Two brothers invented an alphabet for their native language, Fulfulde',
#  'Where will ‘garage orphans’ charge electric cars?',
#  'How Biotech Startup Funding Will Change in the Next 10 Years',
#  'Ignition: An Informal History of Liquid Rocket Propellants (1972) [pdf]',
#  'Wine-dark sea',
#  '10 Years SeL4: Still the Best, Still Getting Better',
#  'When to Shut Down a Startup [video]',
#  'CTVT – A contagious cancer that spreads from dog to dog',
#  'Ceramics enter a new era with laser-welded joints',
#  'The Shady World of Repair Manuals: Copyrighting for Planned Obsolescence (2012)',
#  'Open Source Hardware Hearing Aid Part 1',
#  'The Last Working Olivetti Mainframe Sits In a Tuscan High School',
#  'In the beginning was the command line (1999) [pdf]',
#  'Manufacturers want to quit China for Vietnam, but find it impossible',
#  'Microsoft Has First Major Impact on Chrome',
#  'Casting Glass from 3D Printed Molds',
#  'DEF CON and Stack Overflow: What Our Traffic Says About Cybersecurity',
#  'Geocities Archive',
#  'N-Shot Learning: Learning More with Less Data',
#  'Who Did the Math for General Relativity First, Einstein or Hilbert?',
#  'The Rule of 2',
#  "An 'Exosuit' That Boosts Endurance on the Trail",
#  'Subsurface – An open source scuba dive logging platform',
#  'You May Be Better Off Picking Stocks at Random, Study Finds',
#  'Goals and Rewards Redraw the Brain’s Map of the World',
#  'FBI: Delivery drivers involved in Amazon theft ring',
#  'Solar Powered Raspberry Pi Camera',
#  'Mosquitoes Changed Everything',
#  'Columnist asked researchers what they could find out from just his cell number',
#  'A Commercial Path to Fusion',
#  'StockX was hacked, exposing millions of customers’ data',
#  'Waymo’s Backseat Drivers: Confidential Data Reveals Self-Driving Taxi Hurdles',
#  'MoviePass reportedly changed passwords to prevent users from seeing films',
#  '“Bicycle of the Mind”',
#  'What Germans Are Reading',
#  'Tiny Toy TOTP Generator in 18 Lines of Python',
#  'A Molecular Near Miss',
#  'Supercomputers will start building a 3D map of the world',
#  'What Companies Are For',
#  'Dwindling CPAN Releases',
#  'Capital One Cyber Staff Raised Concerns Before Hack',
#  'Trigger a Kernel Panic to Diagnose Unresponsive EC2 Instances',
#  'Launch HN: Compound (YC S19) – helping employees understand equity compensation',
#  'How We Manage a Million Push Notifications an Hour',
#  'Inventing Monads',
#  'Write Fuzzable Code',
#  'Most software companies ignore user behavior',
#  'An Afternoon in Tokyo with the Man Who Designs Casio G-Shock Watches (2017)',
#  'Analyzing the Facebook ads placed by the US presidential candidates',
#  'KIP-500: Replace ZooKeeper with a Self-Managed Metadata Quorum',
#  'Side channel that leaked data from Intel CPUs patched by silent Windows update',
#  'Chemists discover water microdroplets spontaneously produce hydrogen peroxide',
#  'Rendering on the Web',
#  'Free Software network services and web applications which can be hosted locally',
#  'Phytoplankton Population Drops 40 Percent Since 1950 (2010)',
#  "Root: CERN's scientific data analysis framework for C++",
#  'The subversive messages hidden in The Wizard of Oz',
#  'Flaws in Cellphone Evidence Prompt Review of 10k Verdicts in Denmark',
#  'Economist Raj Chetty has found a surprising tool to fight housing segregation',
#  'Static Analysis at Scale: An Instagram Story',
#  'Camera vs. Lidar',
#  'How Digital Advertising Markets Really Work',
#  'Security flaws caused by compiler optimizations',
#  'How Web Content Can Affect Power Usage',
#  'Music Recommendations in Hyperbolic Space',
#  'A Deep Dive into AMD’s Rome Epyc Architecture',
#  '16-bit RISC-V processor made with carbon nanotubes',
#  'Show HN: Real world (Jupyter notebook embed) way to assess data scientists',
#  'Launch HN: Memfault (YC W19) – Crashlytics for Firmware',
#  'A person has died from a vaping-related condition',
#  'Linux Pressure Stall Information (PSI) by Example',
#  'How to Write a Lisp Interpreter In Python (2010)',
#  'Processor Design: An Introduction (1998)',
#  'Adventure in Prolog Tutorial (2016)',
#  'Show HN: Purely Functional Scripting',
#  'Clever Functional Design',
#  'Google begins penalising domain leasing',
#  'Building a Programming Language Pt. 3 – Interpreting',
#  'Sentient: Classified artificial brain being developed by US intelligence',
#  'Live Avatars with face-api.js',
#  'India’s Messy Electric Vehicle Revolution',
#  'Launch HN: Lang (YC S19) – Internationalization Built for Devs',
#  'I Tried Hiding from Big Tech in a Pile of Privacy Gadgets',
#  'Pokemonsay: Pokemon Version of Cowsay',
#  'Cowrie: a medium-interaction SSH and Telnet honeypot',
#  'Energy Storage Investments Boom as Battery Costs Halve in the Next Decade',
#  'Effortless Elixir Releases and Deployment',
#  "Which Categories of Seed Startups Are Thriving? Which Aren't?",
#  'Hydrophilic disc uses solar power to separate salt from water',
#  'Learning to prove theorems via interacting with proof assistants',
#  'Dark Matter Developers: The Unseen 99% (2012)',
#  'Urgent/11 – Zero Day Vulnerabilities Impacting VxWorks',
#  'Huntington Park’s “RoboCop” stores pedestrians’ faces, scans license plates',
#  'CERN Open Data Portal: Explore more than 2 PB of open data from particle physics',
#  'Getting Started with Lisp in 2019',
#  'What Is Null? (2010)',
#  'Misinterpreting hurricane forecasts',
#  'Scale (YC S16) Raises $100M from Accel and Founders Fund at $1B Valuation',
#  'Programming Algorithms in Lisp: Data Structures',
#  'In Pentagon Contract Fight, Amazon Has Foes in High Places',
#  'Rome Is the Fulcrum of AMD’s Datacenter Pivot',
#  'How to Get into Farming with No Money (1980)',
#  'Phone Companies Ink Deal With All 50 States And D.C. To Combat Robocalls',
#  'Fast Tensors in Clojure – A Sneak Peek',
#  'How the Great Truth Dawned',
#  'FileKit: An open source end-to-end encrypted cloud storage service in JavaScript',
#  'Would you accept cheaper rent in exchange for a monthly Amazon purchasing quota?',
#  'Duckling: a Clojure library that parses text into structured data',
#  'Mitre Systems Engineering Guide (2014) [pdf]',
#  'Texas Power Prices Briefly Surpass $9k Amid Scorching Heat',
#  "Amazon's Plan to Conquer the World of Publishing",
#  'Toptal sues co-founder Breanden Beneschott for fraud',
#  'Finding Amelia Earhart’s Plane Seemed Impossible – Then Came a Startling Clue',
#  "30 years ago: Voyager 2's historic Neptune flyby",
#  'MesaPy: A Memory-Safe Python Implementation based on PyPy (2018)',
#  'Trails of Wind: Data Visualization of the Architecture of Airport Runways',
#  'Show HN: ShapeForm – Schema Driven Forms for React',
#  'Network Effects That Don’t Look Like Network Effects',
#  'Germany Turns to Hydrogen in Quest for Clean Energy Economy',
#  'If you want developers to adopt your software, make it less risky (2017)',
#  'Why the U.S. Army Owns So Many Fossils',
#  'Exploring DNA with Deep Learning',
#  'How the Pentagon Comes Up with Code Words and Secret Project Nicknames',
#  'A Simulated Enigma Machine',
#  'On Building My Own Artificial Pancreas',
#  'Machine Learning That’s Light Enough for an Arduino',
#  "Unshaky – Tries to address double key press issue on Apple's butterfly keyboard",
#  'ZRNA – Software-defined analog circuits',
#  'Simple RPC framework in 300 lines of Go',
#  'A Codebase Is an Organism (2014)',
#  "The perfect language and why Go still isn't it",
#  'Hundreds of people died over a millennium at “Skeleton Lake” in the Himalayas',
#  'All Tridactyl installations might get removed by Firefox on Aug 21',
#  'Divers Find Remains of Ancient Temple in Sunken Egyptian City',
#  'Free and open-source tools for analog filmmaking',
#  'API Gateway Identity Crisis – are they replaced by service mesh?',
#  'I started an online subscription business from Malaysia',
#  'Lifehacker: Tarek Loubani on 3D-Printing in Gaza',
#  'Our Brains Tell Stories So We Can Live (2013)',
#  'Capturing PAL video with an SDR, and a few dead ends',
#  "Solving differential equations on a 6502 with Woz's floating point code",
#  'Computer Stupidities (2013)',
#  'A look back: The Bloomberg Keyboard (2017)',
#  'Jupiter: RISC-V Assembler and Runtime Simulator',
#  '42 Hours of Buckminster Fuller might be just the vision we need',
#  'Project Mu – A modular UEFI environment for building modern devices',
#  'The High Price of Multitasking',
#  'Curve fitting A: Linear Least Squares',
#  'Handler beliefs affect scent detection dog outcomes (2011)',
#  'Sipeed Longan Nano – RISC-V Development Board',
#  'The difference between isolation levels and consistency levels',
#  "Detailed 3D map of Milky Way shows 'warped' shape",
#  'Map Design – a guide to good looking maps (2008) [pdf]',
#  'No Silver Bullet (1986) [pdf]',
#  'Armoured Commander: The WWII Tank Commander Roguelike',
#  "How the brain 'approximates' without counting",
#  'SoftBank plans to lend $20B to its CEO and employees amid volatile markets',
#  'The HP Way: How Bill Hewlett and I Built Our Company (1960)',
#  'How to Build a Pyramid',
#  'How to get consistent results when benchmarking on Linux?',
#  'How to Teach an Iris Scanner That the Eye It’s Looking at Is Dead',
#  'Building a vacuum tube computer',
#  'Portugal’s Marmelada Tastes Nothing Like Marmalade (2018)',
#  'SpaCy PyTorch Transformers',
#  'Real world location virtually recreated to scale in minutes [video]',
#  'Show HN: Dat-keyserver: a distributed PGP keyserver based on the Dat protocol',
#  '"Karel Čapek\'s play ""R.U.R."" premiered in January 1921"',
#  'Apple Card restrictions include no jailbreaking or cryptocurrency purchases',
#  'The Grand C++ Error Explosion Competition',
#  'Turkmenistan on the brink of collapse?',
#  'A profile of Geoffrey Hinton (2018)',
#  'Scientists reverse aging process in rat brain stem cells',
#  'Show HN: Cordless, a Discord terminal client written in Go',
#  '100 Years Ago, a Telephone Tower in Stockholm Connected 5000 Phone Lines (2014)',
#  'Japanese architects who treated buildings like living organisms',
#  'A recent paper proposes to bring zeppelins back',
#  'J-Core Open Processor',
#  'Presidio: Customizable data protection and PII data anonymization service',
#  'The Survival of Iggy Pop',
#  'BPF port-based firewall for systemd services',
#  'Marree Man',
#  'The D-Day rehearsal that cost 800 lives (2014)',
#  'Ray tracing with uLisp',
#  'Show HN: A few simple games not only for kids',
#  'Why Everyone Hates Customer Service',
#  'Commodore 900',
#  'QualPwn – Exploiting Qualcomm WLAN and Modem over the Air',
#  'Study identifies main culprit behind lithium metal battery failure',
#  'With friends like these',
#  'YouTube’s LGBTQ Problem Is a Business-Model Problem',
#  'Suburb in the sky: how Jakartans built an entire village on top of a mall',
#  'Circulating in China’s Financial System: More Than $200B in I.O.U.s',
#  "The Death of Alexander the Great: One of History's Great Unsolved Mysteries",
#  "The 'microworkers' making digital life possible",
#  'Keyringless GnuPG',
#  'The Perfect French Baguette',
#  'Shipping wind turbines is not a breeze',
#  'Iron Age Celtic Woman Was Buried in a Hollowed-Out Tree Trunk',
#  'The Biggest Mistakes First-Time Founders Make [video]',
#  'Boeing changing Max software to use two computers',
#  'Empty trains on the modern Silk Road: when Belt and Road interests don’t align',
#  'Wavelets (1994) [pdf]',
#  'Who Did the Maya Sacrifice?',
#  'A Guide to Magnetorquers for Satellites',
#  'Mobile NixOS: The Present and the Future',
#  'NEC shows ‘flying car’ hovering steadily for minute',
#  'Quantum radar has been demonstrated for the first time',
#  'Ear Speakers – Research, Design, and Evolution',
#  'Wasm vs. PNaCl Performance Benchmark',
#  'Evolving Lindenmayer Systems',
#  'Show HN: Repository of open source space-related software and hardware',
#  'I love my paper dictionary (2017)',
#  'Darpa wants help cracking the election security problem',
#  'The Fed is getting into the Real-Time payments business',
#  'Woman Finds Yellow Diamond While Watching YouTube Video on How to Find Diamonds',
#  'Amazon will pull the plug on dash buttons',
#  'Problem Solving and Clojure 1.9 (2018)',
#  'A new book asserts that rich countries grow with lighter environmental impacts',
#  'Animal movies promote awareness, not harm, say researchers',
#  '2019 Hyundai Kona EV Explodes When Parked',
#  'The League of Entropy Is Making Randomness Truly Random',
#  'A Transparent Display with Per-Pixel Color and Opacity Control',
#  'The “Terrascope”: On the Possibility of Using the Earth as an Atmospheric Lens',
#  'Humans Dominated Earth Earlier Than Previously Thought',
#  'Fuzzification: Anti-Fuzzing Techniques [pdf]',
#  'What Is Zoned Storage and the Zoned Storage Initiative?',
#  'Webmin 1.890 Exploit – What Happened?',
#  'Scaling Static Analyses at Facebook',
#  'The death of a weather satellite as seen by SDR',
#  'Holidays are good for workers and companies alike',
#  'Richard Sorge: The Soviet Union’s Master Spy',
#  'Debunking the Stanford Prison Experiment [pdf]',
#  'Marium, the Dugong Who Charmed Thailand, Dies After Ingesting Plastic',
#  'Simple Python Package to Extract Deep Learning Features',
#  'Massive ‘ocean’ discovered towards Earth’s core (2014)',
#  'DEF CON 2019 – CTF Retrospective',
#  'Kdevops: Framework for setting up and testing the Linux kernel for any project',
#  'Simple, pure, and total functional language that generalizes Datalog',
#  'Continuous 3D Printing Possible With Transparent Polygon Scanning?',
#  'Could Removing Social Media Metrics Reduce Polarization?',
#  'Roaring glacial melt under the bridge to Kangerlussiauq, Greenland',
#  'The New Treasures of Pompeii',
#  'SEC Investigating Data Leak at First American Financial Corp',
#  'The OpenBSD Ada Library',
#  "Don't Say “Homoiconic” (2018)",
#  'US Air Force pauses flights for over a hundred C-130s over ‘atypical’ cracking',
#  'I am a horse in the land of booleans',
#  'We may not be running out of helium after all (2015)',
#  'Launch HN: Shift Health (YC S19) – Understand Your Healthcare Costs Pre-Visit',
#  'SmartyKit Apple I replica',
#  'Gerbil – A meta-dialect of Scheme',
#  'Hawaii Extends Thirty Meter Telescope Permit Amid Protests',
#  'GM Is Now Detroit’s Smallest Auto-Making Employer',
#  'The Dipole Drive: A New Concept in Space Propulsion',
#  'Universal algorithm set to boost microscopes',
#  'Fearing data privacy issues, Google cuts some Android phone data for carriers',
#  "Robotic thread is designed to slip through the brain's blood vessels",
#  'Vickrey–Clarke–Groves Auction',
#  'Prolog Control in Six Slides',
#  'Opinion piece on GHC back ends',
#  'Entropic: A federated package registry for anything',
#  'CBOR – Concise Binary Object Representation',
#  'Can we survive technology? (1955) [pdf]',
#  'Cassettes Are Back, and It’s Not About the Music',
#  'Paul Dirac: The Mozart of Science (2008)',
#  'In praise of xlogo',
#  'Show HN: Historical order book reconstruction API for crypto markets',
#  'Arcs of Seniority',
#  'The Long Game of Research',
#  "A Look at HS2's Old Oak Common Station",
#  'How Judy arrays work and why they are so fast (2002)',
#  'Mining Bitcoin on an Apple II',
#  'Unearthing a masterpiece: a rare Minoan sealstone (2017)',
#  'Golden Ratio',
#  'Show HN: pgcmd – An alternative to psql with JSON output',
#  'Reviving an HP 660LX in 2019',
#  'SSB Rooms: a new server type for Scuttlebutt',
#  'Implementing Poincaré Embeddings (2017)',
#  'Extending OCaml Programs with Lua',
#  'Container Networking with Vxlan, BGP and WireGuard',
#  'A Fine Map from Alexander von Humboldt (1851)',
#  'New research on PTSD in elephants and other animals',
#  '“Awakenings” in Advanced Dementia Patients Hint at Untapped Brain Reserves',
#  'Recycling of plastics enabled by dynamic covalent diketoenamine bonds (2018) [pdf]',
#  'Show HN: Data-viz project for ray-tracing the Moon model',
#  'Five new Real-Time detections of fast radio bursts with UTMOST',
#  'LucidScience – Electronic Projects and Tutorials',
#  'What are children dying from and what can we do about it?',
#  'A Conversation with the Team That Made Bread with Ancient Egyptian Yeast',
#  'Air Force Reveals Tests of Supposed Record-Setting Scramjet from N. Grumman',
#  'The Decline of College Newspapers',
#  'Which Is the Best John Le Carré Novel? (2014)',
#  'Dreaming about Better Sleep: Dreem, Oura and the Rest',
#  'Penn Effect',
#  'Hall’s Law: The Nineteenth Century Prequel to Moore’s Law (2012)',
#  'Volcanoes on the Moon May Have Erupted During the Dinosaur Age (2014)',
#  'The World’s Smartest Chimp Has Died',
#  'Smart plastic incineration posited as solution to global recycling crisis',
#  'Kei – A small and expressive dependent language',
#  'Freshermeat – Open-Source Security Software',
#  'Engineers build advanced microprocessor out of carbon nanotubes',
#  'A New York Farm Stand’s Success: An Eye for the Next Big Thing',
#  'Disneyland’s Disastrous Opening Day (2015)',
#  'A Z-Machine in OCaml (2016)',
#  "Quantum Air buys Bye's electric airplanes",
#  'Famous Graphics Chips: Microsoft’s Talisman',
#  "Engineers develop bone-like metal foam that can be 'healed' at room temperature",
#  'Using the Golden Research Engine to Query the Y Combinator S19 Batch',
#  'A mosque rebuilt once a year',
#  'Flying with Miniature Horses',
#  'The Oral History of the Super Soaker',
#  'A Trailblazing Plan to Fight California Wildfires',
#  'Show HN: Firestorm – An ORM for Firestore',
#  'Programming shape using kirigami tessellations',
#  'Potosí: the mountain of silver that was the first global city',
#  'An Ancient Egypt-to-Black Sea Route? Adventurers to Test Theory',
#  'Exploring the Visible Spectrum in Python',
#  'General Balanced Trees (1999) [pdf]',
#  'Using Wall Street secrets to reduce the cost of cloud infrastructure',
#  'Rediscovering rules for ancient board games',
#  'On the Road in 1980',
#  'The Software Arts',
#  'Making Web-Workers Async Iterables',
#  'Show HN: Quark-IDE and a JavaScript runtime to build cross-platform desktop apps',
#  'Environment and the programming language Self, part 4',
#  'The lost Doves Press typeface and its revival (2015)',
#  'Early Years of Computer Gaming: Steve Russell and Nolan Bushnell (2002) [video]',
#  'The quest to conquer Earth’s space junk problem (2018)',
#  'Swadesh List',
#  'Salvator Mundi and the unreality of the art market']

# %%
#Remove the header from the rdd
hn_header = link_title_rdd.first()
link_title = link_title_rdd.filter(lambda row: row != hn_header)
link_title.collect()
# Out:
# ['Turning a MacBook into a Touchscreen with $1 of Hardware (2018)',
#  'The Lonely Work of Moderating Hacker News',
#  'Introducing nushell',
#  'Google just deleted my nearly 10-year-old free and open-source Android app',
#  'Ebola Is Now Curable',
#  'All the best engineering advice I stole from non-technical people',
#  'I Miss Microsoft Encarta',
#  "Alan Kay's answer to ‘what are some forgotten books programmers should read?’",
#  'Information operations directed at Hong Kong',
#  'Terminating Service for 8Chan',
#  'What happens when you launch Google Chrome for the first time?',
#  'How to Build Good Software',
#  'NULL license plate not such a bright idea',
#  "What Does a Coder Do If They Can't Type?",
#  'Yelp Is Replacing Restaurants’ Phone Numbers So Grubhub Can Take a Cut',
#  'Japanese anime studio Khara moving to Blender',
#  'Deconstructing Google’s excuses on tracking protection',
#  'Cloudflare S-1',
#  '8chan goes dark after hardware provider discontinues service',
#  'Please Add RSS Support to Your Site',
#  'No More Cheap Shipping for Chinese Sellers',
#  'Python Is Eating the World',
#  'Verizon to Sell Tumblr to Automattic',
#  'Tasty Seaweed Reduces Cows’ Methane Emissions by 99%',
#  'Hy',
#  'Things I Learnt from a Senior Software Engineer',
#  'WeWTF',
#  'Linux Journal Ceases Publication: An Awkward Goodbye',
#  'AMD lands Google, Twitter as customers with newest server chip',
#  'US Navy will replace touchscreen with mechanical controls on its destroyers',
#  'Standard Ebooks: Free public-domain ebooks, carefully produced',
#  'Why is modern web development so complicated?',
#  'A man who destroyed his multimillion dollar company in 10 seconds (2018)',
#  'OpenDrop: An Open Source AirDrop Implementation',
#  'A deep dive into iOS Exploit chains found in the wild',
#  'Software Architecture Guide',
#  'Sites using Facebook ‘Like’ button liable for data, EU court rules',
#  "Insect 'apocalypse' in U.S. driven by 50x increase in toxic pesticides: study",
#  'Apple Confirms $1M Reward for Anyone Who Can Hack an iPhone',
#  'Why All of Our Games Look Like Crap',
#  'Tech Interview Handbook',
#  'Fewer Than Half of Google Searches Now Result in a Click',
#  'Ugly Gerry – Font created from congressional districts',
#  'Why has examine.com disappeared from search results?',
#  'A Walk in Hong Kong',
#  'John Carmack on the Joe Rogan Experience [video]',
#  'The Baseline Interpreter: A Faster JavaScript Interpreter in Firefox 70',
#  'Google Doesn’t Want Staff Debating Politics at Work Anymore',
#  'Build Your Own Text Editor',
#  "I've reproduced 130 research papers about “predicting the stock market”",
#  'Ask HN: How Do You Read?',
#  'How to build a plugin system on the web and also sleep well at night',
#  'Europe is edging towards making post-car cities a reality',
#  'New York City Neighbors Build Cheaper Way to Connect to Web',
#  'GitHub Actions now supports CI/CD, free for public repositories',
#  'Consume less, create more',
#  'Living Near Trees, Not Just Green Space, Improves Wellbeing',
#  'Kerbal Space Program 2',
#  'MacBook Pro Keyboard Drives Me Crazy',
#  'Why I Turned Down an AWS Job Offer',
#  'Facebook has been granted patent on shadow banning',
#  "The Linux kernel's inability to gracefully handle low memory pressure",
#  'Show HN: CLI tool for saving web pages as a single file',
#  'Start Your Own ISP',
#  "Every productivity thought I've ever had, as concisely as possible",
#  "Preindustrial workers worked fewer hours than today's (2009)",
#  'Milky Way’s Black Hole Just Flared, Growing 75 Times as Bright for a Few Hours',
#  'Amazon has proven unable or unwilling to effectively police third-party sellers',
#  'Rails 6.0',
#  'Ha-ha wall',
#  'Speaking to yourself in the third person makes you wiser',
#  'IBM Open-Sources Power Chip Instruction Set',
#  'Apple expands parts access to more independent repair businesses',
#  'Paged Out – a new experimental magazine about programming',
#  "Let's build houses for people, not cars",
#  'We Have Ruined Childhood',
#  "Decrement carbon: Stripe's negative emissions commitment",
#  '16M Americans will vote on hackable paperless machines',
#  'Home Chip Fab',
#  'Google and Mozilla are failing to support browser extension developers',
#  "A mathematician's way of converting miles to kilometers",
#  'There is no evil like reCAPTCHA',
#  'Kaspersky AV injected unique ID allowing sites to track users in incognito mode',
#  'Who Owns Huawei?',
#  'The Horror of Microsoft Teams',
#  'Hundreds of extreme self-citing scientists revealed in new database',
#  'Regex for Noobs – An Illustrated Guide',
#  'Apple will soon treat online web tracking the same as a security vulnerability',
#  'The IT Guy vs. the Con Artist',
#  'Death Note: L, Anonymity and Eluding Entropy (2017)',
#  'AMD Rome Second Generation EPYC Review: 2x 64-core Benchmarked',
#  'Amazon Is a Monopoly',
#  'Time anxiety: is it too late?',
#  'WTF – A personal information dashboard for your terminal',
#  'Scientists Discover a Cure for the Deadliest Strain of Tuberculosis',
#  'Show HN: Divjoy – React Codebase and UI Generator',
#  'Proteins That May Restore Damaged Sound-Detecting Cells in the Ear',
#  '15 states are trying to make the electoral college obselete',
#  'Banned C standard library functions in Git source code',
#  'Pronunciations for hexadecimal numbers (1968)',
#  'Turbo, an Improved Rainbow Colormap for Visualization',
#  "From Mac to Linux – the setup I've grown to love",
#  'Time to Get Serious about Tick-Borne Diseases',
#  'Pentagon testing mass surveillance balloons across the US',
#  'Useless Windows 10 Features',
#  'Some Obscure C Features',
#  'Mercedes-Benz pre-safe sound',
#  'TSV Utilities: Command line tools for large, tabular data files',
#  'Psytrance Guide',
#  "Researcher banned on Valve's bug bounty program publishes second Steam 0-day",
#  'Why do developers at Google consider Agile development to be nonsense? (2016)',
#  'Planet: Imaging the entire Earth every day',
#  'Software made me loathe my car',
#  'Dqlite – High-Availability SQLite',
#  'CutiePi – All-in-one Raspberry Pi tablet',
#  "Knuth on Huang's Sensitivity Proof: “I've got the proof down to one page” [pdf]",
#  'Supercentenarians are concentrated into regions with no birth certificates',
#  'Anthony Levandowski Charged with Theft of Trade Secrets',
#  'exFAT in the Linux kernel',
#  'Speed matters: Why working quickly is more important than it seems (2015)',
#  'Programmers: Before you turn 40, get a plan B (2009)',
#  'Information Theory for Intelligent People (2018) [pdf]',
#  'I completed Ultimate Go, took good notes and commented directly on source code',
#  'A Guide to Recording 660FPS Video on a $6 Raspberry Pi Camera',
#  'Super Mario 64 has been decompiled',
#  'YAML: Probably not so great after all',
#  'Rust Language Cheat Sheet',
#  'Thoughts on Rust bloat',
#  'Google Chrome Incognito Mode Can Still Be Detected',
#  'Rules for Intuitive UX',
#  'iTerm2 3.3',
#  'Datadog S-1',
#  'The not so hidden cost of sharing code between iOS and Android',
#  'Show HN: Chart.xkcd – Xkcd-styled chart library',
#  'Tell HN: Danny Cohen Has Died',
#  'Down the Rabbit-Hole',
#  'Three Kinds of Good Tech Debt',
#  'Facebook scans system libraries on Android and uploads them to their server',
#  'Uber Posts $5.2B Loss and Slowest Ever Growth Rate',
#  'The Fully Remote Attack Surface of the iPhone',
#  'Google to Offer a Best Price Guarantee on Certain Flights',
#  'NPM Bans Terminal Ads',
#  'The Architecture of Open Source Applications',
#  'People love working remotely',
#  'Berlin’s Popular Shopping Streets Will Go Car-Free',
#  'Toni Morrison Has Died',
#  'Sourcehut welcomes Bitbucket refugees',
#  'AI startup claims to automate app making but actually just uses humans',
#  'Ask HN: Recommended resources to learn the Linux kernel and OS theory?',
#  'Steam Windows Client Local Privilege Escalation 0day',
#  'Hong Kong ISP Association’s Statement on Selective Blocking of Internet Services',
#  'I wasn’t getting hired as a data scientist, so I sought data on who is',
#  'Juul, Philip Morris Sued Under Racketeer Act for Targeting Kids',
#  'VMware Acquires Carbon Black for $2.1B and Pivotal for $2.7B',
#  'Zen 2 Missives – AMD now delivering efficiencies that are double that of Intel',
#  'Write your own Excel in F# (2018)',
#  'Performance Matters',
#  'Is Perl 6 Being Renamed?',
#  'People Simply Empty Out (1986)',
#  'Black Hat: GDPR privacy law exploited to reveal personal data',
#  'Show HN: I trained a deep learning model to build sites for me',
#  'WebKit Tracking Prevention Policy',
#  'Removing Coordinated Inauthentic Behavior from China',
#  'Calculus For The People',
#  'Anxiety Looks Different in Men',
#  'Yield Curves Invert in U.S., U.K',
#  'Amazon offered ‘Amazon’s Choice’ to vendors who bought ads and lowered prices',
#  'CyberChef – Cyber Swiss Army Knife',
#  'Rust 1.37.0',
#  "A Boeing Code Leak Exposes Security Flaws Deep in a 787's Guts",
#  'Ask HN: Best resources to gain math intuition?',
#  'Mozilla takes action to protect users in Kazakhstan',
#  'Anime4K: Real time high quality video upscaling',
#  'Wine on Windows 10',
#  'Building a distributed time-series database on PostgreSQL',
#  'Xfce 4.14',
#  'Most startup theory is ex-post, therefore bs',
#  'Lessons from Stripe',
#  'Show HN: Wave-based non-line-of-sight computational imaging in Julia',
#  '‘They Get Fired All the Time. And They Have No Idea Why’',
#  '9th Circuit says users can sue Facebook over unlawful use of facial recognition',
#  'Linux kernel drivers in Rust might become an option in the future',
#  'MoviePass Worked Out Great',
#  'A Beginner’s Introduction to Python Web Frameworks (2018)',
#  'Ask HN: Who is hiring? (August 2019)',
#  'Show HN: Data Structures and Algorithms in JavaScript',
#  'Await in Rust',
#  'Cool but obscure X11 tools',
#  'Elsevier threatens others for linking to Sci-Hub but does so itself',
#  'Group sex app leaks locations, pics and personal details',
#  'Apple Is Locking iPhone Batteries to Discourage Repair',
#  '“I would like to maintain the floppy driver”',
#  'Fracking in North America could be partly to blame for methane spike – study',
#  'Flawed Algorithms Are Grading Millions of Students’ Essays',
#  '35 Over 35',
#  'U.S. Designates China as Currency Manipulator',
#  'Sunsetting Mercurial Support in Bitbucket',
#  'Open letter from an Android developer to the Google Play team',
#  'Cue – A language for defining, generating, and validating data',
#  'How Rust optimizes async/await',
#  'One City Saved $5M by Routing School Buses with an Algorithm',
#  'Async-std: an async port of the Rust standard library',
#  'RegExr',
#  'The Art of Warez [video]',
#  'Get your work recognized: write a brag document',
#  'One job, many roles: The different skills needed to be a successful CTO',
#  'Productivity and the Workweek (2000)',
#  'Nigerian Teens Are Making Sci-Fi Shorts with Slick Visual Effects',
#  'The most frequent 777 characters give 90% coverage of Kanji in the wild',
#  'Contributing to the Mozilla code base',
#  'The Lost Art of Lacing Cable (2018)',
#  'Martini: Real-Time Terrain Mesh Generator',
#  'The Impact of Meditating Every Day',
#  'Software was eating the world – now landlords are eating everything',
#  'IBM has released the Power Architecture instruction set to the Linux Foundation',
#  "Plastics: What's Recyclable, What Becomes Trash and Why",
#  'Uber, losing billions, freezes engineering hires',
#  'IRS budget cuts cost $34.3B in lost revenue from big business',
#  'Calculus Is Deeply Irrational',
#  'Every Noise at Once',
#  'AT&T employees were bribed to install phone unlocking malware on company network',
#  'The Problem at Yale Is Not Free Speech',
#  'Silk',
#  'Beyond Meat and KFC partner to test fried plant-based ‘chicken’',
#  'The We Company S-1',
#  'How to return to the flow faster',
#  'The Paxos Algorithm, or How to Win a Turing Award',
#  'Attorney General Barr and Encryption',
#  'Making email more modern with JMAP',
#  'FFmpeg 4.2',
#  'WebAssembly Interface Types: Interoperate with All the Things',
#  'Roblox hits 100M monthly active users, bigger than Minecraft',
#  'Words that do Handstands',
#  'How Men’s Bodies Change When They Become Fathers',
#  'Misconfigured Jira instances exposed data of hundreds of Fortune 500 companies',
#  'Companies Use Borrowed Billions to Buy Back Stock, Not to Invest',
#  'NY State alleges ExxonMobil knew risks of climate change and defrauded investors',
#  'New React DevTools',
#  'WeWork Gets Tax Rebate Meant for Its Small-Business Tenants',
#  'Administration Using the Full Power of the Surveillance State on Whistleblowers',
#  'A book from Alan Turing and a mysterious piece of paper',
#  'How to get your first ten customers (2013)',
#  'Does the Amazon provide 20% of our oxygen?',
#  'Uber proposes policy that would pay drivers a minimum wage of $21 per hour',
#  'The Most Dangerous Writing App',
#  'Why Did China Just Devalue the Yuan? How Trade Works with Free-Floating Currency',
#  'Arend: Theorem Prover Based on Homotopy Type Theory by JetBrains',
#  'BlazingSQL is Now Open Source',
#  'Key Negotiation of Bluetooth Attack',
#  'On-Device, Real-Time Hand Tracking with MediaPipe',
#  'Dirty tricks 6502 programmers use',
#  'Insured price $2,758, cash price $521',
#  'Germans Grow Frustrated with Their Slow-Poke Internet',
#  'Building a Raspberry Pi 3B+ full keyboard handheld',
#  'Show HN: Saag as a Service – macronutrient-portioned Indian spinach curry',
#  'Social exclusion fuels extremism in young men',
#  'CamScanner, a malicious Android app with more than 100M downloads in Google Play',
#  "Moscow's blockchain voting system cracked a month before election",
#  'Anna Karenina Principle',
#  'QEMU VM Escape',
#  'Inflated Bond Ratings Helped Spur the Financial Crisis. They’re Back',
#  'Medieval people bathed regularly',
#  'Devilution – A web port of the original Diablo game',
#  'Cooling a house without air conditioning',
#  '3.8M-year-old skull of an early ape-like human ancestor discovered in Ethiopia',
#  'Huawei Technicians Helped African Governments Spy on Political Opponents',
#  'TypeScript 3.6',
#  'The answer to “Will you mentor me?” is no (2010)',
#  'How to Measure Indoor Air Quality with a Raspberry Pi, RuuviTags and PMS7003',
#  'WeWork Isn’t a Tech Company',
#  "Why Const Doesn't Make C Code Faster",
#  'Verified by Twilio',
#  'Python vs. Rust for Neural Networks',
#  'Big Coal Plants Begin to Close',
#  'Aussie ISV buys ads to wake up Google support',
#  'The Feynman Lectures on Physics: Algebra (1963)',
#  'Coinbase: Responding to Firefox 0-days in the wild',
#  'Gamedev Tutorial: Trigonometry Basics – Sine and Cosine',
#  'Secretly Public Domain: Most books published in the US before 1964',
#  'Show HN: ClojureScript pixel game engine with Blender live-reloading',
#  'Lisp is not based on the Lambda Calculus',
#  'Alphabet overtakes Apple to become most cash-rich company',
#  'Rice University researchers propose a way to boost solar efficiency',
#  'Using Backblaze B2 and Cloudflare Workers for free image hosting',
#  "The worst sales promotion in history: Hoover's free flight fiasco",
#  'The Door Problem of Combat Design',
#  'Wikipedia Is Now a Brave Verified Publisher',
#  'Google Plans to Deprecate FTP URL Support in Chrome',
#  'Killing a process and all of its descendants',
#  'Show HN: I created Postwoman, an online, open-source API request builder',
#  'The Many Possibilities of iMessage File Vulnerability',
#  'The design of littlefs: A fail-safe filesystem designed for microcontrollers',
#  "Ask HN: What's the best setup for ad blocking and tracker blocking?",
#  'Rabbit Holes: The Secret to Technical Expertise',
#  'Show HN: I made a CRM system to make sales fun',
#  'Syslog: Complete System Administrator Guide',
#  'My Sudden Trip to Hell',
#  'Why does all life use the same 20 amino acids?',
#  'Toshiba Introduces New Tiny NVMe SSD Form Factor',
#  'John Carmack on Parallel Implementations (2018)',
#  'GNU Radio 3.8',
#  'Ask HN: How do you handle logging?',
#  'The GitHub registry public beta is live',
#  'A practical guide to CSS transitions and animations',
#  'U.S. Farmers Stung by Tariffs Now Face a $3.5B Corn Loss',
#  'Facebook Hit by Apple’s Crackdown on Messaging Feature',
#  'Privacy Sandbox – Open standards to enhance privacy on the web',
#  'Transformers from Scratch',
#  'We Made Amiga, They Fucked It Up (2015)',
#  'Memory Management in Python',
#  'Die With Me – A chat app you can only use when you have less than 5% battery',
#  'Now Bigger Than eBay, Shopify Sets Its Sights on Amazon',
#  "Let's Build a Video Card",
#  'Pastel: A command-line tool to generate, analyze, convert and manipulate colors',
#  'Pagemap: A mini map for your website',
#  'Minify Your SVGs',
#  'Yubico launches its dual USB-C and Lightning two-factor security key',
#  'A Bloomberg reporter’s account of trying to get back his name and credit rating',
#  'Opioid crisis: Johnson and Johnson hit by landmark ruling',
#  'Big Pharma is using faux generics to keep drug prices high, critics say',
#  "Tokyo's audiophile venues (2016)",
#  'Japan surpasses China as largest foreign holder of US Treasurys',
#  'Statement on the Purpose of a Corporation',
#  'Spying on HTTPS',
#  "Why doesn't mathematics collapse, though humans often make mistakes in proofs?",
#  'Hackers ship their exploits directly to their target’s mailroom',
#  'Major book publishers sue Amazon’s Audible over new speech-to-text feature',
#  'Hacking the Sonos IKEA Symfonisk into a High Quality Speaker Amp',
#  'Kubernetes Security Assessment [pdf]',
#  '“Culture fit” is a two way street (2018)',
#  'What Happens When You ACH a Dead Person?',
#  'Google search takes 7 seconds on certain queries',
#  'Go Module Mirror and Checksum Database Launched',
#  'High levels of oestrogens in the womb linked to autism',
#  'Alone in the Dark',
#  'The fungus that devastates the Cavendish banana has now arrived in Latin America',
#  'Metal shards from Boeing 787 taking off over Rome rain down on people below',
#  'The “terrible” 3 cent MCU – a short survey of sub $0.10 microcontrollers',
#  'The Order of the JSON',
#  'In effect, Seattle is decriminalizing the use of hard drugs',
#  'FAA Bans Recalled Apple Laptops from Flights',
#  'Salsify – A New Architecture for Real-time Internet Video',
#  'Walmart sues Tesla over fires at stores fitted with its solar panels',
#  'Danish bank launches negative interest rate mortgage',
#  'Open-source firmware',
#  'Technical Vision for Qt 6',
#  'Show HN: Yack – Community Browser for Hacker News, Reddit, YouTube and More',
#  'A dream of an ultimate OS (1995)',
#  'A Primer on Bézier Curves (2013)',
#  'Bontrager’s WaveCel material more effective at preventing concussions than MIPS',
#  'The Death of Social Reciprocity in the Era of Digital Distraction',
#  'Amazon wants to control third-party sellers’ product pricing',
#  'PartiQL: One query language for all your data',
#  "A bug I wish I hadn't caught",
#  'A mobile phone that respects your freedom [video]',
#  'Cloud Run Button: Click-to-deploy your Git repos to GCP',
#  'My Home Lab Server with 20 Cores / 40 Threads and 128 GB Memory',
#  'GCC null pointer check removed',
#  "In the US, it's cheaper to build and operate wind farms than buy fossil fuels",
#  'WiringPi – deprecated',
#  'Credit cards have a privacy problem',
#  'Starbucks, monetary superpower',
#  'Building ages in the Netherlands',
#  'Huawei Seeks Independence from the US with RISC-V and Ascend Chips',
#  'Black Hat Talk About ‘Time AI’ Causes Uproar, Is Deleted by Conference',
#  'The hypersane are among us, if only we are prepared to look',
#  'Why I like Clojure',
#  'Cybersecurity Pros Name Their Price as Hacker Attacks Swell',
#  'GCP to introduce an additional charge for publicly addressed VM instances',
#  'YouTube shuts down music companies’ use of manual copyright claims',
#  'Poetry: Dependency Management for Python',
#  'Protocols, Not Platforms: A Technological Approach to Free Speech',
#  'Artichoke – A Ruby made with Rust',
#  'Apollo Guidance Computer switching power supply works after 50 years',
#  'Monads as a Programming Pattern',
#  'Denial of H1-B visas to India’s largest IT services exporters at all-time high',
#  'Show HN: Zero-Config Documentation Websites for Python',
#  'Show HN: We track Reddit, Google trends, Twitter, etc. to find trending topics',
#  'Advice to my younger self: become allergic to the churn',
#  'Show HN: Sourcery – get a free, self-updating website',
#  'Show HN: Lunch Money, a personal budgeting tool with multi-currency support',
#  'New Life Found That Lives Off Electricity (2016)',
#  'Cerebras Systems unveils a 1.2T transistor chip for AI',
#  'Software architects should be involved in earliest system engineering activities',
#  'Using TypeScript with React',
#  'BMW unveils car sprayed with Vantablack',
#  'We shouldn’t take peer review as the ‘gold standard’',
#  'Launch HN: SannTek (YC S19) – Breathalyzer for Cannabis',
#  'The Myth of Consumer-Grade Security',
#  'Nvidia CEO says Google is the only customer building its own silicon at scale',
#  'Racket: Lisp for Learning',
#  'Ask HN: How to be less argumentative online?',
#  'Insurance Companies Are Paying Cops to Investigate Their Own Customers',
#  'Stand Out as a Speaker',
#  'Creeping normality',
#  'NASA said to be investigating first allegation of a crime in space',
#  'Germany for First Time Sells 30-Year Bonds Offering Negative Yields',
#  'America’s elderly seem more screen-obsessed than the young',
#  'Alarming surge in drug-resistant HIV uncovered',
#  'Levenshtein Distance',
#  'Punpedia – The Online Encyclopedia of Puns',
#  'Legit-Looking iPhone Lightning Cables Will Hijack Your Computer',
#  'Open Startups List',
#  'The first solar road has turned out to be a disappointing failure',
#  'Facial recognition: School ID checks lead to GDPR fine',
#  'Twitter confesses to more adtech leaks',
#  'What has to happen with Unix virtual memory when you have no swap space',
#  'Elon Musk Gambled Tesla to Save SolarCity',
#  'How the new open-source typeface used by GitHub and Mozilla came to be',
#  'Splunk acquires cloud monitoring service SignalFx for $1.05B',
#  'Swap, swap, swap, and bad places to work',
#  'Interviews with programming language creators (2010) [pdf]',
#  'Activision Blizzard has moved billions of dollars of profit into tax havens',
#  'How to Make Billions of Dollars Reducing Loneliness',
#  'Seashells – Pipe output from command-line programs to the web in real time',
#  "WeWork IPO Shows It's the Most Magical Unicorn",
#  'Experimental USAF space plane breaks record for orbital spaceflight',
#  'What I Do as a DevOps Consultant',
#  'Making containers safer',
#  'The Erlang Rationale',
#  'Apple suspends Siri response grading in response to privacy concerns',
#  'The Tragedy of UCS-2',
#  'Crispr pioneer among University of California researchers boycotting Elsevier',
#  '‘No One Saw a Thing’: When a Midwest Town Banded Together to Kill the Town Bully',
#  'What Makes a Good Conversation?',
#  'Ruffle – An Adobe Flash Player Written in Rust Compiled to WebAssembly',
#  'Hedonometer',
#  'GitHub Supports Web Authentication (WebAuthn) for Security Keys',
#  'Twelve LaTeX packages to get your paper accepted (2017)',
#  'A Manager’s Guide to Kubernetes Adoption',
#  'Typed Properties in PHP 7.4',
#  'A Readable Specification of TLS 1.3',
#  'Who Owns Your Wireless Service? Crooks Do',
#  'Feds ordered Google location dragnet to solve Wisconsin bank robbery',
#  'Things to Know About GNU Readline',
#  'Mortgage Market Reopens to Risky Borrowers',
#  'Recognizing the signs of disruption in our urban habitat',
#  'Acute Effects of Electronic Cigarette Aerosol Inhalation on Vascular Function',
#  'NOAA Data Confirms July Was Hottest Month Ever Recorded',
#  'JavaScript: The Modern Parts',
#  'Google Warns Developers That All New Android Apps Require 3 Days for Approval',
#  'Rust GUI ecosystem overview',
#  'How Does Esperanto Sound?',
#  'How Command and Conquer: Tiberian Sun punished the computers of the day [video]',
#  'What’s the difference between statistics and machine learning?',
#  'Dropbox no longer follows symlinks to items outside of your Dropbox account',
#  'Climate change made European heatwave up to 3°C hotter',
#  'Unison File Synchronizer',
#  'Michael Cicconetti',
#  'OpenGPT-2: We Replicated GPT-2 Because You Can Too',
#  'Practical Tips for Facelifting a Tech Resume',
#  'Natural Language Processing: The Age of Transformers',
#  'The Portuguese Bank Note Crisis of 1925',
#  'California farmers are planting solar panels as water supplies dry up',
#  'YouTube Said to Be Fined Up to $200M for Children’s Privacy Violations',
#  'Microsoft Is Killing ePub Support in Edge Classic',
#  'Ask HN: Configuration Management for Personal Computer?',
#  'Intel and Rust: The Future of Systems Programming [video]',
#  'From 30 to 230 Docker containers per host',
#  'Wireless Carrier Throttling of Online Video Is Pervasive: Study',
#  'How do black holes destroy information and why is that a problem?',
#  'Waypipe: GSoC Project Complete',
#  'Launch HN: Quirk (YC S19) – Open-Source Cognitive Behavioral Therapy',
#  "Boeing's Crashes Expose Systemic Failings",
#  'Goldman Sachs is spending $100M to shave milliseconds off stock trades',
#  'Bad Times in Tech? Not If You’re a Startup Serving Other Startups',
#  'Why did Turbo Pascal apps fail with a division-by-zero on faster systems?',
#  'Show HN: StoryTime – Create stories about your code instead of documentation',
#  'One of the greatest science fiction magazines is now available online (2017)',
#  'Nixery: Transparently build and serve containers using Nix',
#  'Most internet service providers are gone – Sonic has survived and thrived',
#  'Where do interrupts happen?',
#  'On-disk format robustness requirements for new filesystems',
#  'Giving up on Julia (2016)',
#  'The Ethics of Web Performance',
#  'Keeping Tesla Roadsters Alive Is Serious Work',
#  'Oracle directors give blessing to shareholder lawsuit against Larry Ellison',
#  'LF: Fully Decentralized Fully Replicated Key/Value Store',
#  'A Quarter of Humanity Faces Looming Water Crises',
#  'PacVim – PacVim is a game that teaches you vim commands',
#  'Why Does Infrastructure Cost So Much?',
#  'Laws of Showrunning (2016) [pdf]',
#  'Possible detection of a black hole with a mass that was thought to be impossible',
#  'Launch HN: Dex (YC S19) – personal CRM that reminds you to keep in touch',
#  "A Buddhist monk confronts Japan's suicide culture (2013)",
#  'The flawed three-cueing system for teaching reading',
#  'Home 3D metal printing: first results',
#  'São Paulo’s Outdoor Advertising Ban (2016)',
#  'Google Forcing Nest Cameras’ Visual Indicator Light To Be On',
#  'The Flawed Reasoning Behind the Replication Crisis',
#  'Sugar: Open-source software learning platform for children',
#  'Open Location Code: An Open Source Standard for Addresses',
#  "'It's crazy': Chase forgiving all debt owed by its Canada credit card customers",
#  'Computer Science Illustrated (2014)',
#  'Parsing JSON Is a Minefield (2018)',
#  'I found an easter egg from 1977',
#  'The interviewer skills ladder for high growth companies',
#  'Show HN: Tailwind.run – An Online Playground for Tailwind CSS',
#  'What to do once you admit that decentralization never seems to work (2018)',
#  'Hundreds of exposed Amazon cloud backups found leaking sensitive data',
#  'Removing One Maine Dam 20 Years Ago Changed Everything',
#  'Nonplanar Printing',
#  "Why didn't the Romans contribute much to mathematics?",
#  'Bulk Data Structures C++',
#  'Exploring Weight Agnostic Neural Networks',
#  'Have You Ever Tried to Sell a Diamond? (1982)',
#  'Big O Notation – Using not-boring math to measure code’s efficiency',
#  'Cisco is making it more difficult to use used hardware',
#  'How shrinkflation is playing havoc with economists’ models',
#  'Rotten Apple: Right to Repair Roundup',
#  'Tumblr',
#  'DoorDash Buying Caviar from Square for $410M',
#  'Daniel Radcliffe and the Art of the Fact-Check (2018)',
#  'Svalbard is as close as you can get to a place with open borders',
#  'Dyson Tree',
#  'How I finally won my name from domain resellers after nine years of waiting',
#  "FBI tells lawmakers it can't access Dayton gunman's phone",
#  'Children of a Thailand tribe who see with clarity beneath the waves (2016)',
#  'Franky Zapata: Flyboarding Frenchman crosses English Channel',
#  'Dignity',
#  'Teen Hacker Finds Bugs in School Software That Exposed Millions of Records',
#  'A Pissed-Off Tutorial for Google Wave (2010) [video]',
#  'I Took a Pay Cut for a More Meaningful Job',
#  'IBM Stops Buybacks to Pay for Red Hat',
#  'Parallelism in PostgreSQL',
#  'Tech backlash has come to Stanford',
#  'Google’s rivals opt out of search engine auction, calling it ‘anti-competitive’',
#  'Peloton S-1',
#  'Why a mock doesn’t work',
#  'Patterns on goods designed to trigger Automated License Plate Readers',
#  'Show HN: TeXnique – A LaTeX Typesetting Game',
#  'Upmem Puts CPUs Inside Memory to Allow Applications to Run 20 Times Faster',
#  'More Fires Now Burning in Angola, Congo Than Amazon',
#  'Telegram introduces feature to prevent users from texting too often in a group',
#  'Somehow I Became Respectable',
#  'How to become a great impostor',
#  "Seattle's 'microtransit' experiment drives people to light rail",
#  'Basic Electron Framework Exploitation',
#  'Helsinki Central Library chosen as the best new public library',
#  'SpaceX Smallsat Rideshare Program',
#  'Personal Website for Programmers',
#  'Startups from Y Combinator’s S19 Demo Day 1',
#  'Highlights from Git 2.23',
#  'Show HN: YouTube Decade – The most-viewed videos posted 10 years ago',
#  'Standard JS: npm install funding',
#  'Mapped: The world’s coal power plants',
#  'Kept alive with tubes for nearly 17 years',
#  'Lessons we learned when debugging a scaling problem',
#  'P++ idea: FAQ',
#  'Show HN: Scarf – Platform to help open-source developers monetize their work',
#  'Old Paris Is No More',
#  "Spacebook: AGI's near Real-Time satellite viewer",
#  'The Path to Dijkstra’s Handwriting (2013)',
#  'Ted Chiang: Realist of a Larger Reality',
#  'Escape rooms are big business',
#  'Alcohol Belts of Europe',
#  'Dependent Haskell Is the Future (2018)',
#  'North American versus European distribution systems (2011)',
#  "Social share buttons that don't allow the social sites to track your users",
#  'Nutrient deficiencies in rice grown under higher carbon dioxide',
#  'The body is the missing link for truly intelligent machines (2017)',
#  'Electric motor design claims remarkable improvements',
#  'Living Off the Land in Linux',
#  'No Son of Mine Is Going to Be a Benthamite',
#  'Extended Validation Certificates Are Really Dead',
#  "The Mobility Trap: Why We'll Never Fix Congestion by Speeding Up Traffic",
#  'Static Type Checking in Common Lisp',
#  'Interslavic Language',
#  'Startups from Y Combinator’s S19 Demo Day 2',
#  'Announcing Notqmail',
#  'Why the French love to say no',
#  'Theories of Error Back-Propagation in the Brain',
#  'Black Beekeepers Are Transforming Detroit’s Vacant Lots into Bee Farms (2018)',
#  'GPT-2: 6-Month Follow-Up',
#  'Crossword Panic of 1944',
#  'Libspng – C library for reading and writing PNG files',
#  "Kegan's Theory of the Evolution of Consciousness",
#  'Hospital checklists are meant to save lives, so why do they often fail?',
#  'Understanding SAT by Implementing a Simple SAT Solver in Python (2014)',
#  'A deep dive into Linux namespaces, part 4',
#  'Chemists make first-ever ring of pure carbon',
#  'Datacenter Locations Driven by 19th Century Politics',
#  'Uber Is Biggest Loser as SoftBank Counts IPO Returns',
#  'Using bacteria to make self-healing cement',
#  'Better Encrypted Group Chat',
#  'Exploring Mathematics with Matplotlib and Python',
#  "Moravec's Paradox",
#  'Vibration-minimizing motion retargeting for robotic characters',
#  'Website Builder Webflow (YC S13) Went from Near Bankruptcy to $72M Series A',
#  'Swiss Post Suspends Drone Delivery Service After Second Crash',
#  'Do-It-Yourself OpenJDK Garbage Collector',
#  "Patagonia's Philosopher King (2016)",
#  'J can look like APL or English',
#  "Julia's Release Process",
#  'Math in Data Science',
#  'Getting Real About Distributed System Reliability (2012)',
#  "Don't forget randomness is still just a hypothesis (2006)",
#  'History of the broken vertical bar, being the ¦ form of |',
#  'Show HN: I Built a “Google Alerts” for Hacker News',
#  'TV detector van',
#  'Two brothers invented an alphabet for their native language, Fulfulde',
#  'Where will ‘garage orphans’ charge electric cars?',
#  'How Biotech Startup Funding Will Change in the Next 10 Years',
#  'Ignition: An Informal History of Liquid Rocket Propellants (1972) [pdf]',
#  'Wine-dark sea',
#  '10 Years SeL4: Still the Best, Still Getting Better',
#  'When to Shut Down a Startup [video]',
#  'CTVT – A contagious cancer that spreads from dog to dog',
#  'Ceramics enter a new era with laser-welded joints',
#  'The Shady World of Repair Manuals: Copyrighting for Planned Obsolescence (2012)',
#  'Open Source Hardware Hearing Aid Part 1',
#  'The Last Working Olivetti Mainframe Sits In a Tuscan High School',
#  'In the beginning was the command line (1999) [pdf]',
#  'Manufacturers want to quit China for Vietnam, but find it impossible',
#  'Microsoft Has First Major Impact on Chrome',
#  'Casting Glass from 3D Printed Molds',
#  'DEF CON and Stack Overflow: What Our Traffic Says About Cybersecurity',
#  'Geocities Archive',
#  'N-Shot Learning: Learning More with Less Data',
#  'Who Did the Math for General Relativity First, Einstein or Hilbert?',
#  'The Rule of 2',
#  "An 'Exosuit' That Boosts Endurance on the Trail",
#  'Subsurface – An open source scuba dive logging platform',
#  'You May Be Better Off Picking Stocks at Random, Study Finds',
#  'Goals and Rewards Redraw the Brain’s Map of the World',
#  'FBI: Delivery drivers involved in Amazon theft ring',
#  'Solar Powered Raspberry Pi Camera',
#  'Mosquitoes Changed Everything',
#  'Columnist asked researchers what they could find out from just his cell number',
#  'A Commercial Path to Fusion',
#  'StockX was hacked, exposing millions of customers’ data',
#  'Waymo’s Backseat Drivers: Confidential Data Reveals Self-Driving Taxi Hurdles',
#  'MoviePass reportedly changed passwords to prevent users from seeing films',
#  '“Bicycle of the Mind”',
#  'What Germans Are Reading',
#  'Tiny Toy TOTP Generator in 18 Lines of Python',
#  'A Molecular Near Miss',
#  'Supercomputers will start building a 3D map of the world',
#  'What Companies Are For',
#  'Dwindling CPAN Releases',
#  'Capital One Cyber Staff Raised Concerns Before Hack',
#  'Trigger a Kernel Panic to Diagnose Unresponsive EC2 Instances',
#  'Launch HN: Compound (YC S19) – helping employees understand equity compensation',
#  'How We Manage a Million Push Notifications an Hour',
#  'Inventing Monads',
#  'Write Fuzzable Code',
#  'Most software companies ignore user behavior',
#  'An Afternoon in Tokyo with the Man Who Designs Casio G-Shock Watches (2017)',
#  'Analyzing the Facebook ads placed by the US presidential candidates',
#  'KIP-500: Replace ZooKeeper with a Self-Managed Metadata Quorum',
#  'Side channel that leaked data from Intel CPUs patched by silent Windows update',
#  'Chemists discover water microdroplets spontaneously produce hydrogen peroxide',
#  'Rendering on the Web',
#  'Free Software network services and web applications which can be hosted locally',
#  'Phytoplankton Population Drops 40 Percent Since 1950 (2010)',
#  "Root: CERN's scientific data analysis framework for C++",
#  'The subversive messages hidden in The Wizard of Oz',
#  'Flaws in Cellphone Evidence Prompt Review of 10k Verdicts in Denmark',
#  'Economist Raj Chetty has found a surprising tool to fight housing segregation',
#  'Static Analysis at Scale: An Instagram Story',
#  'Camera vs. Lidar',
#  'How Digital Advertising Markets Really Work',
#  'Security flaws caused by compiler optimizations',
#  'How Web Content Can Affect Power Usage',
#  'Music Recommendations in Hyperbolic Space',
#  'A Deep Dive into AMD’s Rome Epyc Architecture',
#  '16-bit RISC-V processor made with carbon nanotubes',
#  'Show HN: Real world (Jupyter notebook embed) way to assess data scientists',
#  'Launch HN: Memfault (YC W19) – Crashlytics for Firmware',
#  'A person has died from a vaping-related condition',
#  'Linux Pressure Stall Information (PSI) by Example',
#  'How to Write a Lisp Interpreter In Python (2010)',
#  'Processor Design: An Introduction (1998)',
#  'Adventure in Prolog Tutorial (2016)',
#  'Show HN: Purely Functional Scripting',
#  'Clever Functional Design',
#  'Google begins penalising domain leasing',
#  'Building a Programming Language Pt. 3 – Interpreting',
#  'Sentient: Classified artificial brain being developed by US intelligence',
#  'Live Avatars with face-api.js',
#  'India’s Messy Electric Vehicle Revolution',
#  'Launch HN: Lang (YC S19) – Internationalization Built for Devs',
#  'I Tried Hiding from Big Tech in a Pile of Privacy Gadgets',
#  'Pokemonsay: Pokemon Version of Cowsay',
#  'Cowrie: a medium-interaction SSH and Telnet honeypot',
#  'Energy Storage Investments Boom as Battery Costs Halve in the Next Decade',
#  'Effortless Elixir Releases and Deployment',
#  "Which Categories of Seed Startups Are Thriving? Which Aren't?",
#  'Hydrophilic disc uses solar power to separate salt from water',
#  'Learning to prove theorems via interacting with proof assistants',
#  'Dark Matter Developers: The Unseen 99% (2012)',
#  'Urgent/11 – Zero Day Vulnerabilities Impacting VxWorks',
#  'Huntington Park’s “RoboCop” stores pedestrians’ faces, scans license plates',
#  'CERN Open Data Portal: Explore more than 2 PB of open data from particle physics',
#  'Getting Started with Lisp in 2019',
#  'What Is Null? (2010)',
#  'Misinterpreting hurricane forecasts',
#  'Scale (YC S16) Raises $100M from Accel and Founders Fund at $1B Valuation',
#  'Programming Algorithms in Lisp: Data Structures',
#  'In Pentagon Contract Fight, Amazon Has Foes in High Places',
#  'Rome Is the Fulcrum of AMD’s Datacenter Pivot',
#  'How to Get into Farming with No Money (1980)',
#  'Phone Companies Ink Deal With All 50 States And D.C. To Combat Robocalls',
#  'Fast Tensors in Clojure – A Sneak Peek',
#  'How the Great Truth Dawned',
#  'FileKit: An open source end-to-end encrypted cloud storage service in JavaScript',
#  'Would you accept cheaper rent in exchange for a monthly Amazon purchasing quota?',
#  'Duckling: a Clojure library that parses text into structured data',
#  'Mitre Systems Engineering Guide (2014) [pdf]',
#  'Texas Power Prices Briefly Surpass $9k Amid Scorching Heat',
#  "Amazon's Plan to Conquer the World of Publishing",
#  'Toptal sues co-founder Breanden Beneschott for fraud',
#  'Finding Amelia Earhart’s Plane Seemed Impossible – Then Came a Startling Clue',
#  "30 years ago: Voyager 2's historic Neptune flyby",
#  'MesaPy: A Memory-Safe Python Implementation based on PyPy (2018)',
#  'Trails of Wind: Data Visualization of the Architecture of Airport Runways',
#  'Show HN: ShapeForm – Schema Driven Forms for React',
#  'Network Effects That Don’t Look Like Network Effects',
#  'Germany Turns to Hydrogen in Quest for Clean Energy Economy',
#  'If you want developers to adopt your software, make it less risky (2017)',
#  'Why the U.S. Army Owns So Many Fossils',
#  'Exploring DNA with Deep Learning',
#  'How the Pentagon Comes Up with Code Words and Secret Project Nicknames',
#  'A Simulated Enigma Machine',
#  'On Building My Own Artificial Pancreas',
#  'Machine Learning That’s Light Enough for an Arduino',
#  "Unshaky – Tries to address double key press issue on Apple's butterfly keyboard",
#  'ZRNA – Software-defined analog circuits',
#  'Simple RPC framework in 300 lines of Go',
#  'A Codebase Is an Organism (2014)',
#  "The perfect language and why Go still isn't it",
#  'Hundreds of people died over a millennium at “Skeleton Lake” in the Himalayas',
#  'All Tridactyl installations might get removed by Firefox on Aug 21',
#  'Divers Find Remains of Ancient Temple in Sunken Egyptian City',
#  'Free and open-source tools for analog filmmaking',
#  'API Gateway Identity Crisis – are they replaced by service mesh?',
#  'I started an online subscription business from Malaysia',
#  'Lifehacker: Tarek Loubani on 3D-Printing in Gaza',
#  'Our Brains Tell Stories So We Can Live (2013)',
#  'Capturing PAL video with an SDR, and a few dead ends',
#  "Solving differential equations on a 6502 with Woz's floating point code",
#  'Computer Stupidities (2013)',
#  'A look back: The Bloomberg Keyboard (2017)',
#  'Jupiter: RISC-V Assembler and Runtime Simulator',
#  '42 Hours of Buckminster Fuller might be just the vision we need',
#  'Project Mu – A modular UEFI environment for building modern devices',
#  'The High Price of Multitasking',
#  'Curve fitting A: Linear Least Squares',
#  'Handler beliefs affect scent detection dog outcomes (2011)',
#  'Sipeed Longan Nano – RISC-V Development Board',
#  'The difference between isolation levels and consistency levels',
#  "Detailed 3D map of Milky Way shows 'warped' shape",
#  'Map Design – a guide to good looking maps (2008) [pdf]',
#  'No Silver Bullet (1986) [pdf]',
#  'Armoured Commander: The WWII Tank Commander Roguelike',
#  "How the brain 'approximates' without counting",
#  'SoftBank plans to lend $20B to its CEO and employees amid volatile markets',
#  'The HP Way: How Bill Hewlett and I Built Our Company (1960)',
#  'How to Build a Pyramid',
#  'How to get consistent results when benchmarking on Linux?',
#  'How to Teach an Iris Scanner That the Eye It’s Looking at Is Dead',
#  'Building a vacuum tube computer',
#  'Portugal’s Marmelada Tastes Nothing Like Marmalade (2018)',
#  'SpaCy PyTorch Transformers',
#  'Real world location virtually recreated to scale in minutes [video]',
#  'Show HN: Dat-keyserver: a distributed PGP keyserver based on the Dat protocol',
#  '"Karel Čapek\'s play ""R.U.R."" premiered in January 1921"',
#  'Apple Card restrictions include no jailbreaking or cryptocurrency purchases',
#  'The Grand C++ Error Explosion Competition',
#  'Turkmenistan on the brink of collapse?',
#  'A profile of Geoffrey Hinton (2018)',
#  'Scientists reverse aging process in rat brain stem cells',
#  'Show HN: Cordless, a Discord terminal client written in Go',
#  '100 Years Ago, a Telephone Tower in Stockholm Connected 5000 Phone Lines (2014)',
#  'Japanese architects who treated buildings like living organisms',
#  'A recent paper proposes to bring zeppelins back',
#  'J-Core Open Processor',
#  'Presidio: Customizable data protection and PII data anonymization service',
#  'The Survival of Iggy Pop',
#  'BPF port-based firewall for systemd services',
#  'Marree Man',
#  'The D-Day rehearsal that cost 800 lives (2014)',
#  'Ray tracing with uLisp',
#  'Show HN: A few simple games not only for kids',
#  'Why Everyone Hates Customer Service',
#  'Commodore 900',
#  'QualPwn – Exploiting Qualcomm WLAN and Modem over the Air',
#  'Study identifies main culprit behind lithium metal battery failure',
#  'With friends like these',
#  'YouTube’s LGBTQ Problem Is a Business-Model Problem',
#  'Suburb in the sky: how Jakartans built an entire village on top of a mall',
#  'Circulating in China’s Financial System: More Than $200B in I.O.U.s',
#  "The Death of Alexander the Great: One of History's Great Unsolved Mysteries",
#  "The 'microworkers' making digital life possible",
#  'Keyringless GnuPG',
#  'The Perfect French Baguette',
#  'Shipping wind turbines is not a breeze',
#  'Iron Age Celtic Woman Was Buried in a Hollowed-Out Tree Trunk',
#  'The Biggest Mistakes First-Time Founders Make [video]',
#  'Boeing changing Max software to use two computers',
#  'Empty trains on the modern Silk Road: when Belt and Road interests don’t align',
#  'Wavelets (1994) [pdf]',
#  'Who Did the Maya Sacrifice?',
#  'A Guide to Magnetorquers for Satellites',
#  'Mobile NixOS: The Present and the Future',
#  'NEC shows ‘flying car’ hovering steadily for minute',
#  'Quantum radar has been demonstrated for the first time',
#  'Ear Speakers – Research, Design, and Evolution',
#  'Wasm vs. PNaCl Performance Benchmark',
#  'Evolving Lindenmayer Systems',
#  'Show HN: Repository of open source space-related software and hardware',
#  'I love my paper dictionary (2017)',
#  'Darpa wants help cracking the election security problem',
#  'The Fed is getting into the Real-Time payments business',
#  'Woman Finds Yellow Diamond While Watching YouTube Video on How to Find Diamonds',
#  'Amazon will pull the plug on dash buttons',
#  'Problem Solving and Clojure 1.9 (2018)',
#  'A new book asserts that rich countries grow with lighter environmental impacts',
#  'Animal movies promote awareness, not harm, say researchers',
#  '2019 Hyundai Kona EV Explodes When Parked',
#  'The League of Entropy Is Making Randomness Truly Random',
#  'A Transparent Display with Per-Pixel Color and Opacity Control',
#  'The “Terrascope”: On the Possibility of Using the Earth as an Atmospheric Lens',
#  'Humans Dominated Earth Earlier Than Previously Thought',
#  'Fuzzification: Anti-Fuzzing Techniques [pdf]',
#  'What Is Zoned Storage and the Zoned Storage Initiative?',
#  'Webmin 1.890 Exploit – What Happened?',
#  'Scaling Static Analyses at Facebook',
#  'The death of a weather satellite as seen by SDR',
#  'Holidays are good for workers and companies alike',
#  'Richard Sorge: The Soviet Union’s Master Spy',
#  'Debunking the Stanford Prison Experiment [pdf]',
#  'Marium, the Dugong Who Charmed Thailand, Dies After Ingesting Plastic',
#  'Simple Python Package to Extract Deep Learning Features',
#  'Massive ‘ocean’ discovered towards Earth’s core (2014)',
#  'DEF CON 2019 – CTF Retrospective',
#  'Kdevops: Framework for setting up and testing the Linux kernel for any project',
#  'Simple, pure, and total functional language that generalizes Datalog',
#  'Continuous 3D Printing Possible With Transparent Polygon Scanning?',
#  'Could Removing Social Media Metrics Reduce Polarization?',
#  'Roaring glacial melt under the bridge to Kangerlussiauq, Greenland',
#  'The New Treasures of Pompeii',
#  'SEC Investigating Data Leak at First American Financial Corp',
#  'The OpenBSD Ada Library',
#  "Don't Say “Homoiconic” (2018)",
#  'US Air Force pauses flights for over a hundred C-130s over ‘atypical’ cracking',
#  'I am a horse in the land of booleans',
#  'We may not be running out of helium after all (2015)',
#  'Launch HN: Shift Health (YC S19) – Understand Your Healthcare Costs Pre-Visit',
#  'SmartyKit Apple I replica',
#  'Gerbil – A meta-dialect of Scheme',
#  'Hawaii Extends Thirty Meter Telescope Permit Amid Protests',
#  'GM Is Now Detroit’s Smallest Auto-Making Employer',
#  'The Dipole Drive: A New Concept in Space Propulsion',
#  'Universal algorithm set to boost microscopes',
#  'Fearing data privacy issues, Google cuts some Android phone data for carriers',
#  "Robotic thread is designed to slip through the brain's blood vessels",
#  'Vickrey–Clarke–Groves Auction',
#  'Prolog Control in Six Slides',
#  'Opinion piece on GHC back ends',
#  'Entropic: A federated package registry for anything',
#  'CBOR – Concise Binary Object Representation',
#  'Can we survive technology? (1955) [pdf]',
#  'Cassettes Are Back, and It’s Not About the Music',
#  'Paul Dirac: The Mozart of Science (2008)',
#  'In praise of xlogo',
#  'Show HN: Historical order book reconstruction API for crypto markets',
#  'Arcs of Seniority',
#  'The Long Game of Research',
#  "A Look at HS2's Old Oak Common Station",
#  'How Judy arrays work and why they are so fast (2002)',
#  'Mining Bitcoin on an Apple II',
#  'Unearthing a masterpiece: a rare Minoan sealstone (2017)',
#  'Golden Ratio',
#  'Show HN: pgcmd – An alternative to psql with JSON output',
#  'Reviving an HP 660LX in 2019',
#  'SSB Rooms: a new server type for Scuttlebutt',
#  'Implementing Poincaré Embeddings (2017)',
#  'Extending OCaml Programs with Lua',
#  'Container Networking with Vxlan, BGP and WireGuard',
#  'A Fine Map from Alexander von Humboldt (1851)',
#  'New research on PTSD in elephants and other animals',
#  '“Awakenings” in Advanced Dementia Patients Hint at Untapped Brain Reserves',
#  'Recycling of plastics enabled by dynamic covalent diketoenamine bonds (2018) [pdf]',
#  'Show HN: Data-viz project for ray-tracing the Moon model',
#  'Five new Real-Time detections of fast radio bursts with UTMOST',
#  'LucidScience – Electronic Projects and Tutorials',
#  'What are children dying from and what can we do about it?',
#  'A Conversation with the Team That Made Bread with Ancient Egyptian Yeast',
#  'Air Force Reveals Tests of Supposed Record-Setting Scramjet from N. Grumman',
#  'The Decline of College Newspapers',
#  'Which Is the Best John Le Carré Novel? (2014)',
#  'Dreaming about Better Sleep: Dreem, Oura and the Rest',
#  'Penn Effect',
#  'Hall’s Law: The Nineteenth Century Prequel to Moore’s Law (2012)',
#  'Volcanoes on the Moon May Have Erupted During the Dinosaur Age (2014)',
#  'The World’s Smartest Chimp Has Died',
#  'Smart plastic incineration posited as solution to global recycling crisis',
#  'Kei – A small and expressive dependent language',
#  'Freshermeat – Open-Source Security Software',
#  'Engineers build advanced microprocessor out of carbon nanotubes',
#  'A New York Farm Stand’s Success: An Eye for the Next Big Thing',
#  'Disneyland’s Disastrous Opening Day (2015)',
#  'A Z-Machine in OCaml (2016)',
#  "Quantum Air buys Bye's electric airplanes",
#  'Famous Graphics Chips: Microsoft’s Talisman',
#  "Engineers develop bone-like metal foam that can be 'healed' at room temperature",
#  'Using the Golden Research Engine to Query the Y Combinator S19 Batch',
#  'A mosque rebuilt once a year',
#  'Flying with Miniature Horses',
#  'The Oral History of the Super Soaker',
#  'A Trailblazing Plan to Fight California Wildfires',
#  'Show HN: Firestorm – An ORM for Firestore',
#  'Programming shape using kirigami tessellations',
#  'Potosí: the mountain of silver that was the first global city',
#  'An Ancient Egypt-to-Black Sea Route? Adventurers to Test Theory',
#  'Exploring the Visible Spectrum in Python',
#  'General Balanced Trees (1999) [pdf]',
#  'Using Wall Street secrets to reduce the cost of cloud infrastructure',
#  'Rediscovering rules for ancient board games',
#  'On the Road in 1980',
#  'The Software Arts',
#  'Making Web-Workers Async Iterables',
#  'Show HN: Quark-IDE and a JavaScript runtime to build cross-platform desktop apps',
#  'Environment and the programming language Self, part 4',
#  'The lost Doves Press typeface and its revival (2015)',
#  'Early Years of Computer Gaming: Steve Russell and Nolan Bushnell (2002) [video]',
#  'The quest to conquer Earth’s space junk problem (2018)',
#  'Swadesh List',
#  'Salvator Mundi and the unreality of the art market']

# %%
#Convert the titles to lower case
link_titles_lower = link_title.map(lambda x : x.lower())
link_titles_lower.collect()
# Out:
# ['turning a macbook into a touchscreen with $1 of hardware (2018)',
#  'the lonely work of moderating hacker news',
#  'introducing nushell',
#  'google just deleted my nearly 10-year-old free and open-source android app',
#  'ebola is now curable',
#  'all the best engineering advice i stole from non-technical people',
#  'i miss microsoft encarta',
#  "alan kay's answer to ‘what are some forgotten books programmers should read?’",
#  'information operations directed at hong kong',
#  'terminating service for 8chan',
#  'what happens when you launch google chrome for the first time?',
#  'how to build good software',
#  'null license plate not such a bright idea',
#  "what does a coder do if they can't type?",
#  'yelp is replacing restaurants’ phone numbers so grubhub can take a cut',
#  'japanese anime studio khara moving to blender',
#  'deconstructing google’s excuses on tracking protection',
#  'cloudflare s-1',
#  '8chan goes dark after hardware provider discontinues service',
#  'please add rss support to your site',
#  'no more cheap shipping for chinese sellers',
#  'python is eating the world',
#  'verizon to sell tumblr to automattic',
#  'tasty seaweed reduces cows’ methane emissions by 99%',
#  'hy',
#  'things i learnt from a senior software engineer',
#  'wewtf',
#  'linux journal ceases publication: an awkward goodbye',
#  'amd lands google, twitter as customers with newest server chip',
#  'us navy will replace touchscreen with mechanical controls on its destroyers',
#  'standard ebooks: free public-domain ebooks, carefully produced',
#  'why is modern web development so complicated?',
#  'a man who destroyed his multimillion dollar company in 10 seconds (2018)',
#  'opendrop: an open source airdrop implementation',
#  'a deep dive into ios exploit chains found in the wild',
#  'software architecture guide',
#  'sites using facebook ‘like’ button liable for data, eu court rules',
#  "insect 'apocalypse' in u.s. driven by 50x increase in toxic pesticides: study",
#  'apple confirms $1m reward for anyone who can hack an iphone',
#  'why all of our games look like crap',
#  'tech interview handbook',
#  'fewer than half of google searches now result in a click',
#  'ugly gerry – font created from congressional districts',
#  'why has examine.com disappeared from search results?',
#  'a walk in hong kong',
#  'john carmack on the joe rogan experience [video]',
#  'the baseline interpreter: a faster javascript interpreter in firefox 70',
#  'google doesn’t want staff debating politics at work anymore',
#  'build your own text editor',
#  "i've reproduced 130 research papers about “predicting the stock market”",
#  'ask hn: how do you read?',
#  'how to build a plugin system on the web and also sleep well at night',
#  'europe is edging towards making post-car cities a reality',
#  'new york city neighbors build cheaper way to connect to web',
#  'github actions now supports ci/cd, free for public repositories',
#  'consume less, create more',
#  'living near trees, not just green space, improves wellbeing',
#  'kerbal space program 2',
#  'macbook pro keyboard drives me crazy',
#  'why i turned down an aws job offer',
#  'facebook has been granted patent on shadow banning',
#  "the linux kernel's inability to gracefully handle low memory pressure",
#  'show hn: cli tool for saving web pages as a single file',
#  'start your own isp',
#  "every productivity thought i've ever had, as concisely as possible",
#  "preindustrial workers worked fewer hours than today's (2009)",
#  'milky way’s black hole just flared, growing 75 times as bright for a few hours',
#  'amazon has proven unable or unwilling to effectively police third-party sellers',
#  'rails 6.0',
#  'ha-ha wall',
#  'speaking to yourself in the third person makes you wiser',
#  'ibm open-sources power chip instruction set',
#  'apple expands parts access to more independent repair businesses',
#  'paged out – a new experimental magazine about programming',
#  "let's build houses for people, not cars",
#  'we have ruined childhood',
#  "decrement carbon: stripe's negative emissions commitment",
#  '16m americans will vote on hackable paperless machines',
#  'home chip fab',
#  'google and mozilla are failing to support browser extension developers',
#  "a mathematician's way of converting miles to kilometers",
#  'there is no evil like recaptcha',
#  'kaspersky av injected unique id allowing sites to track users in incognito mode',
#  'who owns huawei?',
#  'the horror of microsoft teams',
#  'hundreds of extreme self-citing scientists revealed in new database',
#  'regex for noobs – an illustrated guide',
#  'apple will soon treat online web tracking the same as a security vulnerability',
#  'the it guy vs. the con artist',
#  'death note: l, anonymity and eluding entropy (2017)',
#  'amd rome second generation epyc review: 2x 64-core benchmarked',
#  'amazon is a monopoly',
#  'time anxiety: is it too late?',
#  'wtf – a personal information dashboard for your terminal',
#  'scientists discover a cure for the deadliest strain of tuberculosis',
#  'show hn: divjoy – react codebase and ui generator',
#  'proteins that may restore damaged sound-detecting cells in the ear',
#  '15 states are trying to make the electoral college obselete',
#  'banned c standard library functions in git source code',
#  'pronunciations for hexadecimal numbers (1968)',
#  'turbo, an improved rainbow colormap for visualization',
#  "from mac to linux – the setup i've grown to love",
#  'time to get serious about tick-borne diseases',
#  'pentagon testing mass surveillance balloons across the us',
#  'useless windows 10 features',
#  'some obscure c features',
#  'mercedes-benz pre-safe sound',
#  'tsv utilities: command line tools for large, tabular data files',
#  'psytrance guide',
#  "researcher banned on valve's bug bounty program publishes second steam 0-day",
#  'why do developers at google consider agile development to be nonsense? (2016)',
#  'planet: imaging the entire earth every day',
#  'software made me loathe my car',
#  'dqlite – high-availability sqlite',
#  'cutiepi – all-in-one raspberry pi tablet',
#  "knuth on huang's sensitivity proof: “i've got the proof down to one page” [pdf]",
#  'supercentenarians are concentrated into regions with no birth certificates',
#  'anthony levandowski charged with theft of trade secrets',
#  'exfat in the linux kernel',
#  'speed matters: why working quickly is more important than it seems (2015)',
#  'programmers: before you turn 40, get a plan b (2009)',
#  'information theory for intelligent people (2018) [pdf]',
#  'i completed ultimate go, took good notes and commented directly on source code',
#  'a guide to recording 660fps video on a $6 raspberry pi camera',
#  'super mario 64 has been decompiled',
#  'yaml: probably not so great after all',
#  'rust language cheat sheet',
#  'thoughts on rust bloat',
#  'google chrome incognito mode can still be detected',
#  'rules for intuitive ux',
#  'iterm2 3.3',
#  'datadog s-1',
#  'the not so hidden cost of sharing code between ios and android',
#  'show hn: chart.xkcd – xkcd-styled chart library',
#  'tell hn: danny cohen has died',
#  'down the rabbit-hole',
#  'three kinds of good tech debt',
#  'facebook scans system libraries on android and uploads them to their server',
#  'uber posts $5.2b loss and slowest ever growth rate',
#  'the fully remote attack surface of the iphone',
#  'google to offer a best price guarantee on certain flights',
#  'npm bans terminal ads',
#  'the architecture of open source applications',
#  'people love working remotely',
#  'berlin’s popular shopping streets will go car-free',
#  'toni morrison has died',
#  'sourcehut welcomes bitbucket refugees',
#  'ai startup claims to automate app making but actually just uses humans',
#  'ask hn: recommended resources to learn the linux kernel and os theory?',
#  'steam windows client local privilege escalation 0day',
#  'hong kong isp association’s statement on selective blocking of internet services',
#  'i wasn’t getting hired as a data scientist, so i sought data on who is',
#  'juul, philip morris sued under racketeer act for targeting kids',
#  'vmware acquires carbon black for $2.1b and pivotal for $2.7b',
#  'zen 2 missives – amd now delivering efficiencies that are double that of intel',
#  'write your own excel in f# (2018)',
#  'performance matters',
#  'is perl 6 being renamed?',
#  'people simply empty out (1986)',
#  'black hat: gdpr privacy law exploited to reveal personal data',
#  'show hn: i trained a deep learning model to build sites for me',
#  'webkit tracking prevention policy',
#  'removing coordinated inauthentic behavior from china',
#  'calculus for the people',
#  'anxiety looks different in men',
#  'yield curves invert in u.s., u.k',
#  'amazon offered ‘amazon’s choice’ to vendors who bought ads and lowered prices',
#  'cyberchef – cyber swiss army knife',
#  'rust 1.37.0',
#  "a boeing code leak exposes security flaws deep in a 787's guts",
#  'ask hn: best resources to gain math intuition?',
#  'mozilla takes action to protect users in kazakhstan',
#  'anime4k: real time high quality video upscaling',
#  'wine on windows 10',
#  'building a distributed time-series database on postgresql',
#  'xfce 4.14',
#  'most startup theory is ex-post, therefore bs',
#  'lessons from stripe',
#  'show hn: wave-based non-line-of-sight computational imaging in julia',
#  '‘they get fired all the time. and they have no idea why’',
#  '9th circuit says users can sue facebook over unlawful use of facial recognition',
#  'linux kernel drivers in rust might become an option in the future',
#  'moviepass worked out great',
#  'a beginner’s introduction to python web frameworks (2018)',
#  'ask hn: who is hiring? (august 2019)',
#  'show hn: data structures and algorithms in javascript',
#  'await in rust',
#  'cool but obscure x11 tools',
#  'elsevier threatens others for linking to sci-hub but does so itself',
#  'group sex app leaks locations, pics and personal details',
#  'apple is locking iphone batteries to discourage repair',
#  '“i would like to maintain the floppy driver”',
#  'fracking in north america could be partly to blame for methane spike – study',
#  'flawed algorithms are grading millions of students’ essays',
#  '35 over 35',
#  'u.s. designates china as currency manipulator',
#  'sunsetting mercurial support in bitbucket',
#  'open letter from an android developer to the google play team',
#  'cue – a language for defining, generating, and validating data',
#  'how rust optimizes async/await',
#  'one city saved $5m by routing school buses with an algorithm',
#  'async-std: an async port of the rust standard library',
#  'regexr',
#  'the art of warez [video]',
#  'get your work recognized: write a brag document',
#  'one job, many roles: the different skills needed to be a successful cto',
#  'productivity and the workweek (2000)',
#  'nigerian teens are making sci-fi shorts with slick visual effects',
#  'the most frequent 777 characters give 90% coverage of kanji in the wild',
#  'contributing to the mozilla code base',
#  'the lost art of lacing cable (2018)',
#  'martini: real-time terrain mesh generator',
#  'the impact of meditating every day',
#  'software was eating the world – now landlords are eating everything',
#  'ibm has released the power architecture instruction set to the linux foundation',
#  "plastics: what's recyclable, what becomes trash and why",
#  'uber, losing billions, freezes engineering hires',
#  'irs budget cuts cost $34.3b in lost revenue from big business',
#  'calculus is deeply irrational',
#  'every noise at once',
#  'at&t employees were bribed to install phone unlocking malware on company network',
#  'the problem at yale is not free speech',
#  'silk',
#  'beyond meat and kfc partner to test fried plant-based ‘chicken’',
#  'the we company s-1',
#  'how to return to the flow faster',
#  'the paxos algorithm, or how to win a turing award',
#  'attorney general barr and encryption',
#  'making email more modern with jmap',
#  'ffmpeg 4.2',
#  'webassembly interface types: interoperate with all the things',
#  'roblox hits 100m monthly active users, bigger than minecraft',
#  'words that do handstands',
#  'how men’s bodies change when they become fathers',
#  'misconfigured jira instances exposed data of hundreds of fortune 500 companies',
#  'companies use borrowed billions to buy back stock, not to invest',
#  'ny state alleges exxonmobil knew risks of climate change and defrauded investors',
#  'new react devtools',
#  'wework gets tax rebate meant for its small-business tenants',
#  'administration using the full power of the surveillance state on whistleblowers',
#  'a book from alan turing and a mysterious piece of paper',
#  'how to get your first ten customers (2013)',
#  'does the amazon provide 20% of our oxygen?',
#  'uber proposes policy that would pay drivers a minimum wage of $21 per hour',
#  'the most dangerous writing app',
#  'why did china just devalue the yuan? how trade works with free-floating currency',
#  'arend: theorem prover based on homotopy type theory by jetbrains',
#  'blazingsql is now open source',
#  'key negotiation of bluetooth attack',
#  'on-device, real-time hand tracking with mediapipe',
#  'dirty tricks 6502 programmers use',
#  'insured price $2,758, cash price $521',
#  'germans grow frustrated with their slow-poke internet',
#  'building a raspberry pi 3b+ full keyboard handheld',
#  'show hn: saag as a service – macronutrient-portioned indian spinach curry',
#  'social exclusion fuels extremism in young men',
#  'camscanner, a malicious android app with more than 100m downloads in google play',
#  "moscow's blockchain voting system cracked a month before election",
#  'anna karenina principle',
#  'qemu vm escape',
#  'inflated bond ratings helped spur the financial crisis. they’re back',
#  'medieval people bathed regularly',
#  'devilution – a web port of the original diablo game',
#  'cooling a house without air conditioning',
#  '3.8m-year-old skull of an early ape-like human ancestor discovered in ethiopia',
#  'huawei technicians helped african governments spy on political opponents',
#  'typescript 3.6',
#  'the answer to “will you mentor me?” is no (2010)',
#  'how to measure indoor air quality with a raspberry pi, ruuvitags and pms7003',
#  'wework isn’t a tech company',
#  "why const doesn't make c code faster",
#  'verified by twilio',
#  'python vs. rust for neural networks',
#  'big coal plants begin to close',
#  'aussie isv buys ads to wake up google support',
#  'the feynman lectures on physics: algebra (1963)',
#  'coinbase: responding to firefox 0-days in the wild',
#  'gamedev tutorial: trigonometry basics – sine and cosine',
#  'secretly public domain: most books published in the us before 1964',
#  'show hn: clojurescript pixel game engine with blender live-reloading',
#  'lisp is not based on the lambda calculus',
#  'alphabet overtakes apple to become most cash-rich company',
#  'rice university researchers propose a way to boost solar efficiency',
#  'using backblaze b2 and cloudflare workers for free image hosting',
#  "the worst sales promotion in history: hoover's free flight fiasco",
#  'the door problem of combat design',
#  'wikipedia is now a brave verified publisher',
#  'google plans to deprecate ftp url support in chrome',
#  'killing a process and all of its descendants',
#  'show hn: i created postwoman, an online, open-source api request builder',
#  'the many possibilities of imessage file vulnerability',
#  'the design of littlefs: a fail-safe filesystem designed for microcontrollers',
#  "ask hn: what's the best setup for ad blocking and tracker blocking?",
#  'rabbit holes: the secret to technical expertise',
#  'show hn: i made a crm system to make sales fun',
#  'syslog: complete system administrator guide',
#  'my sudden trip to hell',
#  'why does all life use the same 20 amino acids?',
#  'toshiba introduces new tiny nvme ssd form factor',
#  'john carmack on parallel implementations (2018)',
#  'gnu radio 3.8',
#  'ask hn: how do you handle logging?',
#  'the github registry public beta is live',
#  'a practical guide to css transitions and animations',
#  'u.s. farmers stung by tariffs now face a $3.5b corn loss',
#  'facebook hit by apple’s crackdown on messaging feature',
#  'privacy sandbox – open standards to enhance privacy on the web',
#  'transformers from scratch',
#  'we made amiga, they fucked it up (2015)',
#  'memory management in python',
#  'die with me – a chat app you can only use when you have less than 5% battery',
#  'now bigger than ebay, shopify sets its sights on amazon',
#  "let's build a video card",
#  'pastel: a command-line tool to generate, analyze, convert and manipulate colors',
#  'pagemap: a mini map for your website',
#  'minify your svgs',
#  'yubico launches its dual usb-c and lightning two-factor security key',
#  'a bloomberg reporter’s account of trying to get back his name and credit rating',
#  'opioid crisis: johnson and johnson hit by landmark ruling',
#  'big pharma is using faux generics to keep drug prices high, critics say',
#  "tokyo's audiophile venues (2016)",
#  'japan surpasses china as largest foreign holder of us treasurys',
#  'statement on the purpose of a corporation',
#  'spying on https',
#  "why doesn't mathematics collapse, though humans often make mistakes in proofs?",
#  'hackers ship their exploits directly to their target’s mailroom',
#  'major book publishers sue amazon’s audible over new speech-to-text feature',
#  'hacking the sonos ikea symfonisk into a high quality speaker amp',
#  'kubernetes security assessment [pdf]',
#  '“culture fit” is a two way street (2018)',
#  'what happens when you ach a dead person?',
#  'google search takes 7 seconds on certain queries',
#  'go module mirror and checksum database launched',
#  'high levels of oestrogens in the womb linked to autism',
#  'alone in the dark',
#  'the fungus that devastates the cavendish banana has now arrived in latin america',
#  'metal shards from boeing 787 taking off over rome rain down on people below',
#  'the “terrible” 3 cent mcu – a short survey of sub $0.10 microcontrollers',
#  'the order of the json',
#  'in effect, seattle is decriminalizing the use of hard drugs',
#  'faa bans recalled apple laptops from flights',
#  'salsify – a new architecture for real-time internet video',
#  'walmart sues tesla over fires at stores fitted with its solar panels',
#  'danish bank launches negative interest rate mortgage',
#  'open-source firmware',
#  'technical vision for qt 6',
#  'show hn: yack – community browser for hacker news, reddit, youtube and more',
#  'a dream of an ultimate os (1995)',
#  'a primer on bézier curves (2013)',
#  'bontrager’s wavecel material more effective at preventing concussions than mips',
#  'the death of social reciprocity in the era of digital distraction',
#  'amazon wants to control third-party sellers’ product pricing',
#  'partiql: one query language for all your data',
#  "a bug i wish i hadn't caught",
#  'a mobile phone that respects your freedom [video]',
#  'cloud run button: click-to-deploy your git repos to gcp',
#  'my home lab server with 20 cores / 40 threads and 128 gb memory',
#  'gcc null pointer check removed',
#  "in the us, it's cheaper to build and operate wind farms than buy fossil fuels",
#  'wiringpi – deprecated',
#  'credit cards have a privacy problem',
#  'starbucks, monetary superpower',
#  'building ages in the netherlands',
#  'huawei seeks independence from the us with risc-v and ascend chips',
#  'black hat talk about ‘time ai’ causes uproar, is deleted by conference',
#  'the hypersane are among us, if only we are prepared to look',
#  'why i like clojure',
#  'cybersecurity pros name their price as hacker attacks swell',
#  'gcp to introduce an additional charge for publicly addressed vm instances',
#  'youtube shuts down music companies’ use of manual copyright claims',
#  'poetry: dependency management for python',
#  'protocols, not platforms: a technological approach to free speech',
#  'artichoke – a ruby made with rust',
#  'apollo guidance computer switching power supply works after 50 years',
#  'monads as a programming pattern',
#  'denial of h1-b visas to india’s largest it services exporters at all-time high',
#  'show hn: zero-config documentation websites for python',
#  'show hn: we track reddit, google trends, twitter, etc. to find trending topics',
#  'advice to my younger self: become allergic to the churn',
#  'show hn: sourcery – get a free, self-updating website',
#  'show hn: lunch money, a personal budgeting tool with multi-currency support',
#  'new life found that lives off electricity (2016)',
#  'cerebras systems unveils a 1.2t transistor chip for ai',
#  'software architects should be involved in earliest system engineering activities',
#  'using typescript with react',
#  'bmw unveils car sprayed with vantablack',
#  'we shouldn’t take peer review as the ‘gold standard’',
#  'launch hn: sanntek (yc s19) – breathalyzer for cannabis',
#  'the myth of consumer-grade security',
#  'nvidia ceo says google is the only customer building its own silicon at scale',
#  'racket: lisp for learning',
#  'ask hn: how to be less argumentative online?',
#  'insurance companies are paying cops to investigate their own customers',
#  'stand out as a speaker',
#  'creeping normality',
#  'nasa said to be investigating first allegation of a crime in space',
#  'germany for first time sells 30-year bonds offering negative yields',
#  'america’s elderly seem more screen-obsessed than the young',
#  'alarming surge in drug-resistant hiv uncovered',
#  'levenshtein distance',
#  'punpedia – the online encyclopedia of puns',
#  'legit-looking iphone lightning cables will hijack your computer',
#  'open startups list',
#  'the first solar road has turned out to be a disappointing failure',
#  'facial recognition: school id checks lead to gdpr fine',
#  'twitter confesses to more adtech leaks',
#  'what has to happen with unix virtual memory when you have no swap space',
#  'elon musk gambled tesla to save solarcity',
#  'how the new open-source typeface used by github and mozilla came to be',
#  'splunk acquires cloud monitoring service signalfx for $1.05b',
#  'swap, swap, swap, and bad places to work',
#  'interviews with programming language creators (2010) [pdf]',
#  'activision blizzard has moved billions of dollars of profit into tax havens',
#  'how to make billions of dollars reducing loneliness',
#  'seashells – pipe output from command-line programs to the web in real time',
#  "wework ipo shows it's the most magical unicorn",
#  'experimental usaf space plane breaks record for orbital spaceflight',
#  'what i do as a devops consultant',
#  'making containers safer',
#  'the erlang rationale',
#  'apple suspends siri response grading in response to privacy concerns',
#  'the tragedy of ucs-2',
#  'crispr pioneer among university of california researchers boycotting elsevier',
#  '‘no one saw a thing’: when a midwest town banded together to kill the town bully',
#  'what makes a good conversation?',
#  'ruffle – an adobe flash player written in rust compiled to webassembly',
#  'hedonometer',
#  'github supports web authentication (webauthn) for security keys',
#  'twelve latex packages to get your paper accepted (2017)',
#  'a manager’s guide to kubernetes adoption',
#  'typed properties in php 7.4',
#  'a readable specification of tls 1.3',
#  'who owns your wireless service? crooks do',
#  'feds ordered google location dragnet to solve wisconsin bank robbery',
#  'things to know about gnu readline',
#  'mortgage market reopens to risky borrowers',
#  'recognizing the signs of disruption in our urban habitat',
#  'acute effects of electronic cigarette aerosol inhalation on vascular function',
#  'noaa data confirms july was hottest month ever recorded',
#  'javascript: the modern parts',
#  'google warns developers that all new android apps require 3 days for approval',
#  'rust gui ecosystem overview',
#  'how does esperanto sound?',
#  'how command and conquer: tiberian sun punished the computers of the day [video]',
#  'what’s the difference between statistics and machine learning?',
#  'dropbox no longer follows symlinks to items outside of your dropbox account',
#  'climate change made european heatwave up to 3°c hotter',
#  'unison file synchronizer',
#  'michael cicconetti',
#  'opengpt-2: we replicated gpt-2 because you can too',
#  'practical tips for facelifting a tech resume',
#  'natural language processing: the age of transformers',
#  'the portuguese bank note crisis of 1925',
#  'california farmers are planting solar panels as water supplies dry up',
#  'youtube said to be fined up to $200m for children’s privacy violations',
#  'microsoft is killing epub support in edge classic',
#  'ask hn: configuration management for personal computer?',
#  'intel and rust: the future of systems programming [video]',
#  'from 30 to 230 docker containers per host',
#  'wireless carrier throttling of online video is pervasive: study',
#  'how do black holes destroy information and why is that a problem?',
#  'waypipe: gsoc project complete',
#  'launch hn: quirk (yc s19) – open-source cognitive behavioral therapy',
#  "boeing's crashes expose systemic failings",
#  'goldman sachs is spending $100m to shave milliseconds off stock trades',
#  'bad times in tech? not if you’re a startup serving other startups',
#  'why did turbo pascal apps fail with a division-by-zero on faster systems?',
#  'show hn: storytime – create stories about your code instead of documentation',
#  'one of the greatest science fiction magazines is now available online (2017)',
#  'nixery: transparently build and serve containers using nix',
#  'most internet service providers are gone – sonic has survived and thrived',
#  'where do interrupts happen?',
#  'on-disk format robustness requirements for new filesystems',
#  'giving up on julia (2016)',
#  'the ethics of web performance',
#  'keeping tesla roadsters alive is serious work',
#  'oracle directors give blessing to shareholder lawsuit against larry ellison',
#  'lf: fully decentralized fully replicated key/value store',
#  'a quarter of humanity faces looming water crises',
#  'pacvim – pacvim is a game that teaches you vim commands',
#  'why does infrastructure cost so much?',
#  'laws of showrunning (2016) [pdf]',
#  'possible detection of a black hole with a mass that was thought to be impossible',
#  'launch hn: dex (yc s19) – personal crm that reminds you to keep in touch',
#  "a buddhist monk confronts japan's suicide culture (2013)",
#  'the flawed three-cueing system for teaching reading',
#  'home 3d metal printing: first results',
#  'são paulo’s outdoor advertising ban (2016)',
#  'google forcing nest cameras’ visual indicator light to be on',
#  'the flawed reasoning behind the replication crisis',
#  'sugar: open-source software learning platform for children',
#  'open location code: an open source standard for addresses',
#  "'it's crazy': chase forgiving all debt owed by its canada credit card customers",
#  'computer science illustrated (2014)',
#  'parsing json is a minefield (2018)',
#  'i found an easter egg from 1977',
#  'the interviewer skills ladder for high growth companies',
#  'show hn: tailwind.run – an online playground for tailwind css',
#  'what to do once you admit that decentralization never seems to work (2018)',
#  'hundreds of exposed amazon cloud backups found leaking sensitive data',
#  'removing one maine dam 20 years ago changed everything',
#  'nonplanar printing',
#  "why didn't the romans contribute much to mathematics?",
#  'bulk data structures c++',
#  'exploring weight agnostic neural networks',
#  'have you ever tried to sell a diamond? (1982)',
#  'big o notation – using not-boring math to measure code’s efficiency',
#  'cisco is making it more difficult to use used hardware',
#  'how shrinkflation is playing havoc with economists’ models',
#  'rotten apple: right to repair roundup',
#  'tumblr',
#  'doordash buying caviar from square for $410m',
#  'daniel radcliffe and the art of the fact-check (2018)',
#  'svalbard is as close as you can get to a place with open borders',
#  'dyson tree',
#  'how i finally won my name from domain resellers after nine years of waiting',
#  "fbi tells lawmakers it can't access dayton gunman's phone",
#  'children of a thailand tribe who see with clarity beneath the waves (2016)',
#  'franky zapata: flyboarding frenchman crosses english channel',
#  'dignity',
#  'teen hacker finds bugs in school software that exposed millions of records',
#  'a pissed-off tutorial for google wave (2010) [video]',
#  'i took a pay cut for a more meaningful job',
#  'ibm stops buybacks to pay for red hat',
#  'parallelism in postgresql',
#  'tech backlash has come to stanford',
#  'google’s rivals opt out of search engine auction, calling it ‘anti-competitive’',
#  'peloton s-1',
#  'why a mock doesn’t work',
#  'patterns on goods designed to trigger automated license plate readers',
#  'show hn: texnique – a latex typesetting game',
#  'upmem puts cpus inside memory to allow applications to run 20 times faster',
#  'more fires now burning in angola, congo than amazon',
#  'telegram introduces feature to prevent users from texting too often in a group',
#  'somehow i became respectable',
#  'how to become a great impostor',
#  "seattle's 'microtransit' experiment drives people to light rail",
#  'basic electron framework exploitation',
#  'helsinki central library chosen as the best new public library',
#  'spacex smallsat rideshare program',
#  'personal website for programmers',
#  'startups from y combinator’s s19 demo day 1',
#  'highlights from git 2.23',
#  'show hn: youtube decade – the most-viewed videos posted 10 years ago',
#  'standard js: npm install funding',
#  'mapped: the world’s coal power plants',
#  'kept alive with tubes for nearly 17 years',
#  'lessons we learned when debugging a scaling problem',
#  'p++ idea: faq',
#  'show hn: scarf – platform to help open-source developers monetize their work',
#  'old paris is no more',
#  "spacebook: agi's near real-time satellite viewer",
#  'the path to dijkstra’s handwriting (2013)',
#  'ted chiang: realist of a larger reality',
#  'escape rooms are big business',
#  'alcohol belts of europe',
#  'dependent haskell is the future (2018)',
#  'north american versus european distribution systems (2011)',
#  "social share buttons that don't allow the social sites to track your users",
#  'nutrient deficiencies in rice grown under higher carbon dioxide',
#  'the body is the missing link for truly intelligent machines (2017)',
#  'electric motor design claims remarkable improvements',
#  'living off the land in linux',
#  'no son of mine is going to be a benthamite',
#  'extended validation certificates are really dead',
#  "the mobility trap: why we'll never fix congestion by speeding up traffic",
#  'static type checking in common lisp',
#  'interslavic language',
#  'startups from y combinator’s s19 demo day 2',
#  'announcing notqmail',
#  'why the french love to say no',
#  'theories of error back-propagation in the brain',
#  'black beekeepers are transforming detroit’s vacant lots into bee farms (2018)',
#  'gpt-2: 6-month follow-up',
#  'crossword panic of 1944',
#  'libspng – c library for reading and writing png files',
#  "kegan's theory of the evolution of consciousness",
#  'hospital checklists are meant to save lives, so why do they often fail?',
#  'understanding sat by implementing a simple sat solver in python (2014)',
#  'a deep dive into linux namespaces, part 4',
#  'chemists make first-ever ring of pure carbon',
#  'datacenter locations driven by 19th century politics',
#  'uber is biggest loser as softbank counts ipo returns',
#  'using bacteria to make self-healing cement',
#  'better encrypted group chat',
#  'exploring mathematics with matplotlib and python',
#  "moravec's paradox",
#  'vibration-minimizing motion retargeting for robotic characters',
#  'website builder webflow (yc s13) went from near bankruptcy to $72m series a',
#  'swiss post suspends drone delivery service after second crash',
#  'do-it-yourself openjdk garbage collector',
#  "patagonia's philosopher king (2016)",
#  'j can look like apl or english',
#  "julia's release process",
#  'math in data science',
#  'getting real about distributed system reliability (2012)',
#  "don't forget randomness is still just a hypothesis (2006)",
#  'history of the broken vertical bar, being the ¦ form of |',
#  'show hn: i built a “google alerts” for hacker news',
#  'tv detector van',
#  'two brothers invented an alphabet for their native language, fulfulde',
#  'where will ‘garage orphans’ charge electric cars?',
#  'how biotech startup funding will change in the next 10 years',
#  'ignition: an informal history of liquid rocket propellants (1972) [pdf]',
#  'wine-dark sea',
#  '10 years sel4: still the best, still getting better',
#  'when to shut down a startup [video]',
#  'ctvt – a contagious cancer that spreads from dog to dog',
#  'ceramics enter a new era with laser-welded joints',
#  'the shady world of repair manuals: copyrighting for planned obsolescence (2012)',
#  'open source hardware hearing aid part 1',
#  'the last working olivetti mainframe sits in a tuscan high school',
#  'in the beginning was the command line (1999) [pdf]',
#  'manufacturers want to quit china for vietnam, but find it impossible',
#  'microsoft has first major impact on chrome',
#  'casting glass from 3d printed molds',
#  'def con and stack overflow: what our traffic says about cybersecurity',
#  'geocities archive',
#  'n-shot learning: learning more with less data',
#  'who did the math for general relativity first, einstein or hilbert?',
#  'the rule of 2',
#  "an 'exosuit' that boosts endurance on the trail",
#  'subsurface – an open source scuba dive logging platform',
#  'you may be better off picking stocks at random, study finds',
#  'goals and rewards redraw the brain’s map of the world',
#  'fbi: delivery drivers involved in amazon theft ring',
#  'solar powered raspberry pi camera',
#  'mosquitoes changed everything',
#  'columnist asked researchers what they could find out from just his cell number',
#  'a commercial path to fusion',
#  'stockx was hacked, exposing millions of customers’ data',
#  'waymo’s backseat drivers: confidential data reveals self-driving taxi hurdles',
#  'moviepass reportedly changed passwords to prevent users from seeing films',
#  '“bicycle of the mind”',
#  'what germans are reading',
#  'tiny toy totp generator in 18 lines of python',
#  'a molecular near miss',
#  'supercomputers will start building a 3d map of the world',
#  'what companies are for',
#  'dwindling cpan releases',
#  'capital one cyber staff raised concerns before hack',
#  'trigger a kernel panic to diagnose unresponsive ec2 instances',
#  'launch hn: compound (yc s19) – helping employees understand equity compensation',
#  'how we manage a million push notifications an hour',
#  'inventing monads',
#  'write fuzzable code',
#  'most software companies ignore user behavior',
#  'an afternoon in tokyo with the man who designs casio g-shock watches (2017)',
#  'analyzing the facebook ads placed by the us presidential candidates',
#  'kip-500: replace zookeeper with a self-managed metadata quorum',
#  'side channel that leaked data from intel cpus patched by silent windows update',
#  'chemists discover water microdroplets spontaneously produce hydrogen peroxide',
#  'rendering on the web',
#  'free software network services and web applications which can be hosted locally',
#  'phytoplankton population drops 40 percent since 1950 (2010)',
#  "root: cern's scientific data analysis framework for c++",
#  'the subversive messages hidden in the wizard of oz',
#  'flaws in cellphone evidence prompt review of 10k verdicts in denmark',
#  'economist raj chetty has found a surprising tool to fight housing segregation',
#  'static analysis at scale: an instagram story',
#  'camera vs. lidar',
#  'how digital advertising markets really work',
#  'security flaws caused by compiler optimizations',
#  'how web content can affect power usage',
#  'music recommendations in hyperbolic space',
#  'a deep dive into amd’s rome epyc architecture',
#  '16-bit risc-v processor made with carbon nanotubes',
#  'show hn: real world (jupyter notebook embed) way to assess data scientists',
#  'launch hn: memfault (yc w19) – crashlytics for firmware',
#  'a person has died from a vaping-related condition',
#  'linux pressure stall information (psi) by example',
#  'how to write a lisp interpreter in python (2010)',
#  'processor design: an introduction (1998)',
#  'adventure in prolog tutorial (2016)',
#  'show hn: purely functional scripting',
#  'clever functional design',
#  'google begins penalising domain leasing',
#  'building a programming language pt. 3 – interpreting',
#  'sentient: classified artificial brain being developed by us intelligence',
#  'live avatars with face-api.js',
#  'india’s messy electric vehicle revolution',
#  'launch hn: lang (yc s19) – internationalization built for devs',
#  'i tried hiding from big tech in a pile of privacy gadgets',
#  'pokemonsay: pokemon version of cowsay',
#  'cowrie: a medium-interaction ssh and telnet honeypot',
#  'energy storage investments boom as battery costs halve in the next decade',
#  'effortless elixir releases and deployment',
#  "which categories of seed startups are thriving? which aren't?",
#  'hydrophilic disc uses solar power to separate salt from water',
#  'learning to prove theorems via interacting with proof assistants',
#  'dark matter developers: the unseen 99% (2012)',
#  'urgent/11 – zero day vulnerabilities impacting vxworks',
#  'huntington park’s “robocop” stores pedestrians’ faces, scans license plates',
#  'cern open data portal: explore more than 2 pb of open data from particle physics',
#  'getting started with lisp in 2019',
#  'what is null? (2010)',
#  'misinterpreting hurricane forecasts',
#  'scale (yc s16) raises $100m from accel and founders fund at $1b valuation',
#  'programming algorithms in lisp: data structures',
#  'in pentagon contract fight, amazon has foes in high places',
#  'rome is the fulcrum of amd’s datacenter pivot',
#  'how to get into farming with no money (1980)',
#  'phone companies ink deal with all 50 states and d.c. to combat robocalls',
#  'fast tensors in clojure – a sneak peek',
#  'how the great truth dawned',
#  'filekit: an open source end-to-end encrypted cloud storage service in javascript',
#  'would you accept cheaper rent in exchange for a monthly amazon purchasing quota?',
#  'duckling: a clojure library that parses text into structured data',
#  'mitre systems engineering guide (2014) [pdf]',
#  'texas power prices briefly surpass $9k amid scorching heat',
#  "amazon's plan to conquer the world of publishing",
#  'toptal sues co-founder breanden beneschott for fraud',
#  'finding amelia earhart’s plane seemed impossible – then came a startling clue',
#  "30 years ago: voyager 2's historic neptune flyby",
#  'mesapy: a memory-safe python implementation based on pypy (2018)',
#  'trails of wind: data visualization of the architecture of airport runways',
#  'show hn: shapeform – schema driven forms for react',
#  'network effects that don’t look like network effects',
#  'germany turns to hydrogen in quest for clean energy economy',
#  'if you want developers to adopt your software, make it less risky (2017)',
#  'why the u.s. army owns so many fossils',
#  'exploring dna with deep learning',
#  'how the pentagon comes up with code words and secret project nicknames',
#  'a simulated enigma machine',
#  'on building my own artificial pancreas',
#  'machine learning that’s light enough for an arduino',
#  "unshaky – tries to address double key press issue on apple's butterfly keyboard",
#  'zrna – software-defined analog circuits',
#  'simple rpc framework in 300 lines of go',
#  'a codebase is an organism (2014)',
#  "the perfect language and why go still isn't it",
#  'hundreds of people died over a millennium at “skeleton lake” in the himalayas',
#  'all tridactyl installations might get removed by firefox on aug 21',
#  'divers find remains of ancient temple in sunken egyptian city',
#  'free and open-source tools for analog filmmaking',
#  'api gateway identity crisis – are they replaced by service mesh?',
#  'i started an online subscription business from malaysia',
#  'lifehacker: tarek loubani on 3d-printing in gaza',
#  'our brains tell stories so we can live (2013)',
#  'capturing pal video with an sdr, and a few dead ends',
#  "solving differential equations on a 6502 with woz's floating point code",
#  'computer stupidities (2013)',
#  'a look back: the bloomberg keyboard (2017)',
#  'jupiter: risc-v assembler and runtime simulator',
#  '42 hours of buckminster fuller might be just the vision we need',
#  'project mu – a modular uefi environment for building modern devices',
#  'the high price of multitasking',
#  'curve fitting a: linear least squares',
#  'handler beliefs affect scent detection dog outcomes (2011)',
#  'sipeed longan nano – risc-v development board',
#  'the difference between isolation levels and consistency levels',
#  "detailed 3d map of milky way shows 'warped' shape",
#  'map design – a guide to good looking maps (2008) [pdf]',
#  'no silver bullet (1986) [pdf]',
#  'armoured commander: the wwii tank commander roguelike',
#  "how the brain 'approximates' without counting",
#  'softbank plans to lend $20b to its ceo and employees amid volatile markets',
#  'the hp way: how bill hewlett and i built our company (1960)',
#  'how to build a pyramid',
#  'how to get consistent results when benchmarking on linux?',
#  'how to teach an iris scanner that the eye it’s looking at is dead',
#  'building a vacuum tube computer',
#  'portugal’s marmelada tastes nothing like marmalade (2018)',
#  'spacy pytorch transformers',
#  'real world location virtually recreated to scale in minutes [video]',
#  'show hn: dat-keyserver: a distributed pgp keyserver based on the dat protocol',
#  '"karel čapek\'s play ""r.u.r."" premiered in january 1921"',
#  'apple card restrictions include no jailbreaking or cryptocurrency purchases',
#  'the grand c++ error explosion competition',
#  'turkmenistan on the brink of collapse?',
#  'a profile of geoffrey hinton (2018)',
#  'scientists reverse aging process in rat brain stem cells',
#  'show hn: cordless, a discord terminal client written in go',
#  '100 years ago, a telephone tower in stockholm connected 5000 phone lines (2014)',
#  'japanese architects who treated buildings like living organisms',
#  'a recent paper proposes to bring zeppelins back',
#  'j-core open processor',
#  'presidio: customizable data protection and pii data anonymization service',
#  'the survival of iggy pop',
#  'bpf port-based firewall for systemd services',
#  'marree man',
#  'the d-day rehearsal that cost 800 lives (2014)',
#  'ray tracing with ulisp',
#  'show hn: a few simple games not only for kids',
#  'why everyone hates customer service',
#  'commodore 900',
#  'qualpwn – exploiting qualcomm wlan and modem over the air',
#  'study identifies main culprit behind lithium metal battery failure',
#  'with friends like these',
#  'youtube’s lgbtq problem is a business-model problem',
#  'suburb in the sky: how jakartans built an entire village on top of a mall',
#  'circulating in china’s financial system: more than $200b in i.o.u.s',
#  "the death of alexander the great: one of history's great unsolved mysteries",
#  "the 'microworkers' making digital life possible",
#  'keyringless gnupg',
#  'the perfect french baguette',
#  'shipping wind turbines is not a breeze',
#  'iron age celtic woman was buried in a hollowed-out tree trunk',
#  'the biggest mistakes first-time founders make [video]',
#  'boeing changing max software to use two computers',
#  'empty trains on the modern silk road: when belt and road interests don’t align',
#  'wavelets (1994) [pdf]',
#  'who did the maya sacrifice?',
#  'a guide to magnetorquers for satellites',
#  'mobile nixos: the present and the future',
#  'nec shows ‘flying car’ hovering steadily for minute',
#  'quantum radar has been demonstrated for the first time',
#  'ear speakers – research, design, and evolution',
#  'wasm vs. pnacl performance benchmark',
#  'evolving lindenmayer systems',
#  'show hn: repository of open source space-related software and hardware',
#  'i love my paper dictionary (2017)',
#  'darpa wants help cracking the election security problem',
#  'the fed is getting into the real-time payments business',
#  'woman finds yellow diamond while watching youtube video on how to find diamonds',
#  'amazon will pull the plug on dash buttons',
#  'problem solving and clojure 1.9 (2018)',
#  'a new book asserts that rich countries grow with lighter environmental impacts',
#  'animal movies promote awareness, not harm, say researchers',
#  '2019 hyundai kona ev explodes when parked',
#  'the league of entropy is making randomness truly random',
#  'a transparent display with per-pixel color and opacity control',
#  'the “terrascope”: on the possibility of using the earth as an atmospheric lens',
#  'humans dominated earth earlier than previously thought',
#  'fuzzification: anti-fuzzing techniques [pdf]',
#  'what is zoned storage and the zoned storage initiative?',
#  'webmin 1.890 exploit – what happened?',
#  'scaling static analyses at facebook',
#  'the death of a weather satellite as seen by sdr',
#  'holidays are good for workers and companies alike',
#  'richard sorge: the soviet union’s master spy',
#  'debunking the stanford prison experiment [pdf]',
#  'marium, the dugong who charmed thailand, dies after ingesting plastic',
#  'simple python package to extract deep learning features',
#  'massive ‘ocean’ discovered towards earth’s core (2014)',
#  'def con 2019 – ctf retrospective',
#  'kdevops: framework for setting up and testing the linux kernel for any project',
#  'simple, pure, and total functional language that generalizes datalog',
#  'continuous 3d printing possible with transparent polygon scanning?',
#  'could removing social media metrics reduce polarization?',
#  'roaring glacial melt under the bridge to kangerlussiauq, greenland',
#  'the new treasures of pompeii',
#  'sec investigating data leak at first american financial corp',
#  'the openbsd ada library',
#  "don't say “homoiconic” (2018)",
#  'us air force pauses flights for over a hundred c-130s over ‘atypical’ cracking',
#  'i am a horse in the land of booleans',
#  'we may not be running out of helium after all (2015)',
#  'launch hn: shift health (yc s19) – understand your healthcare costs pre-visit',
#  'smartykit apple i replica',
#  'gerbil – a meta-dialect of scheme',
#  'hawaii extends thirty meter telescope permit amid protests',
#  'gm is now detroit’s smallest auto-making employer',
#  'the dipole drive: a new concept in space propulsion',
#  'universal algorithm set to boost microscopes',
#  'fearing data privacy issues, google cuts some android phone data for carriers',
#  "robotic thread is designed to slip through the brain's blood vessels",
#  'vickrey–clarke–groves auction',
#  'prolog control in six slides',
#  'opinion piece on ghc back ends',
#  'entropic: a federated package registry for anything',
#  'cbor – concise binary object representation',
#  'can we survive technology? (1955) [pdf]',
#  'cassettes are back, and it’s not about the music',
#  'paul dirac: the mozart of science (2008)',
#  'in praise of xlogo',
#  'show hn: historical order book reconstruction api for crypto markets',
#  'arcs of seniority',
#  'the long game of research',
#  "a look at hs2's old oak common station",
#  'how judy arrays work and why they are so fast (2002)',
#  'mining bitcoin on an apple ii',
#  'unearthing a masterpiece: a rare minoan sealstone (2017)',
#  'golden ratio',
#  'show hn: pgcmd – an alternative to psql with json output',
#  'reviving an hp 660lx in 2019',
#  'ssb rooms: a new server type for scuttlebutt',
#  'implementing poincaré embeddings (2017)',
#  'extending ocaml programs with lua',
#  'container networking with vxlan, bgp and wireguard',
#  'a fine map from alexander von humboldt (1851)',
#  'new research on ptsd in elephants and other animals',
#  '“awakenings” in advanced dementia patients hint at untapped brain reserves',
#  'recycling of plastics enabled by dynamic covalent diketoenamine bonds (2018) [pdf]',
#  'show hn: data-viz project for ray-tracing the moon model',
#  'five new real-time detections of fast radio bursts with utmost',
#  'lucidscience – electronic projects and tutorials',
#  'what are children dying from and what can we do about it?',
#  'a conversation with the team that made bread with ancient egyptian yeast',
#  'air force reveals tests of supposed record-setting scramjet from n. grumman',
#  'the decline of college newspapers',
#  'which is the best john le carré novel? (2014)',
#  'dreaming about better sleep: dreem, oura and the rest',
#  'penn effect',
#  'hall’s law: the nineteenth century prequel to moore’s law (2012)',
#  'volcanoes on the moon may have erupted during the dinosaur age (2014)',
#  'the world’s smartest chimp has died',
#  'smart plastic incineration posited as solution to global recycling crisis',
#  'kei – a small and expressive dependent language',
#  'freshermeat – open-source security software',
#  'engineers build advanced microprocessor out of carbon nanotubes',
#  'a new york farm stand’s success: an eye for the next big thing',
#  'disneyland’s disastrous opening day (2015)',
#  'a z-machine in ocaml (2016)',
#  "quantum air buys bye's electric airplanes",
#  'famous graphics chips: microsoft’s talisman',
#  "engineers develop bone-like metal foam that can be 'healed' at room temperature",
#  'using the golden research engine to query the y combinator s19 batch',
#  'a mosque rebuilt once a year',
#  'flying with miniature horses',
#  'the oral history of the super soaker',
#  'a trailblazing plan to fight california wildfires',
#  'show hn: firestorm – an orm for firestore',
#  'programming shape using kirigami tessellations',
#  'potosí: the mountain of silver that was the first global city',
#  'an ancient egypt-to-black sea route? adventurers to test theory',
#  'exploring the visible spectrum in python',
#  'general balanced trees (1999) [pdf]',
#  'using wall street secrets to reduce the cost of cloud infrastructure',
#  'rediscovering rules for ancient board games',
#  'on the road in 1980',
#  'the software arts',
#  'making web-workers async iterables',
#  'show hn: quark-ide and a javascript runtime to build cross-platform desktop apps',
#  'environment and the programming language self, part 4',
#  'the lost doves press typeface and its revival (2015)',
#  'early years of computer gaming: steve russell and nolan bushnell (2002) [video]',
#  'the quest to conquer earth’s space junk problem (2018)',
#  'swadesh list',
#  'salvator mundi and the unreality of the art market']

# %% [markdown]
# The following section addresses the preparation of the corpus for the application of NLP techniques.
# Each sentence in the corpus will be tokenized, follwed by the tokenization of each word in each tokenized sentence.

# %%
# Load the neccessary nltk libs before we start applying some NLP techniques
import nltk
from   nltk.corpus import stopwords
from   nltk.stem   import WordNetLemmatizer

# %%
#Tokenize the title sentences and display
def SententceTokenizer(x):
    return nltk.sent_tokenize(x)

#Perform Sentence Tokenisation
link_titles_tokenize = link_titles_lower.map(SententceTokenizer)

#Have a peak
link_titles_tokenize.collect()
# Out:
# [['turning a macbook into a touchscreen with $1 of hardware (2018)'],
#  ['the lonely work of moderating hacker news'],
#  ['introducing nushell'],
#  ['google just deleted my nearly 10-year-old free and open-source android app'],
#  ['ebola is now curable'],
#  ['all the best engineering advice i stole from non-technical people'],
#  ['i miss microsoft encarta'],
#  ["alan kay's answer to ‘what are some forgotten books programmers should read?’"],
#  ['information operations directed at hong kong'],
#  ['terminating service for 8chan'],
#  ['what happens when you launch google chrome for the first time?'],
#  ['how to build good software'],
#  ['null license plate not such a bright idea'],
#  ["what does a coder do if they can't type?"],
#  ['yelp is replacing restaurants’ phone numbers so grubhub can take a cut'],
#  ['japanese anime studio khara moving to blender'],
#  ['deconstructing google’s excuses on tracking protection'],
#  ['cloudflare s-1'],
#  ['8chan goes dark after hardware provider discontinues service'],
#  ['please add rss support to your site'],
#  ['no more cheap shipping for chinese sellers'],
#  ['python is eating the world'],
#  ['verizon to sell tumblr to automattic'],
#  ['tasty seaweed reduces cows’ methane emissions by 99%'],
#  ['hy'],
#  ['things i learnt from a senior software engineer'],
#  ['wewtf'],
#  ['linux journal ceases publication: an awkward goodbye'],
#  ['amd lands google, twitter as customers with newest server chip'],
#  ['us navy will replace touchscreen with mechanical controls on its destroyers'],
#  ['standard ebooks: free public-domain ebooks, carefully produced'],
#  ['why is modern web development so complicated?'],
#  ['a man who destroyed his multimillion dollar company in 10 seconds (2018)'],
#  ['opendrop: an open source airdrop implementation'],
#  ['a deep dive into ios exploit chains found in the wild'],
#  ['software architecture guide'],
#  ['sites using facebook ‘like’ button liable for data, eu court rules'],
#  ["insect 'apocalypse' in u.s. driven by 50x increase in toxic pesticides: study"],
#  ['apple confirms $1m reward for anyone who can hack an iphone'],
#  ['why all of our games look like crap'],
#  ['tech interview handbook'],
#  ['fewer than half of google searches now result in a click'],
#  ['ugly gerry – font created from congressional districts'],
#  ['why has examine.com disappeared from search results?'],
#  ['a walk in hong kong'],
#  ['john carmack on the joe rogan experience [video]'],
#  ['the baseline interpreter: a faster javascript interpreter in firefox 70'],
#  ['google doesn’t want staff debating politics at work anymore'],
#  ['build your own text editor'],
#  ["i've reproduced 130 research papers about “predicting the stock market”"],
#  ['ask hn: how do you read?'],
#  ['how to build a plugin system on the web and also sleep well at night'],
#  ['europe is edging towards making post-car cities a reality'],
#  ['new york city neighbors build cheaper way to connect to web'],
#  ['github actions now supports ci/cd, free for public repositories'],
#  ['consume less, create more'],
#  ['living near trees, not just green space, improves wellbeing'],
#  ['kerbal space program 2'],
#  ['macbook pro keyboard drives me crazy'],
#  ['why i turned down an aws job offer'],
#  ['facebook has been granted patent on shadow banning'],
#  ["the linux kernel's inability to gracefully handle low memory pressure"],
#  ['show hn: cli tool for saving web pages as a single file'],
#  ['start your own isp'],
#  ["every productivity thought i've ever had, as concisely as possible"],
#  ["preindustrial workers worked fewer hours than today's (2009)"],
#  ['milky way’s black hole just flared, growing 75 times as bright for a few hours'],
#  ['amazon has proven unable or unwilling to effectively police third-party sellers'],
#  ['rails 6.0'],
#  ['ha-ha wall'],
#  ['speaking to yourself in the third person makes you wiser'],
#  ['ibm open-sources power chip instruction set'],
#  ['apple expands parts access to more independent repair businesses'],
#  ['paged out – a new experimental magazine about programming'],
#  ["let's build houses for people, not cars"],
#  ['we have ruined childhood'],
#  ["decrement carbon: stripe's negative emissions commitment"],
#  ['16m americans will vote on hackable paperless machines'],
#  ['home chip fab'],
#  ['google and mozilla are failing to support browser extension developers'],
#  ["a mathematician's way of converting miles to kilometers"],
#  ['there is no evil like recaptcha'],
#  ['kaspersky av injected unique id allowing sites to track users in incognito mode'],
#  ['who owns huawei?'],
#  ['the horror of microsoft teams'],
#  ['hundreds of extreme self-citing scientists revealed in new database'],
#  ['regex for noobs – an illustrated guide'],
#  ['apple will soon treat online web tracking the same as a security vulnerability'],
#  ['the it guy vs. the con artist'],
#  ['death note: l, anonymity and eluding entropy (2017)'],
#  ['amd rome second generation epyc review: 2x 64-core benchmarked'],
#  ['amazon is a monopoly'],
#  ['time anxiety: is it too late?'],
#  ['wtf – a personal information dashboard for your terminal'],
#  ['scientists discover a cure for the deadliest strain of tuberculosis'],
#  ['show hn: divjoy – react codebase and ui generator'],
#  ['proteins that may restore damaged sound-detecting cells in the ear'],
#  ['15 states are trying to make the electoral college obselete'],
#  ['banned c standard library functions in git source code'],
#  ['pronunciations for hexadecimal numbers (1968)'],
#  ['turbo, an improved rainbow colormap for visualization'],
#  ["from mac to linux – the setup i've grown to love"],
#  ['time to get serious about tick-borne diseases'],
#  ['pentagon testing mass surveillance balloons across the us'],
#  ['useless windows 10 features'],
#  ['some obscure c features'],
#  ['mercedes-benz pre-safe sound'],
#  ['tsv utilities: command line tools for large, tabular data files'],
#  ['psytrance guide'],
#  ["researcher banned on valve's bug bounty program publishes second steam 0-day"],
#  ['why do developers at google consider agile development to be nonsense?',
#   '(2016)'],
#  ['planet: imaging the entire earth every day'],
#  ['software made me loathe my car'],
#  ['dqlite – high-availability sqlite'],
#  ['cutiepi – all-in-one raspberry pi tablet'],
#  ["knuth on huang's sensitivity proof: “i've got the proof down to one page” [pdf]"],
#  ['supercentenarians are concentrated into regions with no birth certificates'],
#  ['anthony levandowski charged with theft of trade secrets'],
#  ['exfat in the linux kernel'],
#  ['speed matters: why working quickly is more important than it seems (2015)'],
#  ['programmers: before you turn 40, get a plan b (2009)'],
#  ['information theory for intelligent people (2018) [pdf]'],
#  ['i completed ultimate go, took good notes and commented directly on source code'],
#  ['a guide to recording 660fps video on a $6 raspberry pi camera'],
#  ['super mario 64 has been decompiled'],
#  ['yaml: probably not so great after all'],
#  ['rust language cheat sheet'],
#  ['thoughts on rust bloat'],
#  ['google chrome incognito mode can still be detected'],
#  ['rules for intuitive ux'],
#  ['iterm2 3.3'],
#  ['datadog s-1'],
#  ['the not so hidden cost of sharing code between ios and android'],
#  ['show hn: chart.xkcd – xkcd-styled chart library'],
#  ['tell hn: danny cohen has died'],
#  ['down the rabbit-hole'],
#  ['three kinds of good tech debt'],
#  ['facebook scans system libraries on android and uploads them to their server'],
#  ['uber posts $5.2b loss and slowest ever growth rate'],
#  ['the fully remote attack surface of the iphone'],
#  ['google to offer a best price guarantee on certain flights'],
#  ['npm bans terminal ads'],
#  ['the architecture of open source applications'],
#  ['people love working remotely'],
#  ['berlin’s popular shopping streets will go car-free'],
#  ['toni morrison has died'],
#  ['sourcehut welcomes bitbucket refugees'],
#  ['ai startup claims to automate app making but actually just uses humans'],
#  ['ask hn: recommended resources to learn the linux kernel and os theory?'],
#  ['steam windows client local privilege escalation 0day'],
#  ['hong kong isp association’s statement on selective blocking of internet services'],
#  ['i wasn’t getting hired as a data scientist, so i sought data on who is'],
#  ['juul, philip morris sued under racketeer act for targeting kids'],
#  ['vmware acquires carbon black for $2.1b and pivotal for $2.7b'],
#  ['zen 2 missives – amd now delivering efficiencies that are double that of intel'],
#  ['write your own excel in f# (2018)'],
#  ['performance matters'],
#  ['is perl 6 being renamed?'],
#  ['people simply empty out (1986)'],
#  ['black hat: gdpr privacy law exploited to reveal personal data'],
#  ['show hn: i trained a deep learning model to build sites for me'],
#  ['webkit tracking prevention policy'],
#  ['removing coordinated inauthentic behavior from china'],
#  ['calculus for the people'],
#  ['anxiety looks different in men'],
#  ['yield curves invert in u.s., u.k'],
#  ['amazon offered ‘amazon’s choice’ to vendors who bought ads and lowered prices'],
#  ['cyberchef – cyber swiss army knife'],
#  ['rust 1.37.0'],
#  ["a boeing code leak exposes security flaws deep in a 787's guts"],
#  ['ask hn: best resources to gain math intuition?'],
#  ['mozilla takes action to protect users in kazakhstan'],
#  ['anime4k: real time high quality video upscaling'],
#  ['wine on windows 10'],
#  ['building a distributed time-series database on postgresql'],
#  ['xfce 4.14'],
#  ['most startup theory is ex-post, therefore bs'],
#  ['lessons from stripe'],
#  ['show hn: wave-based non-line-of-sight computational imaging in julia'],
#  ['‘they get fired all the time.', 'and they have no idea why’'],
#  ['9th circuit says users can sue facebook over unlawful use of facial recognition'],
#  ['linux kernel drivers in rust might become an option in the future'],
#  ['moviepass worked out great'],
#  ['a beginner’s introduction to python web frameworks (2018)'],
#  ['ask hn: who is hiring?', '(august 2019)'],
#  ['show hn: data structures and algorithms in javascript'],
#  ['await in rust'],
#  ['cool but obscure x11 tools'],
#  ['elsevier threatens others for linking to sci-hub but does so itself'],
#  ['group sex app leaks locations, pics and personal details'],
#  ['apple is locking iphone batteries to discourage repair'],
#  ['“i would like to maintain the floppy driver”'],
#  ['fracking in north america could be partly to blame for methane spike – study'],
#  ['flawed algorithms are grading millions of students’ essays'],
#  ['35 over 35'],
#  ['u.s. designates china as currency manipulator'],
#  ['sunsetting mercurial support in bitbucket'],
#  ['open letter from an android developer to the google play team'],
#  ['cue – a language for defining, generating, and validating data'],
#  ['how rust optimizes async/await'],
#  ['one city saved $5m by routing school buses with an algorithm'],
#  ['async-std: an async port of the rust standard library'],
#  ['regexr'],
#  ['the art of warez [video]'],
#  ['get your work recognized: write a brag document'],
#  ['one job, many roles: the different skills needed to be a successful cto'],
#  ['productivity and the workweek (2000)'],
#  ['nigerian teens are making sci-fi shorts with slick visual effects'],
#  ['the most frequent 777 characters give 90% coverage of kanji in the wild'],
#  ['contributing to the mozilla code base'],
#  ['the lost art of lacing cable (2018)'],
#  ['martini: real-time terrain mesh generator'],
#  ['the impact of meditating every day'],
#  ['software was eating the world – now landlords are eating everything'],
#  ['ibm has released the power architecture instruction set to the linux foundation'],
#  ["plastics: what's recyclable, what becomes trash and why"],
#  ['uber, losing billions, freezes engineering hires'],
#  ['irs budget cuts cost $34.3b in lost revenue from big business'],
#  ['calculus is deeply irrational'],
#  ['every noise at once'],
#  ['at&t employees were bribed to install phone unlocking malware on company network'],
#  ['the problem at yale is not free speech'],
#  ['silk'],
#  ['beyond meat and kfc partner to test fried plant-based ‘chicken’'],
#  ['the we company s-1'],
#  ['how to return to the flow faster'],
#  ['the paxos algorithm, or how to win a turing award'],
#  ['attorney general barr and encryption'],
#  ['making email more modern with jmap'],
#  ['ffmpeg 4.2'],
#  ['webassembly interface types: interoperate with all the things'],
#  ['roblox hits 100m monthly active users, bigger than minecraft'],
#  ['words that do handstands'],
#  ['how men’s bodies change when they become fathers'],
#  ['misconfigured jira instances exposed data of hundreds of fortune 500 companies'],
#  ['companies use borrowed billions to buy back stock, not to invest'],
#  ['ny state alleges exxonmobil knew risks of climate change and defrauded investors'],
#  ['new react devtools'],
#  ['wework gets tax rebate meant for its small-business tenants'],
#  ['administration using the full power of the surveillance state on whistleblowers'],
#  ['a book from alan turing and a mysterious piece of paper'],
#  ['how to get your first ten customers (2013)'],
#  ['does the amazon provide 20% of our oxygen?'],
#  ['uber proposes policy that would pay drivers a minimum wage of $21 per hour'],
#  ['the most dangerous writing app'],
#  ['why did china just devalue the yuan?',
#   'how trade works with free-floating currency'],
#  ['arend: theorem prover based on homotopy type theory by jetbrains'],
#  ['blazingsql is now open source'],
#  ['key negotiation of bluetooth attack'],
#  ['on-device, real-time hand tracking with mediapipe'],
#  ['dirty tricks 6502 programmers use'],
#  ['insured price $2,758, cash price $521'],
#  ['germans grow frustrated with their slow-poke internet'],
#  ['building a raspberry pi 3b+ full keyboard handheld'],
#  ['show hn: saag as a service – macronutrient-portioned indian spinach curry'],
#  ['social exclusion fuels extremism in young men'],
#  ['camscanner, a malicious android app with more than 100m downloads in google play'],
#  ["moscow's blockchain voting system cracked a month before election"],
#  ['anna karenina principle'],
#  ['qemu vm escape'],
#  ['inflated bond ratings helped spur the financial crisis.', 'they’re back'],
#  ['medieval people bathed regularly'],
#  ['devilution – a web port of the original diablo game'],
#  ['cooling a house without air conditioning'],
#  ['3.8m-year-old skull of an early ape-like human ancestor discovered in ethiopia'],
#  ['huawei technicians helped african governments spy on political opponents'],
#  ['typescript 3.6'],
#  ['the answer to “will you mentor me?” is no (2010)'],
#  ['how to measure indoor air quality with a raspberry pi, ruuvitags and pms7003'],
#  ['wework isn’t a tech company'],
#  ["why const doesn't make c code faster"],
#  ['verified by twilio'],
#  ['python vs. rust for neural networks'],
#  ['big coal plants begin to close'],
#  ['aussie isv buys ads to wake up google support'],
#  ['the feynman lectures on physics: algebra (1963)'],
#  ['coinbase: responding to firefox 0-days in the wild'],
#  ['gamedev tutorial: trigonometry basics – sine and cosine'],
#  ['secretly public domain: most books published in the us before 1964'],
#  ['show hn: clojurescript pixel game engine with blender live-reloading'],
#  ['lisp is not based on the lambda calculus'],
#  ['alphabet overtakes apple to become most cash-rich company'],
#  ['rice university researchers propose a way to boost solar efficiency'],
#  ['using backblaze b2 and cloudflare workers for free image hosting'],
#  ["the worst sales promotion in history: hoover's free flight fiasco"],
#  ['the door problem of combat design'],
#  ['wikipedia is now a brave verified publisher'],
#  ['google plans to deprecate ftp url support in chrome'],
#  ['killing a process and all of its descendants'],
#  ['show hn: i created postwoman, an online, open-source api request builder'],
#  ['the many possibilities of imessage file vulnerability'],
#  ['the design of littlefs: a fail-safe filesystem designed for microcontrollers'],
#  ["ask hn: what's the best setup for ad blocking and tracker blocking?"],
#  ['rabbit holes: the secret to technical expertise'],
#  ['show hn: i made a crm system to make sales fun'],
#  ['syslog: complete system administrator guide'],
#  ['my sudden trip to hell'],
#  ['why does all life use the same 20 amino acids?'],
#  ['toshiba introduces new tiny nvme ssd form factor'],
#  ['john carmack on parallel implementations (2018)'],
#  ['gnu radio 3.8'],
#  ['ask hn: how do you handle logging?'],
#  ['the github registry public beta is live'],
#  ['a practical guide to css transitions and animations'],
#  ['u.s. farmers stung by tariffs now face a $3.5b corn loss'],
#  ['facebook hit by apple’s crackdown on messaging feature'],
#  ['privacy sandbox – open standards to enhance privacy on the web'],
#  ['transformers from scratch'],
#  ['we made amiga, they fucked it up (2015)'],
#  ['memory management in python'],
#  ['die with me – a chat app you can only use when you have less than 5% battery'],
#  ['now bigger than ebay, shopify sets its sights on amazon'],
#  ["let's build a video card"],
#  ['pastel: a command-line tool to generate, analyze, convert and manipulate colors'],
#  ['pagemap: a mini map for your website'],
#  ['minify your svgs'],
#  ['yubico launches its dual usb-c and lightning two-factor security key'],
#  ['a bloomberg reporter’s account of trying to get back his name and credit rating'],
#  ['opioid crisis: johnson and johnson hit by landmark ruling'],
#  ['big pharma is using faux generics to keep drug prices high, critics say'],
#  ["tokyo's audiophile venues (2016)"],
#  ['japan surpasses china as largest foreign holder of us treasurys'],
#  ['statement on the purpose of a corporation'],
#  ['spying on https'],
#  ["why doesn't mathematics collapse, though humans often make mistakes in proofs?"],
#  ['hackers ship their exploits directly to their target’s mailroom'],
#  ['major book publishers sue amazon’s audible over new speech-to-text feature'],
#  ['hacking the sonos ikea symfonisk into a high quality speaker amp'],
#  ['kubernetes security assessment [pdf]'],
#  ['“culture fit” is a two way street (2018)'],
#  ['what happens when you ach a dead person?'],
#  ['google search takes 7 seconds on certain queries'],
#  ['go module mirror and checksum database launched'],
#  ['high levels of oestrogens in the womb linked to autism'],
#  ['alone in the dark'],
#  ['the fungus that devastates the cavendish banana has now arrived in latin america'],
#  ['metal shards from boeing 787 taking off over rome rain down on people below'],
#  ['the “terrible” 3 cent mcu – a short survey of sub $0.10 microcontrollers'],
#  ['the order of the json'],
#  ['in effect, seattle is decriminalizing the use of hard drugs'],
#  ['faa bans recalled apple laptops from flights'],
#  ['salsify – a new architecture for real-time internet video'],
#  ['walmart sues tesla over fires at stores fitted with its solar panels'],
#  ['danish bank launches negative interest rate mortgage'],
#  ['open-source firmware'],
#  ['technical vision for qt 6'],
#  ['show hn: yack – community browser for hacker news, reddit, youtube and more'],
#  ['a dream of an ultimate os (1995)'],
#  ['a primer on bézier curves (2013)'],
#  ['bontrager’s wavecel material more effective at preventing concussions than mips'],
#  ['the death of social reciprocity in the era of digital distraction'],
#  ['amazon wants to control third-party sellers’ product pricing'],
#  ['partiql: one query language for all your data'],
#  ["a bug i wish i hadn't caught"],
#  ['a mobile phone that respects your freedom [video]'],
#  ['cloud run button: click-to-deploy your git repos to gcp'],
#  ['my home lab server with 20 cores / 40 threads and 128 gb memory'],
#  ['gcc null pointer check removed'],
#  ["in the us, it's cheaper to build and operate wind farms than buy fossil fuels"],
#  ['wiringpi – deprecated'],
#  ['credit cards have a privacy problem'],
#  ['starbucks, monetary superpower'],
#  ['building ages in the netherlands'],
#  ['huawei seeks independence from the us with risc-v and ascend chips'],
#  ['black hat talk about ‘time ai’ causes uproar, is deleted by conference'],
#  ['the hypersane are among us, if only we are prepared to look'],
#  ['why i like clojure'],
#  ['cybersecurity pros name their price as hacker attacks swell'],
#  ['gcp to introduce an additional charge for publicly addressed vm instances'],
#  ['youtube shuts down music companies’ use of manual copyright claims'],
#  ['poetry: dependency management for python'],
#  ['protocols, not platforms: a technological approach to free speech'],
#  ['artichoke – a ruby made with rust'],
#  ['apollo guidance computer switching power supply works after 50 years'],
#  ['monads as a programming pattern'],
#  ['denial of h1-b visas to india’s largest it services exporters at all-time high'],
#  ['show hn: zero-config documentation websites for python'],
#  ['show hn: we track reddit, google trends, twitter, etc.',
#   'to find trending topics'],
#  ['advice to my younger self: become allergic to the churn'],
#  ['show hn: sourcery – get a free, self-updating website'],
#  ['show hn: lunch money, a personal budgeting tool with multi-currency support'],
#  ['new life found that lives off electricity (2016)'],
#  ['cerebras systems unveils a 1.2t transistor chip for ai'],
#  ['software architects should be involved in earliest system engineering activities'],
#  ['using typescript with react'],
#  ['bmw unveils car sprayed with vantablack'],
#  ['we shouldn’t take peer review as the ‘gold standard’'],
#  ['launch hn: sanntek (yc s19) – breathalyzer for cannabis'],
#  ['the myth of consumer-grade security'],
#  ['nvidia ceo says google is the only customer building its own silicon at scale'],
#  ['racket: lisp for learning'],
#  ['ask hn: how to be less argumentative online?'],
#  ['insurance companies are paying cops to investigate their own customers'],
#  ['stand out as a speaker'],
#  ['creeping normality'],
#  ['nasa said to be investigating first allegation of a crime in space'],
#  ['germany for first time sells 30-year bonds offering negative yields'],
#  ['america’s elderly seem more screen-obsessed than the young'],
#  ['alarming surge in drug-resistant hiv uncovered'],
#  ['levenshtein distance'],
#  ['punpedia – the online encyclopedia of puns'],
#  ['legit-looking iphone lightning cables will hijack your computer'],
#  ['open startups list'],
#  ['the first solar road has turned out to be a disappointing failure'],
#  ['facial recognition: school id checks lead to gdpr fine'],
#  ['twitter confesses to more adtech leaks'],
#  ['what has to happen with unix virtual memory when you have no swap space'],
#  ['elon musk gambled tesla to save solarcity'],
#  ['how the new open-source typeface used by github and mozilla came to be'],
#  ['splunk acquires cloud monitoring service signalfx for $1.05b'],
#  ['swap, swap, swap, and bad places to work'],
#  ['interviews with programming language creators (2010) [pdf]'],
#  ['activision blizzard has moved billions of dollars of profit into tax havens'],
#  ['how to make billions of dollars reducing loneliness'],
#  ['seashells – pipe output from command-line programs to the web in real time'],
#  ["wework ipo shows it's the most magical unicorn"],
#  ['experimental usaf space plane breaks record for orbital spaceflight'],
#  ['what i do as a devops consultant'],
#  ['making containers safer'],
#  ['the erlang rationale'],
#  ['apple suspends siri response grading in response to privacy concerns'],
#  ['the tragedy of ucs-2'],
#  ['crispr pioneer among university of california researchers boycotting elsevier'],
#  ['‘no one saw a thing’: when a midwest town banded together to kill the town bully'],
#  ['what makes a good conversation?'],
#  ['ruffle – an adobe flash player written in rust compiled to webassembly'],
#  ['hedonometer'],
#  ['github supports web authentication (webauthn) for security keys'],
#  ['twelve latex packages to get your paper accepted (2017)'],
#  ['a manager’s guide to kubernetes adoption'],
#  ['typed properties in php 7.4'],
#  ['a readable specification of tls 1.3'],
#  ['who owns your wireless service?', 'crooks do'],
#  ['feds ordered google location dragnet to solve wisconsin bank robbery'],
#  ['things to know about gnu readline'],
#  ['mortgage market reopens to risky borrowers'],
#  ['recognizing the signs of disruption in our urban habitat'],
#  ['acute effects of electronic cigarette aerosol inhalation on vascular function'],
#  ['noaa data confirms july was hottest month ever recorded'],
#  ['javascript: the modern parts'],
#  ['google warns developers that all new android apps require 3 days for approval'],
#  ['rust gui ecosystem overview'],
#  ['how does esperanto sound?'],
#  ['how command and conquer: tiberian sun punished the computers of the day [video]'],
#  ['what’s the difference between statistics and machine learning?'],
#  ['dropbox no longer follows symlinks to items outside of your dropbox account'],
#  ['climate change made european heatwave up to 3°c hotter'],
#  ['unison file synchronizer'],
#  ['michael cicconetti'],
#  ['opengpt-2: we replicated gpt-2 because you can too'],
#  ['practical tips for facelifting a tech resume'],
#  ['natural language processing: the age of transformers'],
#  ['the portuguese bank note crisis of 1925'],
#  ['california farmers are planting solar panels as water supplies dry up'],
#  ['youtube said to be fined up to $200m for children’s privacy violations'],
#  ['microsoft is killing epub support in edge classic'],
#  ['ask hn: configuration management for personal computer?'],
#  ['intel and rust: the future of systems programming [video]'],
#  ['from 30 to 230 docker containers per host'],
#  ['wireless carrier throttling of online video is pervasive: study'],
#  ['how do black holes destroy information and why is that a problem?'],
#  ['waypipe: gsoc project complete'],
#  ['launch hn: quirk (yc s19) – open-source cognitive behavioral therapy'],
#  ["boeing's crashes expose systemic failings"],
#  ['goldman sachs is spending $100m to shave milliseconds off stock trades'],
#  ['bad times in tech?', 'not if you’re a startup serving other startups'],
#  ['why did turbo pascal apps fail with a division-by-zero on faster systems?'],
#  ['show hn: storytime – create stories about your code instead of documentation'],
#  ['one of the greatest science fiction magazines is now available online (2017)'],
#  ['nixery: transparently build and serve containers using nix'],
#  ['most internet service providers are gone – sonic has survived and thrived'],
#  ['where do interrupts happen?'],
#  ['on-disk format robustness requirements for new filesystems'],
#  ['giving up on julia (2016)'],
#  ['the ethics of web performance'],
#  ['keeping tesla roadsters alive is serious work'],
#  ['oracle directors give blessing to shareholder lawsuit against larry ellison'],
#  ['lf: fully decentralized fully replicated key/value store'],
#  ['a quarter of humanity faces looming water crises'],
#  ['pacvim – pacvim is a game that teaches you vim commands'],
#  ['why does infrastructure cost so much?'],
#  ['laws of showrunning (2016) [pdf]'],
#  ['possible detection of a black hole with a mass that was thought to be impossible'],
#  ['launch hn: dex (yc s19) – personal crm that reminds you to keep in touch'],
#  ["a buddhist monk confronts japan's suicide culture (2013)"],
#  ['the flawed three-cueing system for teaching reading'],
#  ['home 3d metal printing: first results'],
#  ['são paulo’s outdoor advertising ban (2016)'],
#  ['google forcing nest cameras’ visual indicator light to be on'],
#  ['the flawed reasoning behind the replication crisis'],
#  ['sugar: open-source software learning platform for children'],
#  ['open location code: an open source standard for addresses'],
#  ["'it's crazy': chase forgiving all debt owed by its canada credit card customers"],
#  ['computer science illustrated (2014)'],
#  ['parsing json is a minefield (2018)'],
#  ['i found an easter egg from 1977'],
#  ['the interviewer skills ladder for high growth companies'],
#  ['show hn: tailwind.run – an online playground for tailwind css'],
#  ['what to do once you admit that decentralization never seems to work (2018)'],
#  ['hundreds of exposed amazon cloud backups found leaking sensitive data'],
#  ['removing one maine dam 20 years ago changed everything'],
#  ['nonplanar printing'],
#  ["why didn't the romans contribute much to mathematics?"],
#  ['bulk data structures c++'],
#  ['exploring weight agnostic neural networks'],
#  ['have you ever tried to sell a diamond?', '(1982)'],
#  ['big o notation – using not-boring math to measure code’s efficiency'],
#  ['cisco is making it more difficult to use used hardware'],
#  ['how shrinkflation is playing havoc with economists’ models'],
#  ['rotten apple: right to repair roundup'],
#  ['tumblr'],
#  ['doordash buying caviar from square for $410m'],
#  ['daniel radcliffe and the art of the fact-check (2018)'],
#  ['svalbard is as close as you can get to a place with open borders'],
#  ['dyson tree'],
#  ['how i finally won my name from domain resellers after nine years of waiting'],
#  ["fbi tells lawmakers it can't access dayton gunman's phone"],
#  ['children of a thailand tribe who see with clarity beneath the waves (2016)'],
#  ['franky zapata: flyboarding frenchman crosses english channel'],
#  ['dignity'],
#  ['teen hacker finds bugs in school software that exposed millions of records'],
#  ['a pissed-off tutorial for google wave (2010) [video]'],
#  ['i took a pay cut for a more meaningful job'],
#  ['ibm stops buybacks to pay for red hat'],
#  ['parallelism in postgresql'],
#  ['tech backlash has come to stanford'],
#  ['google’s rivals opt out of search engine auction, calling it ‘anti-competitive’'],
#  ['peloton s-1'],
#  ['why a mock doesn’t work'],
#  ['patterns on goods designed to trigger automated license plate readers'],
#  ['show hn: texnique – a latex typesetting game'],
#  ['upmem puts cpus inside memory to allow applications to run 20 times faster'],
#  ['more fires now burning in angola, congo than amazon'],
#  ['telegram introduces feature to prevent users from texting too often in a group'],
#  ['somehow i became respectable'],
#  ['how to become a great impostor'],
#  ["seattle's 'microtransit' experiment drives people to light rail"],
#  ['basic electron framework exploitation'],
#  ['helsinki central library chosen as the best new public library'],
#  ['spacex smallsat rideshare program'],
#  ['personal website for programmers'],
#  ['startups from y combinator’s s19 demo day 1'],
#  ['highlights from git 2.23'],
#  ['show hn: youtube decade – the most-viewed videos posted 10 years ago'],
#  ['standard js: npm install funding'],
#  ['mapped: the world’s coal power plants'],
#  ['kept alive with tubes for nearly 17 years'],
#  ['lessons we learned when debugging a scaling problem'],
#  ['p++ idea: faq'],
#  ['show hn: scarf – platform to help open-source developers monetize their work'],
#  ['old paris is no more'],
#  ["spacebook: agi's near real-time satellite viewer"],
#  ['the path to dijkstra’s handwriting (2013)'],
#  ['ted chiang: realist of a larger reality'],
#  ['escape rooms are big business'],
#  ['alcohol belts of europe'],
#  ['dependent haskell is the future (2018)'],
#  ['north american versus european distribution systems (2011)'],
#  ["social share buttons that don't allow the social sites to track your users"],
#  ['nutrient deficiencies in rice grown under higher carbon dioxide'],
#  ['the body is the missing link for truly intelligent machines (2017)'],
#  ['electric motor design claims remarkable improvements'],
#  ['living off the land in linux'],
#  ['no son of mine is going to be a benthamite'],
#  ['extended validation certificates are really dead'],
#  ["the mobility trap: why we'll never fix congestion by speeding up traffic"],
#  ['static type checking in common lisp'],
#  ['interslavic language'],
#  ['startups from y combinator’s s19 demo day 2'],
#  ['announcing notqmail'],
#  ['why the french love to say no'],
#  ['theories of error back-propagation in the brain'],
#  ['black beekeepers are transforming detroit’s vacant lots into bee farms (2018)'],
#  ['gpt-2: 6-month follow-up'],
#  ['crossword panic of 1944'],
#  ['libspng – c library for reading and writing png files'],
#  ["kegan's theory of the evolution of consciousness"],
#  ['hospital checklists are meant to save lives, so why do they often fail?'],
#  ['understanding sat by implementing a simple sat solver in python (2014)'],
#  ['a deep dive into linux namespaces, part 4'],
#  ['chemists make first-ever ring of pure carbon'],
#  ['datacenter locations driven by 19th century politics'],
#  ['uber is biggest loser as softbank counts ipo returns'],
#  ['using bacteria to make self-healing cement'],
#  ['better encrypted group chat'],
#  ['exploring mathematics with matplotlib and python'],
#  ["moravec's paradox"],
#  ['vibration-minimizing motion retargeting for robotic characters'],
#  ['website builder webflow (yc s13) went from near bankruptcy to $72m series a'],
#  ['swiss post suspends drone delivery service after second crash'],
#  ['do-it-yourself openjdk garbage collector'],
#  ["patagonia's philosopher king (2016)"],
#  ['j can look like apl or english'],
#  ["julia's release process"],
#  ['math in data science'],
#  ['getting real about distributed system reliability (2012)'],
#  ["don't forget randomness is still just a hypothesis (2006)"],
#  ['history of the broken vertical bar, being the ¦ form of |'],
#  ['show hn: i built a “google alerts” for hacker news'],
#  ['tv detector van'],
#  ['two brothers invented an alphabet for their native language, fulfulde'],
#  ['where will ‘garage orphans’ charge electric cars?'],
#  ['how biotech startup funding will change in the next 10 years'],
#  ['ignition: an informal history of liquid rocket propellants (1972) [pdf]'],
#  ['wine-dark sea'],
#  ['10 years sel4: still the best, still getting better'],
#  ['when to shut down a startup [video]'],
#  ['ctvt – a contagious cancer that spreads from dog to dog'],
#  ['ceramics enter a new era with laser-welded joints'],
#  ['the shady world of repair manuals: copyrighting for planned obsolescence (2012)'],
#  ['open source hardware hearing aid part 1'],
#  ['the last working olivetti mainframe sits in a tuscan high school'],
#  ['in the beginning was the command line (1999) [pdf]'],
#  ['manufacturers want to quit china for vietnam, but find it impossible'],
#  ['microsoft has first major impact on chrome'],
#  ['casting glass from 3d printed molds'],
#  ['def con and stack overflow: what our traffic says about cybersecurity'],
#  ['geocities archive'],
#  ['n-shot learning: learning more with less data'],
#  ['who did the math for general relativity first, einstein or hilbert?'],
#  ['the rule of 2'],
#  ["an 'exosuit' that boosts endurance on the trail"],
#  ['subsurface – an open source scuba dive logging platform'],
#  ['you may be better off picking stocks at random, study finds'],
#  ['goals and rewards redraw the brain’s map of the world'],
#  ['fbi: delivery drivers involved in amazon theft ring'],
#  ['solar powered raspberry pi camera'],
#  ['mosquitoes changed everything'],
#  ['columnist asked researchers what they could find out from just his cell number'],
#  ['a commercial path to fusion'],
#  ['stockx was hacked, exposing millions of customers’ data'],
#  ['waymo’s backseat drivers: confidential data reveals self-driving taxi hurdles'],
#  ['moviepass reportedly changed passwords to prevent users from seeing films'],
#  ['“bicycle of the mind”'],
#  ['what germans are reading'],
#  ['tiny toy totp generator in 18 lines of python'],
#  ['a molecular near miss'],
#  ['supercomputers will start building a 3d map of the world'],
#  ['what companies are for'],
#  ['dwindling cpan releases'],
#  ['capital one cyber staff raised concerns before hack'],
#  ['trigger a kernel panic to diagnose unresponsive ec2 instances'],
#  ['launch hn: compound (yc s19) – helping employees understand equity compensation'],
#  ['how we manage a million push notifications an hour'],
#  ['inventing monads'],
#  ['write fuzzable code'],
#  ['most software companies ignore user behavior'],
#  ['an afternoon in tokyo with the man who designs casio g-shock watches (2017)'],
#  ['analyzing the facebook ads placed by the us presidential candidates'],
#  ['kip-500: replace zookeeper with a self-managed metadata quorum'],
#  ['side channel that leaked data from intel cpus patched by silent windows update'],
#  ['chemists discover water microdroplets spontaneously produce hydrogen peroxide'],
#  ['rendering on the web'],
#  ['free software network services and web applications which can be hosted locally'],
#  ['phytoplankton population drops 40 percent since 1950 (2010)'],
#  ["root: cern's scientific data analysis framework for c++"],
#  ['the subversive messages hidden in the wizard of oz'],
#  ['flaws in cellphone evidence prompt review of 10k verdicts in denmark'],
#  ['economist raj chetty has found a surprising tool to fight housing segregation'],
#  ['static analysis at scale: an instagram story'],
#  ['camera vs. lidar'],
#  ['how digital advertising markets really work'],
#  ['security flaws caused by compiler optimizations'],
#  ['how web content can affect power usage'],
#  ['music recommendations in hyperbolic space'],
#  ['a deep dive into amd’s rome epyc architecture'],
#  ['16-bit risc-v processor made with carbon nanotubes'],
#  ['show hn: real world (jupyter notebook embed) way to assess data scientists'],
#  ['launch hn: memfault (yc w19) – crashlytics for firmware'],
#  ['a person has died from a vaping-related condition'],
#  ['linux pressure stall information (psi) by example'],
#  ['how to write a lisp interpreter in python (2010)'],
#  ['processor design: an introduction (1998)'],
#  ['adventure in prolog tutorial (2016)'],
#  ['show hn: purely functional scripting'],
#  ['clever functional design'],
#  ['google begins penalising domain leasing'],
#  ['building a programming language pt.', '3 – interpreting'],
#  ['sentient: classified artificial brain being developed by us intelligence'],
#  ['live avatars with face-api.js'],
#  ['india’s messy electric vehicle revolution'],
#  ['launch hn: lang (yc s19) – internationalization built for devs'],
#  ['i tried hiding from big tech in a pile of privacy gadgets'],
#  ['pokemonsay: pokemon version of cowsay'],
#  ['cowrie: a medium-interaction ssh and telnet honeypot'],
#  ['energy storage investments boom as battery costs halve in the next decade'],
#  ['effortless elixir releases and deployment'],
#  ['which categories of seed startups are thriving?', "which aren't?"],
#  ['hydrophilic disc uses solar power to separate salt from water'],
#  ['learning to prove theorems via interacting with proof assistants'],
#  ['dark matter developers: the unseen 99% (2012)'],
#  ['urgent/11 – zero day vulnerabilities impacting vxworks'],
#  ['huntington park’s “robocop” stores pedestrians’ faces, scans license plates'],
#  ['cern open data portal: explore more than 2 pb of open data from particle physics'],
#  ['getting started with lisp in 2019'],
#  ['what is null?', '(2010)'],
#  ['misinterpreting hurricane forecasts'],
#  ['scale (yc s16) raises $100m from accel and founders fund at $1b valuation'],
#  ['programming algorithms in lisp: data structures'],
#  ['in pentagon contract fight, amazon has foes in high places'],
#  ['rome is the fulcrum of amd’s datacenter pivot'],
#  ['how to get into farming with no money (1980)'],
#  ['phone companies ink deal with all 50 states and d.c. to combat robocalls'],
#  ['fast tensors in clojure – a sneak peek'],
#  ['how the great truth dawned'],
#  ['filekit: an open source end-to-end encrypted cloud storage service in javascript'],
#  ['would you accept cheaper rent in exchange for a monthly amazon purchasing quota?'],
#  ['duckling: a clojure library that parses text into structured data'],
#  ['mitre systems engineering guide (2014) [pdf]'],
#  ['texas power prices briefly surpass $9k amid scorching heat'],
#  ["amazon's plan to conquer the world of publishing"],
#  ['toptal sues co-founder breanden beneschott for fraud'],
#  ['finding amelia earhart’s plane seemed impossible – then came a startling clue'],
#  ["30 years ago: voyager 2's historic neptune flyby"],
#  ['mesapy: a memory-safe python implementation based on pypy (2018)'],
#  ['trails of wind: data visualization of the architecture of airport runways'],
#  ['show hn: shapeform – schema driven forms for react'],
#  ['network effects that don’t look like network effects'],
#  ['germany turns to hydrogen in quest for clean energy economy'],
#  ['if you want developers to adopt your software, make it less risky (2017)'],
#  ['why the u.s. army owns so many fossils'],
#  ['exploring dna with deep learning'],
#  ['how the pentagon comes up with code words and secret project nicknames'],
#  ['a simulated enigma machine'],
#  ['on building my own artificial pancreas'],
#  ['machine learning that’s light enough for an arduino'],
#  ["unshaky – tries to address double key press issue on apple's butterfly keyboard"],
#  ['zrna – software-defined analog circuits'],
#  ['simple rpc framework in 300 lines of go'],
#  ['a codebase is an organism (2014)'],
#  ["the perfect language and why go still isn't it"],
#  ['hundreds of people died over a millennium at “skeleton lake” in the himalayas'],
#  ['all tridactyl installations might get removed by firefox on aug 21'],
#  ['divers find remains of ancient temple in sunken egyptian city'],
#  ['free and open-source tools for analog filmmaking'],
#  ['api gateway identity crisis – are they replaced by service mesh?'],
#  ['i started an online subscription business from malaysia'],
#  ['lifehacker: tarek loubani on 3d-printing in gaza'],
#  ['our brains tell stories so we can live (2013)'],
#  ['capturing pal video with an sdr, and a few dead ends'],
#  ["solving differential equations on a 6502 with woz's floating point code"],
#  ['computer stupidities (2013)'],
#  ['a look back: the bloomberg keyboard (2017)'],
#  ['jupiter: risc-v assembler and runtime simulator'],
#  ['42 hours of buckminster fuller might be just the vision we need'],
#  ['project mu – a modular uefi environment for building modern devices'],
#  ['the high price of multitasking'],
#  ['curve fitting a: linear least squares'],
#  ['handler beliefs affect scent detection dog outcomes (2011)'],
#  ['sipeed longan nano – risc-v development board'],
#  ['the difference between isolation levels and consistency levels'],
#  ["detailed 3d map of milky way shows 'warped' shape"],
#  ['map design – a guide to good looking maps (2008) [pdf]'],
#  ['no silver bullet (1986) [pdf]'],
#  ['armoured commander: the wwii tank commander roguelike'],
#  ["how the brain 'approximates' without counting"],
#  ['softbank plans to lend $20b to its ceo and employees amid volatile markets'],
#  ['the hp way: how bill hewlett and i built our company (1960)'],
#  ['how to build a pyramid'],
#  ['how to get consistent results when benchmarking on linux?'],
#  ['how to teach an iris scanner that the eye it’s looking at is dead'],
#  ['building a vacuum tube computer'],
#  ['portugal’s marmelada tastes nothing like marmalade (2018)'],
#  ['spacy pytorch transformers'],
#  ['real world location virtually recreated to scale in minutes [video]'],
#  ['show hn: dat-keyserver: a distributed pgp keyserver based on the dat protocol'],
#  ['"karel čapek\'s play ""r.u.r.""', 'premiered in january 1921"'],
#  ['apple card restrictions include no jailbreaking or cryptocurrency purchases'],
#  ['the grand c++ error explosion competition'],
#  ['turkmenistan on the brink of collapse?'],
#  ['a profile of geoffrey hinton (2018)'],
#  ['scientists reverse aging process in rat brain stem cells'],
#  ['show hn: cordless, a discord terminal client written in go'],
#  ['100 years ago, a telephone tower in stockholm connected 5000 phone lines (2014)'],
#  ['japanese architects who treated buildings like living organisms'],
#  ['a recent paper proposes to bring zeppelins back'],
#  ['j-core open processor'],
#  ['presidio: customizable data protection and pii data anonymization service'],
#  ['the survival of iggy pop'],
#  ['bpf port-based firewall for systemd services'],
#  ['marree man'],
#  ['the d-day rehearsal that cost 800 lives (2014)'],
#  ['ray tracing with ulisp'],
#  ['show hn: a few simple games not only for kids'],
#  ['why everyone hates customer service'],
#  ['commodore 900'],
#  ['qualpwn – exploiting qualcomm wlan and modem over the air'],
#  ['study identifies main culprit behind lithium metal battery failure'],
#  ['with friends like these'],
#  ['youtube’s lgbtq problem is a business-model problem'],
#  ['suburb in the sky: how jakartans built an entire village on top of a mall'],
#  ['circulating in china’s financial system: more than $200b in i.o.u.s'],
#  ["the death of alexander the great: one of history's great unsolved mysteries"],
#  ["the 'microworkers' making digital life possible"],
#  ['keyringless gnupg'],
#  ['the perfect french baguette'],
#  ['shipping wind turbines is not a breeze'],
#  ['iron age celtic woman was buried in a hollowed-out tree trunk'],
#  ['the biggest mistakes first-time founders make [video]'],
#  ['boeing changing max software to use two computers'],
#  ['empty trains on the modern silk road: when belt and road interests don’t align'],
#  ['wavelets (1994) [pdf]'],
#  ['who did the maya sacrifice?'],
#  ['a guide to magnetorquers for satellites'],
#  ['mobile nixos: the present and the future'],
#  ['nec shows ‘flying car’ hovering steadily for minute'],
#  ['quantum radar has been demonstrated for the first time'],
#  ['ear speakers – research, design, and evolution'],
#  ['wasm vs. pnacl performance benchmark'],
#  ['evolving lindenmayer systems'],
#  ['show hn: repository of open source space-related software and hardware'],
#  ['i love my paper dictionary (2017)'],
#  ['darpa wants help cracking the election security problem'],
#  ['the fed is getting into the real-time payments business'],
#  ['woman finds yellow diamond while watching youtube video on how to find diamonds'],
#  ['amazon will pull the plug on dash buttons'],
#  ['problem solving and clojure 1.9 (2018)'],
#  ['a new book asserts that rich countries grow with lighter environmental impacts'],
#  ['animal movies promote awareness, not harm, say researchers'],
#  ['2019 hyundai kona ev explodes when parked'],
#  ['the league of entropy is making randomness truly random'],
#  ['a transparent display with per-pixel color and opacity control'],
#  ['the “terrascope”: on the possibility of using the earth as an atmospheric lens'],
#  ['humans dominated earth earlier than previously thought'],
#  ['fuzzification: anti-fuzzing techniques [pdf]'],
#  ['what is zoned storage and the zoned storage initiative?'],
#  ['webmin 1.890 exploit – what happened?'],
#  ['scaling static analyses at facebook'],
#  ['the death of a weather satellite as seen by sdr'],
#  ['holidays are good for workers and companies alike'],
#  ['richard sorge: the soviet union’s master spy'],
#  ['debunking the stanford prison experiment [pdf]'],
#  ['marium, the dugong who charmed thailand, dies after ingesting plastic'],
#  ['simple python package to extract deep learning features'],
#  ['massive ‘ocean’ discovered towards earth’s core (2014)'],
#  ['def con 2019 – ctf retrospective'],
#  ['kdevops: framework for setting up and testing the linux kernel for any project'],
#  ['simple, pure, and total functional language that generalizes datalog'],
#  ['continuous 3d printing possible with transparent polygon scanning?'],
#  ['could removing social media metrics reduce polarization?'],
#  ['roaring glacial melt under the bridge to kangerlussiauq, greenland'],
#  ['the new treasures of pompeii'],
#  ['sec investigating data leak at first american financial corp'],
#  ['the openbsd ada library'],
#  ["don't say “homoiconic” (2018)"],
#  ['us air force pauses flights for over a hundred c-130s over ‘atypical’ cracking'],
#  ['i am a horse in the land of booleans'],
#  ['we may not be running out of helium after all (2015)'],
#  ['launch hn: shift health (yc s19) – understand your healthcare costs pre-visit'],
#  ['smartykit apple i replica'],
#  ['gerbil – a meta-dialect of scheme'],
#  ['hawaii extends thirty meter telescope permit amid protests'],
#  ['gm is now detroit’s smallest auto-making employer'],
#  ['the dipole drive: a new concept in space propulsion'],
#  ['universal algorithm set to boost microscopes'],
#  ['fearing data privacy issues, google cuts some android phone data for carriers'],
#  ["robotic thread is designed to slip through the brain's blood vessels"],
#  ['vickrey–clarke–groves auction'],
#  ['prolog control in six slides'],
#  ['opinion piece on ghc back ends'],
#  ['entropic: a federated package registry for anything'],
#  ['cbor – concise binary object representation'],
#  ['can we survive technology?', '(1955) [pdf]'],
#  ['cassettes are back, and it’s not about the music'],
#  ['paul dirac: the mozart of science (2008)'],
#  ['in praise of xlogo'],
#  ['show hn: historical order book reconstruction api for crypto markets'],
#  ['arcs of seniority'],
#  ['the long game of research'],
#  ["a look at hs2's old oak common station"],
#  ['how judy arrays work and why they are so fast (2002)'],
#  ['mining bitcoin on an apple ii'],
#  ['unearthing a masterpiece: a rare minoan sealstone (2017)'],
#  ['golden ratio'],
#  ['show hn: pgcmd – an alternative to psql with json output'],
#  ['reviving an hp 660lx in 2019'],
#  ['ssb rooms: a new server type for scuttlebutt'],
#  ['implementing poincaré embeddings (2017)'],
#  ['extending ocaml programs with lua'],
#  ['container networking with vxlan, bgp and wireguard'],
#  ['a fine map from alexander von humboldt (1851)'],
#  ['new research on ptsd in elephants and other animals'],
#  ['“awakenings” in advanced dementia patients hint at untapped brain reserves'],
#  ['recycling of plastics enabled by dynamic covalent diketoenamine bonds (2018) [pdf]'],
#  ['show hn: data-viz project for ray-tracing the moon model'],
#  ['five new real-time detections of fast radio bursts with utmost'],
#  ['lucidscience – electronic projects and tutorials'],
#  ['what are children dying from and what can we do about it?'],
#  ['a conversation with the team that made bread with ancient egyptian yeast'],
#  ['air force reveals tests of supposed record-setting scramjet from n. grumman'],
#  ['the decline of college newspapers'],
#  ['which is the best john le carré novel?', '(2014)'],
#  ['dreaming about better sleep: dreem, oura and the rest'],
#  ['penn effect'],
#  ['hall’s law: the nineteenth century prequel to moore’s law (2012)'],
#  ['volcanoes on the moon may have erupted during the dinosaur age (2014)'],
#  ['the world’s smartest chimp has died'],
#  ['smart plastic incineration posited as solution to global recycling crisis'],
#  ['kei – a small and expressive dependent language'],
#  ['freshermeat – open-source security software'],
#  ['engineers build advanced microprocessor out of carbon nanotubes'],
#  ['a new york farm stand’s success: an eye for the next big thing'],
#  ['disneyland’s disastrous opening day (2015)'],
#  ['a z-machine in ocaml (2016)'],
#  ["quantum air buys bye's electric airplanes"],
#  ['famous graphics chips: microsoft’s talisman'],
#  ["engineers develop bone-like metal foam that can be 'healed' at room temperature"],
#  ['using the golden research engine to query the y combinator s19 batch'],
#  ['a mosque rebuilt once a year'],
#  ['flying with miniature horses'],
#  ['the oral history of the super soaker'],
#  ['a trailblazing plan to fight california wildfires'],
#  ['show hn: firestorm – an orm for firestore'],
#  ['programming shape using kirigami tessellations'],
#  ['potosí: the mountain of silver that was the first global city'],
#  ['an ancient egypt-to-black sea route?', 'adventurers to test theory'],
#  ['exploring the visible spectrum in python'],
#  ['general balanced trees (1999) [pdf]'],
#  ['using wall street secrets to reduce the cost of cloud infrastructure'],
#  ['rediscovering rules for ancient board games'],
#  ['on the road in 1980'],
#  ['the software arts'],
#  ['making web-workers async iterables'],
#  ['show hn: quark-ide and a javascript runtime to build cross-platform desktop apps'],
#  ['environment and the programming language self, part 4'],
#  ['the lost doves press typeface and its revival (2015)'],
#  ['early years of computer gaming: steve russell and nolan bushnell (2002) [video]'],
#  ['the quest to conquer earth’s space junk problem (2018)'],
#  ['swadesh list'],
#  ['salvator mundi and the unreality of the art market']]

# %%
#Tokenize each word in the each title sentence 
def WordTokenizer(x):
    token_words = [word for line in x for word in line.split()]
    return token_words

link_titles_tokenize_word = link_titles_tokenize.map(WordTokenizer)

link_titles_tokenize_word.collect()
# Out:
# [['turning',
#   'a',
#   'macbook',
#   'into',
#   'a',
#   'touchscreen',
#   'with',
#   '$1',
#   'of',
#   'hardware',
#   '(2018)'],
#  ['the', 'lonely', 'work', 'of', 'moderating', 'hacker', 'news'],
#  ['introducing', 'nushell'],
#  ['google',
#   'just',
#   'deleted',
#   'my',
#   'nearly',
#   '10-year-old',
#   'free',
#   'and',
#   'open-source',
#   'android',
#   'app'],
#  ['ebola', 'is', 'now', 'curable'],
#  ['all',
#   'the',
#   'best',
#   'engineering',
#   'advice',
#   'i',
#   'stole',
#   'from',
#   'non-technical',
#   'people'],
#  ['i', 'miss', 'microsoft', 'encarta'],
#  ['alan',
#   "kay's",
#   'answer',
#   'to',
#   '‘what',
#   'are',
#   'some',
#   'forgotten',
#   'books',
#   'programmers',
#   'should',
#   'read?’'],
#  ['information', 'operations', 'directed', 'at', 'hong', 'kong'],
#  ['terminating', 'service', 'for', '8chan'],
#  ['what',
#   'happens',
#   'when',
#   'you',
#   'launch',
#   'google',
#   'chrome',
#   'for',
#   'the',
#   'first',
#   'time?'],
#  ['how', 'to', 'build', 'good', 'software'],
#  ['null', 'license', 'plate', 'not', 'such', 'a', 'bright', 'idea'],
#  ['what', 'does', 'a', 'coder', 'do', 'if', 'they', "can't", 'type?'],
#  ['yelp',
#   'is',
#   'replacing',
#   'restaurants’',
#   'phone',
#   'numbers',
#   'so',
#   'grubhub',
#   'can',
#   'take',
#   'a',
#   'cut'],
#  ['japanese', 'anime', 'studio', 'khara', 'moving', 'to', 'blender'],
#  ['deconstructing', 'google’s', 'excuses', 'on', 'tracking', 'protection'],
#  ['cloudflare', 's-1'],
#  ['8chan',
#   'goes',
#   'dark',
#   'after',
#   'hardware',
#   'provider',
#   'discontinues',
#   'service'],
#  ['please', 'add', 'rss', 'support', 'to', 'your', 'site'],
#  ['no', 'more', 'cheap', 'shipping', 'for', 'chinese', 'sellers'],
#  ['python', 'is', 'eating', 'the', 'world'],
#  ['verizon', 'to', 'sell', 'tumblr', 'to', 'automattic'],
#  ['tasty', 'seaweed', 'reduces', 'cows’', 'methane', 'emissions', 'by', '99%'],
#  ['hy'],
#  ['things', 'i', 'learnt', 'from', 'a', 'senior', 'software', 'engineer'],
#  ['wewtf'],
#  ['linux', 'journal', 'ceases', 'publication:', 'an', 'awkward', 'goodbye'],
#  ['amd',
#   'lands',
#   'google,',
#   'twitter',
#   'as',
#   'customers',
#   'with',
#   'newest',
#   'server',
#   'chip'],
#  ['us',
#   'navy',
#   'will',
#   'replace',
#   'touchscreen',
#   'with',
#   'mechanical',
#   'controls',
#   'on',
#   'its',
#   'destroyers'],
#  ['standard',
#   'ebooks:',
#   'free',
#   'public-domain',
#   'ebooks,',
#   'carefully',
#   'produced'],
#  ['why', 'is', 'modern', 'web', 'development', 'so', 'complicated?'],
#  ['a',
#   'man',
#   'who',
#   'destroyed',
#   'his',
#   'multimillion',
#   'dollar',
#   'company',
#   'in',
#   '10',
#   'seconds',
#   '(2018)'],
#  ['opendrop:', 'an', 'open', 'source', 'airdrop', 'implementation'],
#  ['a',
#   'deep',
#   'dive',
#   'into',
#   'ios',
#   'exploit',
#   'chains',
#   'found',
#   'in',
#   'the',
#   'wild'],
#  ['software', 'architecture', 'guide'],
#  ['sites',
#   'using',
#   'facebook',
#   '‘like’',
#   'button',
#   'liable',
#   'for',
#   'data,',
#   'eu',
#   'court',
#   'rules'],
#  ['insect',
#   "'apocalypse'",
#   'in',
#   'u.s.',
#   'driven',
#   'by',
#   '50x',
#   'increase',
#   'in',
#   'toxic',
#   'pesticides:',
#   'study'],
#  ['apple',
#   'confirms',
#   '$1m',
#   'reward',
#   'for',
#   'anyone',
#   'who',
#   'can',
#   'hack',
#   'an',
#   'iphone'],
#  ['why', 'all', 'of', 'our', 'games', 'look', 'like', 'crap'],
#  ['tech', 'interview', 'handbook'],
#  ['fewer',
#   'than',
#   'half',
#   'of',
#   'google',
#   'searches',
#   'now',
#   'result',
#   'in',
#   'a',
#   'click'],
#  ['ugly',
#   'gerry',
#   '–',
#   'font',
#   'created',
#   'from',
#   'congressional',
#   'districts'],
#  ['why', 'has', 'examine.com', 'disappeared', 'from', 'search', 'results?'],
#  ['a', 'walk', 'in', 'hong', 'kong'],
#  ['john', 'carmack', 'on', 'the', 'joe', 'rogan', 'experience', '[video]'],
#  ['the',
#   'baseline',
#   'interpreter:',
#   'a',
#   'faster',
#   'javascript',
#   'interpreter',
#   'in',
#   'firefox',
#   '70'],
#  ['google',
#   'doesn’t',
#   'want',
#   'staff',
#   'debating',
#   'politics',
#   'at',
#   'work',
#   'anymore'],
#  ['build', 'your', 'own', 'text', 'editor'],
#  ["i've",
#   'reproduced',
#   '130',
#   'research',
#   'papers',
#   'about',
#   '“predicting',
#   'the',
#   'stock',
#   'market”'],
#  ['ask', 'hn:', 'how', 'do', 'you', 'read?'],
#  ['how',
#   'to',
#   'build',
#   'a',
#   'plugin',
#   'system',
#   'on',
#   'the',
#   'web',
#   'and',
#   'also',
#   'sleep',
#   'well',
#   'at',
#   'night'],
#  ['europe',
#   'is',
#   'edging',
#   'towards',
#   'making',
#   'post-car',
#   'cities',
#   'a',
#   'reality'],
#  ['new',
#   'york',
#   'city',
#   'neighbors',
#   'build',
#   'cheaper',
#   'way',
#   'to',
#   'connect',
#   'to',
#   'web'],
#  ['github',
#   'actions',
#   'now',
#   'supports',
#   'ci/cd,',
#   'free',
#   'for',
#   'public',
#   'repositories'],
#  ['consume', 'less,', 'create', 'more'],
#  ['living',
#   'near',
#   'trees,',
#   'not',
#   'just',
#   'green',
#   'space,',
#   'improves',
#   'wellbeing'],
#  ['kerbal', 'space', 'program', '2'],
#  ['macbook', 'pro', 'keyboard', 'drives', 'me', 'crazy'],
#  ['why', 'i', 'turned', 'down', 'an', 'aws', 'job', 'offer'],
#  ['facebook', 'has', 'been', 'granted', 'patent', 'on', 'shadow', 'banning'],
#  ['the',
#   'linux',
#   "kernel's",
#   'inability',
#   'to',
#   'gracefully',
#   'handle',
#   'low',
#   'memory',
#   'pressure'],
#  ['show',
#   'hn:',
#   'cli',
#   'tool',
#   'for',
#   'saving',
#   'web',
#   'pages',
#   'as',
#   'a',
#   'single',
#   'file'],
#  ['start', 'your', 'own', 'isp'],
#  ['every',
#   'productivity',
#   'thought',
#   "i've",
#   'ever',
#   'had,',
#   'as',
#   'concisely',
#   'as',
#   'possible'],
#  ['preindustrial',
#   'workers',
#   'worked',
#   'fewer',
#   'hours',
#   'than',
#   "today's",
#   '(2009)'],
#  ['milky',
#   'way’s',
#   'black',
#   'hole',
#   'just',
#   'flared,',
#   'growing',
#   '75',
#   'times',
#   'as',
#   'bright',
#   'for',
#   'a',
#   'few',
#   'hours'],
#  ['amazon',
#   'has',
#   'proven',
#   'unable',
#   'or',
#   'unwilling',
#   'to',
#   'effectively',
#   'police',
#   'third-party',
#   'sellers'],
#  ['rails', '6.0'],
#  ['ha-ha', 'wall'],
#  ['speaking',
#   'to',
#   'yourself',
#   'in',
#   'the',
#   'third',
#   'person',
#   'makes',
#   'you',
#   'wiser'],
#  ['ibm', 'open-sources', 'power', 'chip', 'instruction', 'set'],
#  ['apple',
#   'expands',
#   'parts',
#   'access',
#   'to',
#   'more',
#   'independent',
#   'repair',
#   'businesses'],
#  ['paged',
#   'out',
#   '–',
#   'a',
#   'new',
#   'experimental',
#   'magazine',
#   'about',
#   'programming'],
#  ["let's", 'build', 'houses', 'for', 'people,', 'not', 'cars'],
#  ['we', 'have', 'ruined', 'childhood'],
#  ['decrement', 'carbon:', "stripe's", 'negative', 'emissions', 'commitment'],
#  ['16m',
#   'americans',
#   'will',
#   'vote',
#   'on',
#   'hackable',
#   'paperless',
#   'machines'],
#  ['home', 'chip', 'fab'],
#  ['google',
#   'and',
#   'mozilla',
#   'are',
#   'failing',
#   'to',
#   'support',
#   'browser',
#   'extension',
#   'developers'],
#  ['a',
#   "mathematician's",
#   'way',
#   'of',
#   'converting',
#   'miles',
#   'to',
#   'kilometers'],
#  ['there', 'is', 'no', 'evil', 'like', 'recaptcha'],
#  ['kaspersky',
#   'av',
#   'injected',
#   'unique',
#   'id',
#   'allowing',
#   'sites',
#   'to',
#   'track',
#   'users',
#   'in',
#   'incognito',
#   'mode'],
#  ['who', 'owns', 'huawei?'],
#  ['the', 'horror', 'of', 'microsoft', 'teams'],
#  ['hundreds',
#   'of',
#   'extreme',
#   'self-citing',
#   'scientists',
#   'revealed',
#   'in',
#   'new',
#   'database'],
#  ['regex', 'for', 'noobs', '–', 'an', 'illustrated', 'guide'],
#  ['apple',
#   'will',
#   'soon',
#   'treat',
#   'online',
#   'web',
#   'tracking',
#   'the',
#   'same',
#   'as',
#   'a',
#   'security',
#   'vulnerability'],
#  ['the', 'it', 'guy', 'vs.', 'the', 'con', 'artist'],
#  ['death', 'note:', 'l,', 'anonymity', 'and', 'eluding', 'entropy', '(2017)'],
#  ['amd',
#   'rome',
#   'second',
#   'generation',
#   'epyc',
#   'review:',
#   '2x',
#   '64-core',
#   'benchmarked'],
#  ['amazon', 'is', 'a', 'monopoly'],
#  ['time', 'anxiety:', 'is', 'it', 'too', 'late?'],
#  ['wtf',
#   '–',
#   'a',
#   'personal',
#   'information',
#   'dashboard',
#   'for',
#   'your',
#   'terminal'],
#  ['scientists',
#   'discover',
#   'a',
#   'cure',
#   'for',
#   'the',
#   'deadliest',
#   'strain',
#   'of',
#   'tuberculosis'],
#  ['show', 'hn:', 'divjoy', '–', 'react', 'codebase', 'and', 'ui', 'generator'],
#  ['proteins',
#   'that',
#   'may',
#   'restore',
#   'damaged',
#   'sound-detecting',
#   'cells',
#   'in',
#   'the',
#   'ear'],
#  ['15',
#   'states',
#   'are',
#   'trying',
#   'to',
#   'make',
#   'the',
#   'electoral',
#   'college',
#   'obselete'],
#  ['banned',
#   'c',
#   'standard',
#   'library',
#   'functions',
#   'in',
#   'git',
#   'source',
#   'code'],
#  ['pronunciations', 'for', 'hexadecimal', 'numbers', '(1968)'],
#  ['turbo,', 'an', 'improved', 'rainbow', 'colormap', 'for', 'visualization'],
#  ['from',
#   'mac',
#   'to',
#   'linux',
#   '–',
#   'the',
#   'setup',
#   "i've",
#   'grown',
#   'to',
#   'love'],
#  ['time', 'to', 'get', 'serious', 'about', 'tick-borne', 'diseases'],
#  ['pentagon',
#   'testing',
#   'mass',
#   'surveillance',
#   'balloons',
#   'across',
#   'the',
#   'us'],
#  ['useless', 'windows', '10', 'features'],
#  ['some', 'obscure', 'c', 'features'],
#  ['mercedes-benz', 'pre-safe', 'sound'],
#  ['tsv',
#   'utilities:',
#   'command',
#   'line',
#   'tools',
#   'for',
#   'large,',
#   'tabular',
#   'data',
#   'files'],
#  ['psytrance', 'guide'],
#  ['researcher',
#   'banned',
#   'on',
#   "valve's",
#   'bug',
#   'bounty',
#   'program',
#   'publishes',
#   'second',
#   'steam',
#   '0-day'],
#  ['why',
#   'do',
#   'developers',
#   'at',
#   'google',
#   'consider',
#   'agile',
#   'development',
#   'to',
#   'be',
#   'nonsense?',
#   '(2016)'],
#  ['planet:', 'imaging', 'the', 'entire', 'earth', 'every', 'day'],
#  ['software', 'made', 'me', 'loathe', 'my', 'car'],
#  ['dqlite', '–', 'high-availability', 'sqlite'],
#  ['cutiepi', '–', 'all-in-one', 'raspberry', 'pi', 'tablet'],
#  ['knuth',
#   'on',
#   "huang's",
#   'sensitivity',
#   'proof:',
#   "“i've",
#   'got',
#   'the',
#   'proof',
#   'down',
#   'to',
#   'one',
#   'page”',
#   '[pdf]'],
#  ['supercentenarians',
#   'are',
#   'concentrated',
#   'into',
#   'regions',
#   'with',
#   'no',
#   'birth',
#   'certificates'],
#  ['anthony',
#   'levandowski',
#   'charged',
#   'with',
#   'theft',
#   'of',
#   'trade',
#   'secrets'],
#  ['exfat', 'in', 'the', 'linux', 'kernel'],
#  ['speed',
#   'matters:',
#   'why',
#   'working',
#   'quickly',
#   'is',
#   'more',
#   'important',
#   'than',
#   'it',
#   'seems',
#   '(2015)'],
#  ['programmers:',
#   'before',
#   'you',
#   'turn',
#   '40,',
#   'get',
#   'a',
#   'plan',
#   'b',
#   '(2009)'],
#  ['information', 'theory', 'for', 'intelligent', 'people', '(2018)', '[pdf]'],
#  ['i',
#   'completed',
#   'ultimate',
#   'go,',
#   'took',
#   'good',
#   'notes',
#   'and',
#   'commented',
#   'directly',
#   'on',
#   'source',
#   'code'],
#  ['a',
#   'guide',
#   'to',
#   'recording',
#   '660fps',
#   'video',
#   'on',
#   'a',
#   '$6',
#   'raspberry',
#   'pi',
#   'camera'],
#  ['super', 'mario', '64', 'has', 'been', 'decompiled'],
#  ['yaml:', 'probably', 'not', 'so', 'great', 'after', 'all'],
#  ['rust', 'language', 'cheat', 'sheet'],
#  ['thoughts', 'on', 'rust', 'bloat'],
#  ['google', 'chrome', 'incognito', 'mode', 'can', 'still', 'be', 'detected'],
#  ['rules', 'for', 'intuitive', 'ux'],
#  ['iterm2', '3.3'],
#  ['datadog', 's-1'],
#  ['the',
#   'not',
#   'so',
#   'hidden',
#   'cost',
#   'of',
#   'sharing',
#   'code',
#   'between',
#   'ios',
#   'and',
#   'android'],
#  ['show', 'hn:', 'chart.xkcd', '–', 'xkcd-styled', 'chart', 'library'],
#  ['tell', 'hn:', 'danny', 'cohen', 'has', 'died'],
#  ['down', 'the', 'rabbit-hole'],
#  ['three', 'kinds', 'of', 'good', 'tech', 'debt'],
#  ['facebook',
#   'scans',
#   'system',
#   'libraries',
#   'on',
#   'android',
#   'and',
#   'uploads',
#   'them',
#   'to',
#   'their',
#   'server'],
#  ['uber',
#   'posts',
#   '$5.2b',
#   'loss',
#   'and',
#   'slowest',
#   'ever',
#   'growth',
#   'rate'],
#  ['the', 'fully', 'remote', 'attack', 'surface', 'of', 'the', 'iphone'],
#  ['google',
#   'to',
#   'offer',
#   'a',
#   'best',
#   'price',
#   'guarantee',
#   'on',
#   'certain',
#   'flights'],
#  ['npm', 'bans', 'terminal', 'ads'],
#  ['the', 'architecture', 'of', 'open', 'source', 'applications'],
#  ['people', 'love', 'working', 'remotely'],
#  ['berlin’s', 'popular', 'shopping', 'streets', 'will', 'go', 'car-free'],
#  ['toni', 'morrison', 'has', 'died'],
#  ['sourcehut', 'welcomes', 'bitbucket', 'refugees'],
#  ['ai',
#   'startup',
#   'claims',
#   'to',
#   'automate',
#   'app',
#   'making',
#   'but',
#   'actually',
#   'just',
#   'uses',
#   'humans'],
#  ['ask',
#   'hn:',
#   'recommended',
#   'resources',
#   'to',
#   'learn',
#   'the',
#   'linux',
#   'kernel',
#   'and',
#   'os',
#   'theory?'],
#  ['steam', 'windows', 'client', 'local', 'privilege', 'escalation', '0day'],
#  ['hong',
#   'kong',
#   'isp',
#   'association’s',
#   'statement',
#   'on',
#   'selective',
#   'blocking',
#   'of',
#   'internet',
#   'services'],
#  ['i',
#   'wasn’t',
#   'getting',
#   'hired',
#   'as',
#   'a',
#   'data',
#   'scientist,',
#   'so',
#   'i',
#   'sought',
#   'data',
#   'on',
#   'who',
#   'is'],
#  ['juul,',
#   'philip',
#   'morris',
#   'sued',
#   'under',
#   'racketeer',
#   'act',
#   'for',
#   'targeting',
#   'kids'],
#  ['vmware',
#   'acquires',
#   'carbon',
#   'black',
#   'for',
#   '$2.1b',
#   'and',
#   'pivotal',
#   'for',
#   '$2.7b'],
#  ['zen',
#   '2',
#   'missives',
#   '–',
#   'amd',
#   'now',
#   'delivering',
#   'efficiencies',
#   'that',
#   'are',
#   'double',
#   'that',
#   'of',
#   'intel'],
#  ['write', 'your', 'own', 'excel', 'in', 'f#', '(2018)'],
#  ['performance', 'matters'],
#  ['is', 'perl', '6', 'being', 'renamed?'],
#  ['people', 'simply', 'empty', 'out', '(1986)'],
#  ['black',
#   'hat:',
#   'gdpr',
#   'privacy',
#   'law',
#   'exploited',
#   'to',
#   'reveal',
#   'personal',
#   'data'],
#  ['show',
#   'hn:',
#   'i',
#   'trained',
#   'a',
#   'deep',
#   'learning',
#   'model',
#   'to',
#   'build',
#   'sites',
#   'for',
#   'me'],
#  ['webkit', 'tracking', 'prevention', 'policy'],
#  ['removing', 'coordinated', 'inauthentic', 'behavior', 'from', 'china'],
#  ['calculus', 'for', 'the', 'people'],
#  ['anxiety', 'looks', 'different', 'in', 'men'],
#  ['yield', 'curves', 'invert', 'in', 'u.s.,', 'u.k'],
#  ['amazon',
#   'offered',
#   '‘amazon’s',
#   'choice’',
#   'to',
#   'vendors',
#   'who',
#   'bought',
#   'ads',
#   'and',
#   'lowered',
#   'prices'],
#  ['cyberchef', '–', 'cyber', 'swiss', 'army', 'knife'],
#  ['rust', '1.37.0'],
#  ['a',
#   'boeing',
#   'code',
#   'leak',
#   'exposes',
#   'security',
#   'flaws',
#   'deep',
#   'in',
#   'a',
#   "787's",
#   'guts'],
#  ['ask', 'hn:', 'best', 'resources', 'to', 'gain', 'math', 'intuition?'],
#  ['mozilla', 'takes', 'action', 'to', 'protect', 'users', 'in', 'kazakhstan'],
#  ['anime4k:', 'real', 'time', 'high', 'quality', 'video', 'upscaling'],
#  ['wine', 'on', 'windows', '10'],
#  ['building',
#   'a',
#   'distributed',
#   'time-series',
#   'database',
#   'on',
#   'postgresql'],
#  ['xfce', '4.14'],
#  ['most', 'startup', 'theory', 'is', 'ex-post,', 'therefore', 'bs'],
#  ['lessons', 'from', 'stripe'],
#  ['show',
#   'hn:',
#   'wave-based',
#   'non-line-of-sight',
#   'computational',
#   'imaging',
#   'in',
#   'julia'],
#  ['‘they',
#   'get',
#   'fired',
#   'all',
#   'the',
#   'time.',
#   'and',
#   'they',
#   'have',
#   'no',
#   'idea',
#   'why’'],
#  ['9th',
#   'circuit',
#   'says',
#   'users',
#   'can',
#   'sue',
#   'facebook',
#   'over',
#   'unlawful',
#   'use',
#   'of',
#   'facial',
#   'recognition'],
#  ['linux',
#   'kernel',
#   'drivers',
#   'in',
#   'rust',
#   'might',
#   'become',
#   'an',
#   'option',
#   'in',
#   'the',
#   'future'],
#  ['moviepass', 'worked', 'out', 'great'],
#  ['a',
#   'beginner’s',
#   'introduction',
#   'to',
#   'python',
#   'web',
#   'frameworks',
#   '(2018)'],
#  ['ask', 'hn:', 'who', 'is', 'hiring?', '(august', '2019)'],
#  ['show',
#   'hn:',
#   'data',
#   'structures',
#   'and',
#   'algorithms',
#   'in',
#   'javascript'],
#  ['await', 'in', 'rust'],
#  ['cool', 'but', 'obscure', 'x11', 'tools'],
#  ['elsevier',
#   'threatens',
#   'others',
#   'for',
#   'linking',
#   'to',
#   'sci-hub',
#   'but',
#   'does',
#   'so',
#   'itself'],
#  ['group',
#   'sex',
#   'app',
#   'leaks',
#   'locations,',
#   'pics',
#   'and',
#   'personal',
#   'details'],
#  ['apple',
#   'is',
#   'locking',
#   'iphone',
#   'batteries',
#   'to',
#   'discourage',
#   'repair'],
#  ['“i', 'would', 'like', 'to', 'maintain', 'the', 'floppy', 'driver”'],
#  ['fracking',
#   'in',
#   'north',
#   'america',
#   'could',
#   'be',
#   'partly',
#   'to',
#   'blame',
#   'for',
#   'methane',
#   'spike',
#   '–',
#   'study'],
#  ['flawed',
#   'algorithms',
#   'are',
#   'grading',
#   'millions',
#   'of',
#   'students’',
#   'essays'],
#  ['35', 'over', '35'],
#  ['u.s.', 'designates', 'china', 'as', 'currency', 'manipulator'],
#  ['sunsetting', 'mercurial', 'support', 'in', 'bitbucket'],
#  ['open',
#   'letter',
#   'from',
#   'an',
#   'android',
#   'developer',
#   'to',
#   'the',
#   'google',
#   'play',
#   'team'],
#  ['cue',
#   '–',
#   'a',
#   'language',
#   'for',
#   'defining,',
#   'generating,',
#   'and',
#   'validating',
#   'data'],
#  ['how', 'rust', 'optimizes', 'async/await'],
#  ['one',
#   'city',
#   'saved',
#   '$5m',
#   'by',
#   'routing',
#   'school',
#   'buses',
#   'with',
#   'an',
#   'algorithm'],
#  ['async-std:',
#   'an',
#   'async',
#   'port',
#   'of',
#   'the',
#   'rust',
#   'standard',
#   'library'],
#  ['regexr'],
#  ['the', 'art', 'of', 'warez', '[video]'],
#  ['get', 'your', 'work', 'recognized:', 'write', 'a', 'brag', 'document'],
#  ['one',
#   'job,',
#   'many',
#   'roles:',
#   'the',
#   'different',
#   'skills',
#   'needed',
#   'to',
#   'be',
#   'a',
#   'successful',
#   'cto'],
#  ['productivity', 'and', 'the', 'workweek', '(2000)'],
#  ['nigerian',
#   'teens',
#   'are',
#   'making',
#   'sci-fi',
#   'shorts',
#   'with',
#   'slick',
#   'visual',
#   'effects'],
#  ['the',
#   'most',
#   'frequent',
#   '777',
#   'characters',
#   'give',
#   '90%',
#   'coverage',
#   'of',
#   'kanji',
#   'in',
#   'the',
#   'wild'],
#  ['contributing', 'to', 'the', 'mozilla', 'code', 'base'],
#  ['the', 'lost', 'art', 'of', 'lacing', 'cable', '(2018)'],
#  ['martini:', 'real-time', 'terrain', 'mesh', 'generator'],
#  ['the', 'impact', 'of', 'meditating', 'every', 'day'],
#  ['software',
#   'was',
#   'eating',
#   'the',
#   'world',
#   '–',
#   'now',
#   'landlords',
#   'are',
#   'eating',
#   'everything'],
#  ['ibm',
#   'has',
#   'released',
#   'the',
#   'power',
#   'architecture',
#   'instruction',
#   'set',
#   'to',
#   'the',
#   'linux',
#   'foundation'],
#  ['plastics:',
#   "what's",
#   'recyclable,',
#   'what',
#   'becomes',
#   'trash',
#   'and',
#   'why'],
#  ['uber,', 'losing', 'billions,', 'freezes', 'engineering', 'hires'],
#  ['irs',
#   'budget',
#   'cuts',
#   'cost',
#   '$34.3b',
#   'in',
#   'lost',
#   'revenue',
#   'from',
#   'big',
#   'business'],
#  ['calculus', 'is', 'deeply', 'irrational'],
#  ['every', 'noise', 'at', 'once'],
#  ['at&t',
#   'employees',
#   'were',
#   'bribed',
#   'to',
#   'install',
#   'phone',
#   'unlocking',
#   'malware',
#   'on',
#   'company',
#   'network'],
#  ['the', 'problem', 'at', 'yale', 'is', 'not', 'free', 'speech'],
#  ['silk'],
#  ['beyond',
#   'meat',
#   'and',
#   'kfc',
#   'partner',
#   'to',
#   'test',
#   'fried',
#   'plant-based',
#   '‘chicken’'],
#  ['the', 'we', 'company', 's-1'],
#  ['how', 'to', 'return', 'to', 'the', 'flow', 'faster'],
#  ['the',
#   'paxos',
#   'algorithm,',
#   'or',
#   'how',
#   'to',
#   'win',
#   'a',
#   'turing',
#   'award'],
#  ['attorney', 'general', 'barr', 'and', 'encryption'],
#  ['making', 'email', 'more', 'modern', 'with', 'jmap'],
#  ['ffmpeg', '4.2'],
#  ['webassembly',
#   'interface',
#   'types:',
#   'interoperate',
#   'with',
#   'all',
#   'the',
#   'things'],
#  ['roblox',
#   'hits',
#   '100m',
#   'monthly',
#   'active',
#   'users,',
#   'bigger',
#   'than',
#   'minecraft'],
#  ['words', 'that', 'do', 'handstands'],
#  ['how', 'men’s', 'bodies', 'change', 'when', 'they', 'become', 'fathers'],
#  ['misconfigured',
#   'jira',
#   'instances',
#   'exposed',
#   'data',
#   'of',
#   'hundreds',
#   'of',
#   'fortune',
#   '500',
#   'companies'],
#  ['companies',
#   'use',
#   'borrowed',
#   'billions',
#   'to',
#   'buy',
#   'back',
#   'stock,',
#   'not',
#   'to',
#   'invest'],
#  ['ny',
#   'state',
#   'alleges',
#   'exxonmobil',
#   'knew',
#   'risks',
#   'of',
#   'climate',
#   'change',
#   'and',
#   'defrauded',
#   'investors'],
#  ['new', 'react', 'devtools'],
#  ['wework',
#   'gets',
#   'tax',
#   'rebate',
#   'meant',
#   'for',
#   'its',
#   'small-business',
#   'tenants'],
#  ['administration',
#   'using',
#   'the',
#   'full',
#   'power',
#   'of',
#   'the',
#   'surveillance',
#   'state',
#   'on',
#   'whistleblowers'],
#  ['a',
#   'book',
#   'from',
#   'alan',
#   'turing',
#   'and',
#   'a',
#   'mysterious',
#   'piece',
#   'of',
#   'paper'],
#  ['how', 'to', 'get', 'your', 'first', 'ten', 'customers', '(2013)'],
#  ['does', 'the', 'amazon', 'provide', '20%', 'of', 'our', 'oxygen?'],
#  ['uber',
#   'proposes',
#   'policy',
#   'that',
#   'would',
#   'pay',
#   'drivers',
#   'a',
#   'minimum',
#   'wage',
#   'of',
#   '$21',
#   'per',
#   'hour'],
#  ['the', 'most', 'dangerous', 'writing', 'app'],
#  ['why',
#   'did',
#   'china',
#   'just',
#   'devalue',
#   'the',
#   'yuan?',
#   'how',
#   'trade',
#   'works',
#   'with',
#   'free-floating',
#   'currency'],
#  ['arend:',
#   'theorem',
#   'prover',
#   'based',
#   'on',
#   'homotopy',
#   'type',
#   'theory',
#   'by',
#   'jetbrains'],
#  ['blazingsql', 'is', 'now', 'open', 'source'],
#  ['key', 'negotiation', 'of', 'bluetooth', 'attack'],
#  ['on-device,', 'real-time', 'hand', 'tracking', 'with', 'mediapipe'],
#  ['dirty', 'tricks', '6502', 'programmers', 'use'],
#  ['insured', 'price', '$2,758,', 'cash', 'price', '$521'],
#  ['germans', 'grow', 'frustrated', 'with', 'their', 'slow-poke', 'internet'],
#  ['building', 'a', 'raspberry', 'pi', '3b+', 'full', 'keyboard', 'handheld'],
#  ['show',
#   'hn:',
#   'saag',
#   'as',
#   'a',
#   'service',
#   '–',
#   'macronutrient-portioned',
#   'indian',
#   'spinach',
#   'curry'],
#  ['social', 'exclusion', 'fuels', 'extremism', 'in', 'young', 'men'],
#  ['camscanner,',
#   'a',
#   'malicious',
#   'android',
#   'app',
#   'with',
#   'more',
#   'than',
#   '100m',
#   'downloads',
#   'in',
#   'google',
#   'play'],
#  ["moscow's",
#   'blockchain',
#   'voting',
#   'system',
#   'cracked',
#   'a',
#   'month',
#   'before',
#   'election'],
#  ['anna', 'karenina', 'principle'],
#  ['qemu', 'vm', 'escape'],
#  ['inflated',
#   'bond',
#   'ratings',
#   'helped',
#   'spur',
#   'the',
#   'financial',
#   'crisis.',
#   'they’re',
#   'back'],
#  ['medieval', 'people', 'bathed', 'regularly'],
#  ['devilution',
#   '–',
#   'a',
#   'web',
#   'port',
#   'of',
#   'the',
#   'original',
#   'diablo',
#   'game'],
#  ['cooling', 'a', 'house', 'without', 'air', 'conditioning'],
#  ['3.8m-year-old',
#   'skull',
#   'of',
#   'an',
#   'early',
#   'ape-like',
#   'human',
#   'ancestor',
#   'discovered',
#   'in',
#   'ethiopia'],
#  ['huawei',
#   'technicians',
#   'helped',
#   'african',
#   'governments',
#   'spy',
#   'on',
#   'political',
#   'opponents'],
#  ['typescript', '3.6'],
#  ['the',
#   'answer',
#   'to',
#   '“will',
#   'you',
#   'mentor',
#   'me?”',
#   'is',
#   'no',
#   '(2010)'],
#  ['how',
#   'to',
#   'measure',
#   'indoor',
#   'air',
#   'quality',
#   'with',
#   'a',
#   'raspberry',
#   'pi,',
#   'ruuvitags',
#   'and',
#   'pms7003'],
#  ['wework', 'isn’t', 'a', 'tech', 'company'],
#  ['why', 'const', "doesn't", 'make', 'c', 'code', 'faster'],
#  ['verified', 'by', 'twilio'],
#  ['python', 'vs.', 'rust', 'for', 'neural', 'networks'],
#  ['big', 'coal', 'plants', 'begin', 'to', 'close'],
#  ['aussie', 'isv', 'buys', 'ads', 'to', 'wake', 'up', 'google', 'support'],
#  ['the', 'feynman', 'lectures', 'on', 'physics:', 'algebra', '(1963)'],
#  ['coinbase:', 'responding', 'to', 'firefox', '0-days', 'in', 'the', 'wild'],
#  ['gamedev',
#   'tutorial:',
#   'trigonometry',
#   'basics',
#   '–',
#   'sine',
#   'and',
#   'cosine'],
#  ['secretly',
#   'public',
#   'domain:',
#   'most',
#   'books',
#   'published',
#   'in',
#   'the',
#   'us',
#   'before',
#   '1964'],
#  ['show',
#   'hn:',
#   'clojurescript',
#   'pixel',
#   'game',
#   'engine',
#   'with',
#   'blender',
#   'live-reloading'],
#  ['lisp', 'is', 'not', 'based', 'on', 'the', 'lambda', 'calculus'],
#  ['alphabet',
#   'overtakes',
#   'apple',
#   'to',
#   'become',
#   'most',
#   'cash-rich',
#   'company'],
#  ['rice',
#   'university',
#   'researchers',
#   'propose',
#   'a',
#   'way',
#   'to',
#   'boost',
#   'solar',
#   'efficiency'],
#  ['using',
#   'backblaze',
#   'b2',
#   'and',
#   'cloudflare',
#   'workers',
#   'for',
#   'free',
#   'image',
#   'hosting'],
#  ['the',
#   'worst',
#   'sales',
#   'promotion',
#   'in',
#   'history:',
#   "hoover's",
#   'free',
#   'flight',
#   'fiasco'],
#  ['the', 'door', 'problem', 'of', 'combat', 'design'],
#  ['wikipedia', 'is', 'now', 'a', 'brave', 'verified', 'publisher'],
#  ['google',
#   'plans',
#   'to',
#   'deprecate',
#   'ftp',
#   'url',
#   'support',
#   'in',
#   'chrome'],
#  ['killing', 'a', 'process', 'and', 'all', 'of', 'its', 'descendants'],
#  ['show',
#   'hn:',
#   'i',
#   'created',
#   'postwoman,',
#   'an',
#   'online,',
#   'open-source',
#   'api',
#   'request',
#   'builder'],
#  ['the', 'many', 'possibilities', 'of', 'imessage', 'file', 'vulnerability'],
#  ['the',
#   'design',
#   'of',
#   'littlefs:',
#   'a',
#   'fail-safe',
#   'filesystem',
#   'designed',
#   'for',
#   'microcontrollers'],
#  ['ask',
#   'hn:',
#   "what's",
#   'the',
#   'best',
#   'setup',
#   'for',
#   'ad',
#   'blocking',
#   'and',
#   'tracker',
#   'blocking?'],
#  ['rabbit', 'holes:', 'the', 'secret', 'to', 'technical', 'expertise'],
#  ['show',
#   'hn:',
#   'i',
#   'made',
#   'a',
#   'crm',
#   'system',
#   'to',
#   'make',
#   'sales',
#   'fun'],
#  ['syslog:', 'complete', 'system', 'administrator', 'guide'],
#  ['my', 'sudden', 'trip', 'to', 'hell'],
#  ['why', 'does', 'all', 'life', 'use', 'the', 'same', '20', 'amino', 'acids?'],
#  ['toshiba', 'introduces', 'new', 'tiny', 'nvme', 'ssd', 'form', 'factor'],
#  ['john', 'carmack', 'on', 'parallel', 'implementations', '(2018)'],
#  ['gnu', 'radio', '3.8'],
#  ['ask', 'hn:', 'how', 'do', 'you', 'handle', 'logging?'],
#  ['the', 'github', 'registry', 'public', 'beta', 'is', 'live'],
#  ['a', 'practical', 'guide', 'to', 'css', 'transitions', 'and', 'animations'],
#  ['u.s.',
#   'farmers',
#   'stung',
#   'by',
#   'tariffs',
#   'now',
#   'face',
#   'a',
#   '$3.5b',
#   'corn',
#   'loss'],
#  ['facebook',
#   'hit',
#   'by',
#   'apple’s',
#   'crackdown',
#   'on',
#   'messaging',
#   'feature'],
#  ['privacy',
#   'sandbox',
#   '–',
#   'open',
#   'standards',
#   'to',
#   'enhance',
#   'privacy',
#   'on',
#   'the',
#   'web'],
#  ['transformers', 'from', 'scratch'],
#  ['we', 'made', 'amiga,', 'they', 'fucked', 'it', 'up', '(2015)'],
#  ['memory', 'management', 'in', 'python'],
#  ['die',
#   'with',
#   'me',
#   '–',
#   'a',
#   'chat',
#   'app',
#   'you',
#   'can',
#   'only',
#   'use',
#   'when',
#   'you',
#   'have',
#   'less',
#   'than',
#   '5%',
#   'battery'],
#  ['now',
#   'bigger',
#   'than',
#   'ebay,',
#   'shopify',
#   'sets',
#   'its',
#   'sights',
#   'on',
#   'amazon'],
#  ["let's", 'build', 'a', 'video', 'card'],
#  ['pastel:',
#   'a',
#   'command-line',
#   'tool',
#   'to',
#   'generate,',
#   'analyze,',
#   'convert',
#   'and',
#   'manipulate',
#   'colors'],
#  ['pagemap:', 'a', 'mini', 'map', 'for', 'your', 'website'],
#  ['minify', 'your', 'svgs'],
#  ['yubico',
#   'launches',
#   'its',
#   'dual',
#   'usb-c',
#   'and',
#   'lightning',
#   'two-factor',
#   'security',
#   'key'],
#  ['a',
#   'bloomberg',
#   'reporter’s',
#   'account',
#   'of',
#   'trying',
#   'to',
#   'get',
#   'back',
#   'his',
#   'name',
#   'and',
#   'credit',
#   'rating'],
#  ['opioid',
#   'crisis:',
#   'johnson',
#   'and',
#   'johnson',
#   'hit',
#   'by',
#   'landmark',
#   'ruling'],
#  ['big',
#   'pharma',
#   'is',
#   'using',
#   'faux',
#   'generics',
#   'to',
#   'keep',
#   'drug',
#   'prices',
#   'high,',
#   'critics',
#   'say'],
#  ["tokyo's", 'audiophile', 'venues', '(2016)'],
#  ['japan',
#   'surpasses',
#   'china',
#   'as',
#   'largest',
#   'foreign',
#   'holder',
#   'of',
#   'us',
#   'treasurys'],
#  ['statement', 'on', 'the', 'purpose', 'of', 'a', 'corporation'],
#  ['spying', 'on', 'https'],
#  ['why',
#   "doesn't",
#   'mathematics',
#   'collapse,',
#   'though',
#   'humans',
#   'often',
#   'make',
#   'mistakes',
#   'in',
#   'proofs?'],
#  ['hackers',
#   'ship',
#   'their',
#   'exploits',
#   'directly',
#   'to',
#   'their',
#   'target’s',
#   'mailroom'],
#  ['major',
#   'book',
#   'publishers',
#   'sue',
#   'amazon’s',
#   'audible',
#   'over',
#   'new',
#   'speech-to-text',
#   'feature'],
#  ['hacking',
#   'the',
#   'sonos',
#   'ikea',
#   'symfonisk',
#   'into',
#   'a',
#   'high',
#   'quality',
#   'speaker',
#   'amp'],
#  ['kubernetes', 'security', 'assessment', '[pdf]'],
#  ['“culture', 'fit”', 'is', 'a', 'two', 'way', 'street', '(2018)'],
#  ['what', 'happens', 'when', 'you', 'ach', 'a', 'dead', 'person?'],
#  ['google', 'search', 'takes', '7', 'seconds', 'on', 'certain', 'queries'],
#  ['go', 'module', 'mirror', 'and', 'checksum', 'database', 'launched'],
#  ['high',
#   'levels',
#   'of',
#   'oestrogens',
#   'in',
#   'the',
#   'womb',
#   'linked',
#   'to',
#   'autism'],
#  ['alone', 'in', 'the', 'dark'],
#  ['the',
#   'fungus',
#   'that',
#   'devastates',
#   'the',
#   'cavendish',
#   'banana',
#   'has',
#   'now',
#   'arrived',
#   'in',
#   'latin',
#   'america'],
#  ['metal',
#   'shards',
#   'from',
#   'boeing',
#   '787',
#   'taking',
#   'off',
#   'over',
#   'rome',
#   'rain',
#   'down',
#   'on',
#   'people',
#   'below'],
#  ['the',
#   '“terrible”',
#   '3',
#   'cent',
#   'mcu',
#   '–',
#   'a',
#   'short',
#   'survey',
#   'of',
#   'sub',
#   '$0.10',
#   'microcontrollers'],
#  ['the', 'order', 'of', 'the', 'json'],
#  ['in',
#   'effect,',
#   'seattle',
#   'is',
#   'decriminalizing',
#   'the',
#   'use',
#   'of',
#   'hard',
#   'drugs'],
#  ['faa', 'bans', 'recalled', 'apple', 'laptops', 'from', 'flights'],
#  ['salsify',
#   '–',
#   'a',
#   'new',
#   'architecture',
#   'for',
#   'real-time',
#   'internet',
#   'video'],
#  ['walmart',
#   'sues',
#   'tesla',
#   'over',
#   'fires',
#   'at',
#   'stores',
#   'fitted',
#   'with',
#   'its',
#   'solar',
#   'panels'],
#  ['danish', 'bank', 'launches', 'negative', 'interest', 'rate', 'mortgage'],
#  ['open-source', 'firmware'],
#  ['technical', 'vision', 'for', 'qt', '6'],
#  ['show',
#   'hn:',
#   'yack',
#   '–',
#   'community',
#   'browser',
#   'for',
#   'hacker',
#   'news,',
#   'reddit,',
#   'youtube',
#   'and',
#   'more'],
#  ['a', 'dream', 'of', 'an', 'ultimate', 'os', '(1995)'],
#  ['a', 'primer', 'on', 'bézier', 'curves', '(2013)'],
#  ['bontrager’s',
#   'wavecel',
#   'material',
#   'more',
#   'effective',
#   'at',
#   'preventing',
#   'concussions',
#   'than',
#   'mips'],
#  ['the',
#   'death',
#   'of',
#   'social',
#   'reciprocity',
#   'in',
#   'the',
#   'era',
#   'of',
#   'digital',
#   'distraction'],
#  ['amazon',
#   'wants',
#   'to',
#   'control',
#   'third-party',
#   'sellers’',
#   'product',
#   'pricing'],
#  ['partiql:', 'one', 'query', 'language', 'for', 'all', 'your', 'data'],
#  ['a', 'bug', 'i', 'wish', 'i', "hadn't", 'caught'],
#  ['a', 'mobile', 'phone', 'that', 'respects', 'your', 'freedom', '[video]'],
#  ['cloud',
#   'run',
#   'button:',
#   'click-to-deploy',
#   'your',
#   'git',
#   'repos',
#   'to',
#   'gcp'],
#  ['my',
#   'home',
#   'lab',
#   'server',
#   'with',
#   '20',
#   'cores',
#   '/',
#   '40',
#   'threads',
#   'and',
#   '128',
#   'gb',
#   'memory'],
#  ['gcc', 'null', 'pointer', 'check', 'removed'],
#  ['in',
#   'the',
#   'us,',
#   "it's",
#   'cheaper',
#   'to',
#   'build',
#   'and',
#   'operate',
#   'wind',
#   'farms',
#   'than',
#   'buy',
#   'fossil',
#   'fuels'],
#  ['wiringpi', '–', 'deprecated'],
#  ['credit', 'cards', 'have', 'a', 'privacy', 'problem'],
#  ['starbucks,', 'monetary', 'superpower'],
#  ['building', 'ages', 'in', 'the', 'netherlands'],
#  ['huawei',
#   'seeks',
#   'independence',
#   'from',
#   'the',
#   'us',
#   'with',
#   'risc-v',
#   'and',
#   'ascend',
#   'chips'],
#  ['black',
#   'hat',
#   'talk',
#   'about',
#   '‘time',
#   'ai’',
#   'causes',
#   'uproar,',
#   'is',
#   'deleted',
#   'by',
#   'conference'],
#  ['the',
#   'hypersane',
#   'are',
#   'among',
#   'us,',
#   'if',
#   'only',
#   'we',
#   'are',
#   'prepared',
#   'to',
#   'look'],
#  ['why', 'i', 'like', 'clojure'],
#  ['cybersecurity',
#   'pros',
#   'name',
#   'their',
#   'price',
#   'as',
#   'hacker',
#   'attacks',
#   'swell'],
#  ['gcp',
#   'to',
#   'introduce',
#   'an',
#   'additional',
#   'charge',
#   'for',
#   'publicly',
#   'addressed',
#   'vm',
#   'instances'],
#  ['youtube',
#   'shuts',
#   'down',
#   'music',
#   'companies’',
#   'use',
#   'of',
#   'manual',
#   'copyright',
#   'claims'],
#  ['poetry:', 'dependency', 'management', 'for', 'python'],
#  ['protocols,',
#   'not',
#   'platforms:',
#   'a',
#   'technological',
#   'approach',
#   'to',
#   'free',
#   'speech'],
#  ['artichoke', '–', 'a', 'ruby', 'made', 'with', 'rust'],
#  ['apollo',
#   'guidance',
#   'computer',
#   'switching',
#   'power',
#   'supply',
#   'works',
#   'after',
#   '50',
#   'years'],
#  ['monads', 'as', 'a', 'programming', 'pattern'],
#  ['denial',
#   'of',
#   'h1-b',
#   'visas',
#   'to',
#   'india’s',
#   'largest',
#   'it',
#   'services',
#   'exporters',
#   'at',
#   'all-time',
#   'high'],
#  ['show', 'hn:', 'zero-config', 'documentation', 'websites', 'for', 'python'],
#  ['show',
#   'hn:',
#   'we',
#   'track',
#   'reddit,',
#   'google',
#   'trends,',
#   'twitter,',
#   'etc.',
#   'to',
#   'find',
#   'trending',
#   'topics'],
#  ['advice',
#   'to',
#   'my',
#   'younger',
#   'self:',
#   'become',
#   'allergic',
#   'to',
#   'the',
#   'churn'],
#  ['show',
#   'hn:',
#   'sourcery',
#   '–',
#   'get',
#   'a',
#   'free,',
#   'self-updating',
#   'website'],
#  ['show',
#   'hn:',
#   'lunch',
#   'money,',
#   'a',
#   'personal',
#   'budgeting',
#   'tool',
#   'with',
#   'multi-currency',
#   'support'],
#  ['new', 'life', 'found', 'that', 'lives', 'off', 'electricity', '(2016)'],
#  ['cerebras',
#   'systems',
#   'unveils',
#   'a',
#   '1.2t',
#   'transistor',
#   'chip',
#   'for',
#   'ai'],
#  ['software',
#   'architects',
#   'should',
#   'be',
#   'involved',
#   'in',
#   'earliest',
#   'system',
#   'engineering',
#   'activities'],
#  ['using', 'typescript', 'with', 'react'],
#  ['bmw', 'unveils', 'car', 'sprayed', 'with', 'vantablack'],
#  ['we',
#   'shouldn’t',
#   'take',
#   'peer',
#   'review',
#   'as',
#   'the',
#   '‘gold',
#   'standard’'],
#  ['launch',
#   'hn:',
#   'sanntek',
#   '(yc',
#   's19)',
#   '–',
#   'breathalyzer',
#   'for',
#   'cannabis'],
#  ['the', 'myth', 'of', 'consumer-grade', 'security'],
#  ['nvidia',
#   'ceo',
#   'says',
#   'google',
#   'is',
#   'the',
#   'only',
#   'customer',
#   'building',
#   'its',
#   'own',
#   'silicon',
#   'at',
#   'scale'],
#  ['racket:', 'lisp', 'for', 'learning'],
#  ['ask', 'hn:', 'how', 'to', 'be', 'less', 'argumentative', 'online?'],
#  ['insurance',
#   'companies',
#   'are',
#   'paying',
#   'cops',
#   'to',
#   'investigate',
#   'their',
#   'own',
#   'customers'],
#  ['stand', 'out', 'as', 'a', 'speaker'],
#  ['creeping', 'normality'],
#  ['nasa',
#   'said',
#   'to',
#   'be',
#   'investigating',
#   'first',
#   'allegation',
#   'of',
#   'a',
#   'crime',
#   'in',
#   'space'],
#  ['germany',
#   'for',
#   'first',
#   'time',
#   'sells',
#   '30-year',
#   'bonds',
#   'offering',
#   'negative',
#   'yields'],
#  ['america’s',
#   'elderly',
#   'seem',
#   'more',
#   'screen-obsessed',
#   'than',
#   'the',
#   'young'],
#  ['alarming', 'surge', 'in', 'drug-resistant', 'hiv', 'uncovered'],
#  ['levenshtein', 'distance'],
#  ['punpedia', '–', 'the', 'online', 'encyclopedia', 'of', 'puns'],
#  ['legit-looking',
#   'iphone',
#   'lightning',
#   'cables',
#   'will',
#   'hijack',
#   'your',
#   'computer'],
#  ['open', 'startups', 'list'],
#  ['the',
#   'first',
#   'solar',
#   'road',
#   'has',
#   'turned',
#   'out',
#   'to',
#   'be',
#   'a',
#   'disappointing',
#   'failure'],
#  ['facial',
#   'recognition:',
#   'school',
#   'id',
#   'checks',
#   'lead',
#   'to',
#   'gdpr',
#   'fine'],
#  ['twitter', 'confesses', 'to', 'more', 'adtech', 'leaks'],
#  ['what',
#   'has',
#   'to',
#   'happen',
#   'with',
#   'unix',
#   'virtual',
#   'memory',
#   'when',
#   'you',
#   'have',
#   'no',
#   'swap',
#   'space'],
#  ['elon', 'musk', 'gambled', 'tesla', 'to', 'save', 'solarcity'],
#  ['how',
#   'the',
#   'new',
#   'open-source',
#   'typeface',
#   'used',
#   'by',
#   'github',
#   'and',
#   'mozilla',
#   'came',
#   'to',
#   'be'],
#  ['splunk',
#   'acquires',
#   'cloud',
#   'monitoring',
#   'service',
#   'signalfx',
#   'for',
#   '$1.05b'],
#  ['swap,', 'swap,', 'swap,', 'and', 'bad', 'places', 'to', 'work'],
#  ['interviews',
#   'with',
#   'programming',
#   'language',
#   'creators',
#   '(2010)',
#   '[pdf]'],
#  ['activision',
#   'blizzard',
#   'has',
#   'moved',
#   'billions',
#   'of',
#   'dollars',
#   'of',
#   'profit',
#   'into',
#   'tax',
#   'havens'],
#  ['how', 'to', 'make', 'billions', 'of', 'dollars', 'reducing', 'loneliness'],
#  ['seashells',
#   '–',
#   'pipe',
#   'output',
#   'from',
#   'command-line',
#   'programs',
#   'to',
#   'the',
#   'web',
#   'in',
#   'real',
#   'time'],
#  ['wework', 'ipo', 'shows', "it's", 'the', 'most', 'magical', 'unicorn'],
#  ['experimental',
#   'usaf',
#   'space',
#   'plane',
#   'breaks',
#   'record',
#   'for',
#   'orbital',
#   'spaceflight'],
#  ['what', 'i', 'do', 'as', 'a', 'devops', 'consultant'],
#  ['making', 'containers', 'safer'],
#  ['the', 'erlang', 'rationale'],
#  ['apple',
#   'suspends',
#   'siri',
#   'response',
#   'grading',
#   'in',
#   'response',
#   'to',
#   'privacy',
#   'concerns'],
#  ['the', 'tragedy', 'of', 'ucs-2'],
#  ['crispr',
#   'pioneer',
#   'among',
#   'university',
#   'of',
#   'california',
#   'researchers',
#   'boycotting',
#   'elsevier'],
#  ['‘no',
#   'one',
#   'saw',
#   'a',
#   'thing’:',
#   'when',
#   'a',
#   'midwest',
#   'town',
#   'banded',
#   'together',
#   'to',
#   'kill',
#   'the',
#   'town',
#   'bully'],
#  ['what', 'makes', 'a', 'good', 'conversation?'],
#  ['ruffle',
#   '–',
#   'an',
#   'adobe',
#   'flash',
#   'player',
#   'written',
#   'in',
#   'rust',
#   'compiled',
#   'to',
#   'webassembly'],
#  ['hedonometer'],
#  ['github',
#   'supports',
#   'web',
#   'authentication',
#   '(webauthn)',
#   'for',
#   'security',
#   'keys'],
#  ['twelve',
#   'latex',
#   'packages',
#   'to',
#   'get',
#   'your',
#   'paper',
#   'accepted',
#   '(2017)'],
#  ['a', 'manager’s', 'guide', 'to', 'kubernetes', 'adoption'],
#  ['typed', 'properties', 'in', 'php', '7.4'],
#  ['a', 'readable', 'specification', 'of', 'tls', '1.3'],
#  ['who', 'owns', 'your', 'wireless', 'service?', 'crooks', 'do'],
#  ['feds',
#   'ordered',
#   'google',
#   'location',
#   'dragnet',
#   'to',
#   'solve',
#   'wisconsin',
#   'bank',
#   'robbery'],
#  ['things', 'to', 'know', 'about', 'gnu', 'readline'],
#  ['mortgage', 'market', 'reopens', 'to', 'risky', 'borrowers'],
#  ['recognizing',
#   'the',
#   'signs',
#   'of',
#   'disruption',
#   'in',
#   'our',
#   'urban',
#   'habitat'],
#  ['acute',
#   'effects',
#   'of',
#   'electronic',
#   'cigarette',
#   'aerosol',
#   'inhalation',
#   'on',
#   'vascular',
#   'function'],
#  ['noaa',
#   'data',
#   'confirms',
#   'july',
#   'was',
#   'hottest',
#   'month',
#   'ever',
#   'recorded'],
#  ['javascript:', 'the', 'modern', 'parts'],
#  ['google',
#   'warns',
#   'developers',
#   'that',
#   'all',
#   'new',
#   'android',
#   'apps',
#   'require',
#   '3',
#   'days',
#   'for',
#   'approval'],
#  ['rust', 'gui', 'ecosystem', 'overview'],
#  ['how', 'does', 'esperanto', 'sound?'],
#  ['how',
#   'command',
#   'and',
#   'conquer:',
#   'tiberian',
#   'sun',
#   'punished',
#   'the',
#   'computers',
#   'of',
#   'the',
#   'day',
#   '[video]'],
#  ['what’s',
#   'the',
#   'difference',
#   'between',
#   'statistics',
#   'and',
#   'machine',
#   'learning?'],
#  ['dropbox',
#   'no',
#   'longer',
#   'follows',
#   'symlinks',
#   'to',
#   'items',
#   'outside',
#   'of',
#   'your',
#   'dropbox',
#   'account'],
#  ['climate',
#   'change',
#   'made',
#   'european',
#   'heatwave',
#   'up',
#   'to',
#   '3°c',
#   'hotter'],
#  ['unison', 'file', 'synchronizer'],
#  ['michael', 'cicconetti'],
#  ['opengpt-2:', 'we', 'replicated', 'gpt-2', 'because', 'you', 'can', 'too'],
#  ['practical', 'tips', 'for', 'facelifting', 'a', 'tech', 'resume'],
#  ['natural', 'language', 'processing:', 'the', 'age', 'of', 'transformers'],
#  ['the', 'portuguese', 'bank', 'note', 'crisis', 'of', '1925'],
#  ['california',
#   'farmers',
#   'are',
#   'planting',
#   'solar',
#   'panels',
#   'as',
#   'water',
#   'supplies',
#   'dry',
#   'up'],
#  ['youtube',
#   'said',
#   'to',
#   'be',
#   'fined',
#   'up',
#   'to',
#   '$200m',
#   'for',
#   'children’s',
#   'privacy',
#   'violations'],
#  ['microsoft', 'is', 'killing', 'epub', 'support', 'in', 'edge', 'classic'],
#  ['ask', 'hn:', 'configuration', 'management', 'for', 'personal', 'computer?'],
#  ['intel',
#   'and',
#   'rust:',
#   'the',
#   'future',
#   'of',
#   'systems',
#   'programming',
#   '[video]'],
#  ['from', '30', 'to', '230', 'docker', 'containers', 'per', 'host'],
#  ['wireless',
#   'carrier',
#   'throttling',
#   'of',
#   'online',
#   'video',
#   'is',
#   'pervasive:',
#   'study'],
#  ['how',
#   'do',
#   'black',
#   'holes',
#   'destroy',
#   'information',
#   'and',
#   'why',
#   'is',
#   'that',
#   'a',
#   'problem?'],
#  ['waypipe:', 'gsoc', 'project', 'complete'],
#  ['launch',
#   'hn:',
#   'quirk',
#   '(yc',
#   's19)',
#   '–',
#   'open-source',
#   'cognitive',
#   'behavioral',
#   'therapy'],
#  ["boeing's", 'crashes', 'expose', 'systemic', 'failings'],
#  ['goldman',
#   'sachs',
#   'is',
#   'spending',
#   '$100m',
#   'to',
#   'shave',
#   'milliseconds',
#   'off',
#   'stock',
#   'trades'],
#  ['bad',
#   'times',
#   'in',
#   'tech?',
#   'not',
#   'if',
#   'you’re',
#   'a',
#   'startup',
#   'serving',
#   'other',
#   'startups'],
#  ['why',
#   'did',
#   'turbo',
#   'pascal',
#   'apps',
#   'fail',
#   'with',
#   'a',
#   'division-by-zero',
#   'on',
#   'faster',
#   'systems?'],
#  ['show',
#   'hn:',
#   'storytime',
#   '–',
#   'create',
#   'stories',
#   'about',
#   'your',
#   'code',
#   'instead',
#   'of',
#   'documentation'],
#  ['one',
#   'of',
#   'the',
#   'greatest',
#   'science',
#   'fiction',
#   'magazines',
#   'is',
#   'now',
#   'available',
#   'online',
#   '(2017)'],
#  ['nixery:',
#   'transparently',
#   'build',
#   'and',
#   'serve',
#   'containers',
#   'using',
#   'nix'],
#  ['most',
#   'internet',
#   'service',
#   'providers',
#   'are',
#   'gone',
#   '–',
#   'sonic',
#   'has',
#   'survived',
#   'and',
#   'thrived'],
#  ['where', 'do', 'interrupts', 'happen?'],
#  ['on-disk',
#   'format',
#   'robustness',
#   'requirements',
#   'for',
#   'new',
#   'filesystems'],
#  ['giving', 'up', 'on', 'julia', '(2016)'],
#  ['the', 'ethics', 'of', 'web', 'performance'],
#  ['keeping', 'tesla', 'roadsters', 'alive', 'is', 'serious', 'work'],
#  ['oracle',
#   'directors',
#   'give',
#   'blessing',
#   'to',
#   'shareholder',
#   'lawsuit',
#   'against',
#   'larry',
#   'ellison'],
#  ['lf:',
#   'fully',
#   'decentralized',
#   'fully',
#   'replicated',
#   'key/value',
#   'store'],
#  ['a', 'quarter', 'of', 'humanity', 'faces', 'looming', 'water', 'crises'],
#  ['pacvim',
#   '–',
#   'pacvim',
#   'is',
#   'a',
#   'game',
#   'that',
#   'teaches',
#   'you',
#   'vim',
#   'commands'],
#  ['why', 'does', 'infrastructure', 'cost', 'so', 'much?'],
#  ['laws', 'of', 'showrunning', '(2016)', '[pdf]'],
#  ['possible',
#   'detection',
#   'of',
#   'a',
#   'black',
#   'hole',
#   'with',
#   'a',
#   'mass',
#   'that',
#   'was',
#   'thought',
#   'to',
#   'be',
#   'impossible'],
#  ['launch',
#   'hn:',
#   'dex',
#   '(yc',
#   's19)',
#   '–',
#   'personal',
#   'crm',
#   'that',
#   'reminds',
#   'you',
#   'to',
#   'keep',
#   'in',
#   'touch'],
#  ['a',
#   'buddhist',
#   'monk',
#   'confronts',
#   "japan's",
#   'suicide',
#   'culture',
#   '(2013)'],
#  ['the', 'flawed', 'three-cueing', 'system', 'for', 'teaching', 'reading'],
#  ['home', '3d', 'metal', 'printing:', 'first', 'results'],
#  ['são', 'paulo’s', 'outdoor', 'advertising', 'ban', '(2016)'],
#  ['google',
#   'forcing',
#   'nest',
#   'cameras’',
#   'visual',
#   'indicator',
#   'light',
#   'to',
#   'be',
#   'on'],
#  ['the', 'flawed', 'reasoning', 'behind', 'the', 'replication', 'crisis'],
#  ['sugar:',
#   'open-source',
#   'software',
#   'learning',
#   'platform',
#   'for',
#   'children'],
#  ['open',
#   'location',
#   'code:',
#   'an',
#   'open',
#   'source',
#   'standard',
#   'for',
#   'addresses'],
#  ["'it's",
#   "crazy':",
#   'chase',
#   'forgiving',
#   'all',
#   'debt',
#   'owed',
#   'by',
#   'its',
#   'canada',
#   'credit',
#   'card',
#   'customers'],
#  ['computer', 'science', 'illustrated', '(2014)'],
#  ['parsing', 'json', 'is', 'a', 'minefield', '(2018)'],
#  ['i', 'found', 'an', 'easter', 'egg', 'from', '1977'],
#  ['the',
#   'interviewer',
#   'skills',
#   'ladder',
#   'for',
#   'high',
#   'growth',
#   'companies'],
#  ['show',
#   'hn:',
#   'tailwind.run',
#   '–',
#   'an',
#   'online',
#   'playground',
#   'for',
#   'tailwind',
#   'css'],
#  ['what',
#   'to',
#   'do',
#   'once',
#   'you',
#   'admit',
#   'that',
#   'decentralization',
#   'never',
#   'seems',
#   'to',
#   'work',
#   '(2018)'],
#  ['hundreds',
#   'of',
#   'exposed',
#   'amazon',
#   'cloud',
#   'backups',
#   'found',
#   'leaking',
#   'sensitive',
#   'data'],
#  ['removing',
#   'one',
#   'maine',
#   'dam',
#   '20',
#   'years',
#   'ago',
#   'changed',
#   'everything'],
#  ['nonplanar', 'printing'],
#  ['why',
#   "didn't",
#   'the',
#   'romans',
#   'contribute',
#   'much',
#   'to',
#   'mathematics?'],
#  ['bulk', 'data', 'structures', 'c++'],
#  ['exploring', 'weight', 'agnostic', 'neural', 'networks'],
#  ['have', 'you', 'ever', 'tried', 'to', 'sell', 'a', 'diamond?', '(1982)'],
#  ['big',
#   'o',
#   'notation',
#   '–',
#   'using',
#   'not-boring',
#   'math',
#   'to',
#   'measure',
#   'code’s',
#   'efficiency'],
#  ['cisco',
#   'is',
#   'making',
#   'it',
#   'more',
#   'difficult',
#   'to',
#   'use',
#   'used',
#   'hardware'],
#  ['how',
#   'shrinkflation',
#   'is',
#   'playing',
#   'havoc',
#   'with',
#   'economists’',
#   'models'],
#  ['rotten', 'apple:', 'right', 'to', 'repair', 'roundup'],
#  ['tumblr'],
#  ['doordash', 'buying', 'caviar', 'from', 'square', 'for', '$410m'],
#  ['daniel',
#   'radcliffe',
#   'and',
#   'the',
#   'art',
#   'of',
#   'the',
#   'fact-check',
#   '(2018)'],
#  ['svalbard',
#   'is',
#   'as',
#   'close',
#   'as',
#   'you',
#   'can',
#   'get',
#   'to',
#   'a',
#   'place',
#   'with',
#   'open',
#   'borders'],
#  ['dyson', 'tree'],
#  ['how',
#   'i',
#   'finally',
#   'won',
#   'my',
#   'name',
#   'from',
#   'domain',
#   'resellers',
#   'after',
#   'nine',
#   'years',
#   'of',
#   'waiting'],
#  ['fbi',
#   'tells',
#   'lawmakers',
#   'it',
#   "can't",
#   'access',
#   'dayton',
#   "gunman's",
#   'phone'],
#  ['children',
#   'of',
#   'a',
#   'thailand',
#   'tribe',
#   'who',
#   'see',
#   'with',
#   'clarity',
#   'beneath',
#   'the',
#   'waves',
#   '(2016)'],
#  ['franky',
#   'zapata:',
#   'flyboarding',
#   'frenchman',
#   'crosses',
#   'english',
#   'channel'],
#  ['dignity'],
#  ['teen',
#   'hacker',
#   'finds',
#   'bugs',
#   'in',
#   'school',
#   'software',
#   'that',
#   'exposed',
#   'millions',
#   'of',
#   'records'],
#  ['a', 'pissed-off', 'tutorial', 'for', 'google', 'wave', '(2010)', '[video]'],
#  ['i', 'took', 'a', 'pay', 'cut', 'for', 'a', 'more', 'meaningful', 'job'],
#  ['ibm', 'stops', 'buybacks', 'to', 'pay', 'for', 'red', 'hat'],
#  ['parallelism', 'in', 'postgresql'],
#  ['tech', 'backlash', 'has', 'come', 'to', 'stanford'],
#  ['google’s',
#   'rivals',
#   'opt',
#   'out',
#   'of',
#   'search',
#   'engine',
#   'auction,',
#   'calling',
#   'it',
#   '‘anti-competitive’'],
#  ['peloton', 's-1'],
#  ['why', 'a', 'mock', 'doesn’t', 'work'],
#  ['patterns',
#   'on',
#   'goods',
#   'designed',
#   'to',
#   'trigger',
#   'automated',
#   'license',
#   'plate',
#   'readers'],
#  ['show', 'hn:', 'texnique', '–', 'a', 'latex', 'typesetting', 'game'],
#  ['upmem',
#   'puts',
#   'cpus',
#   'inside',
#   'memory',
#   'to',
#   'allow',
#   'applications',
#   'to',
#   'run',
#   '20',
#   'times',
#   'faster'],
#  ['more',
#   'fires',
#   'now',
#   'burning',
#   'in',
#   'angola,',
#   'congo',
#   'than',
#   'amazon'],
#  ['telegram',
#   'introduces',
#   'feature',
#   'to',
#   'prevent',
#   'users',
#   'from',
#   'texting',
#   'too',
#   'often',
#   'in',
#   'a',
#   'group'],
#  ['somehow', 'i', 'became', 'respectable'],
#  ['how', 'to', 'become', 'a', 'great', 'impostor'],
#  ["seattle's",
#   "'microtransit'",
#   'experiment',
#   'drives',
#   'people',
#   'to',
#   'light',
#   'rail'],
#  ['basic', 'electron', 'framework', 'exploitation'],
#  ['helsinki',
#   'central',
#   'library',
#   'chosen',
#   'as',
#   'the',
#   'best',
#   'new',
#   'public',
#   'library'],
#  ['spacex', 'smallsat', 'rideshare', 'program'],
#  ['personal', 'website', 'for', 'programmers'],
#  ['startups', 'from', 'y', 'combinator’s', 's19', 'demo', 'day', '1'],
#  ['highlights', 'from', 'git', '2.23'],
#  ['show',
#   'hn:',
#   'youtube',
#   'decade',
#   '–',
#   'the',
#   'most-viewed',
#   'videos',
#   'posted',
#   '10',
#   'years',
#   'ago'],
#  ['standard', 'js:', 'npm', 'install', 'funding'],
#  ['mapped:', 'the', 'world’s', 'coal', 'power', 'plants'],
#  ['kept', 'alive', 'with', 'tubes', 'for', 'nearly', '17', 'years'],
#  ['lessons', 'we', 'learned', 'when', 'debugging', 'a', 'scaling', 'problem'],
#  ['p++', 'idea:', 'faq'],
#  ['show',
#   'hn:',
#   'scarf',
#   '–',
#   'platform',
#   'to',
#   'help',
#   'open-source',
#   'developers',
#   'monetize',
#   'their',
#   'work'],
#  ['old', 'paris', 'is', 'no', 'more'],
#  ['spacebook:', "agi's", 'near', 'real-time', 'satellite', 'viewer'],
#  ['the', 'path', 'to', 'dijkstra’s', 'handwriting', '(2013)'],
#  ['ted', 'chiang:', 'realist', 'of', 'a', 'larger', 'reality'],
#  ['escape', 'rooms', 'are', 'big', 'business'],
#  ['alcohol', 'belts', 'of', 'europe'],
#  ['dependent', 'haskell', 'is', 'the', 'future', '(2018)'],
#  ['north',
#   'american',
#   'versus',
#   'european',
#   'distribution',
#   'systems',
#   '(2011)'],
#  ['social',
#   'share',
#   'buttons',
#   'that',
#   "don't",
#   'allow',
#   'the',
#   'social',
#   'sites',
#   'to',
#   'track',
#   'your',
#   'users'],
#  ['nutrient',
#   'deficiencies',
#   'in',
#   'rice',
#   'grown',
#   'under',
#   'higher',
#   'carbon',
#   'dioxide'],
#  ['the',
#   'body',
#   'is',
#   'the',
#   'missing',
#   'link',
#   'for',
#   'truly',
#   'intelligent',
#   'machines',
#   '(2017)'],
#  ['electric', 'motor', 'design', 'claims', 'remarkable', 'improvements'],
#  ['living', 'off', 'the', 'land', 'in', 'linux'],
#  ['no', 'son', 'of', 'mine', 'is', 'going', 'to', 'be', 'a', 'benthamite'],
#  ['extended', 'validation', 'certificates', 'are', 'really', 'dead'],
#  ['the',
#   'mobility',
#   'trap:',
#   'why',
#   "we'll",
#   'never',
#   'fix',
#   'congestion',
#   'by',
#   'speeding',
#   'up',
#   'traffic'],
#  ['static', 'type', 'checking', 'in', 'common', 'lisp'],
#  ['interslavic', 'language'],
# ...
#  ['capturing',
#   'pal',
#   'video',
#   'with',
#   'an',
#   'sdr,',
#   'and',
#   'a',
#   'few',
#   'dead',
#   'ends'],
#  ['solving',
#   'differential',
#   'equations',
#   'on',
#   'a',
#   '6502',
#   'with',
#   "woz's",
#   'floating',
#   'point',
#   'code'],
#  ['computer', 'stupidities', '(2013)'],
#  ['a', 'look', 'back:', 'the', 'bloomberg', 'keyboard', '(2017)'],
#  ['jupiter:', 'risc-v', 'assembler', 'and', 'runtime', 'simulator'],
#  ['42',
#   'hours',
#   'of',
#   'buckminster',
#   'fuller',
#   'might',
#   'be',
#   'just',
#   'the',
#   'vision',
#   'we',
#   'need'],
#  ['project',
#   'mu',
#   '–',
#   'a',
#   'modular',
#   'uefi',
#   'environment',
#   'for',
#   'building',
#   'modern',
#   'devices'],
#  ['the', 'high', 'price', 'of', 'multitasking'],
#  ['curve', 'fitting', 'a:', 'linear', 'least', 'squares'],
#  ['handler',
#   'beliefs',
#   'affect',
#   'scent',
#   'detection',
#   'dog',
#   'outcomes',
#   '(2011)'],
#  ['sipeed', 'longan', 'nano', '–', 'risc-v', 'development', 'board'],
#  ['the',
#   'difference',
#   'between',
#   'isolation',
#   'levels',
#   'and',
#   'consistency',
#   'levels'],
#  ['detailed', '3d', 'map', 'of', 'milky', 'way', 'shows', "'warped'", 'shape'],
#  ['map',
#   'design',
#   '–',
#   'a',
#   'guide',
#   'to',
#   'good',
#   'looking',
#   'maps',
#   '(2008)',
#   '[pdf]'],
#  ['no', 'silver', 'bullet', '(1986)', '[pdf]'],
#  ['armoured', 'commander:', 'the', 'wwii', 'tank', 'commander', 'roguelike'],
#  ['how', 'the', 'brain', "'approximates'", 'without', 'counting'],
#  ['softbank',
#   'plans',
#   'to',
#   'lend',
#   '$20b',
#   'to',
#   'its',
#   'ceo',
#   'and',
#   'employees',
#   'amid',
#   'volatile',
#   'markets'],
#  ['the',
#   'hp',
#   'way:',
#   'how',
#   'bill',
#   'hewlett',
#   'and',
#   'i',
#   'built',
#   'our',
#   'company',
#   '(1960)'],
#  ['how', 'to', 'build', 'a', 'pyramid'],
#  ['how',
#   'to',
#   'get',
#   'consistent',
#   'results',
#   'when',
#   'benchmarking',
#   'on',
#   'linux?'],
#  ['how',
#   'to',
#   'teach',
#   'an',
#   'iris',
#   'scanner',
#   'that',
#   'the',
#   'eye',
#   'it’s',
#   'looking',
#   'at',
#   'is',
#   'dead'],
#  ['building', 'a', 'vacuum', 'tube', 'computer'],
#  ['portugal’s',
#   'marmelada',
#   'tastes',
#   'nothing',
#   'like',
#   'marmalade',
#   '(2018)'],
#  ['spacy', 'pytorch', 'transformers'],
#  ['real',
#   'world',
#   'location',
#   'virtually',
#   'recreated',
#   'to',
#   'scale',
#   'in',
#   'minutes',
#   '[video]'],
#  ['show',
#   'hn:',
#   'dat-keyserver:',
#   'a',
#   'distributed',
#   'pgp',
#   'keyserver',
#   'based',
#   'on',
#   'the',
#   'dat',
#   'protocol'],
#  ['"karel',
#   "čapek's",
#   'play',
#   '""r.u.r.""',
#   'premiered',
#   'in',
#   'january',
#   '1921"'],
#  ['apple',
#   'card',
#   'restrictions',
#   'include',
#   'no',
#   'jailbreaking',
#   'or',
#   'cryptocurrency',
#   'purchases'],
#  ['the', 'grand', 'c++', 'error', 'explosion', 'competition'],
#  ['turkmenistan', 'on', 'the', 'brink', 'of', 'collapse?'],
#  ['a', 'profile', 'of', 'geoffrey', 'hinton', '(2018)'],
#  ['scientists',
#   'reverse',
#   'aging',
#   'process',
#   'in',
#   'rat',
#   'brain',
#   'stem',
#   'cells'],
#  ['show',
#   'hn:',
#   'cordless,',
#   'a',
#   'discord',
#   'terminal',
#   'client',
#   'written',
#   'in',
#   'go'],
#  ['100',
#   'years',
#   'ago,',
#   'a',
#   'telephone',
#   'tower',
#   'in',
#   'stockholm',
#   'connected',
#   '5000',
#   'phone',
#   'lines',
#   '(2014)'],
#  ['japanese',
#   'architects',
#   'who',
#   'treated',
#   'buildings',
#   'like',
#   'living',
#   'organisms'],
#  ['a', 'recent', 'paper', 'proposes', 'to', 'bring', 'zeppelins', 'back'],
#  ['j-core', 'open', 'processor'],
#  ['presidio:',
#   'customizable',
#   'data',
#   'protection',
#   'and',
#   'pii',
#   'data',
#   'anonymization',
#   'service'],
#  ['the', 'survival', 'of', 'iggy', 'pop'],
#  ['bpf', 'port-based', 'firewall', 'for', 'systemd', 'services'],
#  ['marree', 'man'],
#  ['the', 'd-day', 'rehearsal', 'that', 'cost', '800', 'lives', '(2014)'],
#  ['ray', 'tracing', 'with', 'ulisp'],
#  ['show', 'hn:', 'a', 'few', 'simple', 'games', 'not', 'only', 'for', 'kids'],
#  ['why', 'everyone', 'hates', 'customer', 'service'],
#  ['commodore', '900'],
#  ['qualpwn',
#   '–',
#   'exploiting',
#   'qualcomm',
#   'wlan',
#   'and',
#   'modem',
#   'over',
#   'the',
#   'air'],
#  ['study',
#   'identifies',
#   'main',
#   'culprit',
#   'behind',
#   'lithium',
#   'metal',
#   'battery',
#   'failure'],
#  ['with', 'friends', 'like', 'these'],
#  ['youtube’s', 'lgbtq', 'problem', 'is', 'a', 'business-model', 'problem'],
#  ['suburb',
#   'in',
#   'the',
#   'sky:',
#   'how',
#   'jakartans',
#   'built',
#   'an',
#   'entire',
#   'village',
#   'on',
#   'top',
#   'of',
#   'a',
#   'mall'],
#  ['circulating',
#   'in',
#   'china’s',
#   'financial',
#   'system:',
#   'more',
#   'than',
#   '$200b',
#   'in',
#   'i.o.u.s'],
#  ['the',
#   'death',
#   'of',
#   'alexander',
#   'the',
#   'great:',
#   'one',
#   'of',
#   "history's",
#   'great',
#   'unsolved',
#   'mysteries'],
#  ['the', "'microworkers'", 'making', 'digital', 'life', 'possible'],
#  ['keyringless', 'gnupg'],
#  ['the', 'perfect', 'french', 'baguette'],
#  ['shipping', 'wind', 'turbines', 'is', 'not', 'a', 'breeze'],
#  ['iron',
#   'age',
#   'celtic',
#   'woman',
#   'was',
#   'buried',
#   'in',
#   'a',
#   'hollowed-out',
#   'tree',
#   'trunk'],
#  ['the', 'biggest', 'mistakes', 'first-time', 'founders', 'make', '[video]'],
#  ['boeing', 'changing', 'max', 'software', 'to', 'use', 'two', 'computers'],
#  ['empty',
#   'trains',
#   'on',
#   'the',
#   'modern',
#   'silk',
#   'road:',
#   'when',
#   'belt',
#   'and',
#   'road',
#   'interests',
#   'don’t',
#   'align'],
#  ['wavelets', '(1994)', '[pdf]'],
#  ['who', 'did', 'the', 'maya', 'sacrifice?'],
#  ['a', 'guide', 'to', 'magnetorquers', 'for', 'satellites'],
#  ['mobile', 'nixos:', 'the', 'present', 'and', 'the', 'future'],
#  ['nec', 'shows', '‘flying', 'car’', 'hovering', 'steadily', 'for', 'minute'],
#  ['quantum',
#   'radar',
#   'has',
#   'been',
#   'demonstrated',
#   'for',
#   'the',
#   'first',
#   'time'],
#  ['ear', 'speakers', '–', 'research,', 'design,', 'and', 'evolution'],
#  ['wasm', 'vs.', 'pnacl', 'performance', 'benchmark'],
#  ['evolving', 'lindenmayer', 'systems'],
#  ['show',
#   'hn:',
#   'repository',
#   'of',
#   'open',
#   'source',
#   'space-related',
#   'software',
#   'and',
#   'hardware'],
#  ['i', 'love', 'my', 'paper', 'dictionary', '(2017)'],
#  ['darpa',
#   'wants',
#   'help',
#   'cracking',
#   'the',
#   'election',
#   'security',
#   'problem'],
#  ['the',
#   'fed',
#   'is',
#   'getting',
#   'into',
#   'the',
#   'real-time',
#   'payments',
#   'business'],
#  ['woman',
#   'finds',
#   'yellow',
#   'diamond',
#   'while',
#   'watching',
#   'youtube',
#   'video',
#   'on',
#   'how',
#   'to',
#   'find',
#   'diamonds'],
#  ['amazon', 'will', 'pull', 'the', 'plug', 'on', 'dash', 'buttons'],
#  ['problem', 'solving', 'and', 'clojure', '1.9', '(2018)'],
#  ['a',
#   'new',
#   'book',
#   'asserts',
#   'that',
#   'rich',
#   'countries',
#   'grow',
#   'with',
#   'lighter',
#   'environmental',
#   'impacts'],
#  ['animal',
#   'movies',
#   'promote',
#   'awareness,',
#   'not',
#   'harm,',
#   'say',
#   'researchers'],
#  ['2019', 'hyundai', 'kona', 'ev', 'explodes', 'when', 'parked'],
#  ['the',
#   'league',
#   'of',
#   'entropy',
#   'is',
#   'making',
#   'randomness',
#   'truly',
#   'random'],
#  ['a',
#   'transparent',
#   'display',
#   'with',
#   'per-pixel',
#   'color',
#   'and',
#   'opacity',
#   'control'],
#  ['the',
#   '“terrascope”:',
#   'on',
#   'the',
#   'possibility',
#   'of',
#   'using',
#   'the',
#   'earth',
#   'as',
#   'an',
#   'atmospheric',
#   'lens'],
#  ['humans', 'dominated', 'earth', 'earlier', 'than', 'previously', 'thought'],
#  ['fuzzification:', 'anti-fuzzing', 'techniques', '[pdf]'],
#  ['what',
#   'is',
#   'zoned',
#   'storage',
#   'and',
#   'the',
#   'zoned',
#   'storage',
#   'initiative?'],
#  ['webmin', '1.890', 'exploit', '–', 'what', 'happened?'],
#  ['scaling', 'static', 'analyses', 'at', 'facebook'],
#  ['the',
#   'death',
#   'of',
#   'a',
#   'weather',
#   'satellite',
#   'as',
#   'seen',
#   'by',
#   'sdr'],
#  ['holidays', 'are', 'good', 'for', 'workers', 'and', 'companies', 'alike'],
#  ['richard', 'sorge:', 'the', 'soviet', 'union’s', 'master', 'spy'],
#  ['debunking', 'the', 'stanford', 'prison', 'experiment', '[pdf]'],
#  ['marium,',
#   'the',
#   'dugong',
#   'who',
#   'charmed',
#   'thailand,',
#   'dies',
#   'after',
#   'ingesting',
#   'plastic'],
#  ['simple',
#   'python',
#   'package',
#   'to',
#   'extract',
#   'deep',
#   'learning',
#   'features'],
#  ['massive', '‘ocean’', 'discovered', 'towards', 'earth’s', 'core', '(2014)'],
#  ['def', 'con', '2019', '–', 'ctf', 'retrospective'],
#  ['kdevops:',
#   'framework',
#   'for',
#   'setting',
#   'up',
#   'and',
#   'testing',
#   'the',
#   'linux',
#   'kernel',
#   'for',
#   'any',
#   'project'],
#  ['simple,',
#   'pure,',
#   'and',
#   'total',
#   'functional',
#   'language',
#   'that',
#   'generalizes',
#   'datalog'],
#  ['continuous',
#   '3d',
#   'printing',
#   'possible',
#   'with',
#   'transparent',
#   'polygon',
#   'scanning?'],
#  ['could',
#   'removing',
#   'social',
#   'media',
#   'metrics',
#   'reduce',
#   'polarization?'],
#  ['roaring',
#   'glacial',
#   'melt',
#   'under',
#   'the',
#   'bridge',
#   'to',
#   'kangerlussiauq,',
#   'greenland'],
#  ['the', 'new', 'treasures', 'of', 'pompeii'],
#  ['sec',
#   'investigating',
#   'data',
#   'leak',
#   'at',
#   'first',
#   'american',
#   'financial',
#   'corp'],
#  ['the', 'openbsd', 'ada', 'library'],
#  ["don't", 'say', '“homoiconic”', '(2018)'],
#  ['us',
#   'air',
#   'force',
#   'pauses',
#   'flights',
#   'for',
#   'over',
#   'a',
#   'hundred',
#   'c-130s',
#   'over',
#   '‘atypical’',
#   'cracking'],
#  ['i', 'am', 'a', 'horse', 'in', 'the', 'land', 'of', 'booleans'],
#  ['we',
#   'may',
#   'not',
#   'be',
#   'running',
#   'out',
#   'of',
#   'helium',
#   'after',
#   'all',
#   '(2015)'],
#  ['launch',
#   'hn:',
#   'shift',
#   'health',
#   '(yc',
#   's19)',
#   '–',
#   'understand',
#   'your',
#   'healthcare',
#   'costs',
#   'pre-visit'],
#  ['smartykit', 'apple', 'i', 'replica'],
#  ['gerbil', '–', 'a', 'meta-dialect', 'of', 'scheme'],
#  ['hawaii',
#   'extends',
#   'thirty',
#   'meter',
#   'telescope',
#   'permit',
#   'amid',
#   'protests'],
#  ['gm', 'is', 'now', 'detroit’s', 'smallest', 'auto-making', 'employer'],
#  ['the',
#   'dipole',
#   'drive:',
#   'a',
#   'new',
#   'concept',
#   'in',
#   'space',
#   'propulsion'],
#  ['universal', 'algorithm', 'set', 'to', 'boost', 'microscopes'],
#  ['fearing',
#   'data',
#   'privacy',
#   'issues,',
#   'google',
#   'cuts',
#   'some',
#   'android',
#   'phone',
#   'data',
#   'for',
#   'carriers'],
#  ['robotic',
#   'thread',
#   'is',
#   'designed',
#   'to',
#   'slip',
#   'through',
#   'the',
#   "brain's",
#   'blood',
#   'vessels'],
#  ['vickrey–clarke–groves', 'auction'],
#  ['prolog', 'control', 'in', 'six', 'slides'],
#  ['opinion', 'piece', 'on', 'ghc', 'back', 'ends'],
#  ['entropic:', 'a', 'federated', 'package', 'registry', 'for', 'anything'],
#  ['cbor', '–', 'concise', 'binary', 'object', 'representation'],
#  ['can', 'we', 'survive', 'technology?', '(1955)', '[pdf]'],
#  ['cassettes', 'are', 'back,', 'and', 'it’s', 'not', 'about', 'the', 'music'],
#  ['paul', 'dirac:', 'the', 'mozart', 'of', 'science', '(2008)'],
#  ['in', 'praise', 'of', 'xlogo'],
#  ['show',
#   'hn:',
#   'historical',
#   'order',
#   'book',
#   'reconstruction',
#   'api',
#   'for',
#   'crypto',
#   'markets'],
#  ['arcs', 'of', 'seniority'],
#  ['the', 'long', 'game', 'of', 'research'],
#  ['a', 'look', 'at', "hs2's", 'old', 'oak', 'common', 'station'],
#  ['how',
#   'judy',
#   'arrays',
#   'work',
#   'and',
#   'why',
#   'they',
#   'are',
#   'so',
#   'fast',
#   '(2002)'],
#  ['mining', 'bitcoin', 'on', 'an', 'apple', 'ii'],
#  ['unearthing',
#   'a',
#   'masterpiece:',
#   'a',
#   'rare',
#   'minoan',
#   'sealstone',
#   '(2017)'],
#  ['golden', 'ratio'],
#  ['show',
#   'hn:',
#   'pgcmd',
#   '–',
#   'an',
#   'alternative',
#   'to',
#   'psql',
#   'with',
#   'json',
#   'output'],
#  ['reviving', 'an', 'hp', '660lx', 'in', '2019'],
#  ['ssb', 'rooms:', 'a', 'new', 'server', 'type', 'for', 'scuttlebutt'],
#  ['implementing', 'poincaré', 'embeddings', '(2017)'],
#  ['extending', 'ocaml', 'programs', 'with', 'lua'],
#  ['container', 'networking', 'with', 'vxlan,', 'bgp', 'and', 'wireguard'],
#  ['a', 'fine', 'map', 'from', 'alexander', 'von', 'humboldt', '(1851)'],
#  ['new',
#   'research',
#   'on',
#   'ptsd',
#   'in',
#   'elephants',
#   'and',
#   'other',
#   'animals'],
#  ['“awakenings”',
#   'in',
#   'advanced',
#   'dementia',
#   'patients',
#   'hint',
#   'at',
#   'untapped',
#   'brain',
#   'reserves'],
#  ['recycling',
#   'of',
#   'plastics',
#   'enabled',
#   'by',
#   'dynamic',
#   'covalent',
#   'diketoenamine',
#   'bonds',
#   '(2018)',
#   '[pdf]'],
#  ['show',
#   'hn:',
#   'data-viz',
#   'project',
#   'for',
#   'ray-tracing',
#   'the',
#   'moon',
#   'model'],
#  ['five',
#   'new',
#   'real-time',
#   'detections',
#   'of',
#   'fast',
#   'radio',
#   'bursts',
#   'with',
#   'utmost'],
#  ['lucidscience', '–', 'electronic', 'projects', 'and', 'tutorials'],
#  ['what',
#   'are',
#   'children',
#   'dying',
#   'from',
#   'and',
#   'what',
#   'can',
#   'we',
#   'do',
#   'about',
#   'it?'],
#  ['a',
#   'conversation',
#   'with',
#   'the',
#   'team',
#   'that',
#   'made',
#   'bread',
#   'with',
#   'ancient',
#   'egyptian',
#   'yeast'],
#  ['air',
#   'force',
#   'reveals',
#   'tests',
#   'of',
#   'supposed',
#   'record-setting',
#   'scramjet',
#   'from',
#   'n.',
#   'grumman'],
#  ['the', 'decline', 'of', 'college', 'newspapers'],
#  ['which', 'is', 'the', 'best', 'john', 'le', 'carré', 'novel?', '(2014)'],
#  ['dreaming',
#   'about',
#   'better',
#   'sleep:',
#   'dreem,',
#   'oura',
#   'and',
#   'the',
#   'rest'],
#  ['penn', 'effect'],
#  ['hall’s',
#   'law:',
#   'the',
#   'nineteenth',
#   'century',
#   'prequel',
#   'to',
#   'moore’s',
#   'law',
#   '(2012)'],
#  ['volcanoes',
#   'on',
#   'the',
#   'moon',
#   'may',
#   'have',
#   'erupted',
#   'during',
#   'the',
#   'dinosaur',
#   'age',
#   '(2014)'],
#  ['the', 'world’s', 'smartest', 'chimp', 'has', 'died'],
#  ['smart',
#   'plastic',
#   'incineration',
#   'posited',
#   'as',
#   'solution',
#   'to',
#   'global',
#   'recycling',
#   'crisis'],
#  ['kei', '–', 'a', 'small', 'and', 'expressive', 'dependent', 'language'],
#  ['freshermeat', '–', 'open-source', 'security', 'software'],
#  ['engineers',
#   'build',
#   'advanced',
#   'microprocessor',
#   'out',
#   'of',
#   'carbon',
#   'nanotubes'],
#  ['a',
#   'new',
#   'york',
#   'farm',
#   'stand’s',
#   'success:',
#   'an',
#   'eye',
#   'for',
#   'the',
#   'next',
#   'big',
#   'thing'],
#  ['disneyland’s', 'disastrous', 'opening', 'day', '(2015)'],
#  ['a', 'z-machine', 'in', 'ocaml', '(2016)'],
#  ['quantum', 'air', 'buys', "bye's", 'electric', 'airplanes'],
#  ['famous', 'graphics', 'chips:', 'microsoft’s', 'talisman'],
#  ['engineers',
#   'develop',
#   'bone-like',
#   'metal',
#   'foam',
#   'that',
#   'can',
#   'be',
#   "'healed'",
#   'at',
#   'room',
#   'temperature'],
#  ['using',
#   'the',
#   'golden',
#   'research',
#   'engine',
#   'to',
#   'query',
#   'the',
#   'y',
#   'combinator',
#   's19',
#   'batch'],
#  ['a', 'mosque', 'rebuilt', 'once', 'a', 'year'],
#  ['flying', 'with', 'miniature', 'horses'],
#  ['the', 'oral', 'history', 'of', 'the', 'super', 'soaker'],
#  ['a', 'trailblazing', 'plan', 'to', 'fight', 'california', 'wildfires'],
#  ['show', 'hn:', 'firestorm', '–', 'an', 'orm', 'for', 'firestore'],
#  ['programming', 'shape', 'using', 'kirigami', 'tessellations'],
#  ['potosí:',
#   'the',
#   'mountain',
#   'of',
#   'silver',
#   'that',
#   'was',
#   'the',
#   'first',
#   'global',
#   'city'],
#  ['an',
#   'ancient',
#   'egypt-to-black',
#   'sea',
#   'route?',
#   'adventurers',
#   'to',
#   'test',
#   'theory'],
#  ['exploring', 'the', 'visible', 'spectrum', 'in', 'python'],
#  ['general', 'balanced', 'trees', '(1999)', '[pdf]'],
#  ['using',
#   'wall',
#   'street',
#   'secrets',
#   'to',
#   'reduce',
#   'the',
#   'cost',
#   'of',
#   'cloud',
#   'infrastructure'],
#  ['rediscovering', 'rules', 'for', 'ancient', 'board', 'games'],
#  ['on', 'the', 'road', 'in', '1980'],
#  ['the', 'software', 'arts'],
#  ['making', 'web-workers', 'async', 'iterables'],
#  ['show',
#   'hn:',
#   'quark-ide',
#   'and',
#   'a',
#   'javascript',
#   'runtime',
#   'to',
#   'build',
#   'cross-platform',
#   'desktop',
#   'apps'],
#  ['environment',
#   'and',
#   'the',
#   'programming',
#   'language',
#   'self,',
#   'part',
#   '4'],
#  ['the',
#   'lost',
#   'doves',
#   'press',
#   'typeface',
#   'and',
#   'its',
#   'revival',
#   '(2015)'],
#  ['early',
#   'years',
#   'of',
#   'computer',
#   'gaming:',
#   'steve',
#   'russell',
#   'and',
#   'nolan',
#   'bushnell',
#   '(2002)',
#   '[video]'],
#  ['the',
#   'quest',
#   'to',
#   'conquer',
#   'earth’s',
#   'space',
#   'junk',
#   'problem',
#   '(2018)'],
#  ['swadesh', 'list'],
#  ['salvator',
#   'mundi',
#   'and',
#   'the',
#   'unreality',
#   'of',
#   'the',
#   'art',
#   'market']]

# %%
import string

def removePunctuationsFunct(x):
    list_punct=list(string.punctuation)
    filtered = [''.join(c for c in s if c not in list_punct) for s in x] 
    filtered_space = [s for s in filtered if s] #remove empty space 
    return filtered
#link_titles_tokenize_word
#link_titles_punct = link_titles_clean.map(removePunctuationsFunct)
link_titles_punct = link_titles_tokenize_word.map(removePunctuationsFunct)
link_titles_punct.collect()
# Out:
# [['turning',
#   'a',
#   'macbook',
#   'into',
#   'a',
#   'touchscreen',
#   'with',
#   '1',
#   'of',
#   'hardware',
#   '2018'],
#  ['the', 'lonely', 'work', 'of', 'moderating', 'hacker', 'news'],
#  ['introducing', 'nushell'],
#  ['google',
#   'just',
#   'deleted',
#   'my',
#   'nearly',
#   '10yearold',
#   'free',
#   'and',
#   'opensource',
#   'android',
#   'app'],
#  ['ebola', 'is', 'now', 'curable'],
#  ['all',
#   'the',
#   'best',
#   'engineering',
#   'advice',
#   'i',
#   'stole',
#   'from',
#   'nontechnical',
#   'people'],
#  ['i', 'miss', 'microsoft', 'encarta'],
#  ['alan',
#   'kays',
#   'answer',
#   'to',
#   '‘what',
#   'are',
#   'some',
#   'forgotten',
#   'books',
#   'programmers',
#   'should',
#   'read’'],
#  ['information', 'operations', 'directed', 'at', 'hong', 'kong'],
#  ['terminating', 'service', 'for', '8chan'],
#  ['what',
#   'happens',
#   'when',
#   'you',
#   'launch',
#   'google',
#   'chrome',
#   'for',
#   'the',
#   'first',
#   'time'],
#  ['how', 'to', 'build', 'good', 'software'],
#  ['null', 'license', 'plate', 'not', 'such', 'a', 'bright', 'idea'],
#  ['what', 'does', 'a', 'coder', 'do', 'if', 'they', 'cant', 'type'],
#  ['yelp',
#   'is',
#   'replacing',
#   'restaurants’',
#   'phone',
#   'numbers',
#   'so',
#   'grubhub',
#   'can',
#   'take',
#   'a',
#   'cut'],
#  ['japanese', 'anime', 'studio', 'khara', 'moving', 'to', 'blender'],
#  ['deconstructing', 'google’s', 'excuses', 'on', 'tracking', 'protection'],
#  ['cloudflare', 's1'],
#  ['8chan',
#   'goes',
#   'dark',
#   'after',
#   'hardware',
#   'provider',
#   'discontinues',
#   'service'],
#  ['please', 'add', 'rss', 'support', 'to', 'your', 'site'],
#  ['no', 'more', 'cheap', 'shipping', 'for', 'chinese', 'sellers'],
#  ['python', 'is', 'eating', 'the', 'world'],
#  ['verizon', 'to', 'sell', 'tumblr', 'to', 'automattic'],
#  ['tasty', 'seaweed', 'reduces', 'cows’', 'methane', 'emissions', 'by', '99'],
#  ['hy'],
#  ['things', 'i', 'learnt', 'from', 'a', 'senior', 'software', 'engineer'],
#  ['wewtf'],
#  ['linux', 'journal', 'ceases', 'publication', 'an', 'awkward', 'goodbye'],
#  ['amd',
#   'lands',
#   'google',
#   'twitter',
#   'as',
#   'customers',
#   'with',
#   'newest',
#   'server',
#   'chip'],
#  ['us',
#   'navy',
#   'will',
#   'replace',
#   'touchscreen',
#   'with',
#   'mechanical',
#   'controls',
#   'on',
#   'its',
#   'destroyers'],
#  ['standard',
#   'ebooks',
#   'free',
#   'publicdomain',
#   'ebooks',
#   'carefully',
#   'produced'],
#  ['why', 'is', 'modern', 'web', 'development', 'so', 'complicated'],
#  ['a',
#   'man',
#   'who',
#   'destroyed',
#   'his',
#   'multimillion',
#   'dollar',
#   'company',
#   'in',
#   '10',
#   'seconds',
#   '2018'],
#  ['opendrop', 'an', 'open', 'source', 'airdrop', 'implementation'],
#  ['a',
#   'deep',
#   'dive',
#   'into',
#   'ios',
#   'exploit',
#   'chains',
#   'found',
#   'in',
#   'the',
#   'wild'],
#  ['software', 'architecture', 'guide'],
#  ['sites',
#   'using',
#   'facebook',
#   '‘like’',
#   'button',
#   'liable',
#   'for',
#   'data',
#   'eu',
#   'court',
#   'rules'],
#  ['insect',
#   'apocalypse',
#   'in',
#   'us',
#   'driven',
#   'by',
#   '50x',
#   'increase',
#   'in',
#   'toxic',
#   'pesticides',
#   'study'],
#  ['apple',
#   'confirms',
#   '1m',
#   'reward',
#   'for',
#   'anyone',
#   'who',
#   'can',
#   'hack',
#   'an',
#   'iphone'],
#  ['why', 'all', 'of', 'our', 'games', 'look', 'like', 'crap'],
#  ['tech', 'interview', 'handbook'],
#  ['fewer',
#   'than',
#   'half',
#   'of',
#   'google',
#   'searches',
#   'now',
#   'result',
#   'in',
#   'a',
#   'click'],
#  ['ugly',
#   'gerry',
#   '–',
#   'font',
#   'created',
#   'from',
#   'congressional',
#   'districts'],
#  ['why', 'has', 'examinecom', 'disappeared', 'from', 'search', 'results'],
#  ['a', 'walk', 'in', 'hong', 'kong'],
#  ['john', 'carmack', 'on', 'the', 'joe', 'rogan', 'experience', 'video'],
#  ['the',
#   'baseline',
#   'interpreter',
#   'a',
#   'faster',
#   'javascript',
#   'interpreter',
#   'in',
#   'firefox',
#   '70'],
#  ['google',
#   'doesn’t',
#   'want',
#   'staff',
#   'debating',
#   'politics',
#   'at',
#   'work',
#   'anymore'],
#  ['build', 'your', 'own', 'text', 'editor'],
#  ['ive',
#   'reproduced',
#   '130',
#   'research',
#   'papers',
#   'about',
#   '“predicting',
#   'the',
#   'stock',
#   'market”'],
#  ['ask', 'hn', 'how', 'do', 'you', 'read'],
#  ['how',
#   'to',
#   'build',
#   'a',
#   'plugin',
#   'system',
#   'on',
#   'the',
#   'web',
#   'and',
#   'also',
#   'sleep',
#   'well',
#   'at',
#   'night'],
#  ['europe',
#   'is',
#   'edging',
#   'towards',
#   'making',
#   'postcar',
#   'cities',
#   'a',
#   'reality'],
#  ['new',
#   'york',
#   'city',
#   'neighbors',
#   'build',
#   'cheaper',
#   'way',
#   'to',
#   'connect',
#   'to',
#   'web'],
#  ['github',
#   'actions',
#   'now',
#   'supports',
#   'cicd',
#   'free',
#   'for',
#   'public',
#   'repositories'],
#  ['consume', 'less', 'create', 'more'],
#  ['living',
#   'near',
#   'trees',
#   'not',
#   'just',
#   'green',
#   'space',
#   'improves',
#   'wellbeing'],
#  ['kerbal', 'space', 'program', '2'],
#  ['macbook', 'pro', 'keyboard', 'drives', 'me', 'crazy'],
#  ['why', 'i', 'turned', 'down', 'an', 'aws', 'job', 'offer'],
#  ['facebook', 'has', 'been', 'granted', 'patent', 'on', 'shadow', 'banning'],
#  ['the',
#   'linux',
#   'kernels',
#   'inability',
#   'to',
#   'gracefully',
#   'handle',
#   'low',
#   'memory',
#   'pressure'],
#  ['show',
#   'hn',
#   'cli',
#   'tool',
#   'for',
#   'saving',
#   'web',
#   'pages',
#   'as',
#   'a',
#   'single',
#   'file'],
#  ['start', 'your', 'own', 'isp'],
#  ['every',
#   'productivity',
#   'thought',
#   'ive',
#   'ever',
#   'had',
#   'as',
#   'concisely',
#   'as',
#   'possible'],
#  ['preindustrial',
#   'workers',
#   'worked',
#   'fewer',
#   'hours',
#   'than',
#   'todays',
#   '2009'],
#  ['milky',
#   'way’s',
#   'black',
#   'hole',
#   'just',
#   'flared',
#   'growing',
#   '75',
#   'times',
#   'as',
#   'bright',
#   'for',
#   'a',
#   'few',
#   'hours'],
#  ['amazon',
#   'has',
#   'proven',
#   'unable',
#   'or',
#   'unwilling',
#   'to',
#   'effectively',
#   'police',
#   'thirdparty',
#   'sellers'],
#  ['rails', '60'],
#  ['haha', 'wall'],
#  ['speaking',
#   'to',
#   'yourself',
#   'in',
#   'the',
#   'third',
#   'person',
#   'makes',
#   'you',
#   'wiser'],
#  ['ibm', 'opensources', 'power', 'chip', 'instruction', 'set'],
#  ['apple',
#   'expands',
#   'parts',
#   'access',
#   'to',
#   'more',
#   'independent',
#   'repair',
#   'businesses'],
#  ['paged',
#   'out',
#   '–',
#   'a',
#   'new',
#   'experimental',
#   'magazine',
#   'about',
#   'programming'],
#  ['lets', 'build', 'houses', 'for', 'people', 'not', 'cars'],
#  ['we', 'have', 'ruined', 'childhood'],
#  ['decrement', 'carbon', 'stripes', 'negative', 'emissions', 'commitment'],
#  ['16m',
#   'americans',
#   'will',
#   'vote',
#   'on',
#   'hackable',
#   'paperless',
#   'machines'],
#  ['home', 'chip', 'fab'],
#  ['google',
#   'and',
#   'mozilla',
#   'are',
#   'failing',
#   'to',
#   'support',
#   'browser',
#   'extension',
#   'developers'],
#  ['a',
#   'mathematicians',
#   'way',
#   'of',
#   'converting',
#   'miles',
#   'to',
#   'kilometers'],
#  ['there', 'is', 'no', 'evil', 'like', 'recaptcha'],
#  ['kaspersky',
#   'av',
#   'injected',
#   'unique',
#   'id',
#   'allowing',
#   'sites',
#   'to',
#   'track',
#   'users',
#   'in',
#   'incognito',
#   'mode'],
#  ['who', 'owns', 'huawei'],
#  ['the', 'horror', 'of', 'microsoft', 'teams'],
#  ['hundreds',
#   'of',
#   'extreme',
#   'selfciting',
#   'scientists',
#   'revealed',
#   'in',
#   'new',
#   'database'],
#  ['regex', 'for', 'noobs', '–', 'an', 'illustrated', 'guide'],
#  ['apple',
#   'will',
#   'soon',
#   'treat',
#   'online',
#   'web',
#   'tracking',
#   'the',
#   'same',
#   'as',
#   'a',
#   'security',
#   'vulnerability'],
#  ['the', 'it', 'guy', 'vs', 'the', 'con', 'artist'],
#  ['death', 'note', 'l', 'anonymity', 'and', 'eluding', 'entropy', '2017'],
#  ['amd',
#   'rome',
#   'second',
#   'generation',
#   'epyc',
#   'review',
#   '2x',
#   '64core',
#   'benchmarked'],
#  ['amazon', 'is', 'a', 'monopoly'],
#  ['time', 'anxiety', 'is', 'it', 'too', 'late'],
#  ['wtf',
#   '–',
#   'a',
#   'personal',
#   'information',
#   'dashboard',
#   'for',
#   'your',
#   'terminal'],
#  ['scientists',
#   'discover',
#   'a',
#   'cure',
#   'for',
#   'the',
#   'deadliest',
#   'strain',
#   'of',
#   'tuberculosis'],
#  ['show', 'hn', 'divjoy', '–', 'react', 'codebase', 'and', 'ui', 'generator'],
#  ['proteins',
#   'that',
#   'may',
#   'restore',
#   'damaged',
#   'sounddetecting',
#   'cells',
#   'in',
#   'the',
#   'ear'],
#  ['15',
#   'states',
#   'are',
#   'trying',
#   'to',
#   'make',
#   'the',
#   'electoral',
#   'college',
#   'obselete'],
#  ['banned',
#   'c',
#   'standard',
#   'library',
#   'functions',
#   'in',
#   'git',
#   'source',
#   'code'],
#  ['pronunciations', 'for', 'hexadecimal', 'numbers', '1968'],
#  ['turbo', 'an', 'improved', 'rainbow', 'colormap', 'for', 'visualization'],
#  ['from',
#   'mac',
#   'to',
#   'linux',
#   '–',
#   'the',
#   'setup',
#   'ive',
#   'grown',
#   'to',
#   'love'],
#  ['time', 'to', 'get', 'serious', 'about', 'tickborne', 'diseases'],
#  ['pentagon',
#   'testing',
#   'mass',
#   'surveillance',
#   'balloons',
#   'across',
#   'the',
#   'us'],
#  ['useless', 'windows', '10', 'features'],
#  ['some', 'obscure', 'c', 'features'],
#  ['mercedesbenz', 'presafe', 'sound'],
#  ['tsv',
#   'utilities',
#   'command',
#   'line',
#   'tools',
#   'for',
#   'large',
#   'tabular',
#   'data',
#   'files'],
#  ['psytrance', 'guide'],
#  ['researcher',
#   'banned',
#   'on',
#   'valves',
#   'bug',
#   'bounty',
#   'program',
#   'publishes',
#   'second',
#   'steam',
#   '0day'],
#  ['why',
#   'do',
#   'developers',
#   'at',
#   'google',
#   'consider',
#   'agile',
#   'development',
#   'to',
#   'be',
#   'nonsense',
#   '2016'],
#  ['planet', 'imaging', 'the', 'entire', 'earth', 'every', 'day'],
#  ['software', 'made', 'me', 'loathe', 'my', 'car'],
#  ['dqlite', '–', 'highavailability', 'sqlite'],
#  ['cutiepi', '–', 'allinone', 'raspberry', 'pi', 'tablet'],
#  ['knuth',
#   'on',
#   'huangs',
#   'sensitivity',
#   'proof',
#   '“ive',
#   'got',
#   'the',
#   'proof',
#   'down',
#   'to',
#   'one',
#   'page”',
#   'pdf'],
#  ['supercentenarians',
#   'are',
#   'concentrated',
#   'into',
#   'regions',
#   'with',
#   'no',
#   'birth',
#   'certificates'],
#  ['anthony',
#   'levandowski',
#   'charged',
#   'with',
#   'theft',
#   'of',
#   'trade',
#   'secrets'],
#  ['exfat', 'in', 'the', 'linux', 'kernel'],
#  ['speed',
#   'matters',
#   'why',
#   'working',
#   'quickly',
#   'is',
#   'more',
#   'important',
#   'than',
#   'it',
#   'seems',
#   '2015'],
#  ['programmers',
#   'before',
#   'you',
#   'turn',
#   '40',
#   'get',
#   'a',
#   'plan',
#   'b',
#   '2009'],
#  ['information', 'theory', 'for', 'intelligent', 'people', '2018', 'pdf'],
#  ['i',
#   'completed',
#   'ultimate',
#   'go',
#   'took',
#   'good',
#   'notes',
#   'and',
#   'commented',
#   'directly',
#   'on',
#   'source',
#   'code'],
#  ['a',
#   'guide',
#   'to',
#   'recording',
#   '660fps',
#   'video',
#   'on',
#   'a',
#   '6',
#   'raspberry',
#   'pi',
#   'camera'],
#  ['super', 'mario', '64', 'has', 'been', 'decompiled'],
#  ['yaml', 'probably', 'not', 'so', 'great', 'after', 'all'],
#  ['rust', 'language', 'cheat', 'sheet'],
#  ['thoughts', 'on', 'rust', 'bloat'],
#  ['google', 'chrome', 'incognito', 'mode', 'can', 'still', 'be', 'detected'],
#  ['rules', 'for', 'intuitive', 'ux'],
#  ['iterm2', '33'],
#  ['datadog', 's1'],
#  ['the',
#   'not',
#   'so',
#   'hidden',
#   'cost',
#   'of',
#   'sharing',
#   'code',
#   'between',
#   'ios',
#   'and',
#   'android'],
#  ['show', 'hn', 'chartxkcd', '–', 'xkcdstyled', 'chart', 'library'],
#  ['tell', 'hn', 'danny', 'cohen', 'has', 'died'],
#  ['down', 'the', 'rabbithole'],
#  ['three', 'kinds', 'of', 'good', 'tech', 'debt'],
#  ['facebook',
#   'scans',
#   'system',
#   'libraries',
#   'on',
#   'android',
#   'and',
#   'uploads',
#   'them',
#   'to',
#   'their',
#   'server'],
#  ['uber', 'posts', '52b', 'loss', 'and', 'slowest', 'ever', 'growth', 'rate'],
#  ['the', 'fully', 'remote', 'attack', 'surface', 'of', 'the', 'iphone'],
#  ['google',
#   'to',
#   'offer',
#   'a',
#   'best',
#   'price',
#   'guarantee',
#   'on',
#   'certain',
#   'flights'],
#  ['npm', 'bans', 'terminal', 'ads'],
#  ['the', 'architecture', 'of', 'open', 'source', 'applications'],
#  ['people', 'love', 'working', 'remotely'],
#  ['berlin’s', 'popular', 'shopping', 'streets', 'will', 'go', 'carfree'],
#  ['toni', 'morrison', 'has', 'died'],
#  ['sourcehut', 'welcomes', 'bitbucket', 'refugees'],
#  ['ai',
#   'startup',
#   'claims',
#   'to',
#   'automate',
#   'app',
#   'making',
#   'but',
#   'actually',
#   'just',
#   'uses',
#   'humans'],
#  ['ask',
#   'hn',
#   'recommended',
#   'resources',
#   'to',
#   'learn',
#   'the',
#   'linux',
#   'kernel',
#   'and',
#   'os',
#   'theory'],
#  ['steam', 'windows', 'client', 'local', 'privilege', 'escalation', '0day'],
#  ['hong',
#   'kong',
#   'isp',
#   'association’s',
#   'statement',
#   'on',
#   'selective',
#   'blocking',
#   'of',
#   'internet',
#   'services'],
#  ['i',
#   'wasn’t',
#   'getting',
#   'hired',
#   'as',
#   'a',
#   'data',
#   'scientist',
#   'so',
#   'i',
#   'sought',
#   'data',
#   'on',
#   'who',
#   'is'],
#  ['juul',
#   'philip',
#   'morris',
#   'sued',
#   'under',
#   'racketeer',
#   'act',
#   'for',
#   'targeting',
#   'kids'],
#  ['vmware',
#   'acquires',
#   'carbon',
#   'black',
#   'for',
#   '21b',
#   'and',
#   'pivotal',
#   'for',
#   '27b'],
#  ['zen',
#   '2',
#   'missives',
#   '–',
#   'amd',
#   'now',
#   'delivering',
#   'efficiencies',
#   'that',
#   'are',
#   'double',
#   'that',
#   'of',
#   'intel'],
#  ['write', 'your', 'own', 'excel', 'in', 'f', '2018'],
#  ['performance', 'matters'],
#  ['is', 'perl', '6', 'being', 'renamed'],
#  ['people', 'simply', 'empty', 'out', '1986'],
#  ['black',
#   'hat',
#   'gdpr',
#   'privacy',
#   'law',
#   'exploited',
#   'to',
#   'reveal',
#   'personal',
#   'data'],
#  ['show',
#   'hn',
#   'i',
#   'trained',
#   'a',
#   'deep',
#   'learning',
#   'model',
#   'to',
#   'build',
#   'sites',
#   'for',
#   'me'],
#  ['webkit', 'tracking', 'prevention', 'policy'],
#  ['removing', 'coordinated', 'inauthentic', 'behavior', 'from', 'china'],
#  ['calculus', 'for', 'the', 'people'],
#  ['anxiety', 'looks', 'different', 'in', 'men'],
#  ['yield', 'curves', 'invert', 'in', 'us', 'uk'],
#  ['amazon',
#   'offered',
#   '‘amazon’s',
#   'choice’',
#   'to',
#   'vendors',
#   'who',
#   'bought',
#   'ads',
#   'and',
#   'lowered',
#   'prices'],
#  ['cyberchef', '–', 'cyber', 'swiss', 'army', 'knife'],
#  ['rust', '1370'],
#  ['a',
#   'boeing',
#   'code',
#   'leak',
#   'exposes',
#   'security',
#   'flaws',
#   'deep',
#   'in',
#   'a',
#   '787s',
#   'guts'],
#  ['ask', 'hn', 'best', 'resources', 'to', 'gain', 'math', 'intuition'],
#  ['mozilla', 'takes', 'action', 'to', 'protect', 'users', 'in', 'kazakhstan'],
#  ['anime4k', 'real', 'time', 'high', 'quality', 'video', 'upscaling'],
#  ['wine', 'on', 'windows', '10'],
#  ['building',
#   'a',
#   'distributed',
#   'timeseries',
#   'database',
#   'on',
#   'postgresql'],
#  ['xfce', '414'],
#  ['most', 'startup', 'theory', 'is', 'expost', 'therefore', 'bs'],
#  ['lessons', 'from', 'stripe'],
#  ['show',
#   'hn',
#   'wavebased',
#   'nonlineofsight',
#   'computational',
#   'imaging',
#   'in',
#   'julia'],
#  ['‘they',
#   'get',
#   'fired',
#   'all',
#   'the',
#   'time',
#   'and',
#   'they',
#   'have',
#   'no',
#   'idea',
#   'why’'],
#  ['9th',
#   'circuit',
#   'says',
#   'users',
#   'can',
#   'sue',
#   'facebook',
#   'over',
#   'unlawful',
#   'use',
#   'of',
#   'facial',
#   'recognition'],
#  ['linux',
#   'kernel',
#   'drivers',
#   'in',
#   'rust',
#   'might',
#   'become',
#   'an',
#   'option',
#   'in',
#   'the',
#   'future'],
#  ['moviepass', 'worked', 'out', 'great'],
#  ['a',
#   'beginner’s',
#   'introduction',
#   'to',
#   'python',
#   'web',
#   'frameworks',
#   '2018'],
#  ['ask', 'hn', 'who', 'is', 'hiring', 'august', '2019'],
#  ['show', 'hn', 'data', 'structures', 'and', 'algorithms', 'in', 'javascript'],
#  ['await', 'in', 'rust'],
#  ['cool', 'but', 'obscure', 'x11', 'tools'],
#  ['elsevier',
#   'threatens',
#   'others',
#   'for',
#   'linking',
#   'to',
#   'scihub',
#   'but',
#   'does',
#   'so',
#   'itself'],
#  ['group',
#   'sex',
#   'app',
#   'leaks',
#   'locations',
#   'pics',
#   'and',
#   'personal',
#   'details'],
#  ['apple',
#   'is',
#   'locking',
#   'iphone',
#   'batteries',
#   'to',
#   'discourage',
#   'repair'],
#  ['“i', 'would', 'like', 'to', 'maintain', 'the', 'floppy', 'driver”'],
#  ['fracking',
#   'in',
#   'north',
#   'america',
#   'could',
#   'be',
#   'partly',
#   'to',
#   'blame',
#   'for',
#   'methane',
#   'spike',
#   '–',
#   'study'],
#  ['flawed',
#   'algorithms',
#   'are',
#   'grading',
#   'millions',
#   'of',
#   'students’',
#   'essays'],
#  ['35', 'over', '35'],
#  ['us', 'designates', 'china', 'as', 'currency', 'manipulator'],
#  ['sunsetting', 'mercurial', 'support', 'in', 'bitbucket'],
#  ['open',
#   'letter',
#   'from',
#   'an',
#   'android',
#   'developer',
#   'to',
#   'the',
#   'google',
#   'play',
#   'team'],
#  ['cue',
#   '–',
#   'a',
#   'language',
#   'for',
#   'defining',
#   'generating',
#   'and',
#   'validating',
#   'data'],
#  ['how', 'rust', 'optimizes', 'asyncawait'],
#  ['one',
#   'city',
#   'saved',
#   '5m',
#   'by',
#   'routing',
#   'school',
#   'buses',
#   'with',
#   'an',
#   'algorithm'],
#  ['asyncstd',
#   'an',
#   'async',
#   'port',
#   'of',
#   'the',
#   'rust',
#   'standard',
#   'library'],
#  ['regexr'],
#  ['the', 'art', 'of', 'warez', 'video'],
#  ['get', 'your', 'work', 'recognized', 'write', 'a', 'brag', 'document'],
#  ['one',
#   'job',
#   'many',
#   'roles',
#   'the',
#   'different',
#   'skills',
#   'needed',
#   'to',
#   'be',
#   'a',
#   'successful',
#   'cto'],
#  ['productivity', 'and', 'the', 'workweek', '2000'],
#  ['nigerian',
#   'teens',
#   'are',
#   'making',
#   'scifi',
#   'shorts',
#   'with',
#   'slick',
#   'visual',
#   'effects'],
#  ['the',
#   'most',
#   'frequent',
#   '777',
#   'characters',
#   'give',
#   '90',
#   'coverage',
#   'of',
#   'kanji',
#   'in',
#   'the',
#   'wild'],
#  ['contributing', 'to', 'the', 'mozilla', 'code', 'base'],
#  ['the', 'lost', 'art', 'of', 'lacing', 'cable', '2018'],
#  ['martini', 'realtime', 'terrain', 'mesh', 'generator'],
#  ['the', 'impact', 'of', 'meditating', 'every', 'day'],
#  ['software',
#   'was',
#   'eating',
#   'the',
#   'world',
#   '–',
#   'now',
#   'landlords',
#   'are',
#   'eating',
#   'everything'],
#  ['ibm',
#   'has',
#   'released',
#   'the',
#   'power',
#   'architecture',
#   'instruction',
#   'set',
#   'to',
#   'the',
#   'linux',
#   'foundation'],
#  ['plastics', 'whats', 'recyclable', 'what', 'becomes', 'trash', 'and', 'why'],
#  ['uber', 'losing', 'billions', 'freezes', 'engineering', 'hires'],
#  ['irs',
#   'budget',
#   'cuts',
#   'cost',
#   '343b',
#   'in',
#   'lost',
#   'revenue',
#   'from',
#   'big',
#   'business'],
#  ['calculus', 'is', 'deeply', 'irrational'],
#  ['every', 'noise', 'at', 'once'],
#  ['att',
#   'employees',
#   'were',
#   'bribed',
#   'to',
#   'install',
#   'phone',
#   'unlocking',
#   'malware',
#   'on',
#   'company',
#   'network'],
#  ['the', 'problem', 'at', 'yale', 'is', 'not', 'free', 'speech'],
#  ['silk'],
#  ['beyond',
#   'meat',
#   'and',
#   'kfc',
#   'partner',
#   'to',
#   'test',
#   'fried',
#   'plantbased',
#   '‘chicken’'],
#  ['the', 'we', 'company', 's1'],
#  ['how', 'to', 'return', 'to', 'the', 'flow', 'faster'],
#  ['the',
#   'paxos',
#   'algorithm',
#   'or',
#   'how',
#   'to',
#   'win',
#   'a',
#   'turing',
#   'award'],
#  ['attorney', 'general', 'barr', 'and', 'encryption'],
#  ['making', 'email', 'more', 'modern', 'with', 'jmap'],
#  ['ffmpeg', '42'],
#  ['webassembly',
#   'interface',
#   'types',
#   'interoperate',
#   'with',
#   'all',
#   'the',
#   'things'],
#  ['roblox',
#   'hits',
#   '100m',
#   'monthly',
#   'active',
#   'users',
#   'bigger',
#   'than',
#   'minecraft'],
#  ['words', 'that', 'do', 'handstands'],
#  ['how', 'men’s', 'bodies', 'change', 'when', 'they', 'become', 'fathers'],
#  ['misconfigured',
#   'jira',
#   'instances',
#   'exposed',
#   'data',
#   'of',
#   'hundreds',
#   'of',
#   'fortune',
#   '500',
#   'companies'],
#  ['companies',
#   'use',
#   'borrowed',
#   'billions',
#   'to',
#   'buy',
#   'back',
#   'stock',
#   'not',
#   'to',
#   'invest'],
#  ['ny',
#   'state',
#   'alleges',
#   'exxonmobil',
#   'knew',
#   'risks',
#   'of',
#   'climate',
#   'change',
#   'and',
#   'defrauded',
#   'investors'],
#  ['new', 'react', 'devtools'],
#  ['wework',
#   'gets',
#   'tax',
#   'rebate',
#   'meant',
#   'for',
#   'its',
#   'smallbusiness',
#   'tenants'],
#  ['administration',
#   'using',
#   'the',
#   'full',
#   'power',
#   'of',
#   'the',
#   'surveillance',
#   'state',
#   'on',
#   'whistleblowers'],
#  ['a',
#   'book',
#   'from',
#   'alan',
#   'turing',
#   'and',
#   'a',
#   'mysterious',
#   'piece',
#   'of',
#   'paper'],
#  ['how', 'to', 'get', 'your', 'first', 'ten', 'customers', '2013'],
#  ['does', 'the', 'amazon', 'provide', '20', 'of', 'our', 'oxygen'],
#  ['uber',
#   'proposes',
#   'policy',
#   'that',
#   'would',
#   'pay',
#   'drivers',
#   'a',
#   'minimum',
#   'wage',
#   'of',
#   '21',
#   'per',
#   'hour'],
#  ['the', 'most', 'dangerous', 'writing', 'app'],
#  ['why',
#   'did',
#   'china',
#   'just',
#   'devalue',
#   'the',
#   'yuan',
#   'how',
#   'trade',
#   'works',
#   'with',
#   'freefloating',
#   'currency'],
#  ['arend',
#   'theorem',
#   'prover',
#   'based',
#   'on',
#   'homotopy',
#   'type',
#   'theory',
#   'by',
#   'jetbrains'],
#  ['blazingsql', 'is', 'now', 'open', 'source'],
#  ['key', 'negotiation', 'of', 'bluetooth', 'attack'],
#  ['ondevice', 'realtime', 'hand', 'tracking', 'with', 'mediapipe'],
#  ['dirty', 'tricks', '6502', 'programmers', 'use'],
#  ['insured', 'price', '2758', 'cash', 'price', '521'],
#  ['germans', 'grow', 'frustrated', 'with', 'their', 'slowpoke', 'internet'],
#  ['building', 'a', 'raspberry', 'pi', '3b', 'full', 'keyboard', 'handheld'],
#  ['show',
#   'hn',
#   'saag',
#   'as',
#   'a',
#   'service',
#   '–',
#   'macronutrientportioned',
#   'indian',
#   'spinach',
#   'curry'],
#  ['social', 'exclusion', 'fuels', 'extremism', 'in', 'young', 'men'],
#  ['camscanner',
#   'a',
#   'malicious',
#   'android',
#   'app',
#   'with',
#   'more',
#   'than',
#   '100m',
#   'downloads',
#   'in',
#   'google',
#   'play'],
#  ['moscows',
#   'blockchain',
#   'voting',
#   'system',
#   'cracked',
#   'a',
#   'month',
#   'before',
#   'election'],
#  ['anna', 'karenina', 'principle'],
#  ['qemu', 'vm', 'escape'],
#  ['inflated',
#   'bond',
#   'ratings',
#   'helped',
#   'spur',
#   'the',
#   'financial',
#   'crisis',
#   'they’re',
#   'back'],
#  ['medieval', 'people', 'bathed', 'regularly'],
#  ['devilution',
#   '–',
#   'a',
#   'web',
#   'port',
#   'of',
#   'the',
#   'original',
#   'diablo',
#   'game'],
#  ['cooling', 'a', 'house', 'without', 'air', 'conditioning'],
#  ['38myearold',
#   'skull',
#   'of',
#   'an',
#   'early',
#   'apelike',
#   'human',
#   'ancestor',
#   'discovered',
#   'in',
#   'ethiopia'],
#  ['huawei',
#   'technicians',
#   'helped',
#   'african',
#   'governments',
#   'spy',
#   'on',
#   'political',
#   'opponents'],
#  ['typescript', '36'],
#  ['the', 'answer', 'to', '“will', 'you', 'mentor', 'me”', 'is', 'no', '2010'],
#  ['how',
#   'to',
#   'measure',
#   'indoor',
#   'air',
#   'quality',
#   'with',
#   'a',
#   'raspberry',
#   'pi',
#   'ruuvitags',
#   'and',
#   'pms7003'],
#  ['wework', 'isn’t', 'a', 'tech', 'company'],
#  ['why', 'const', 'doesnt', 'make', 'c', 'code', 'faster'],
#  ['verified', 'by', 'twilio'],
#  ['python', 'vs', 'rust', 'for', 'neural', 'networks'],
#  ['big', 'coal', 'plants', 'begin', 'to', 'close'],
#  ['aussie', 'isv', 'buys', 'ads', 'to', 'wake', 'up', 'google', 'support'],
#  ['the', 'feynman', 'lectures', 'on', 'physics', 'algebra', '1963'],
#  ['coinbase', 'responding', 'to', 'firefox', '0days', 'in', 'the', 'wild'],
#  ['gamedev',
#   'tutorial',
#   'trigonometry',
#   'basics',
#   '–',
#   'sine',
#   'and',
#   'cosine'],
#  ['secretly',
#   'public',
#   'domain',
#   'most',
#   'books',
#   'published',
#   'in',
#   'the',
#   'us',
#   'before',
#   '1964'],
#  ['show',
#   'hn',
#   'clojurescript',
#   'pixel',
#   'game',
#   'engine',
#   'with',
#   'blender',
#   'livereloading'],
#  ['lisp', 'is', 'not', 'based', 'on', 'the', 'lambda', 'calculus'],
#  ['alphabet',
#   'overtakes',
#   'apple',
#   'to',
#   'become',
#   'most',
#   'cashrich',
#   'company'],
#  ['rice',
#   'university',
#   'researchers',
#   'propose',
#   'a',
#   'way',
#   'to',
#   'boost',
#   'solar',
#   'efficiency'],
#  ['using',
#   'backblaze',
#   'b2',
#   'and',
#   'cloudflare',
#   'workers',
#   'for',
#   'free',
#   'image',
#   'hosting'],
#  ['the',
#   'worst',
#   'sales',
#   'promotion',
#   'in',
#   'history',
#   'hoovers',
#   'free',
#   'flight',
#   'fiasco'],
#  ['the', 'door', 'problem', 'of', 'combat', 'design'],
#  ['wikipedia', 'is', 'now', 'a', 'brave', 'verified', 'publisher'],
#  ['google',
#   'plans',
#   'to',
#   'deprecate',
#   'ftp',
#   'url',
#   'support',
#   'in',
#   'chrome'],
#  ['killing', 'a', 'process', 'and', 'all', 'of', 'its', 'descendants'],
#  ['show',
#   'hn',
#   'i',
#   'created',
#   'postwoman',
#   'an',
#   'online',
#   'opensource',
#   'api',
#   'request',
#   'builder'],
#  ['the', 'many', 'possibilities', 'of', 'imessage', 'file', 'vulnerability'],
#  ['the',
#   'design',
#   'of',
#   'littlefs',
#   'a',
#   'failsafe',
#   'filesystem',
#   'designed',
#   'for',
#   'microcontrollers'],
#  ['ask',
#   'hn',
#   'whats',
#   'the',
#   'best',
#   'setup',
#   'for',
#   'ad',
#   'blocking',
#   'and',
#   'tracker',
#   'blocking'],
#  ['rabbit', 'holes', 'the', 'secret', 'to', 'technical', 'expertise'],
#  ['show',
#   'hn',
#   'i',
#   'made',
#   'a',
#   'crm',
#   'system',
#   'to',
#   'make',
#   'sales',
#   'fun'],
#  ['syslog', 'complete', 'system', 'administrator', 'guide'],
#  ['my', 'sudden', 'trip', 'to', 'hell'],
#  ['why', 'does', 'all', 'life', 'use', 'the', 'same', '20', 'amino', 'acids'],
#  ['toshiba', 'introduces', 'new', 'tiny', 'nvme', 'ssd', 'form', 'factor'],
#  ['john', 'carmack', 'on', 'parallel', 'implementations', '2018'],
#  ['gnu', 'radio', '38'],
#  ['ask', 'hn', 'how', 'do', 'you', 'handle', 'logging'],
#  ['the', 'github', 'registry', 'public', 'beta', 'is', 'live'],
#  ['a', 'practical', 'guide', 'to', 'css', 'transitions', 'and', 'animations'],
#  ['us',
#   'farmers',
#   'stung',
#   'by',
#   'tariffs',
#   'now',
#   'face',
#   'a',
#   '35b',
#   'corn',
#   'loss'],
#  ['facebook',
#   'hit',
#   'by',
#   'apple’s',
#   'crackdown',
#   'on',
#   'messaging',
#   'feature'],
#  ['privacy',
#   'sandbox',
#   '–',
#   'open',
#   'standards',
#   'to',
#   'enhance',
#   'privacy',
#   'on',
#   'the',
#   'web'],
#  ['transformers', 'from', 'scratch'],
#  ['we', 'made', 'amiga', 'they', 'fucked', 'it', 'up', '2015'],
#  ['memory', 'management', 'in', 'python'],
#  ['die',
#   'with',
#   'me',
#   '–',
#   'a',
#   'chat',
#   'app',
#   'you',
#   'can',
#   'only',
#   'use',
#   'when',
#   'you',
#   'have',
#   'less',
#   'than',
#   '5',
#   'battery'],
#  ['now',
#   'bigger',
#   'than',
#   'ebay',
#   'shopify',
#   'sets',
#   'its',
#   'sights',
#   'on',
#   'amazon'],
#  ['lets', 'build', 'a', 'video', 'card'],
#  ['pastel',
#   'a',
#   'commandline',
#   'tool',
#   'to',
#   'generate',
#   'analyze',
#   'convert',
#   'and',
#   'manipulate',
#   'colors'],
#  ['pagemap', 'a', 'mini', 'map', 'for', 'your', 'website'],
#  ['minify', 'your', 'svgs'],
#  ['yubico',
#   'launches',
#   'its',
#   'dual',
#   'usbc',
#   'and',
#   'lightning',
#   'twofactor',
#   'security',
#   'key'],
#  ['a',
#   'bloomberg',
#   'reporter’s',
#   'account',
#   'of',
#   'trying',
#   'to',
#   'get',
#   'back',
#   'his',
#   'name',
#   'and',
#   'credit',
#   'rating'],
#  ['opioid',
#   'crisis',
#   'johnson',
#   'and',
#   'johnson',
#   'hit',
#   'by',
#   'landmark',
#   'ruling'],
#  ['big',
#   'pharma',
#   'is',
#   'using',
#   'faux',
#   'generics',
#   'to',
#   'keep',
#   'drug',
#   'prices',
#   'high',
#   'critics',
#   'say'],
#  ['tokyos', 'audiophile', 'venues', '2016'],
#  ['japan',
#   'surpasses',
#   'china',
#   'as',
#   'largest',
#   'foreign',
#   'holder',
#   'of',
#   'us',
#   'treasurys'],
#  ['statement', 'on', 'the', 'purpose', 'of', 'a', 'corporation'],
#  ['spying', 'on', 'https'],
#  ['why',
#   'doesnt',
#   'mathematics',
#   'collapse',
#   'though',
#   'humans',
#   'often',
#   'make',
#   'mistakes',
#   'in',
#   'proofs'],
#  ['hackers',
#   'ship',
#   'their',
#   'exploits',
#   'directly',
#   'to',
#   'their',
#   'target’s',
#   'mailroom'],
#  ['major',
#   'book',
#   'publishers',
#   'sue',
#   'amazon’s',
#   'audible',
#   'over',
#   'new',
#   'speechtotext',
#   'feature'],
#  ['hacking',
#   'the',
#   'sonos',
#   'ikea',
#   'symfonisk',
#   'into',
#   'a',
#   'high',
#   'quality',
#   'speaker',
#   'amp'],
#  ['kubernetes', 'security', 'assessment', 'pdf'],
#  ['“culture', 'fit”', 'is', 'a', 'two', 'way', 'street', '2018'],
#  ['what', 'happens', 'when', 'you', 'ach', 'a', 'dead', 'person'],
#  ['google', 'search', 'takes', '7', 'seconds', 'on', 'certain', 'queries'],
#  ['go', 'module', 'mirror', 'and', 'checksum', 'database', 'launched'],
#  ['high',
#   'levels',
#   'of',
#   'oestrogens',
#   'in',
#   'the',
#   'womb',
#   'linked',
#   'to',
#   'autism'],
#  ['alone', 'in', 'the', 'dark'],
#  ['the',
#   'fungus',
#   'that',
#   'devastates',
#   'the',
#   'cavendish',
#   'banana',
#   'has',
#   'now',
#   'arrived',
#   'in',
#   'latin',
#   'america'],
#  ['metal',
#   'shards',
#   'from',
#   'boeing',
#   '787',
#   'taking',
#   'off',
#   'over',
#   'rome',
#   'rain',
#   'down',
#   'on',
#   'people',
#   'below'],
#  ['the',
#   '“terrible”',
#   '3',
#   'cent',
#   'mcu',
#   '–',
#   'a',
#   'short',
#   'survey',
#   'of',
#   'sub',
#   '010',
#   'microcontrollers'],
#  ['the', 'order', 'of', 'the', 'json'],
#  ['in',
#   'effect',
#   'seattle',
#   'is',
#   'decriminalizing',
#   'the',
#   'use',
#   'of',
#   'hard',
#   'drugs'],
#  ['faa', 'bans', 'recalled', 'apple', 'laptops', 'from', 'flights'],
#  ['salsify',
#   '–',
#   'a',
#   'new',
#   'architecture',
#   'for',
#   'realtime',
#   'internet',
#   'video'],
#  ['walmart',
#   'sues',
#   'tesla',
#   'over',
#   'fires',
#   'at',
#   'stores',
#   'fitted',
#   'with',
#   'its',
#   'solar',
#   'panels'],
#  ['danish', 'bank', 'launches', 'negative', 'interest', 'rate', 'mortgage'],
#  ['opensource', 'firmware'],
#  ['technical', 'vision', 'for', 'qt', '6'],
#  ['show',
#   'hn',
#   'yack',
#   '–',
#   'community',
#   'browser',
#   'for',
#   'hacker',
#   'news',
#   'reddit',
#   'youtube',
#   'and',
#   'more'],
#  ['a', 'dream', 'of', 'an', 'ultimate', 'os', '1995'],
#  ['a', 'primer', 'on', 'bézier', 'curves', '2013'],
#  ['bontrager’s',
#   'wavecel',
#   'material',
#   'more',
#   'effective',
#   'at',
#   'preventing',
#   'concussions',
#   'than',
#   'mips'],
#  ['the',
#   'death',
#   'of',
#   'social',
#   'reciprocity',
#   'in',
#   'the',
#   'era',
#   'of',
#   'digital',
#   'distraction'],
#  ['amazon',
#   'wants',
#   'to',
#   'control',
#   'thirdparty',
#   'sellers’',
#   'product',
#   'pricing'],
#  ['partiql', 'one', 'query', 'language', 'for', 'all', 'your', 'data'],
#  ['a', 'bug', 'i', 'wish', 'i', 'hadnt', 'caught'],
#  ['a', 'mobile', 'phone', 'that', 'respects', 'your', 'freedom', 'video'],
#  ['cloud',
#   'run',
#   'button',
#   'clicktodeploy',
#   'your',
#   'git',
#   'repos',
#   'to',
#   'gcp'],
#  ['my',
#   'home',
#   'lab',
#   'server',
#   'with',
#   '20',
#   'cores',
#   '',
#   '40',
#   'threads',
#   'and',
#   '128',
#   'gb',
#   'memory'],
#  ['gcc', 'null', 'pointer', 'check', 'removed'],
#  ['in',
#   'the',
#   'us',
#   'its',
#   'cheaper',
#   'to',
#   'build',
#   'and',
#   'operate',
#   'wind',
#   'farms',
#   'than',
#   'buy',
#   'fossil',
#   'fuels'],
#  ['wiringpi', '–', 'deprecated'],
#  ['credit', 'cards', 'have', 'a', 'privacy', 'problem'],
#  ['starbucks', 'monetary', 'superpower'],
#  ['building', 'ages', 'in', 'the', 'netherlands'],
#  ['huawei',
#   'seeks',
#   'independence',
#   'from',
#   'the',
#   'us',
#   'with',
#   'riscv',
#   'and',
#   'ascend',
#   'chips'],
#  ['black',
#   'hat',
#   'talk',
#   'about',
#   '‘time',
#   'ai’',
#   'causes',
#   'uproar',
#   'is',
#   'deleted',
#   'by',
#   'conference'],
#  ['the',
#   'hypersane',
#   'are',
#   'among',
#   'us',
#   'if',
#   'only',
#   'we',
#   'are',
#   'prepared',
#   'to',
#   'look'],
#  ['why', 'i', 'like', 'clojure'],
#  ['cybersecurity',
#   'pros',
#   'name',
#   'their',
#   'price',
#   'as',
#   'hacker',
#   'attacks',
#   'swell'],
#  ['gcp',
#   'to',
#   'introduce',
#   'an',
#   'additional',
#   'charge',
#   'for',
#   'publicly',
#   'addressed',
#   'vm',
#   'instances'],
#  ['youtube',
#   'shuts',
#   'down',
#   'music',
#   'companies’',
#   'use',
#   'of',
#   'manual',
#   'copyright',
#   'claims'],
#  ['poetry', 'dependency', 'management', 'for', 'python'],
#  ['protocols',
#   'not',
#   'platforms',
#   'a',
#   'technological',
#   'approach',
#   'to',
#   'free',
#   'speech'],
#  ['artichoke', '–', 'a', 'ruby', 'made', 'with', 'rust'],
#  ['apollo',
#   'guidance',
#   'computer',
#   'switching',
#   'power',
#   'supply',
#   'works',
#   'after',
#   '50',
#   'years'],
#  ['monads', 'as', 'a', 'programming', 'pattern'],
#  ['denial',
#   'of',
#   'h1b',
#   'visas',
#   'to',
#   'india’s',
#   'largest',
#   'it',
#   'services',
#   'exporters',
#   'at',
#   'alltime',
#   'high'],
#  ['show', 'hn', 'zeroconfig', 'documentation', 'websites', 'for', 'python'],
#  ['show',
#   'hn',
#   'we',
#   'track',
#   'reddit',
#   'google',
#   'trends',
#   'twitter',
#   'etc',
#   'to',
#   'find',
#   'trending',
#   'topics'],
#  ['advice',
#   'to',
#   'my',
#   'younger',
#   'self',
#   'become',
#   'allergic',
#   'to',
#   'the',
#   'churn'],
#  ['show',
#   'hn',
#   'sourcery',
#   '–',
#   'get',
#   'a',
#   'free',
#   'selfupdating',
#   'website'],
#  ['show',
#   'hn',
#   'lunch',
#   'money',
#   'a',
#   'personal',
#   'budgeting',
#   'tool',
#   'with',
#   'multicurrency',
#   'support'],
#  ['new', 'life', 'found', 'that', 'lives', 'off', 'electricity', '2016'],
#  ['cerebras',
#   'systems',
#   'unveils',
#   'a',
#   '12t',
#   'transistor',
#   'chip',
#   'for',
#   'ai'],
#  ['software',
#   'architects',
#   'should',
#   'be',
#   'involved',
#   'in',
#   'earliest',
#   'system',
#   'engineering',
#   'activities'],
#  ['using', 'typescript', 'with', 'react'],
#  ['bmw', 'unveils', 'car', 'sprayed', 'with', 'vantablack'],
#  ['we',
#   'shouldn’t',
#   'take',
#   'peer',
#   'review',
#   'as',
#   'the',
#   '‘gold',
#   'standard’'],
#  ['launch',
#   'hn',
#   'sanntek',
#   'yc',
#   's19',
#   '–',
#   'breathalyzer',
#   'for',
#   'cannabis'],
#  ['the', 'myth', 'of', 'consumergrade', 'security'],
#  ['nvidia',
#   'ceo',
#   'says',
#   'google',
#   'is',
#   'the',
#   'only',
#   'customer',
#   'building',
#   'its',
#   'own',
#   'silicon',
#   'at',
#   'scale'],
#  ['racket', 'lisp', 'for', 'learning'],
#  ['ask', 'hn', 'how', 'to', 'be', 'less', 'argumentative', 'online'],
#  ['insurance',
#   'companies',
#   'are',
#   'paying',
#   'cops',
#   'to',
#   'investigate',
#   'their',
#   'own',
#   'customers'],
#  ['stand', 'out', 'as', 'a', 'speaker'],
#  ['creeping', 'normality'],
#  ['nasa',
#   'said',
#   'to',
#   'be',
#   'investigating',
#   'first',
#   'allegation',
#   'of',
#   'a',
#   'crime',
#   'in',
#   'space'],
#  ['germany',
#   'for',
#   'first',
#   'time',
#   'sells',
#   '30year',
#   'bonds',
#   'offering',
#   'negative',
#   'yields'],
#  ['america’s',
#   'elderly',
#   'seem',
#   'more',
#   'screenobsessed',
#   'than',
#   'the',
#   'young'],
#  ['alarming', 'surge', 'in', 'drugresistant', 'hiv', 'uncovered'],
#  ['levenshtein', 'distance'],
#  ['punpedia', '–', 'the', 'online', 'encyclopedia', 'of', 'puns'],
#  ['legitlooking',
#   'iphone',
#   'lightning',
#   'cables',
#   'will',
#   'hijack',
#   'your',
#   'computer'],
#  ['open', 'startups', 'list'],
#  ['the',
#   'first',
#   'solar',
#   'road',
#   'has',
#   'turned',
#   'out',
#   'to',
#   'be',
#   'a',
#   'disappointing',
#   'failure'],
#  ['facial',
#   'recognition',
#   'school',
#   'id',
#   'checks',
#   'lead',
#   'to',
#   'gdpr',
#   'fine'],
#  ['twitter', 'confesses', 'to', 'more', 'adtech', 'leaks'],
#  ['what',
#   'has',
#   'to',
#   'happen',
#   'with',
#   'unix',
#   'virtual',
#   'memory',
#   'when',
#   'you',
#   'have',
#   'no',
#   'swap',
#   'space'],
#  ['elon', 'musk', 'gambled', 'tesla', 'to', 'save', 'solarcity'],
#  ['how',
#   'the',
#   'new',
#   'opensource',
#   'typeface',
#   'used',
#   'by',
#   'github',
#   'and',
#   'mozilla',
#   'came',
#   'to',
#   'be'],
#  ['splunk',
#   'acquires',
#   'cloud',
#   'monitoring',
#   'service',
#   'signalfx',
#   'for',
#   '105b'],
#  ['swap', 'swap', 'swap', 'and', 'bad', 'places', 'to', 'work'],
#  ['interviews', 'with', 'programming', 'language', 'creators', '2010', 'pdf'],
#  ['activision',
#   'blizzard',
#   'has',
#   'moved',
#   'billions',
#   'of',
#   'dollars',
#   'of',
#   'profit',
#   'into',
#   'tax',
#   'havens'],
#  ['how', 'to', 'make', 'billions', 'of', 'dollars', 'reducing', 'loneliness'],
#  ['seashells',
#   '–',
#   'pipe',
#   'output',
#   'from',
#   'commandline',
#   'programs',
#   'to',
#   'the',
#   'web',
#   'in',
#   'real',
#   'time'],
#  ['wework', 'ipo', 'shows', 'its', 'the', 'most', 'magical', 'unicorn'],
#  ['experimental',
#   'usaf',
#   'space',
#   'plane',
#   'breaks',
#   'record',
#   'for',
#   'orbital',
#   'spaceflight'],
#  ['what', 'i', 'do', 'as', 'a', 'devops', 'consultant'],
#  ['making', 'containers', 'safer'],
#  ['the', 'erlang', 'rationale'],
#  ['apple',
#   'suspends',
#   'siri',
#   'response',
#   'grading',
#   'in',
#   'response',
#   'to',
#   'privacy',
#   'concerns'],
#  ['the', 'tragedy', 'of', 'ucs2'],
#  ['crispr',
#   'pioneer',
#   'among',
#   'university',
#   'of',
#   'california',
#   'researchers',
#   'boycotting',
#   'elsevier'],
#  ['‘no',
#   'one',
#   'saw',
#   'a',
#   'thing’',
#   'when',
#   'a',
#   'midwest',
#   'town',
#   'banded',
#   'together',
#   'to',
#   'kill',
#   'the',
#   'town',
#   'bully'],
#  ['what', 'makes', 'a', 'good', 'conversation'],
#  ['ruffle',
#   '–',
#   'an',
#   'adobe',
#   'flash',
#   'player',
#   'written',
#   'in',
#   'rust',
#   'compiled',
#   'to',
#   'webassembly'],
#  ['hedonometer'],
#  ['github',
#   'supports',
#   'web',
#   'authentication',
#   'webauthn',
#   'for',
#   'security',
#   'keys'],
#  ['twelve',
#   'latex',
#   'packages',
#   'to',
#   'get',
#   'your',
#   'paper',
#   'accepted',
#   '2017'],
#  ['a', 'manager’s', 'guide', 'to', 'kubernetes', 'adoption'],
#  ['typed', 'properties', 'in', 'php', '74'],
#  ['a', 'readable', 'specification', 'of', 'tls', '13'],
#  ['who', 'owns', 'your', 'wireless', 'service', 'crooks', 'do'],
#  ['feds',
#   'ordered',
#   'google',
#   'location',
#   'dragnet',
#   'to',
#   'solve',
#   'wisconsin',
#   'bank',
#   'robbery'],
#  ['things', 'to', 'know', 'about', 'gnu', 'readline'],
#  ['mortgage', 'market', 'reopens', 'to', 'risky', 'borrowers'],
#  ['recognizing',
#   'the',
#   'signs',
#   'of',
#   'disruption',
#   'in',
#   'our',
#   'urban',
#   'habitat'],
#  ['acute',
#   'effects',
#   'of',
#   'electronic',
#   'cigarette',
#   'aerosol',
#   'inhalation',
#   'on',
#   'vascular',
#   'function'],
#  ['noaa',
#   'data',
#   'confirms',
#   'july',
#   'was',
#   'hottest',
#   'month',
#   'ever',
#   'recorded'],
#  ['javascript', 'the', 'modern', 'parts'],
#  ['google',
#   'warns',
#   'developers',
#   'that',
#   'all',
#   'new',
#   'android',
#   'apps',
#   'require',
#   '3',
#   'days',
#   'for',
#   'approval'],
#  ['rust', 'gui', 'ecosystem', 'overview'],
#  ['how', 'does', 'esperanto', 'sound'],
#  ['how',
#   'command',
#   'and',
#   'conquer',
#   'tiberian',
#   'sun',
#   'punished',
#   'the',
#   'computers',
#   'of',
#   'the',
#   'day',
#   'video'],
#  ['what’s',
#   'the',
#   'difference',
#   'between',
#   'statistics',
#   'and',
#   'machine',
#   'learning'],
#  ['dropbox',
#   'no',
#   'longer',
#   'follows',
#   'symlinks',
#   'to',
#   'items',
#   'outside',
#   'of',
#   'your',
#   'dropbox',
#   'account'],
#  ['climate',
#   'change',
#   'made',
#   'european',
#   'heatwave',
#   'up',
#   'to',
#   '3°c',
#   'hotter'],
#  ['unison', 'file', 'synchronizer'],
#  ['michael', 'cicconetti'],
#  ['opengpt2', 'we', 'replicated', 'gpt2', 'because', 'you', 'can', 'too'],
#  ['practical', 'tips', 'for', 'facelifting', 'a', 'tech', 'resume'],
#  ['natural', 'language', 'processing', 'the', 'age', 'of', 'transformers'],
#  ['the', 'portuguese', 'bank', 'note', 'crisis', 'of', '1925'],
#  ['california',
#   'farmers',
#   'are',
#   'planting',
#   'solar',
#   'panels',
#   'as',
#   'water',
#   'supplies',
#   'dry',
#   'up'],
#  ['youtube',
#   'said',
#   'to',
#   'be',
#   'fined',
#   'up',
#   'to',
#   '200m',
#   'for',
#   'children’s',
#   'privacy',
#   'violations'],
#  ['microsoft', 'is', 'killing', 'epub', 'support', 'in', 'edge', 'classic'],
#  ['ask', 'hn', 'configuration', 'management', 'for', 'personal', 'computer'],
#  ['intel',
#   'and',
#   'rust',
#   'the',
#   'future',
#   'of',
#   'systems',
#   'programming',
#   'video'],
#  ['from', '30', 'to', '230', 'docker', 'containers', 'per', 'host'],
#  ['wireless',
#   'carrier',
#   'throttling',
#   'of',
#   'online',
#   'video',
#   'is',
#   'pervasive',
#   'study'],
#  ['how',
#   'do',
#   'black',
#   'holes',
#   'destroy',
#   'information',
#   'and',
#   'why',
#   'is',
#   'that',
#   'a',
#   'problem'],
#  ['waypipe', 'gsoc', 'project', 'complete'],
#  ['launch',
#   'hn',
#   'quirk',
#   'yc',
#   's19',
#   '–',
#   'opensource',
#   'cognitive',
#   'behavioral',
#   'therapy'],
#  ['boeings', 'crashes', 'expose', 'systemic', 'failings'],
#  ['goldman',
#   'sachs',
#   'is',
#   'spending',
#   '100m',
#   'to',
#   'shave',
#   'milliseconds',
#   'off',
#   'stock',
#   'trades'],
#  ['bad',
#   'times',
#   'in',
#   'tech',
#   'not',
#   'if',
#   'you’re',
#   'a',
#   'startup',
#   'serving',
#   'other',
#   'startups'],
#  ['why',
#   'did',
#   'turbo',
#   'pascal',
#   'apps',
#   'fail',
#   'with',
#   'a',
#   'divisionbyzero',
#   'on',
#   'faster',
#   'systems'],
#  ['show',
#   'hn',
#   'storytime',
#   '–',
#   'create',
#   'stories',
#   'about',
#   'your',
#   'code',
#   'instead',
#   'of',
#   'documentation'],
#  ['one',
#   'of',
#   'the',
#   'greatest',
#   'science',
#   'fiction',
#   'magazines',
#   'is',
#   'now',
#   'available',
#   'online',
#   '2017'],
#  ['nixery',
#   'transparently',
#   'build',
#   'and',
#   'serve',
#   'containers',
#   'using',
#   'nix'],
#  ['most',
#   'internet',
#   'service',
#   'providers',
#   'are',
#   'gone',
#   '–',
#   'sonic',
#   'has',
#   'survived',
#   'and',
#   'thrived'],
#  ['where', 'do', 'interrupts', 'happen'],
#  ['ondisk',
#   'format',
#   'robustness',
#   'requirements',
#   'for',
#   'new',
#   'filesystems'],
#  ['giving', 'up', 'on', 'julia', '2016'],
#  ['the', 'ethics', 'of', 'web', 'performance'],
#  ['keeping', 'tesla', 'roadsters', 'alive', 'is', 'serious', 'work'],
#  ['oracle',
#   'directors',
#   'give',
#   'blessing',
#   'to',
#   'shareholder',
#   'lawsuit',
#   'against',
#   'larry',
#   'ellison'],
#  ['lf', 'fully', 'decentralized', 'fully', 'replicated', 'keyvalue', 'store'],
#  ['a', 'quarter', 'of', 'humanity', 'faces', 'looming', 'water', 'crises'],
#  ['pacvim',
#   '–',
#   'pacvim',
#   'is',
#   'a',
#   'game',
#   'that',
#   'teaches',
#   'you',
#   'vim',
#   'commands'],
#  ['why', 'does', 'infrastructure', 'cost', 'so', 'much'],
#  ['laws', 'of', 'showrunning', '2016', 'pdf'],
#  ['possible',
#   'detection',
#   'of',
#   'a',
#   'black',
#   'hole',
#   'with',
#   'a',
#   'mass',
#   'that',
#   'was',
#   'thought',
#   'to',
#   'be',
#   'impossible'],
#  ['launch',
#   'hn',
#   'dex',
#   'yc',
#   's19',
#   '–',
#   'personal',
#   'crm',
#   'that',
#   'reminds',
#   'you',
#   'to',
#   'keep',
#   'in',
#   'touch'],
#  ['a',
#   'buddhist',
#   'monk',
#   'confronts',
#   'japans',
#   'suicide',
#   'culture',
#   '2013'],
#  ['the', 'flawed', 'threecueing', 'system', 'for', 'teaching', 'reading'],
#  ['home', '3d', 'metal', 'printing', 'first', 'results'],
#  ['são', 'paulo’s', 'outdoor', 'advertising', 'ban', '2016'],
#  ['google',
#   'forcing',
#   'nest',
#   'cameras’',
#   'visual',
#   'indicator',
#   'light',
#   'to',
#   'be',
#   'on'],
#  ['the', 'flawed', 'reasoning', 'behind', 'the', 'replication', 'crisis'],
#  ['sugar',
#   'opensource',
#   'software',
#   'learning',
#   'platform',
#   'for',
#   'children'],
#  ['open',
#   'location',
#   'code',
#   'an',
#   'open',
#   'source',
#   'standard',
#   'for',
#   'addresses'],
#  ['its',
#   'crazy',
#   'chase',
#   'forgiving',
#   'all',
#   'debt',
#   'owed',
#   'by',
#   'its',
#   'canada',
#   'credit',
#   'card',
#   'customers'],
#  ['computer', 'science', 'illustrated', '2014'],
#  ['parsing', 'json', 'is', 'a', 'minefield', '2018'],
#  ['i', 'found', 'an', 'easter', 'egg', 'from', '1977'],
#  ['the',
#   'interviewer',
#   'skills',
#   'ladder',
#   'for',
#   'high',
#   'growth',
#   'companies'],
#  ['show',
#   'hn',
#   'tailwindrun',
#   '–',
#   'an',
#   'online',
#   'playground',
#   'for',
#   'tailwind',
#   'css'],
#  ['what',
#   'to',
#   'do',
#   'once',
#   'you',
#   'admit',
#   'that',
#   'decentralization',
#   'never',
#   'seems',
#   'to',
#   'work',
#   '2018'],
#  ['hundreds',
#   'of',
#   'exposed',
#   'amazon',
#   'cloud',
#   'backups',
#   'found',
#   'leaking',
#   'sensitive',
#   'data'],
#  ['removing',
#   'one',
#   'maine',
#   'dam',
#   '20',
#   'years',
#   'ago',
#   'changed',
#   'everything'],
#  ['nonplanar', 'printing'],
#  ['why', 'didnt', 'the', 'romans', 'contribute', 'much', 'to', 'mathematics'],
#  ['bulk', 'data', 'structures', 'c'],
#  ['exploring', 'weight', 'agnostic', 'neural', 'networks'],
#  ['have', 'you', 'ever', 'tried', 'to', 'sell', 'a', 'diamond', '1982'],
#  ['big',
#   'o',
#   'notation',
#   '–',
#   'using',
#   'notboring',
#   'math',
#   'to',
#   'measure',
#   'code’s',
#   'efficiency'],
#  ['cisco',
#   'is',
#   'making',
#   'it',
#   'more',
#   'difficult',
#   'to',
#   'use',
#   'used',
#   'hardware'],
#  ['how',
#   'shrinkflation',
#   'is',
#   'playing',
#   'havoc',
#   'with',
#   'economists’',
#   'models'],
#  ['rotten', 'apple', 'right', 'to', 'repair', 'roundup'],
#  ['tumblr'],
#  ['doordash', 'buying', 'caviar', 'from', 'square', 'for', '410m'],
#  ['daniel',
#   'radcliffe',
#   'and',
#   'the',
#   'art',
#   'of',
#   'the',
#   'factcheck',
#   '2018'],
#  ['svalbard',
#   'is',
#   'as',
#   'close',
#   'as',
#   'you',
#   'can',
#   'get',
#   'to',
#   'a',
#   'place',
#   'with',
#   'open',
#   'borders'],
#  ['dyson', 'tree'],
#  ['how',
#   'i',
#   'finally',
#   'won',
#   'my',
#   'name',
#   'from',
#   'domain',
#   'resellers',
#   'after',
#   'nine',
#   'years',
#   'of',
#   'waiting'],
#  ['fbi',
#   'tells',
#   'lawmakers',
#   'it',
#   'cant',
#   'access',
#   'dayton',
#   'gunmans',
#   'phone'],
#  ['children',
#   'of',
#   'a',
#   'thailand',
#   'tribe',
#   'who',
#   'see',
#   'with',
#   'clarity',
#   'beneath',
#   'the',
#   'waves',
#   '2016'],
#  ['franky',
#   'zapata',
#   'flyboarding',
#   'frenchman',
#   'crosses',
#   'english',
#   'channel'],
#  ['dignity'],
#  ['teen',
#   'hacker',
#   'finds',
#   'bugs',
#   'in',
#   'school',
#   'software',
#   'that',
#   'exposed',
#   'millions',
#   'of',
#   'records'],
#  ['a', 'pissedoff', 'tutorial', 'for', 'google', 'wave', '2010', 'video'],
#  ['i', 'took', 'a', 'pay', 'cut', 'for', 'a', 'more', 'meaningful', 'job'],
#  ['ibm', 'stops', 'buybacks', 'to', 'pay', 'for', 'red', 'hat'],
#  ['parallelism', 'in', 'postgresql'],
#  ['tech', 'backlash', 'has', 'come', 'to', 'stanford'],
#  ['google’s',
#   'rivals',
#   'opt',
#   'out',
#   'of',
#   'search',
#   'engine',
#   'auction',
#   'calling',
#   'it',
#   '‘anticompetitive’'],
#  ['peloton', 's1'],
#  ['why', 'a', 'mock', 'doesn’t', 'work'],
#  ['patterns',
#   'on',
#   'goods',
#   'designed',
#   'to',
#   'trigger',
#   'automated',
#   'license',
#   'plate',
#   'readers'],
#  ['show', 'hn', 'texnique', '–', 'a', 'latex', 'typesetting', 'game'],
#  ['upmem',
#   'puts',
#   'cpus',
#   'inside',
#   'memory',
#   'to',
#   'allow',
#   'applications',
#   'to',
#   'run',
#   '20',
#   'times',
#   'faster'],
#  ['more',
#   'fires',
#   'now',
#   'burning',
#   'in',
#   'angola',
#   'congo',
#   'than',
#   'amazon'],
#  ['telegram',
#   'introduces',
#   'feature',
#   'to',
#   'prevent',
#   'users',
#   'from',
#   'texting',
#   'too',
#   'often',
#   'in',
#   'a',
#   'group'],
#  ['somehow', 'i', 'became', 'respectable'],
#  ['how', 'to', 'become', 'a', 'great', 'impostor'],
#  ['seattles',
#   'microtransit',
#   'experiment',
#   'drives',
#   'people',
#   'to',
#   'light',
#   'rail'],
#  ['basic', 'electron', 'framework', 'exploitation'],
#  ['helsinki',
#   'central',
#   'library',
#   'chosen',
#   'as',
#   'the',
#   'best',
#   'new',
#   'public',
#   'library'],
#  ['spacex', 'smallsat', 'rideshare', 'program'],
#  ['personal', 'website', 'for', 'programmers'],
#  ['startups', 'from', 'y', 'combinator’s', 's19', 'demo', 'day', '1'],
#  ['highlights', 'from', 'git', '223'],
#  ['show',
#   'hn',
#   'youtube',
#   'decade',
#   '–',
#   'the',
#   'mostviewed',
#   'videos',
#   'posted',
#   '10',
#   'years',
#   'ago'],
#  ['standard', 'js', 'npm', 'install', 'funding'],
#  ['mapped', 'the', 'world’s', 'coal', 'power', 'plants'],
#  ['kept', 'alive', 'with', 'tubes', 'for', 'nearly', '17', 'years'],
#  ['lessons', 'we', 'learned', 'when', 'debugging', 'a', 'scaling', 'problem'],
#  ['p', 'idea', 'faq'],
#  ['show',
#   'hn',
#   'scarf',
#   '–',
#   'platform',
#   'to',
#   'help',
#   'opensource',
#   'developers',
#   'monetize',
#   'their',
#   'work'],
#  ['old', 'paris', 'is', 'no', 'more'],
#  ['spacebook', 'agis', 'near', 'realtime', 'satellite', 'viewer'],
#  ['the', 'path', 'to', 'dijkstra’s', 'handwriting', '2013'],
#  ['ted', 'chiang', 'realist', 'of', 'a', 'larger', 'reality'],
#  ['escape', 'rooms', 'are', 'big', 'business'],
#  ['alcohol', 'belts', 'of', 'europe'],
#  ['dependent', 'haskell', 'is', 'the', 'future', '2018'],
#  ['north',
#   'american',
#   'versus',
#   'european',
#   'distribution',
#   'systems',
#   '2011'],
#  ['social',
#   'share',
#   'buttons',
#   'that',
#   'dont',
#   'allow',
#   'the',
#   'social',
#   'sites',
#   'to',
#   'track',
#   'your',
#   'users'],
#  ['nutrient',
#   'deficiencies',
#   'in',
#   'rice',
#   'grown',
#   'under',
#   'higher',
#   'carbon',
#   'dioxide'],
#  ['the',
#   'body',
#   'is',
#   'the',
#   'missing',
#   'link',
#   'for',
#   'truly',
#   'intelligent',
#   'machines',
#   '2017'],
#  ['electric', 'motor', 'design', 'claims', 'remarkable', 'improvements'],
#  ['living', 'off', 'the', 'land', 'in', 'linux'],
#  ['no', 'son', 'of', 'mine', 'is', 'going', 'to', 'be', 'a', 'benthamite'],
#  ['extended', 'validation', 'certificates', 'are', 'really', 'dead'],
#  ['the',
#   'mobility',
#   'trap',
#   'why',
#   'well',
#   'never',
#   'fix',
#   'congestion',
#   'by',
#   'speeding',
#   'up',
#   'traffic'],
#  ['static', 'type', 'checking', 'in', 'common', 'lisp'],
#  ['interslavic', 'language'],
#  ['startups', 'from', 'y', 'combinator’s', 's19', 'demo', 'day', '2'],
#  ['announcing', 'notqmail'],
#  ['why', 'the', 'french', 'love', 'to', 'say', 'no'],
#  ['theories', 'of', 'error', 'backpropagation', 'in', 'the', 'brain'],
#  ['black',
#   'beekeepers',
#   'are',
#   'transforming',
#   'detroit’s',
#   'vacant',
#   'lots',
#   'into',
#   'bee',
#   'farms',
#   '2018'],
#  ['gpt2', '6month', 'followup'],
#  ['crossword', 'panic', 'of', '1944'],
#  ['libspng',
#   '–',
#   'c',
#   'library',
#   'for',
#   'reading',
#   'and',
#   'writing',
#   'png',
#   'files'],
#  ['kegans', 'theory', 'of', 'the', 'evolution', 'of', 'consciousness'],
#  ['hospital',
# ...
#   'replaced',
#   'by',
#   'service',
#   'mesh'],
#  ['i',
#   'started',
#   'an',
#   'online',
#   'subscription',
#   'business',
#   'from',
#   'malaysia'],
#  ['lifehacker', 'tarek', 'loubani', 'on', '3dprinting', 'in', 'gaza'],
#  ['our', 'brains', 'tell', 'stories', 'so', 'we', 'can', 'live', '2013'],
#  ['capturing',
#   'pal',
#   'video',
#   'with',
#   'an',
#   'sdr',
#   'and',
#   'a',
#   'few',
#   'dead',
#   'ends'],
#  ['solving',
#   'differential',
#   'equations',
#   'on',
#   'a',
#   '6502',
#   'with',
#   'wozs',
#   'floating',
#   'point',
#   'code'],
#  ['computer', 'stupidities', '2013'],
#  ['a', 'look', 'back', 'the', 'bloomberg', 'keyboard', '2017'],
#  ['jupiter', 'riscv', 'assembler', 'and', 'runtime', 'simulator'],
#  ['42',
#   'hours',
#   'of',
#   'buckminster',
#   'fuller',
#   'might',
#   'be',
#   'just',
#   'the',
#   'vision',
#   'we',
#   'need'],
#  ['project',
#   'mu',
#   '–',
#   'a',
#   'modular',
#   'uefi',
#   'environment',
#   'for',
#   'building',
#   'modern',
#   'devices'],
#  ['the', 'high', 'price', 'of', 'multitasking'],
#  ['curve', 'fitting', 'a', 'linear', 'least', 'squares'],
#  ['handler',
#   'beliefs',
#   'affect',
#   'scent',
#   'detection',
#   'dog',
#   'outcomes',
#   '2011'],
#  ['sipeed', 'longan', 'nano', '–', 'riscv', 'development', 'board'],
#  ['the',
#   'difference',
#   'between',
#   'isolation',
#   'levels',
#   'and',
#   'consistency',
#   'levels'],
#  ['detailed', '3d', 'map', 'of', 'milky', 'way', 'shows', 'warped', 'shape'],
#  ['map',
#   'design',
#   '–',
#   'a',
#   'guide',
#   'to',
#   'good',
#   'looking',
#   'maps',
#   '2008',
#   'pdf'],
#  ['no', 'silver', 'bullet', '1986', 'pdf'],
#  ['armoured', 'commander', 'the', 'wwii', 'tank', 'commander', 'roguelike'],
#  ['how', 'the', 'brain', 'approximates', 'without', 'counting'],
#  ['softbank',
#   'plans',
#   'to',
#   'lend',
#   '20b',
#   'to',
#   'its',
#   'ceo',
#   'and',
#   'employees',
#   'amid',
#   'volatile',
#   'markets'],
#  ['the',
#   'hp',
#   'way',
#   'how',
#   'bill',
#   'hewlett',
#   'and',
#   'i',
#   'built',
#   'our',
#   'company',
#   '1960'],
#  ['how', 'to', 'build', 'a', 'pyramid'],
#  ['how',
#   'to',
#   'get',
#   'consistent',
#   'results',
#   'when',
#   'benchmarking',
#   'on',
#   'linux'],
#  ['how',
#   'to',
#   'teach',
#   'an',
#   'iris',
#   'scanner',
#   'that',
#   'the',
#   'eye',
#   'it’s',
#   'looking',
#   'at',
#   'is',
#   'dead'],
#  ['building', 'a', 'vacuum', 'tube', 'computer'],
#  ['portugal’s', 'marmelada', 'tastes', 'nothing', 'like', 'marmalade', '2018'],
#  ['spacy', 'pytorch', 'transformers'],
#  ['real',
#   'world',
#   'location',
#   'virtually',
#   'recreated',
#   'to',
#   'scale',
#   'in',
#   'minutes',
#   'video'],
#  ['show',
#   'hn',
#   'datkeyserver',
#   'a',
#   'distributed',
#   'pgp',
#   'keyserver',
#   'based',
#   'on',
#   'the',
#   'dat',
#   'protocol'],
#  ['karel', 'čapeks', 'play', 'rur', 'premiered', 'in', 'january', '1921'],
#  ['apple',
#   'card',
#   'restrictions',
#   'include',
#   'no',
#   'jailbreaking',
#   'or',
#   'cryptocurrency',
#   'purchases'],
#  ['the', 'grand', 'c', 'error', 'explosion', 'competition'],
#  ['turkmenistan', 'on', 'the', 'brink', 'of', 'collapse'],
#  ['a', 'profile', 'of', 'geoffrey', 'hinton', '2018'],
#  ['scientists',
#   'reverse',
#   'aging',
#   'process',
#   'in',
#   'rat',
#   'brain',
#   'stem',
#   'cells'],
#  ['show',
#   'hn',
#   'cordless',
#   'a',
#   'discord',
#   'terminal',
#   'client',
#   'written',
#   'in',
#   'go'],
#  ['100',
#   'years',
#   'ago',
#   'a',
#   'telephone',
#   'tower',
#   'in',
#   'stockholm',
#   'connected',
#   '5000',
#   'phone',
#   'lines',
#   '2014'],
#  ['japanese',
#   'architects',
#   'who',
#   'treated',
#   'buildings',
#   'like',
#   'living',
#   'organisms'],
#  ['a', 'recent', 'paper', 'proposes', 'to', 'bring', 'zeppelins', 'back'],
#  ['jcore', 'open', 'processor'],
#  ['presidio',
#   'customizable',
#   'data',
#   'protection',
#   'and',
#   'pii',
#   'data',
#   'anonymization',
#   'service'],
#  ['the', 'survival', 'of', 'iggy', 'pop'],
#  ['bpf', 'portbased', 'firewall', 'for', 'systemd', 'services'],
#  ['marree', 'man'],
#  ['the', 'dday', 'rehearsal', 'that', 'cost', '800', 'lives', '2014'],
#  ['ray', 'tracing', 'with', 'ulisp'],
#  ['show', 'hn', 'a', 'few', 'simple', 'games', 'not', 'only', 'for', 'kids'],
#  ['why', 'everyone', 'hates', 'customer', 'service'],
#  ['commodore', '900'],
#  ['qualpwn',
#   '–',
#   'exploiting',
#   'qualcomm',
#   'wlan',
#   'and',
#   'modem',
#   'over',
#   'the',
#   'air'],
#  ['study',
#   'identifies',
#   'main',
#   'culprit',
#   'behind',
#   'lithium',
#   'metal',
#   'battery',
#   'failure'],
#  ['with', 'friends', 'like', 'these'],
#  ['youtube’s', 'lgbtq', 'problem', 'is', 'a', 'businessmodel', 'problem'],
#  ['suburb',
#   'in',
#   'the',
#   'sky',
#   'how',
#   'jakartans',
#   'built',
#   'an',
#   'entire',
#   'village',
#   'on',
#   'top',
#   'of',
#   'a',
#   'mall'],
#  ['circulating',
#   'in',
#   'china’s',
#   'financial',
#   'system',
#   'more',
#   'than',
#   '200b',
#   'in',
#   'ious'],
#  ['the',
#   'death',
#   'of',
#   'alexander',
#   'the',
#   'great',
#   'one',
#   'of',
#   'historys',
#   'great',
#   'unsolved',
#   'mysteries'],
#  ['the', 'microworkers', 'making', 'digital', 'life', 'possible'],
#  ['keyringless', 'gnupg'],
#  ['the', 'perfect', 'french', 'baguette'],
#  ['shipping', 'wind', 'turbines', 'is', 'not', 'a', 'breeze'],
#  ['iron',
#   'age',
#   'celtic',
#   'woman',
#   'was',
#   'buried',
#   'in',
#   'a',
#   'hollowedout',
#   'tree',
#   'trunk'],
#  ['the', 'biggest', 'mistakes', 'firsttime', 'founders', 'make', 'video'],
#  ['boeing', 'changing', 'max', 'software', 'to', 'use', 'two', 'computers'],
#  ['empty',
#   'trains',
#   'on',
#   'the',
#   'modern',
#   'silk',
#   'road',
#   'when',
#   'belt',
#   'and',
#   'road',
#   'interests',
#   'don’t',
#   'align'],
#  ['wavelets', '1994', 'pdf'],
#  ['who', 'did', 'the', 'maya', 'sacrifice'],
#  ['a', 'guide', 'to', 'magnetorquers', 'for', 'satellites'],
#  ['mobile', 'nixos', 'the', 'present', 'and', 'the', 'future'],
#  ['nec', 'shows', '‘flying', 'car’', 'hovering', 'steadily', 'for', 'minute'],
#  ['quantum',
#   'radar',
#   'has',
#   'been',
#   'demonstrated',
#   'for',
#   'the',
#   'first',
#   'time'],
#  ['ear', 'speakers', '–', 'research', 'design', 'and', 'evolution'],
#  ['wasm', 'vs', 'pnacl', 'performance', 'benchmark'],
#  ['evolving', 'lindenmayer', 'systems'],
#  ['show',
#   'hn',
#   'repository',
#   'of',
#   'open',
#   'source',
#   'spacerelated',
#   'software',
#   'and',
#   'hardware'],
#  ['i', 'love', 'my', 'paper', 'dictionary', '2017'],
#  ['darpa',
#   'wants',
#   'help',
#   'cracking',
#   'the',
#   'election',
#   'security',
#   'problem'],
#  ['the',
#   'fed',
#   'is',
#   'getting',
#   'into',
#   'the',
#   'realtime',
#   'payments',
#   'business'],
#  ['woman',
#   'finds',
#   'yellow',
#   'diamond',
#   'while',
#   'watching',
#   'youtube',
#   'video',
#   'on',
#   'how',
#   'to',
#   'find',
#   'diamonds'],
#  ['amazon', 'will', 'pull', 'the', 'plug', 'on', 'dash', 'buttons'],
#  ['problem', 'solving', 'and', 'clojure', '19', '2018'],
#  ['a',
#   'new',
#   'book',
#   'asserts',
#   'that',
#   'rich',
#   'countries',
#   'grow',
#   'with',
#   'lighter',
#   'environmental',
#   'impacts'],
#  ['animal',
#   'movies',
#   'promote',
#   'awareness',
#   'not',
#   'harm',
#   'say',
#   'researchers'],
#  ['2019', 'hyundai', 'kona', 'ev', 'explodes', 'when', 'parked'],
#  ['the',
#   'league',
#   'of',
#   'entropy',
#   'is',
#   'making',
#   'randomness',
#   'truly',
#   'random'],
#  ['a',
#   'transparent',
#   'display',
#   'with',
#   'perpixel',
#   'color',
#   'and',
#   'opacity',
#   'control'],
#  ['the',
#   '“terrascope”',
#   'on',
#   'the',
#   'possibility',
#   'of',
#   'using',
#   'the',
#   'earth',
#   'as',
#   'an',
#   'atmospheric',
#   'lens'],
#  ['humans', 'dominated', 'earth', 'earlier', 'than', 'previously', 'thought'],
#  ['fuzzification', 'antifuzzing', 'techniques', 'pdf'],
#  ['what',
#   'is',
#   'zoned',
#   'storage',
#   'and',
#   'the',
#   'zoned',
#   'storage',
#   'initiative'],
#  ['webmin', '1890', 'exploit', '–', 'what', 'happened'],
#  ['scaling', 'static', 'analyses', 'at', 'facebook'],
#  ['the',
#   'death',
#   'of',
#   'a',
#   'weather',
#   'satellite',
#   'as',
#   'seen',
#   'by',
#   'sdr'],
#  ['holidays', 'are', 'good', 'for', 'workers', 'and', 'companies', 'alike'],
#  ['richard', 'sorge', 'the', 'soviet', 'union’s', 'master', 'spy'],
#  ['debunking', 'the', 'stanford', 'prison', 'experiment', 'pdf'],
#  ['marium',
#   'the',
#   'dugong',
#   'who',
#   'charmed',
#   'thailand',
#   'dies',
#   'after',
#   'ingesting',
#   'plastic'],
#  ['simple',
#   'python',
#   'package',
#   'to',
#   'extract',
#   'deep',
#   'learning',
#   'features'],
#  ['massive', '‘ocean’', 'discovered', 'towards', 'earth’s', 'core', '2014'],
#  ['def', 'con', '2019', '–', 'ctf', 'retrospective'],
#  ['kdevops',
#   'framework',
#   'for',
#   'setting',
#   'up',
#   'and',
#   'testing',
#   'the',
#   'linux',
#   'kernel',
#   'for',
#   'any',
#   'project'],
#  ['simple',
#   'pure',
#   'and',
#   'total',
#   'functional',
#   'language',
#   'that',
#   'generalizes',
#   'datalog'],
#  ['continuous',
#   '3d',
#   'printing',
#   'possible',
#   'with',
#   'transparent',
#   'polygon',
#   'scanning'],
#  ['could', 'removing', 'social', 'media', 'metrics', 'reduce', 'polarization'],
#  ['roaring',
#   'glacial',
#   'melt',
#   'under',
#   'the',
#   'bridge',
#   'to',
#   'kangerlussiauq',
#   'greenland'],
#  ['the', 'new', 'treasures', 'of', 'pompeii'],
#  ['sec',
#   'investigating',
#   'data',
#   'leak',
#   'at',
#   'first',
#   'american',
#   'financial',
#   'corp'],
#  ['the', 'openbsd', 'ada', 'library'],
#  ['dont', 'say', '“homoiconic”', '2018'],
#  ['us',
#   'air',
#   'force',
#   'pauses',
#   'flights',
#   'for',
#   'over',
#   'a',
#   'hundred',
#   'c130s',
#   'over',
#   '‘atypical’',
#   'cracking'],
#  ['i', 'am', 'a', 'horse', 'in', 'the', 'land', 'of', 'booleans'],
#  ['we',
#   'may',
#   'not',
#   'be',
#   'running',
#   'out',
#   'of',
#   'helium',
#   'after',
#   'all',
#   '2015'],
#  ['launch',
#   'hn',
#   'shift',
#   'health',
#   'yc',
#   's19',
#   '–',
#   'understand',
#   'your',
#   'healthcare',
#   'costs',
#   'previsit'],
#  ['smartykit', 'apple', 'i', 'replica'],
#  ['gerbil', '–', 'a', 'metadialect', 'of', 'scheme'],
#  ['hawaii',
#   'extends',
#   'thirty',
#   'meter',
#   'telescope',
#   'permit',
#   'amid',
#   'protests'],
#  ['gm', 'is', 'now', 'detroit’s', 'smallest', 'automaking', 'employer'],
#  ['the',
#   'dipole',
#   'drive',
#   'a',
#   'new',
#   'concept',
#   'in',
#   'space',
#   'propulsion'],
#  ['universal', 'algorithm', 'set', 'to', 'boost', 'microscopes'],
#  ['fearing',
#   'data',
#   'privacy',
#   'issues',
#   'google',
#   'cuts',
#   'some',
#   'android',
#   'phone',
#   'data',
#   'for',
#   'carriers'],
#  ['robotic',
#   'thread',
#   'is',
#   'designed',
#   'to',
#   'slip',
#   'through',
#   'the',
#   'brains',
#   'blood',
#   'vessels'],
#  ['vickrey–clarke–groves', 'auction'],
#  ['prolog', 'control', 'in', 'six', 'slides'],
#  ['opinion', 'piece', 'on', 'ghc', 'back', 'ends'],
#  ['entropic', 'a', 'federated', 'package', 'registry', 'for', 'anything'],
#  ['cbor', '–', 'concise', 'binary', 'object', 'representation'],
#  ['can', 'we', 'survive', 'technology', '1955', 'pdf'],
#  ['cassettes', 'are', 'back', 'and', 'it’s', 'not', 'about', 'the', 'music'],
#  ['paul', 'dirac', 'the', 'mozart', 'of', 'science', '2008'],
#  ['in', 'praise', 'of', 'xlogo'],
#  ['show',
#   'hn',
#   'historical',
#   'order',
#   'book',
#   'reconstruction',
#   'api',
#   'for',
#   'crypto',
#   'markets'],
#  ['arcs', 'of', 'seniority'],
#  ['the', 'long', 'game', 'of', 'research'],
#  ['a', 'look', 'at', 'hs2s', 'old', 'oak', 'common', 'station'],
#  ['how',
#   'judy',
#   'arrays',
#   'work',
#   'and',
#   'why',
#   'they',
#   'are',
#   'so',
#   'fast',
#   '2002'],
#  ['mining', 'bitcoin', 'on', 'an', 'apple', 'ii'],
#  ['unearthing',
#   'a',
#   'masterpiece',
#   'a',
#   'rare',
#   'minoan',
#   'sealstone',
#   '2017'],
#  ['golden', 'ratio'],
#  ['show',
#   'hn',
#   'pgcmd',
#   '–',
#   'an',
#   'alternative',
#   'to',
#   'psql',
#   'with',
#   'json',
#   'output'],
#  ['reviving', 'an', 'hp', '660lx', 'in', '2019'],
#  ['ssb', 'rooms', 'a', 'new', 'server', 'type', 'for', 'scuttlebutt'],
#  ['implementing', 'poincaré', 'embeddings', '2017'],
#  ['extending', 'ocaml', 'programs', 'with', 'lua'],
#  ['container', 'networking', 'with', 'vxlan', 'bgp', 'and', 'wireguard'],
#  ['a', 'fine', 'map', 'from', 'alexander', 'von', 'humboldt', '1851'],
#  ['new',
#   'research',
#   'on',
#   'ptsd',
#   'in',
#   'elephants',
#   'and',
#   'other',
#   'animals'],
#  ['“awakenings”',
#   'in',
#   'advanced',
#   'dementia',
#   'patients',
#   'hint',
#   'at',
#   'untapped',
#   'brain',
#   'reserves'],
#  ['recycling',
#   'of',
#   'plastics',
#   'enabled',
#   'by',
#   'dynamic',
#   'covalent',
#   'diketoenamine',
#   'bonds',
#   '2018',
#   'pdf'],
#  ['show',
#   'hn',
#   'dataviz',
#   'project',
#   'for',
#   'raytracing',
#   'the',
#   'moon',
#   'model'],
#  ['five',
#   'new',
#   'realtime',
#   'detections',
#   'of',
#   'fast',
#   'radio',
#   'bursts',
#   'with',
#   'utmost'],
#  ['lucidscience', '–', 'electronic', 'projects', 'and', 'tutorials'],
#  ['what',
#   'are',
#   'children',
#   'dying',
#   'from',
#   'and',
#   'what',
#   'can',
#   'we',
#   'do',
#   'about',
#   'it'],
#  ['a',
#   'conversation',
#   'with',
#   'the',
#   'team',
#   'that',
#   'made',
#   'bread',
#   'with',
#   'ancient',
#   'egyptian',
#   'yeast'],
#  ['air',
#   'force',
#   'reveals',
#   'tests',
#   'of',
#   'supposed',
#   'recordsetting',
#   'scramjet',
#   'from',
#   'n',
#   'grumman'],
#  ['the', 'decline', 'of', 'college', 'newspapers'],
#  ['which', 'is', 'the', 'best', 'john', 'le', 'carré', 'novel', '2014'],
#  ['dreaming',
#   'about',
#   'better',
#   'sleep',
#   'dreem',
#   'oura',
#   'and',
#   'the',
#   'rest'],
#  ['penn', 'effect'],
#  ['hall’s',
#   'law',
#   'the',
#   'nineteenth',
#   'century',
#   'prequel',
#   'to',
#   'moore’s',
#   'law',
#   '2012'],
#  ['volcanoes',
#   'on',
#   'the',
#   'moon',
#   'may',
#   'have',
#   'erupted',
#   'during',
#   'the',
#   'dinosaur',
#   'age',
#   '2014'],
#  ['the', 'world’s', 'smartest', 'chimp', 'has', 'died'],
#  ['smart',
#   'plastic',
#   'incineration',
#   'posited',
#   'as',
#   'solution',
#   'to',
#   'global',
#   'recycling',
#   'crisis'],
#  ['kei', '–', 'a', 'small', 'and', 'expressive', 'dependent', 'language'],
#  ['freshermeat', '–', 'opensource', 'security', 'software'],
#  ['engineers',
#   'build',
#   'advanced',
#   'microprocessor',
#   'out',
#   'of',
#   'carbon',
#   'nanotubes'],
#  ['a',
#   'new',
#   'york',
#   'farm',
#   'stand’s',
#   'success',
#   'an',
#   'eye',
#   'for',
#   'the',
#   'next',
#   'big',
#   'thing'],
#  ['disneyland’s', 'disastrous', 'opening', 'day', '2015'],
#  ['a', 'zmachine', 'in', 'ocaml', '2016'],
#  ['quantum', 'air', 'buys', 'byes', 'electric', 'airplanes'],
#  ['famous', 'graphics', 'chips', 'microsoft’s', 'talisman'],
#  ['engineers',
#   'develop',
#   'bonelike',
#   'metal',
#   'foam',
#   'that',
#   'can',
#   'be',
#   'healed',
#   'at',
#   'room',
#   'temperature'],
#  ['using',
#   'the',
#   'golden',
#   'research',
#   'engine',
#   'to',
#   'query',
#   'the',
#   'y',
#   'combinator',
#   's19',
#   'batch'],
#  ['a', 'mosque', 'rebuilt', 'once', 'a', 'year'],
#  ['flying', 'with', 'miniature', 'horses'],
#  ['the', 'oral', 'history', 'of', 'the', 'super', 'soaker'],
#  ['a', 'trailblazing', 'plan', 'to', 'fight', 'california', 'wildfires'],
#  ['show', 'hn', 'firestorm', '–', 'an', 'orm', 'for', 'firestore'],
#  ['programming', 'shape', 'using', 'kirigami', 'tessellations'],
#  ['potosí',
#   'the',
#   'mountain',
#   'of',
#   'silver',
#   'that',
#   'was',
#   'the',
#   'first',
#   'global',
#   'city'],
#  ['an',
#   'ancient',
#   'egypttoblack',
#   'sea',
#   'route',
#   'adventurers',
#   'to',
#   'test',
#   'theory'],
#  ['exploring', 'the', 'visible', 'spectrum', 'in', 'python'],
#  ['general', 'balanced', 'trees', '1999', 'pdf'],
#  ['using',
#   'wall',
#   'street',
#   'secrets',
#   'to',
#   'reduce',
#   'the',
#   'cost',
#   'of',
#   'cloud',
#   'infrastructure'],
#  ['rediscovering', 'rules', 'for', 'ancient', 'board', 'games'],
#  ['on', 'the', 'road', 'in', '1980'],
#  ['the', 'software', 'arts'],
#  ['making', 'webworkers', 'async', 'iterables'],
#  ['show',
#   'hn',
#   'quarkide',
#   'and',
#   'a',
#   'javascript',
#   'runtime',
#   'to',
#   'build',
#   'crossplatform',
#   'desktop',
#   'apps'],
#  ['environment', 'and', 'the', 'programming', 'language', 'self', 'part', '4'],
#  ['the',
#   'lost',
#   'doves',
#   'press',
#   'typeface',
#   'and',
#   'its',
#   'revival',
#   '2015'],
#  ['early',
#   'years',
#   'of',
#   'computer',
#   'gaming',
#   'steve',
#   'russell',
#   'and',
#   'nolan',
#   'bushnell',
#   '2002',
#   'video'],
#  ['the',
#   'quest',
#   'to',
#   'conquer',
#   'earth’s',
#   'space',
#   'junk',
#   'problem',
#   '2018'],
#  ['swadesh', 'list'],
#  ['salvator',
#   'mundi',
#   'and',
#   'the',
#   'unreality',
#   'of',
#   'the',
#   'art',
#   'market']]

# %%
#Now we apply lemmatization 
def lemmatizationFunct(x):
    nltk.download('wordnet')
    lemmatizer = WordNetLemmatizer()
    finalLem = [lemmatizer.lemmatize(s) for s in x]
    return finalLem

link_titles_lem = link_titles_punct.map(lemmatizationFunct)
link_titles_lem.collect()
# Out:
# [['turning',
#   'a',
#   'macbook',
#   'into',
#   'a',
#   'touchscreen',
#   'with',
#   '1',
#   'of',
#   'hardware',
#   '2018'],
#  ['the', 'lonely', 'work', 'of', 'moderating', 'hacker', 'news'],
#  ['introducing', 'nushell'],
#  ['google',
#   'just',
#   'deleted',
#   'my',
#   'nearly',
#   '10yearold',
#   'free',
#   'and',
#   'opensource',
#   'android',
#   'app'],
#  ['ebola', 'is', 'now', 'curable'],
#  ['all',
#   'the',
#   'best',
#   'engineering',
#   'advice',
#   'i',
#   'stole',
#   'from',
#   'nontechnical',
#   'people'],
#  ['i', 'miss', 'microsoft', 'encarta'],
#  ['alan',
#   'kays',
#   'answer',
#   'to',
#   '‘what',
#   'are',
#   'some',
#   'forgotten',
#   'book',
#   'programmer',
#   'should',
#   'read’'],
#  ['information', 'operation', 'directed', 'at', 'hong', 'kong'],
#  ['terminating', 'service', 'for', '8chan'],
#  ['what',
#   'happens',
#   'when',
#   'you',
#   'launch',
#   'google',
#   'chrome',
#   'for',
#   'the',
#   'first',
#   'time'],
#  ['how', 'to', 'build', 'good', 'software'],
#  ['null', 'license', 'plate', 'not', 'such', 'a', 'bright', 'idea'],
#  ['what', 'doe', 'a', 'coder', 'do', 'if', 'they', 'cant', 'type'],
#  ['yelp',
#   'is',
#   'replacing',
#   'restaurants’',
#   'phone',
#   'number',
#   'so',
#   'grubhub',
#   'can',
#   'take',
#   'a',
#   'cut'],
#  ['japanese', 'anime', 'studio', 'khara', 'moving', 'to', 'blender'],
#  ['deconstructing', 'google’s', 'excuse', 'on', 'tracking', 'protection'],
#  ['cloudflare', 's1'],
#  ['8chan',
#   'go',
#   'dark',
#   'after',
#   'hardware',
#   'provider',
#   'discontinues',
#   'service'],
#  ['please', 'add', 'r', 'support', 'to', 'your', 'site'],
#  ['no', 'more', 'cheap', 'shipping', 'for', 'chinese', 'seller'],
#  ['python', 'is', 'eating', 'the', 'world'],
#  ['verizon', 'to', 'sell', 'tumblr', 'to', 'automattic'],
#  ['tasty', 'seaweed', 'reduces', 'cows’', 'methane', 'emission', 'by', '99'],
#  ['hy'],
#  ['thing', 'i', 'learnt', 'from', 'a', 'senior', 'software', 'engineer'],
#  ['wewtf'],
#  ['linux', 'journal', 'cease', 'publication', 'an', 'awkward', 'goodbye'],
#  ['amd',
#   'land',
#   'google',
#   'twitter',
#   'a',
#   'customer',
#   'with',
#   'newest',
#   'server',
#   'chip'],
#  ['u',
#   'navy',
#   'will',
#   'replace',
#   'touchscreen',
#   'with',
#   'mechanical',
#   'control',
#   'on',
#   'it',
#   'destroyer'],
#  ['standard',
#   'ebooks',
#   'free',
#   'publicdomain',
#   'ebooks',
#   'carefully',
#   'produced'],
#  ['why', 'is', 'modern', 'web', 'development', 'so', 'complicated'],
#  ['a',
#   'man',
#   'who',
#   'destroyed',
#   'his',
#   'multimillion',
#   'dollar',
#   'company',
#   'in',
#   '10',
#   'second',
#   '2018'],
#  ['opendrop', 'an', 'open', 'source', 'airdrop', 'implementation'],
#  ['a',
#   'deep',
#   'dive',
#   'into',
#   'io',
#   'exploit',
#   'chain',
#   'found',
#   'in',
#   'the',
#   'wild'],
#  ['software', 'architecture', 'guide'],
#  ['site',
#   'using',
#   'facebook',
#   '‘like’',
#   'button',
#   'liable',
#   'for',
#   'data',
#   'eu',
#   'court',
#   'rule'],
#  ['insect',
#   'apocalypse',
#   'in',
#   'u',
#   'driven',
#   'by',
#   '50x',
#   'increase',
#   'in',
#   'toxic',
#   'pesticide',
#   'study'],
#  ['apple',
#   'confirms',
#   '1m',
#   'reward',
#   'for',
#   'anyone',
#   'who',
#   'can',
#   'hack',
#   'an',
#   'iphone'],
#  ['why', 'all', 'of', 'our', 'game', 'look', 'like', 'crap'],
#  ['tech', 'interview', 'handbook'],
#  ['fewer',
#   'than',
#   'half',
#   'of',
#   'google',
#   'search',
#   'now',
#   'result',
#   'in',
#   'a',
#   'click'],
#  ['ugly',
#   'gerry',
#   '–',
#   'font',
#   'created',
#   'from',
#   'congressional',
#   'district'],
#  ['why', 'ha', 'examinecom', 'disappeared', 'from', 'search', 'result'],
#  ['a', 'walk', 'in', 'hong', 'kong'],
#  ['john', 'carmack', 'on', 'the', 'joe', 'rogan', 'experience', 'video'],
#  ['the',
#   'baseline',
#   'interpreter',
#   'a',
#   'faster',
#   'javascript',
#   'interpreter',
#   'in',
#   'firefox',
#   '70'],
#  ['google',
#   'doesn’t',
#   'want',
#   'staff',
#   'debating',
#   'politics',
#   'at',
#   'work',
#   'anymore'],
#  ['build', 'your', 'own', 'text', 'editor'],
#  ['ive',
#   'reproduced',
#   '130',
#   'research',
#   'paper',
#   'about',
#   '“predicting',
#   'the',
#   'stock',
#   'market”'],
#  ['ask', 'hn', 'how', 'do', 'you', 'read'],
#  ['how',
#   'to',
#   'build',
#   'a',
#   'plugin',
#   'system',
#   'on',
#   'the',
#   'web',
#   'and',
#   'also',
#   'sleep',
#   'well',
#   'at',
#   'night'],
#  ['europe',
#   'is',
#   'edging',
#   'towards',
#   'making',
#   'postcar',
#   'city',
#   'a',
#   'reality'],
#  ['new',
#   'york',
#   'city',
#   'neighbor',
#   'build',
#   'cheaper',
#   'way',
#   'to',
#   'connect',
#   'to',
#   'web'],
#  ['github',
#   'action',
#   'now',
#   'support',
#   'cicd',
#   'free',
#   'for',
#   'public',
#   'repository'],
#  ['consume', 'le', 'create', 'more'],
#  ['living',
#   'near',
#   'tree',
#   'not',
#   'just',
#   'green',
#   'space',
#   'improves',
#   'wellbeing'],
#  ['kerbal', 'space', 'program', '2'],
#  ['macbook', 'pro', 'keyboard', 'drive', 'me', 'crazy'],
#  ['why', 'i', 'turned', 'down', 'an', 'aws', 'job', 'offer'],
#  ['facebook', 'ha', 'been', 'granted', 'patent', 'on', 'shadow', 'banning'],
#  ['the',
#   'linux',
#   'kernel',
#   'inability',
#   'to',
#   'gracefully',
#   'handle',
#   'low',
#   'memory',
#   'pressure'],
#  ['show',
#   'hn',
#   'cli',
#   'tool',
#   'for',
#   'saving',
#   'web',
#   'page',
#   'a',
#   'a',
#   'single',
#   'file'],
#  ['start', 'your', 'own', 'isp'],
#  ['every',
#   'productivity',
#   'thought',
#   'ive',
#   'ever',
#   'had',
#   'a',
#   'concisely',
#   'a',
#   'possible'],
#  ['preindustrial',
#   'worker',
#   'worked',
#   'fewer',
#   'hour',
#   'than',
#   'today',
#   '2009'],
#  ['milky',
#   'way’s',
#   'black',
#   'hole',
#   'just',
#   'flared',
#   'growing',
#   '75',
#   'time',
#   'a',
#   'bright',
#   'for',
#   'a',
#   'few',
#   'hour'],
#  ['amazon',
#   'ha',
#   'proven',
#   'unable',
#   'or',
#   'unwilling',
#   'to',
#   'effectively',
#   'police',
#   'thirdparty',
#   'seller'],
#  ['rail', '60'],
#  ['haha', 'wall'],
#  ['speaking',
#   'to',
#   'yourself',
#   'in',
#   'the',
#   'third',
#   'person',
#   'make',
#   'you',
#   'wiser'],
#  ['ibm', 'opensources', 'power', 'chip', 'instruction', 'set'],
#  ['apple',
#   'expands',
#   'part',
#   'access',
#   'to',
#   'more',
#   'independent',
#   'repair',
#   'business'],
#  ['paged',
#   'out',
#   '–',
#   'a',
#   'new',
#   'experimental',
#   'magazine',
#   'about',
#   'programming'],
#  ['let', 'build', 'house', 'for', 'people', 'not', 'car'],
#  ['we', 'have', 'ruined', 'childhood'],
#  ['decrement', 'carbon', 'stripe', 'negative', 'emission', 'commitment'],
#  ['16m', 'american', 'will', 'vote', 'on', 'hackable', 'paperless', 'machine'],
#  ['home', 'chip', 'fab'],
#  ['google',
#   'and',
#   'mozilla',
#   'are',
#   'failing',
#   'to',
#   'support',
#   'browser',
#   'extension',
#   'developer'],
#  ['a', 'mathematician', 'way', 'of', 'converting', 'mile', 'to', 'kilometer'],
#  ['there', 'is', 'no', 'evil', 'like', 'recaptcha'],
#  ['kaspersky',
#   'av',
#   'injected',
#   'unique',
#   'id',
#   'allowing',
#   'site',
#   'to',
#   'track',
#   'user',
#   'in',
#   'incognito',
#   'mode'],
#  ['who', 'owns', 'huawei'],
#  ['the', 'horror', 'of', 'microsoft', 'team'],
#  ['hundred',
#   'of',
#   'extreme',
#   'selfciting',
#   'scientist',
#   'revealed',
#   'in',
#   'new',
#   'database'],
#  ['regex', 'for', 'noobs', '–', 'an', 'illustrated', 'guide'],
#  ['apple',
#   'will',
#   'soon',
#   'treat',
#   'online',
#   'web',
#   'tracking',
#   'the',
#   'same',
#   'a',
#   'a',
#   'security',
#   'vulnerability'],
#  ['the', 'it', 'guy', 'v', 'the', 'con', 'artist'],
#  ['death', 'note', 'l', 'anonymity', 'and', 'eluding', 'entropy', '2017'],
#  ['amd',
#   'rome',
#   'second',
#   'generation',
#   'epyc',
#   'review',
#   '2x',
#   '64core',
#   'benchmarked'],
#  ['amazon', 'is', 'a', 'monopoly'],
#  ['time', 'anxiety', 'is', 'it', 'too', 'late'],
#  ['wtf',
#   '–',
#   'a',
#   'personal',
#   'information',
#   'dashboard',
#   'for',
#   'your',
#   'terminal'],
#  ['scientist',
#   'discover',
#   'a',
#   'cure',
#   'for',
#   'the',
#   'deadliest',
#   'strain',
#   'of',
#   'tuberculosis'],
#  ['show', 'hn', 'divjoy', '–', 'react', 'codebase', 'and', 'ui', 'generator'],
#  ['protein',
#   'that',
#   'may',
#   'restore',
#   'damaged',
#   'sounddetecting',
#   'cell',
#   'in',
#   'the',
#   'ear'],
#  ['15',
#   'state',
#   'are',
#   'trying',
#   'to',
#   'make',
#   'the',
#   'electoral',
#   'college',
#   'obselete'],
#  ['banned',
#   'c',
#   'standard',
#   'library',
#   'function',
#   'in',
#   'git',
#   'source',
#   'code'],
#  ['pronunciation', 'for', 'hexadecimal', 'number', '1968'],
#  ['turbo', 'an', 'improved', 'rainbow', 'colormap', 'for', 'visualization'],
#  ['from',
#   'mac',
#   'to',
#   'linux',
#   '–',
#   'the',
#   'setup',
#   'ive',
#   'grown',
#   'to',
#   'love'],
#  ['time', 'to', 'get', 'serious', 'about', 'tickborne', 'disease'],
#  ['pentagon',
#   'testing',
#   'mass',
#   'surveillance',
#   'balloon',
#   'across',
#   'the',
#   'u'],
#  ['useless', 'window', '10', 'feature'],
#  ['some', 'obscure', 'c', 'feature'],
#  ['mercedesbenz', 'presafe', 'sound'],
#  ['tsv',
#   'utility',
#   'command',
#   'line',
#   'tool',
#   'for',
#   'large',
#   'tabular',
#   'data',
#   'file'],
#  ['psytrance', 'guide'],
#  ['researcher',
#   'banned',
#   'on',
#   'valve',
#   'bug',
#   'bounty',
#   'program',
#   'publishes',
#   'second',
#   'steam',
#   '0day'],
#  ['why',
#   'do',
#   'developer',
#   'at',
#   'google',
#   'consider',
#   'agile',
#   'development',
#   'to',
#   'be',
#   'nonsense',
#   '2016'],
#  ['planet', 'imaging', 'the', 'entire', 'earth', 'every', 'day'],
#  ['software', 'made', 'me', 'loathe', 'my', 'car'],
#  ['dqlite', '–', 'highavailability', 'sqlite'],
#  ['cutiepi', '–', 'allinone', 'raspberry', 'pi', 'tablet'],
#  ['knuth',
#   'on',
#   'huangs',
#   'sensitivity',
#   'proof',
#   '“ive',
#   'got',
#   'the',
#   'proof',
#   'down',
#   'to',
#   'one',
#   'page”',
#   'pdf'],
#  ['supercentenarians',
#   'are',
#   'concentrated',
#   'into',
#   'region',
#   'with',
#   'no',
#   'birth',
#   'certificate'],
#  ['anthony',
#   'levandowski',
#   'charged',
#   'with',
#   'theft',
#   'of',
#   'trade',
#   'secret'],
#  ['exfat', 'in', 'the', 'linux', 'kernel'],
#  ['speed',
#   'matter',
#   'why',
#   'working',
#   'quickly',
#   'is',
#   'more',
#   'important',
#   'than',
#   'it',
#   'seems',
#   '2015'],
#  ['programmer',
#   'before',
#   'you',
#   'turn',
#   '40',
#   'get',
#   'a',
#   'plan',
#   'b',
#   '2009'],
#  ['information', 'theory', 'for', 'intelligent', 'people', '2018', 'pdf'],
#  ['i',
#   'completed',
#   'ultimate',
#   'go',
#   'took',
#   'good',
#   'note',
#   'and',
#   'commented',
#   'directly',
#   'on',
#   'source',
#   'code'],
#  ['a',
#   'guide',
#   'to',
#   'recording',
#   '660fps',
#   'video',
#   'on',
#   'a',
#   '6',
#   'raspberry',
#   'pi',
#   'camera'],
#  ['super', 'mario', '64', 'ha', 'been', 'decompiled'],
#  ['yaml', 'probably', 'not', 'so', 'great', 'after', 'all'],
#  ['rust', 'language', 'cheat', 'sheet'],
#  ['thought', 'on', 'rust', 'bloat'],
#  ['google', 'chrome', 'incognito', 'mode', 'can', 'still', 'be', 'detected'],
#  ['rule', 'for', 'intuitive', 'ux'],
#  ['iterm2', '33'],
#  ['datadog', 's1'],
#  ['the',
#   'not',
#   'so',
#   'hidden',
#   'cost',
#   'of',
#   'sharing',
#   'code',
#   'between',
#   'io',
#   'and',
#   'android'],
#  ['show', 'hn', 'chartxkcd', '–', 'xkcdstyled', 'chart', 'library'],
#  ['tell', 'hn', 'danny', 'cohen', 'ha', 'died'],
#  ['down', 'the', 'rabbithole'],
#  ['three', 'kind', 'of', 'good', 'tech', 'debt'],
#  ['facebook',
#   'scan',
#   'system',
#   'library',
#   'on',
#   'android',
#   'and',
#   'uploads',
#   'them',
#   'to',
#   'their',
#   'server'],
#  ['uber', 'post', '52b', 'loss', 'and', 'slowest', 'ever', 'growth', 'rate'],
#  ['the', 'fully', 'remote', 'attack', 'surface', 'of', 'the', 'iphone'],
#  ['google',
#   'to',
#   'offer',
#   'a',
#   'best',
#   'price',
#   'guarantee',
#   'on',
#   'certain',
#   'flight'],
#  ['npm', 'ban', 'terminal', 'ad'],
#  ['the', 'architecture', 'of', 'open', 'source', 'application'],
#  ['people', 'love', 'working', 'remotely'],
#  ['berlin’s', 'popular', 'shopping', 'street', 'will', 'go', 'carfree'],
#  ['toni', 'morrison', 'ha', 'died'],
#  ['sourcehut', 'welcome', 'bitbucket', 'refugee'],
#  ['ai',
#   'startup',
#   'claim',
#   'to',
#   'automate',
#   'app',
#   'making',
#   'but',
#   'actually',
#   'just',
#   'us',
#   'human'],
#  ['ask',
#   'hn',
#   'recommended',
#   'resource',
#   'to',
#   'learn',
#   'the',
#   'linux',
#   'kernel',
#   'and',
#   'o',
#   'theory'],
#  ['steam', 'window', 'client', 'local', 'privilege', 'escalation', '0day'],
#  ['hong',
#   'kong',
#   'isp',
#   'association’s',
#   'statement',
#   'on',
#   'selective',
#   'blocking',
#   'of',
#   'internet',
#   'service'],
#  ['i',
#   'wasn’t',
#   'getting',
#   'hired',
#   'a',
#   'a',
#   'data',
#   'scientist',
#   'so',
#   'i',
#   'sought',
#   'data',
#   'on',
#   'who',
#   'is'],
#  ['juul',
#   'philip',
#   'morris',
#   'sued',
#   'under',
#   'racketeer',
#   'act',
#   'for',
#   'targeting',
#   'kid'],
#  ['vmware',
#   'acquires',
#   'carbon',
#   'black',
#   'for',
#   '21b',
#   'and',
#   'pivotal',
#   'for',
#   '27b'],
#  ['zen',
#   '2',
#   'missive',
#   '–',
#   'amd',
#   'now',
#   'delivering',
#   'efficiency',
#   'that',
#   'are',
#   'double',
#   'that',
#   'of',
#   'intel'],
#  ['write', 'your', 'own', 'excel', 'in', 'f', '2018'],
#  ['performance', 'matter'],
#  ['is', 'perl', '6', 'being', 'renamed'],
#  ['people', 'simply', 'empty', 'out', '1986'],
#  ['black',
#   'hat',
#   'gdpr',
#   'privacy',
#   'law',
#   'exploited',
#   'to',
#   'reveal',
#   'personal',
#   'data'],
#  ['show',
#   'hn',
#   'i',
#   'trained',
#   'a',
#   'deep',
#   'learning',
#   'model',
#   'to',
#   'build',
#   'site',
#   'for',
#   'me'],
#  ['webkit', 'tracking', 'prevention', 'policy'],
#  ['removing', 'coordinated', 'inauthentic', 'behavior', 'from', 'china'],
#  ['calculus', 'for', 'the', 'people'],
#  ['anxiety', 'look', 'different', 'in', 'men'],
#  ['yield', 'curve', 'invert', 'in', 'u', 'uk'],
#  ['amazon',
#   'offered',
#   '‘amazon’s',
#   'choice’',
#   'to',
#   'vendor',
#   'who',
#   'bought',
#   'ad',
#   'and',
#   'lowered',
#   'price'],
#  ['cyberchef', '–', 'cyber', 'swiss', 'army', 'knife'],
#  ['rust', '1370'],
#  ['a',
#   'boeing',
#   'code',
#   'leak',
#   'expose',
#   'security',
#   'flaw',
#   'deep',
#   'in',
#   'a',
#   '787s',
#   'gut'],
#  ['ask', 'hn', 'best', 'resource', 'to', 'gain', 'math', 'intuition'],
#  ['mozilla', 'take', 'action', 'to', 'protect', 'user', 'in', 'kazakhstan'],
#  ['anime4k', 'real', 'time', 'high', 'quality', 'video', 'upscaling'],
#  ['wine', 'on', 'window', '10'],
#  ['building',
#   'a',
#   'distributed',
#   'timeseries',
#   'database',
#   'on',
#   'postgresql'],
#  ['xfce', '414'],
#  ['most', 'startup', 'theory', 'is', 'expost', 'therefore', 'b'],
#  ['lesson', 'from', 'stripe'],
#  ['show',
#   'hn',
#   'wavebased',
#   'nonlineofsight',
#   'computational',
#   'imaging',
#   'in',
#   'julia'],
#  ['‘they',
#   'get',
#   'fired',
#   'all',
#   'the',
#   'time',
#   'and',
#   'they',
#   'have',
#   'no',
#   'idea',
#   'why’'],
#  ['9th',
#   'circuit',
#   'say',
#   'user',
#   'can',
#   'sue',
#   'facebook',
#   'over',
#   'unlawful',
#   'use',
#   'of',
#   'facial',
#   'recognition'],
#  ['linux',
#   'kernel',
#   'driver',
#   'in',
#   'rust',
#   'might',
#   'become',
#   'an',
#   'option',
#   'in',
#   'the',
#   'future'],
#  ['moviepass', 'worked', 'out', 'great'],
#  ['a',
#   'beginner’s',
#   'introduction',
#   'to',
#   'python',
#   'web',
#   'framework',
#   '2018'],
#  ['ask', 'hn', 'who', 'is', 'hiring', 'august', '2019'],
#  ['show', 'hn', 'data', 'structure', 'and', 'algorithm', 'in', 'javascript'],
#  ['await', 'in', 'rust'],
#  ['cool', 'but', 'obscure', 'x11', 'tool'],
#  ['elsevier',
#   'threatens',
#   'others',
#   'for',
#   'linking',
#   'to',
#   'scihub',
#   'but',
#   'doe',
#   'so',
#   'itself'],
#  ['group',
#   'sex',
#   'app',
#   'leak',
#   'location',
#   'pic',
#   'and',
#   'personal',
#   'detail'],
#  ['apple', 'is', 'locking', 'iphone', 'battery', 'to', 'discourage', 'repair'],
#  ['“i', 'would', 'like', 'to', 'maintain', 'the', 'floppy', 'driver”'],
#  ['fracking',
#   'in',
#   'north',
#   'america',
#   'could',
#   'be',
#   'partly',
#   'to',
#   'blame',
#   'for',
#   'methane',
#   'spike',
#   '–',
#   'study'],
#  ['flawed',
#   'algorithm',
#   'are',
#   'grading',
#   'million',
#   'of',
#   'students’',
#   'essay'],
#  ['35', 'over', '35'],
#  ['u', 'designates', 'china', 'a', 'currency', 'manipulator'],
#  ['sunsetting', 'mercurial', 'support', 'in', 'bitbucket'],
#  ['open',
#   'letter',
#   'from',
#   'an',
#   'android',
#   'developer',
#   'to',
#   'the',
#   'google',
#   'play',
#   'team'],
#  ['cue',
#   '–',
#   'a',
#   'language',
#   'for',
#   'defining',
#   'generating',
#   'and',
#   'validating',
#   'data'],
#  ['how', 'rust', 'optimizes', 'asyncawait'],
#  ['one',
#   'city',
#   'saved',
#   '5m',
#   'by',
#   'routing',
#   'school',
#   'bus',
#   'with',
#   'an',
#   'algorithm'],
#  ['asyncstd',
#   'an',
#   'async',
#   'port',
#   'of',
#   'the',
#   'rust',
#   'standard',
#   'library'],
#  ['regexr'],
#  ['the', 'art', 'of', 'warez', 'video'],
#  ['get', 'your', 'work', 'recognized', 'write', 'a', 'brag', 'document'],
#  ['one',
#   'job',
#   'many',
#   'role',
#   'the',
#   'different',
#   'skill',
#   'needed',
#   'to',
#   'be',
#   'a',
#   'successful',
#   'cto'],
#  ['productivity', 'and', 'the', 'workweek', '2000'],
#  ['nigerian',
#   'teen',
#   'are',
#   'making',
#   'scifi',
#   'short',
#   'with',
#   'slick',
#   'visual',
#   'effect'],
#  ['the',
#   'most',
#   'frequent',
#   '777',
#   'character',
#   'give',
#   '90',
#   'coverage',
#   'of',
#   'kanji',
#   'in',
#   'the',
#   'wild'],
#  ['contributing', 'to', 'the', 'mozilla', 'code', 'base'],
#  ['the', 'lost', 'art', 'of', 'lacing', 'cable', '2018'],
#  ['martini', 'realtime', 'terrain', 'mesh', 'generator'],
#  ['the', 'impact', 'of', 'meditating', 'every', 'day'],
#  ['software',
#   'wa',
#   'eating',
#   'the',
#   'world',
#   '–',
#   'now',
#   'landlord',
#   'are',
#   'eating',
#   'everything'],
#  ['ibm',
#   'ha',
#   'released',
#   'the',
#   'power',
#   'architecture',
#   'instruction',
#   'set',
#   'to',
#   'the',
#   'linux',
#   'foundation'],
#  ['plastic', 'whats', 'recyclable', 'what', 'becomes', 'trash', 'and', 'why'],
#  ['uber', 'losing', 'billion', 'freeze', 'engineering', 'hire'],
#  ['irs',
#   'budget',
#   'cut',
#   'cost',
#   '343b',
#   'in',
#   'lost',
#   'revenue',
#   'from',
#   'big',
#   'business'],
#  ['calculus', 'is', 'deeply', 'irrational'],
#  ['every', 'noise', 'at', 'once'],
#  ['att',
#   'employee',
#   'were',
#   'bribed',
#   'to',
#   'install',
#   'phone',
#   'unlocking',
#   'malware',
#   'on',
#   'company',
#   'network'],
#  ['the', 'problem', 'at', 'yale', 'is', 'not', 'free', 'speech'],
#  ['silk'],
#  ['beyond',
#   'meat',
#   'and',
#   'kfc',
#   'partner',
#   'to',
#   'test',
#   'fried',
#   'plantbased',
#   '‘chicken’'],
#  ['the', 'we', 'company', 's1'],
#  ['how', 'to', 'return', 'to', 'the', 'flow', 'faster'],
#  ['the',
#   'paxos',
#   'algorithm',
#   'or',
#   'how',
#   'to',
#   'win',
#   'a',
#   'turing',
#   'award'],
#  ['attorney', 'general', 'barr', 'and', 'encryption'],
#  ['making', 'email', 'more', 'modern', 'with', 'jmap'],
#  ['ffmpeg', '42'],
#  ['webassembly',
#   'interface',
#   'type',
#   'interoperate',
#   'with',
#   'all',
#   'the',
#   'thing'],
#  ['roblox',
#   'hit',
#   '100m',
#   'monthly',
#   'active',
#   'user',
#   'bigger',
#   'than',
#   'minecraft'],
#  ['word', 'that', 'do', 'handstand'],
#  ['how', 'men’s', 'body', 'change', 'when', 'they', 'become', 'father'],
#  ['misconfigured',
#   'jira',
#   'instance',
#   'exposed',
#   'data',
#   'of',
#   'hundred',
#   'of',
#   'fortune',
#   '500',
#   'company'],
#  ['company',
#   'use',
#   'borrowed',
#   'billion',
#   'to',
#   'buy',
#   'back',
#   'stock',
#   'not',
#   'to',
#   'invest'],
#  ['ny',
#   'state',
#   'alleges',
#   'exxonmobil',
#   'knew',
#   'risk',
#   'of',
#   'climate',
#   'change',
#   'and',
#   'defrauded',
#   'investor'],
#  ['new', 'react', 'devtools'],
#  ['wework',
#   'get',
#   'tax',
#   'rebate',
#   'meant',
#   'for',
#   'it',
#   'smallbusiness',
#   'tenant'],
#  ['administration',
#   'using',
#   'the',
#   'full',
#   'power',
#   'of',
#   'the',
#   'surveillance',
#   'state',
#   'on',
#   'whistleblower'],
#  ['a',
#   'book',
#   'from',
#   'alan',
#   'turing',
#   'and',
#   'a',
#   'mysterious',
#   'piece',
#   'of',
#   'paper'],
#  ['how', 'to', 'get', 'your', 'first', 'ten', 'customer', '2013'],
#  ['doe', 'the', 'amazon', 'provide', '20', 'of', 'our', 'oxygen'],
#  ['uber',
#   'proposes',
#   'policy',
#   'that',
#   'would',
#   'pay',
#   'driver',
#   'a',
#   'minimum',
#   'wage',
#   'of',
#   '21',
#   'per',
#   'hour'],
#  ['the', 'most', 'dangerous', 'writing', 'app'],
#  ['why',
#   'did',
#   'china',
#   'just',
#   'devalue',
#   'the',
#   'yuan',
#   'how',
#   'trade',
#   'work',
#   'with',
#   'freefloating',
#   'currency'],
#  ['arend',
#   'theorem',
#   'prover',
#   'based',
#   'on',
#   'homotopy',
#   'type',
#   'theory',
#   'by',
#   'jetbrains'],
#  ['blazingsql', 'is', 'now', 'open', 'source'],
#  ['key', 'negotiation', 'of', 'bluetooth', 'attack'],
#  ['ondevice', 'realtime', 'hand', 'tracking', 'with', 'mediapipe'],
#  ['dirty', 'trick', '6502', 'programmer', 'use'],
#  ['insured', 'price', '2758', 'cash', 'price', '521'],
#  ['german', 'grow', 'frustrated', 'with', 'their', 'slowpoke', 'internet'],
#  ['building', 'a', 'raspberry', 'pi', '3b', 'full', 'keyboard', 'handheld'],
#  ['show',
#   'hn',
#   'saag',
#   'a',
#   'a',
#   'service',
#   '–',
#   'macronutrientportioned',
#   'indian',
#   'spinach',
#   'curry'],
#  ['social', 'exclusion', 'fuel', 'extremism', 'in', 'young', 'men'],
#  ['camscanner',
#   'a',
#   'malicious',
#   'android',
#   'app',
#   'with',
#   'more',
#   'than',
#   '100m',
#   'downloads',
#   'in',
#   'google',
#   'play'],
#  ['moscow',
#   'blockchain',
#   'voting',
#   'system',
#   'cracked',
#   'a',
#   'month',
#   'before',
#   'election'],
#  ['anna', 'karenina', 'principle'],
#  ['qemu', 'vm', 'escape'],
#  ['inflated',
#   'bond',
#   'rating',
#   'helped',
#   'spur',
#   'the',
#   'financial',
#   'crisis',
#   'they’re',
#   'back'],
#  ['medieval', 'people', 'bathed', 'regularly'],
#  ['devilution',
#   '–',
#   'a',
#   'web',
#   'port',
#   'of',
#   'the',
#   'original',
#   'diablo',
#   'game'],
#  ['cooling', 'a', 'house', 'without', 'air', 'conditioning'],
#  ['38myearold',
#   'skull',
#   'of',
#   'an',
#   'early',
#   'apelike',
#   'human',
#   'ancestor',
#   'discovered',
#   'in',
#   'ethiopia'],
#  ['huawei',
#   'technician',
#   'helped',
#   'african',
#   'government',
#   'spy',
#   'on',
#   'political',
#   'opponent'],
#  ['typescript', '36'],
#  ['the', 'answer', 'to', '“will', 'you', 'mentor', 'me”', 'is', 'no', '2010'],
#  ['how',
#   'to',
#   'measure',
#   'indoor',
#   'air',
#   'quality',
#   'with',
#   'a',
#   'raspberry',
#   'pi',
#   'ruuvitags',
#   'and',
#   'pms7003'],
#  ['wework', 'isn’t', 'a', 'tech', 'company'],
#  ['why', 'const', 'doesnt', 'make', 'c', 'code', 'faster'],
#  ['verified', 'by', 'twilio'],
#  ['python', 'v', 'rust', 'for', 'neural', 'network'],
#  ['big', 'coal', 'plant', 'begin', 'to', 'close'],
#  ['aussie', 'isv', 'buy', 'ad', 'to', 'wake', 'up', 'google', 'support'],
#  ['the', 'feynman', 'lecture', 'on', 'physic', 'algebra', '1963'],
#  ['coinbase', 'responding', 'to', 'firefox', '0days', 'in', 'the', 'wild'],
#  ['gamedev',
#   'tutorial',
#   'trigonometry',
#   'basic',
#   '–',
#   'sine',
#   'and',
#   'cosine'],
#  ['secretly',
#   'public',
#   'domain',
#   'most',
#   'book',
#   'published',
#   'in',
#   'the',
#   'u',
#   'before',
#   '1964'],
#  ['show',
#   'hn',
#   'clojurescript',
#   'pixel',
#   'game',
#   'engine',
#   'with',
#   'blender',
#   'livereloading'],
#  ['lisp', 'is', 'not', 'based', 'on', 'the', 'lambda', 'calculus'],
#  ['alphabet',
#   'overtakes',
#   'apple',
#   'to',
#   'become',
#   'most',
#   'cashrich',
#   'company'],
#  ['rice',
#   'university',
#   'researcher',
#   'propose',
#   'a',
#   'way',
#   'to',
#   'boost',
#   'solar',
#   'efficiency'],
#  ['using',
#   'backblaze',
#   'b2',
#   'and',
#   'cloudflare',
#   'worker',
#   'for',
#   'free',
#   'image',
#   'hosting'],
#  ['the',
#   'worst',
#   'sale',
#   'promotion',
#   'in',
#   'history',
#   'hoover',
#   'free',
#   'flight',
#   'fiasco'],
#  ['the', 'door', 'problem', 'of', 'combat', 'design'],
#  ['wikipedia', 'is', 'now', 'a', 'brave', 'verified', 'publisher'],
#  ['google',
#   'plan',
#   'to',
#   'deprecate',
#   'ftp',
#   'url',
#   'support',
#   'in',
#   'chrome'],
#  ['killing', 'a', 'process', 'and', 'all', 'of', 'it', 'descendant'],
#  ['show',
#   'hn',
#   'i',
#   'created',
#   'postwoman',
#   'an',
#   'online',
#   'opensource',
#   'api',
#   'request',
#   'builder'],
#  ['the', 'many', 'possibility', 'of', 'imessage', 'file', 'vulnerability'],
#  ['the',
#   'design',
#   'of',
#   'littlefs',
#   'a',
#   'failsafe',
#   'filesystem',
#   'designed',
#   'for',
#   'microcontrollers'],
#  ['ask',
#   'hn',
#   'whats',
#   'the',
#   'best',
#   'setup',
#   'for',
#   'ad',
#   'blocking',
#   'and',
#   'tracker',
#   'blocking'],
#  ['rabbit', 'hole', 'the', 'secret', 'to', 'technical', 'expertise'],
#  ['show',
#   'hn',
#   'i',
#   'made',
#   'a',
#   'crm',
#   'system',
#   'to',
#   'make',
#   'sale',
#   'fun'],
#  ['syslog', 'complete', 'system', 'administrator', 'guide'],
#  ['my', 'sudden', 'trip', 'to', 'hell'],
#  ['why', 'doe', 'all', 'life', 'use', 'the', 'same', '20', 'amino', 'acid'],
#  ['toshiba', 'introduces', 'new', 'tiny', 'nvme', 'ssd', 'form', 'factor'],
#  ['john', 'carmack', 'on', 'parallel', 'implementation', '2018'],
#  ['gnu', 'radio', '38'],
#  ['ask', 'hn', 'how', 'do', 'you', 'handle', 'logging'],
#  ['the', 'github', 'registry', 'public', 'beta', 'is', 'live'],
#  ['a', 'practical', 'guide', 'to', 'cs', 'transition', 'and', 'animation'],
#  ['u',
#   'farmer',
#   'stung',
#   'by',
#   'tariff',
#   'now',
#   'face',
#   'a',
#   '35b',
#   'corn',
#   'loss'],
#  ['facebook',
#   'hit',
#   'by',
#   'apple’s',
#   'crackdown',
#   'on',
#   'messaging',
#   'feature'],
#  ['privacy',
#   'sandbox',
#   '–',
#   'open',
#   'standard',
#   'to',
#   'enhance',
#   'privacy',
#   'on',
#   'the',
#   'web'],
#  ['transformer', 'from', 'scratch'],
#  ['we', 'made', 'amiga', 'they', 'fucked', 'it', 'up', '2015'],
#  ['memory', 'management', 'in', 'python'],
#  ['die',
#   'with',
#   'me',
#   '–',
#   'a',
#   'chat',
#   'app',
#   'you',
#   'can',
#   'only',
#   'use',
#   'when',
#   'you',
#   'have',
#   'le',
#   'than',
#   '5',
#   'battery'],
#  ['now',
#   'bigger',
#   'than',
#   'ebay',
#   'shopify',
#   'set',
#   'it',
#   'sight',
#   'on',
#   'amazon'],
#  ['let', 'build', 'a', 'video', 'card'],
#  ['pastel',
#   'a',
#   'commandline',
#   'tool',
#   'to',
#   'generate',
#   'analyze',
#   'convert',
#   'and',
#   'manipulate',
#   'color'],
#  ['pagemap', 'a', 'mini', 'map', 'for', 'your', 'website'],
#  ['minify', 'your', 'svgs'],
#  ['yubico',
#   'launch',
#   'it',
#   'dual',
#   'usbc',
#   'and',
#   'lightning',
#   'twofactor',
#   'security',
#   'key'],
#  ['a',
#   'bloomberg',
#   'reporter’s',
#   'account',
#   'of',
#   'trying',
#   'to',
#   'get',
#   'back',
#   'his',
#   'name',
#   'and',
#   'credit',
#   'rating'],
#  ['opioid',
#   'crisis',
#   'johnson',
#   'and',
#   'johnson',
#   'hit',
#   'by',
#   'landmark',
#   'ruling'],
#  ['big',
#   'pharma',
#   'is',
#   'using',
#   'faux',
#   'generic',
#   'to',
#   'keep',
#   'drug',
#   'price',
#   'high',
#   'critic',
#   'say'],
#  ['tokyo', 'audiophile', 'venue', '2016'],
#  ['japan',
#   'surpasses',
#   'china',
#   'a',
#   'largest',
#   'foreign',
#   'holder',
#   'of',
#   'u',
#   'treasury'],
#  ['statement', 'on', 'the', 'purpose', 'of', 'a', 'corporation'],
#  ['spying', 'on', 'http'],
#  ['why',
#   'doesnt',
#   'mathematics',
#   'collapse',
#   'though',
#   'human',
#   'often',
#   'make',
#   'mistake',
#   'in',
#   'proof'],
#  ['hacker',
#   'ship',
#   'their',
#   'exploit',
#   'directly',
#   'to',
#   'their',
#   'target’s',
#   'mailroom'],
#  ['major',
#   'book',
#   'publisher',
#   'sue',
#   'amazon’s',
#   'audible',
#   'over',
#   'new',
#   'speechtotext',
#   'feature'],
#  ['hacking',
#   'the',
#   'sonos',
#   'ikea',
#   'symfonisk',
#   'into',
#   'a',
#   'high',
#   'quality',
#   'speaker',
#   'amp'],
#  ['kubernetes', 'security', 'assessment', 'pdf'],
#  ['“culture', 'fit”', 'is', 'a', 'two', 'way', 'street', '2018'],
#  ['what', 'happens', 'when', 'you', 'ach', 'a', 'dead', 'person'],
#  ['google', 'search', 'take', '7', 'second', 'on', 'certain', 'query'],
#  ['go', 'module', 'mirror', 'and', 'checksum', 'database', 'launched'],
#  ['high',
#   'level',
#   'of',
#   'oestrogen',
#   'in',
#   'the',
#   'womb',
#   'linked',
#   'to',
#   'autism'],
#  ['alone', 'in', 'the', 'dark'],
#  ['the',
#   'fungus',
#   'that',
#   'devastates',
#   'the',
#   'cavendish',
#   'banana',
#   'ha',
#   'now',
#   'arrived',
#   'in',
#   'latin',
#   'america'],
#  ['metal',
#   'shard',
#   'from',
#   'boeing',
#   '787',
#   'taking',
#   'off',
#   'over',
#   'rome',
#   'rain',
#   'down',
#   'on',
#   'people',
#   'below'],
#  ['the',
#   '“terrible”',
#   '3',
#   'cent',
#   'mcu',
#   '–',
#   'a',
#   'short',
#   'survey',
#   'of',
#   'sub',
#   '010',
#   'microcontrollers'],
#  ['the', 'order', 'of', 'the', 'json'],
#  ['in',
#   'effect',
#   'seattle',
#   'is',
#   'decriminalizing',
#   'the',
#   'use',
#   'of',
#   'hard',
#   'drug'],
#  ['faa', 'ban', 'recalled', 'apple', 'laptop', 'from', 'flight'],
#  ['salsify',
#   '–',
#   'a',
#   'new',
#   'architecture',
#   'for',
#   'realtime',
#   'internet',
#   'video'],
#  ['walmart',
#   'sue',
#   'tesla',
#   'over',
#   'fire',
#   'at',
#   'store',
#   'fitted',
#   'with',
#   'it',
#   'solar',
#   'panel'],
#  ['danish', 'bank', 'launch', 'negative', 'interest', 'rate', 'mortgage'],
#  ['opensource', 'firmware'],
#  ['technical', 'vision', 'for', 'qt', '6'],
#  ['show',
#   'hn',
#   'yack',
#   '–',
#   'community',
#   'browser',
#   'for',
#   'hacker',
#   'news',
#   'reddit',
#   'youtube',
#   'and',
#   'more'],
#  ['a', 'dream', 'of', 'an', 'ultimate', 'o', '1995'],
#  ['a', 'primer', 'on', 'bézier', 'curve', '2013'],
#  ['bontrager’s',
#   'wavecel',
#   'material',
#   'more',
#   'effective',
#   'at',
#   'preventing',
#   'concussion',
#   'than',
#   'mips'],
#  ['the',
#   'death',
#   'of',
#   'social',
#   'reciprocity',
#   'in',
#   'the',
#   'era',
#   'of',
#   'digital',
#   'distraction'],
#  ['amazon',
#   'want',
#   'to',
#   'control',
#   'thirdparty',
#   'sellers’',
#   'product',
#   'pricing'],
#  ['partiql', 'one', 'query', 'language', 'for', 'all', 'your', 'data'],
#  ['a', 'bug', 'i', 'wish', 'i', 'hadnt', 'caught'],
#  ['a', 'mobile', 'phone', 'that', 'respect', 'your', 'freedom', 'video'],
#  ['cloud',
#   'run',
#   'button',
#   'clicktodeploy',
#   'your',
#   'git',
#   'repos',
#   'to',
#   'gcp'],
#  ['my',
#   'home',
#   'lab',
#   'server',
#   'with',
#   '20',
#   'core',
#   '',
#   '40',
#   'thread',
#   'and',
#   '128',
#   'gb',
#   'memory'],
#  ['gcc', 'null', 'pointer', 'check', 'removed'],
#  ['in',
#   'the',
#   'u',
#   'it',
#   'cheaper',
#   'to',
#   'build',
#   'and',
#   'operate',
#   'wind',
#   'farm',
#   'than',
#   'buy',
#   'fossil',
#   'fuel'],
#  ['wiringpi', '–', 'deprecated'],
#  ['credit', 'card', 'have', 'a', 'privacy', 'problem'],
#  ['starbucks', 'monetary', 'superpower'],
#  ['building', 'age', 'in', 'the', 'netherlands'],
#  ['huawei',
#   'seek',
#   'independence',
#   'from',
#   'the',
#   'u',
#   'with',
#   'riscv',
#   'and',
#   'ascend',
#   'chip'],
#  ['black',
#   'hat',
#   'talk',
#   'about',
#   '‘time',
#   'ai’',
#   'cause',
#   'uproar',
#   'is',
#   'deleted',
#   'by',
#   'conference'],
#  ['the',
#   'hypersane',
#   'are',
#   'among',
#   'u',
#   'if',
#   'only',
#   'we',
#   'are',
#   'prepared',
#   'to',
#   'look'],
#  ['why', 'i', 'like', 'clojure'],
#  ['cybersecurity',
#   'pro',
#   'name',
#   'their',
#   'price',
#   'a',
#   'hacker',
#   'attack',
#   'swell'],
#  ['gcp',
#   'to',
#   'introduce',
#   'an',
#   'additional',
#   'charge',
#   'for',
#   'publicly',
#   'addressed',
#   'vm',
#   'instance'],
#  ['youtube',
#   'shuts',
#   'down',
#   'music',
#   'companies’',
#   'use',
#   'of',
#   'manual',
#   'copyright',
#   'claim'],
#  ['poetry', 'dependency', 'management', 'for', 'python'],
#  ['protocol',
#   'not',
#   'platform',
#   'a',
#   'technological',
#   'approach',
#   'to',
#   'free',
#   'speech'],
#  ['artichoke', '–', 'a', 'ruby', 'made', 'with', 'rust'],
#  ['apollo',
#   'guidance',
#   'computer',
#   'switching',
#   'power',
#   'supply',
#   'work',
#   'after',
#   '50',
#   'year'],
#  ['monad', 'a', 'a', 'programming', 'pattern'],
#  ['denial',
#   'of',
#   'h1b',
#   'visa',
#   'to',
#   'india’s',
#   'largest',
#   'it',
#   'service',
#   'exporter',
#   'at',
#   'alltime',
#   'high'],
#  ['show', 'hn', 'zeroconfig', 'documentation', 'website', 'for', 'python'],
#  ['show',
#   'hn',
#   'we',
#   'track',
#   'reddit',
#   'google',
#   'trend',
#   'twitter',
#   'etc',
#   'to',
#   'find',
#   'trending',
#   'topic'],
#  ['advice',
#   'to',
#   'my',
#   'younger',
#   'self',
#   'become',
#   'allergic',
#   'to',
#   'the',
#   'churn'],
#  ['show',
#   'hn',
#   'sourcery',
#   '–',
#   'get',
#   'a',
#   'free',
#   'selfupdating',
#   'website'],
#  ['show',
#   'hn',
#   'lunch',
#   'money',
#   'a',
#   'personal',
#   'budgeting',
#   'tool',
#   'with',
#   'multicurrency',
#   'support'],
#  ['new', 'life', 'found', 'that', 'life', 'off', 'electricity', '2016'],
#  ['cerebras',
#   'system',
#   'unveils',
#   'a',
#   '12t',
#   'transistor',
#   'chip',
#   'for',
#   'ai'],
#  ['software',
#   'architect',
#   'should',
#   'be',
#   'involved',
#   'in',
#   'earliest',
#   'system',
#   'engineering',
#   'activity'],
#  ['using', 'typescript', 'with', 'react'],
#  ['bmw', 'unveils', 'car', 'sprayed', 'with', 'vantablack'],
#  ['we',
#   'shouldn’t',
#   'take',
#   'peer',
#   'review',
#   'a',
#   'the',
#   '‘gold',
#   'standard’'],
#  ['launch',
#   'hn',
#   'sanntek',
#   'yc',
#   's19',
#   '–',
#   'breathalyzer',
#   'for',
#   'cannabis'],
#  ['the', 'myth', 'of', 'consumergrade', 'security'],
#  ['nvidia',
#   'ceo',
#   'say',
#   'google',
#   'is',
#   'the',
#   'only',
#   'customer',
#   'building',
#   'it',
#   'own',
#   'silicon',
#   'at',
#   'scale'],
#  ['racket', 'lisp', 'for', 'learning'],
#  ['ask', 'hn', 'how', 'to', 'be', 'le', 'argumentative', 'online'],
#  ['insurance',
#   'company',
#   'are',
#   'paying',
#   'cop',
#   'to',
#   'investigate',
#   'their',
#   'own',
#   'customer'],
#  ['stand', 'out', 'a', 'a', 'speaker'],
#  ['creeping', 'normality'],
#  ['nasa',
#   'said',
#   'to',
#   'be',
#   'investigating',
#   'first',
#   'allegation',
#   'of',
#   'a',
#   'crime',
#   'in',
#   'space'],
#  ['germany',
#   'for',
#   'first',
#   'time',
#   'sell',
#   '30year',
#   'bond',
#   'offering',
#   'negative',
#   'yield'],
#  ['america’s',
#   'elderly',
#   'seem',
#   'more',
#   'screenobsessed',
#   'than',
#   'the',
#   'young'],
#  ['alarming', 'surge', 'in', 'drugresistant', 'hiv', 'uncovered'],
#  ['levenshtein', 'distance'],
#  ['punpedia', '–', 'the', 'online', 'encyclopedia', 'of', 'pun'],
#  ['legitlooking',
#   'iphone',
#   'lightning',
#   'cable',
#   'will',
#   'hijack',
#   'your',
#   'computer'],
#  ['open', 'startup', 'list'],
#  ['the',
#   'first',
#   'solar',
#   'road',
#   'ha',
#   'turned',
#   'out',
#   'to',
#   'be',
#   'a',
#   'disappointing',
#   'failure'],
#  ['facial',
#   'recognition',
#   'school',
#   'id',
#   'check',
#   'lead',
#   'to',
#   'gdpr',
#   'fine'],
#  ['twitter', 'confesses', 'to', 'more', 'adtech', 'leak'],
#  ['what',
#   'ha',
#   'to',
#   'happen',
#   'with',
#   'unix',
#   'virtual',
#   'memory',
#   'when',
#   'you',
#   'have',
#   'no',
#   'swap',
#   'space'],
#  ['elon', 'musk', 'gambled', 'tesla', 'to', 'save', 'solarcity'],
#  ['how',
#   'the',
#   'new',
#   'opensource',
#   'typeface',
#   'used',
#   'by',
#   'github',
#   'and',
#   'mozilla',
#   'came',
#   'to',
#   'be'],
#  ['splunk',
#   'acquires',
#   'cloud',
#   'monitoring',
#   'service',
#   'signalfx',
#   'for',
#   '105b'],
#  ['swap', 'swap', 'swap', 'and', 'bad', 'place', 'to', 'work'],
#  ['interview', 'with', 'programming', 'language', 'creator', '2010', 'pdf'],
#  ['activision',
#   'blizzard',
#   'ha',
#   'moved',
#   'billion',
#   'of',
#   'dollar',
#   'of',
#   'profit',
#   'into',
#   'tax',
#   'haven'],
#  ['how', 'to', 'make', 'billion', 'of', 'dollar', 'reducing', 'loneliness'],
#  ['seashell',
#   '–',
#   'pipe',
#   'output',
#   'from',
#   'commandline',
#   'program',
#   'to',
#   'the',
#   'web',
#   'in',
#   'real',
#   'time'],
#  ['wework', 'ipo', 'show', 'it', 'the', 'most', 'magical', 'unicorn'],
#  ['experimental',
#   'usaf',
#   'space',
#   'plane',
#   'break',
#   'record',
#   'for',
#   'orbital',
#   'spaceflight'],
#  ['what', 'i', 'do', 'a', 'a', 'devops', 'consultant'],
#  ['making', 'container', 'safer'],
#  ['the', 'erlang', 'rationale'],
#  ['apple',
#   'suspends',
#   'siri',
#   'response',
#   'grading',
#   'in',
#   'response',
#   'to',
#   'privacy',
#   'concern'],
#  ['the', 'tragedy', 'of', 'ucs2'],
#  ['crispr',
#   'pioneer',
#   'among',
#   'university',
#   'of',
#   'california',
#   'researcher',
#   'boycotting',
#   'elsevier'],
#  ['‘no',
#   'one',
#   'saw',
#   'a',
#   'thing’',
#   'when',
#   'a',
#   'midwest',
#   'town',
#   'banded',
#   'together',
#   'to',
#   'kill',
#   'the',
#   'town',
#   'bully'],
#  ['what', 'make', 'a', 'good', 'conversation'],
#  ['ruffle',
#   '–',
#   'an',
#   'adobe',
#   'flash',
#   'player',
#   'written',
#   'in',
#   'rust',
#   'compiled',
#   'to',
#   'webassembly'],
#  ['hedonometer'],
#  ['github',
#   'support',
#   'web',
#   'authentication',
#   'webauthn',
#   'for',
#   'security',
#   'key'],
#  ['twelve',
#   'latex',
#   'package',
#   'to',
#   'get',
#   'your',
#   'paper',
#   'accepted',
#   '2017'],
#  ['a', 'manager’s', 'guide', 'to', 'kubernetes', 'adoption'],
#  ['typed', 'property', 'in', 'php', '74'],
#  ['a', 'readable', 'specification', 'of', 'tl', '13'],
#  ['who', 'owns', 'your', 'wireless', 'service', 'crook', 'do'],
#  ['fed',
#   'ordered',
#   'google',
#   'location',
#   'dragnet',
#   'to',
#   'solve',
#   'wisconsin',
#   'bank',
#   'robbery'],
#  ['thing', 'to', 'know', 'about', 'gnu', 'readline'],
#  ['mortgage', 'market', 'reopens', 'to', 'risky', 'borrower'],
#  ['recognizing',
#   'the',
#   'sign',
#   'of',
#   'disruption',
#   'in',
#   'our',
#   'urban',
#   'habitat'],
#  ['acute',
#   'effect',
#   'of',
#   'electronic',
#   'cigarette',
#   'aerosol',
#   'inhalation',
#   'on',
#   'vascular',
#   'function'],
#  ['noaa',
#   'data',
#   'confirms',
#   'july',
#   'wa',
#   'hottest',
#   'month',
#   'ever',
#   'recorded'],
#  ['javascript', 'the', 'modern', 'part'],
#  ['google',
#   'warns',
#   'developer',
#   'that',
#   'all',
#   'new',
#   'android',
#   'apps',
#   'require',
#   '3',
#   'day',
#   'for',
#   'approval'],
#  ['rust', 'gui', 'ecosystem', 'overview'],
#  ['how', 'doe', 'esperanto', 'sound'],
#  ['how',
#   'command',
#   'and',
#   'conquer',
#   'tiberian',
#   'sun',
#   'punished',
#   'the',
#   'computer',
#   'of',
#   'the',
#   'day',
#   'video'],
#  ['what’s',
#   'the',
#   'difference',
#   'between',
#   'statistic',
#   'and',
#   'machine',
#   'learning'],
#  ['dropbox',
#   'no',
#   'longer',
#   'follows',
#   'symlinks',
#   'to',
#   'item',
#   'outside',
#   'of',
#   'your',
#   'dropbox',
#   'account'],
#  ['climate',
#   'change',
#   'made',
#   'european',
#   'heatwave',
#   'up',
#   'to',
#   '3°c',
#   'hotter'],
#  ['unison', 'file', 'synchronizer'],
#  ['michael', 'cicconetti'],
#  ['opengpt2', 'we', 'replicated', 'gpt2', 'because', 'you', 'can', 'too'],
#  ['practical', 'tip', 'for', 'facelifting', 'a', 'tech', 'resume'],
#  ['natural', 'language', 'processing', 'the', 'age', 'of', 'transformer'],
#  ['the', 'portuguese', 'bank', 'note', 'crisis', 'of', '1925'],
#  ['california',
#   'farmer',
#   'are',
#   'planting',
#   'solar',
#   'panel',
#   'a',
#   'water',
#   'supply',
#   'dry',
#   'up'],
#  ['youtube',
#   'said',
#   'to',
#   'be',
#   'fined',
#   'up',
#   'to',
#   '200m',
#   'for',
#   'children’s',
#   'privacy',
#   'violation'],
#  ['microsoft', 'is', 'killing', 'epub', 'support', 'in', 'edge', 'classic'],
#  ['ask', 'hn', 'configuration', 'management', 'for', 'personal', 'computer'],
#  ['intel',
#   'and',
#   'rust',
#   'the',
#   'future',
#   'of',
#   'system',
#   'programming',
#   'video'],
#  ['from', '30', 'to', '230', 'docker', 'container', 'per', 'host'],
#  ['wireless',
#   'carrier',
#   'throttling',
#   'of',
#   'online',
#   'video',
#   'is',
#   'pervasive',
#   'study'],
#  ['how',
#   'do',
#   'black',
#   'hole',
#   'destroy',
#   'information',
#   'and',
#   'why',
#   'is',
#   'that',
#   'a',
#   'problem'],
#  ['waypipe', 'gsoc', 'project', 'complete'],
#  ['launch',
#   'hn',
#   'quirk',
#   'yc',
#   's19',
#   '–',
#   'opensource',
#   'cognitive',
#   'behavioral',
#   'therapy'],
#  ['boeings', 'crash', 'expose', 'systemic', 'failing'],
#  ['goldman',
#   'sachs',
#   'is',
#   'spending',
#   '100m',
#   'to',
#   'shave',
#   'millisecond',
#   'off',
#   'stock',
#   'trade'],
#  ['bad',
#   'time',
#   'in',
#   'tech',
#   'not',
#   'if',
#   'you’re',
#   'a',
#   'startup',
#   'serving',
#   'other',
#   'startup'],
#  ['why',
#   'did',
#   'turbo',
#   'pascal',
#   'apps',
#   'fail',
#   'with',
#   'a',
#   'divisionbyzero',
#   'on',
#   'faster',
#   'system'],
#  ['show',
#   'hn',
#   'storytime',
#   '–',
#   'create',
#   'story',
#   'about',
#   'your',
#   'code',
#   'instead',
#   'of',
#   'documentation'],
#  ['one',
#   'of',
#   'the',
#   'greatest',
#   'science',
#   'fiction',
#   'magazine',
#   'is',
#   'now',
#   'available',
#   'online',
#   '2017'],
#  ['nixery',
#   'transparently',
#   'build',
#   'and',
#   'serve',
#   'container',
#   'using',
#   'nix'],
#  ['most',
#   'internet',
#   'service',
#   'provider',
#   'are',
#   'gone',
#   '–',
#   'sonic',
#   'ha',
#   'survived',
#   'and',
#   'thrived'],
#  ['where', 'do', 'interrupt', 'happen'],
#  ['ondisk',
#   'format',
#   'robustness',
#   'requirement',
#   'for',
#   'new',
#   'filesystems'],
#  ['giving', 'up', 'on', 'julia', '2016'],
#  ['the', 'ethic', 'of', 'web', 'performance'],
#  ['keeping', 'tesla', 'roadster', 'alive', 'is', 'serious', 'work'],
#  ['oracle',
#   'director',
#   'give',
#   'blessing',
#   'to',
#   'shareholder',
#   'lawsuit',
#   'against',
#   'larry',
#   'ellison'],
#  ['lf', 'fully', 'decentralized', 'fully', 'replicated', 'keyvalue', 'store'],
#  ['a', 'quarter', 'of', 'humanity', 'face', 'looming', 'water', 'crisis'],
#  ['pacvim',
#   '–',
#   'pacvim',
#   'is',
#   'a',
#   'game',
#   'that',
#   'teach',
#   'you',
#   'vim',
#   'command'],
#  ['why', 'doe', 'infrastructure', 'cost', 'so', 'much'],
#  ['law', 'of', 'showrunning', '2016', 'pdf'],
#  ['possible',
#   'detection',
#   'of',
#   'a',
#   'black',
#   'hole',
#   'with',
#   'a',
#   'mass',
#   'that',
#   'wa',
#   'thought',
#   'to',
#   'be',
#   'impossible'],
#  ['launch',
#   'hn',
#   'dex',
#   'yc',
#   's19',
#   '–',
#   'personal',
#   'crm',
#   'that',
#   'reminds',
#   'you',
#   'to',
#   'keep',
#   'in',
#   'touch'],
#  ['a', 'buddhist', 'monk', 'confronts', 'japan', 'suicide', 'culture', '2013'],
#  ['the', 'flawed', 'threecueing', 'system', 'for', 'teaching', 'reading'],
#  ['home', '3d', 'metal', 'printing', 'first', 'result'],
#  ['são', 'paulo’s', 'outdoor', 'advertising', 'ban', '2016'],
#  ['google',
#   'forcing',
#   'nest',
#   'cameras’',
#   'visual',
#   'indicator',
#   'light',
#   'to',
#   'be',
#   'on'],
#  ['the', 'flawed', 'reasoning', 'behind', 'the', 'replication', 'crisis'],
#  ['sugar', 'opensource', 'software', 'learning', 'platform', 'for', 'child'],
#  ['open',
#   'location',
#   'code',
#   'an',
#   'open',
#   'source',
#   'standard',
#   'for',
#   'address'],
#  ['it',
#   'crazy',
#   'chase',
#   'forgiving',
#   'all',
#   'debt',
#   'owed',
#   'by',
#   'it',
#   'canada',
#   'credit',
#   'card',
#   'customer'],
#  ['computer', 'science', 'illustrated', '2014'],
#  ['parsing', 'json', 'is', 'a', 'minefield', '2018'],
#  ['i', 'found', 'an', 'easter', 'egg', 'from', '1977'],
#  ['the', 'interviewer', 'skill', 'ladder', 'for', 'high', 'growth', 'company'],
#  ['show',
#   'hn',
#   'tailwindrun',
#   '–',
#   'an',
#   'online',
#   'playground',
#   'for',
#   'tailwind',
#   'cs'],
#  ['what',
#   'to',
#   'do',
#   'once',
#   'you',
#   'admit',
#   'that',
#   'decentralization',
#   'never',
#   'seems',
#   'to',
#   'work',
#   '2018'],
#  ['hundred',
#   'of',
#   'exposed',
#   'amazon',
#   'cloud',
#   'backup',
#   'found',
#   'leaking',
#   'sensitive',
#   'data'],
#  ['removing',
#   'one',
#   'maine',
#   'dam',
#   '20',
#   'year',
#   'ago',
#   'changed',
#   'everything'],
#  ['nonplanar', 'printing'],
#  ['why', 'didnt', 'the', 'roman', 'contribute', 'much', 'to', 'mathematics'],
#  ['bulk', 'data', 'structure', 'c'],
#  ['exploring', 'weight', 'agnostic', 'neural', 'network'],
#  ['have', 'you', 'ever', 'tried', 'to', 'sell', 'a', 'diamond', '1982'],
#  ['big',
#   'o',
#   'notation',
#   '–',
#   'using',
#   'notboring',
#   'math',
#   'to',
#   'measure',
#   'code’s',
#   'efficiency'],
#  ['cisco',
#   'is',
#   'making',
#   'it',
#   'more',
#   'difficult',
#   'to',
#   'use',
#   'used',
#   'hardware'],
#  ['how',
#   'shrinkflation',
#   'is',
#   'playing',
#   'havoc',
#   'with',
#   'economists’',
#   'model'],
#  ['rotten', 'apple', 'right', 'to', 'repair', 'roundup'],
#  ['tumblr'],
#  ['doordash', 'buying', 'caviar', 'from', 'square', 'for', '410m'],
#  ['daniel',
#   'radcliffe',
#   'and',
#   'the',
#   'art',
#   'of',
#   'the',
#   'factcheck',
#   '2018'],
#  ['svalbard',
#   'is',
#   'a',
#   'close',
#   'a',
#   'you',
#   'can',
#   'get',
#   'to',
#   'a',
#   'place',
#   'with',
#   'open',
#   'border'],
#  ['dyson', 'tree'],
#  ['how',
#   'i',
#   'finally',
#   'won',
#   'my',
#   'name',
#   'from',
#   'domain',
#   'resellers',
#   'after',
#   'nine',
#   'year',
#   'of',
#   'waiting'],
#  ['fbi',
#   'tell',
#   'lawmaker',
#   'it',
#   'cant',
#   'access',
#   'dayton',
#   'gunman',
#   'phone'],
#  ['child',
#   'of',
#   'a',
#   'thailand',
#   'tribe',
#   'who',
#   'see',
#   'with',
#   'clarity',
#   'beneath',
#   'the',
#   'wave',
#   '2016'],
#  ['franky',
#   'zapata',
#   'flyboarding',
#   'frenchman',
#   'cross',
#   'english',
#   'channel'],
#  ['dignity'],
#  ['teen',
#   'hacker',
#   'find',
#   'bug',
#   'in',
#   'school',
#   'software',
#   'that',
#   'exposed',
#   'million',
#   'of',
#   'record'],
#  ['a', 'pissedoff', 'tutorial', 'for', 'google', 'wave', '2010', 'video'],
#  ['i', 'took', 'a', 'pay', 'cut', 'for', 'a', 'more', 'meaningful', 'job'],
#  ['ibm', 'stop', 'buyback', 'to', 'pay', 'for', 'red', 'hat'],
#  ['parallelism', 'in', 'postgresql'],
#  ['tech', 'backlash', 'ha', 'come', 'to', 'stanford'],
#  ['google’s',
#   'rival',
#   'opt',
#   'out',
#   'of',
#   'search',
#   'engine',
#   'auction',
#   'calling',
#   'it',
#   '‘anticompetitive’'],
#  ['peloton', 's1'],
#  ['why', 'a', 'mock', 'doesn’t', 'work'],
#  ['pattern',
#   'on',
#   'good',
#   'designed',
#   'to',
#   'trigger',
#   'automated',
#   'license',
#   'plate',
#   'reader'],
#  ['show', 'hn', 'texnique', '–', 'a', 'latex', 'typesetting', 'game'],
#  ['upmem',
#   'put',
#   'cpu',
#   'inside',
#   'memory',
#   'to',
#   'allow',
#   'application',
#   'to',
#   'run',
#   '20',
#   'time',
#   'faster'],
#  ['more', 'fire', 'now', 'burning', 'in', 'angola', 'congo', 'than', 'amazon'],
#  ['telegram',
#   'introduces',
#   'feature',
#   'to',
#   'prevent',
#   'user',
#   'from',
#   'texting',
#   'too',
#   'often',
#   'in',
#   'a',
#   'group'],
#  ['somehow', 'i', 'became', 'respectable'],
#  ['how', 'to', 'become', 'a', 'great', 'impostor'],
#  ['seattle',
#   'microtransit',
#   'experiment',
#   'drive',
#   'people',
#   'to',
#   'light',
#   'rail'],
#  ['basic', 'electron', 'framework', 'exploitation'],
#  ['helsinki',
#   'central',
#   'library',
#   'chosen',
#   'a',
#   'the',
#   'best',
#   'new',
#   'public',
#   'library'],
#  ['spacex', 'smallsat', 'rideshare', 'program'],
#  ['personal', 'website', 'for', 'programmer'],
#  ['startup', 'from', 'y', 'combinator’s', 's19', 'demo', 'day', '1'],
#  ['highlight', 'from', 'git', '223'],
#  ['show',
#   'hn',
#   'youtube',
#   'decade',
#   '–',
#   'the',
#   'mostviewed',
#   'video',
#   'posted',
#   '10',
#   'year',
#   'ago'],
#  ['standard', 'j', 'npm', 'install', 'funding'],
#  ['mapped', 'the', 'world’s', 'coal', 'power', 'plant'],
#  ['kept', 'alive', 'with', 'tube', 'for', 'nearly', '17', 'year'],
#  ['lesson', 'we', 'learned', 'when', 'debugging', 'a', 'scaling', 'problem'],
#  ['p', 'idea', 'faq'],
#  ['show',
#   'hn',
#   'scarf',
#   '–',
#   'platform',
#   'to',
#   'help',
#   'opensource',
#   'developer',
#   'monetize',
#   'their',
#   'work'],
#  ['old', 'paris', 'is', 'no', 'more'],
#  ['spacebook', 'agis', 'near', 'realtime', 'satellite', 'viewer'],
#  ['the', 'path', 'to', 'dijkstra’s', 'handwriting', '2013'],
#  ['ted', 'chiang', 'realist', 'of', 'a', 'larger', 'reality'],
#  ['escape', 'room', 'are', 'big', 'business'],
#  ['alcohol', 'belt', 'of', 'europe'],
#  ['dependent', 'haskell', 'is', 'the', 'future', '2018'],
#  ['north', 'american', 'versus', 'european', 'distribution', 'system', '2011'],
#  ['social',
#   'share',
#   'button',
#   'that',
#   'dont',
#   'allow',
#   'the',
#   'social',
#   'site',
#   'to',
#   'track',
#   'your',
#   'user'],
#  ['nutrient',
#   'deficiency',
#   'in',
#   'rice',
#   'grown',
#   'under',
#   'higher',
#   'carbon',
#   'dioxide'],
#  ['the',
#   'body',
#   'is',
#   'the',
#   'missing',
#   'link',
#   'for',
#   'truly',
#   'intelligent',
#   'machine',
#   '2017'],
#  ['electric', 'motor', 'design', 'claim', 'remarkable', 'improvement'],
#  ['living', 'off', 'the', 'land', 'in', 'linux'],
#  ['no', 'son', 'of', 'mine', 'is', 'going', 'to', 'be', 'a', 'benthamite'],
#  ['extended', 'validation', 'certificate', 'are', 'really', 'dead'],
#  ['the',
#   'mobility',
#   'trap',
#   'why',
#   'well',
#   'never',
#   'fix',
#   'congestion',
#   'by',
#   'speeding',
#   'up',
#   'traffic'],
#  ['static', 'type', 'checking', 'in', 'common', 'lisp'],
#  ['interslavic', 'language'],
#  ['startup', 'from', 'y', 'combinator’s', 's19', 'demo', 'day', '2'],
#  ['announcing', 'notqmail'],
#  ['why', 'the', 'french', 'love', 'to', 'say', 'no'],
#  ['theory', 'of', 'error', 'backpropagation', 'in', 'the', 'brain'],
#  ['black',
#   'beekeeper',
#   'are',
#   'transforming',
#   'detroit’s',
#   'vacant',
#   'lot',
#   'into',
#   'bee',
#   'farm',
#   '2018'],
#  ['gpt2', '6month', 'followup'],
#  ['crossword', 'panic', 'of', '1944'],
#  ['libspng',
#   '–',
#   'c',
#   'library',
#   'for',
#   'reading',
#   'and',
#   'writing',
#   'png',
#   'file'],
#  ['kegans', 'theory', 'of', 'the', 'evolution', 'of', 'consciousness'],
#  ['hospital',
#   'checklist',
#   'are',
#   'meant',
#   'to',
#   'save',
#   'life',
#   'so',
#   'why',
#   'do',
#   'they',
#   'often',
#   'fail'],
#  ['understanding',
#   'sat',
#   'by',
#   'implementing',
#   'a',
#   'simple',
#   'sat',
#   'solver',
#   'in',
#   'python',
#   '2014'],
#  ['a', 'deep', 'dive', 'into', 'linux', 'namespaces', 'part', '4'],
#  ['chemist', 'make', 'firstever', 'ring', 'of', 'pure', 'carbon'],
#  ['datacenter', 'location', 'driven', 'by', '19th', 'century', 'politics'],
#  ['uber', 'is', 'biggest', 'loser', 'a', 'softbank', 'count', 'ipo', 'return'],
#  ['using', 'bacteria', 'to', 'make', 'selfhealing', 'cement'],
# ...
#   'in',
#   'sunken',
#   'egyptian',
#   'city'],
#  ['free', 'and', 'opensource', 'tool', 'for', 'analog', 'filmmaking'],
#  ['api',
#   'gateway',
#   'identity',
#   'crisis',
#   '–',
#   'are',
#   'they',
#   'replaced',
#   'by',
#   'service',
#   'mesh'],
#  ['i',
#   'started',
#   'an',
#   'online',
#   'subscription',
#   'business',
#   'from',
#   'malaysia'],
#  ['lifehacker', 'tarek', 'loubani', 'on', '3dprinting', 'in', 'gaza'],
#  ['our', 'brain', 'tell', 'story', 'so', 'we', 'can', 'live', '2013'],
#  ['capturing',
#   'pal',
#   'video',
#   'with',
#   'an',
#   'sdr',
#   'and',
#   'a',
#   'few',
#   'dead',
#   'end'],
#  ['solving',
#   'differential',
#   'equation',
#   'on',
#   'a',
#   '6502',
#   'with',
#   'wozs',
#   'floating',
#   'point',
#   'code'],
#  ['computer', 'stupidity', '2013'],
#  ['a', 'look', 'back', 'the', 'bloomberg', 'keyboard', '2017'],
#  ['jupiter', 'riscv', 'assembler', 'and', 'runtime', 'simulator'],
#  ['42',
#   'hour',
#   'of',
#   'buckminster',
#   'fuller',
#   'might',
#   'be',
#   'just',
#   'the',
#   'vision',
#   'we',
#   'need'],
#  ['project',
#   'mu',
#   '–',
#   'a',
#   'modular',
#   'uefi',
#   'environment',
#   'for',
#   'building',
#   'modern',
#   'device'],
#  ['the', 'high', 'price', 'of', 'multitasking'],
#  ['curve', 'fitting', 'a', 'linear', 'least', 'square'],
#  ['handler',
#   'belief',
#   'affect',
#   'scent',
#   'detection',
#   'dog',
#   'outcome',
#   '2011'],
#  ['sipeed', 'longan', 'nano', '–', 'riscv', 'development', 'board'],
#  ['the',
#   'difference',
#   'between',
#   'isolation',
#   'level',
#   'and',
#   'consistency',
#   'level'],
#  ['detailed', '3d', 'map', 'of', 'milky', 'way', 'show', 'warped', 'shape'],
#  ['map',
#   'design',
#   '–',
#   'a',
#   'guide',
#   'to',
#   'good',
#   'looking',
#   'map',
#   '2008',
#   'pdf'],
#  ['no', 'silver', 'bullet', '1986', 'pdf'],
#  ['armoured', 'commander', 'the', 'wwii', 'tank', 'commander', 'roguelike'],
#  ['how', 'the', 'brain', 'approximates', 'without', 'counting'],
#  ['softbank',
#   'plan',
#   'to',
#   'lend',
#   '20b',
#   'to',
#   'it',
#   'ceo',
#   'and',
#   'employee',
#   'amid',
#   'volatile',
#   'market'],
#  ['the',
#   'hp',
#   'way',
#   'how',
#   'bill',
#   'hewlett',
#   'and',
#   'i',
#   'built',
#   'our',
#   'company',
#   '1960'],
#  ['how', 'to', 'build', 'a', 'pyramid'],
#  ['how',
#   'to',
#   'get',
#   'consistent',
#   'result',
#   'when',
#   'benchmarking',
#   'on',
#   'linux'],
#  ['how',
#   'to',
#   'teach',
#   'an',
#   'iris',
#   'scanner',
#   'that',
#   'the',
#   'eye',
#   'it’s',
#   'looking',
#   'at',
#   'is',
#   'dead'],
#  ['building', 'a', 'vacuum', 'tube', 'computer'],
#  ['portugal’s', 'marmelada', 'taste', 'nothing', 'like', 'marmalade', '2018'],
#  ['spacy', 'pytorch', 'transformer'],
#  ['real',
#   'world',
#   'location',
#   'virtually',
#   'recreated',
#   'to',
#   'scale',
#   'in',
#   'minute',
#   'video'],
#  ['show',
#   'hn',
#   'datkeyserver',
#   'a',
#   'distributed',
#   'pgp',
#   'keyserver',
#   'based',
#   'on',
#   'the',
#   'dat',
#   'protocol'],
#  ['karel', 'čapeks', 'play', 'rur', 'premiered', 'in', 'january', '1921'],
#  ['apple',
#   'card',
#   'restriction',
#   'include',
#   'no',
#   'jailbreaking',
#   'or',
#   'cryptocurrency',
#   'purchase'],
#  ['the', 'grand', 'c', 'error', 'explosion', 'competition'],
#  ['turkmenistan', 'on', 'the', 'brink', 'of', 'collapse'],
#  ['a', 'profile', 'of', 'geoffrey', 'hinton', '2018'],
#  ['scientist',
#   'reverse',
#   'aging',
#   'process',
#   'in',
#   'rat',
#   'brain',
#   'stem',
#   'cell'],
#  ['show',
#   'hn',
#   'cordless',
#   'a',
#   'discord',
#   'terminal',
#   'client',
#   'written',
#   'in',
#   'go'],
#  ['100',
#   'year',
#   'ago',
#   'a',
#   'telephone',
#   'tower',
#   'in',
#   'stockholm',
#   'connected',
#   '5000',
#   'phone',
#   'line',
#   '2014'],
#  ['japanese',
#   'architect',
#   'who',
#   'treated',
#   'building',
#   'like',
#   'living',
#   'organism'],
#  ['a', 'recent', 'paper', 'proposes', 'to', 'bring', 'zeppelin', 'back'],
#  ['jcore', 'open', 'processor'],
#  ['presidio',
#   'customizable',
#   'data',
#   'protection',
#   'and',
#   'pii',
#   'data',
#   'anonymization',
#   'service'],
#  ['the', 'survival', 'of', 'iggy', 'pop'],
#  ['bpf', 'portbased', 'firewall', 'for', 'systemd', 'service'],
#  ['marree', 'man'],
#  ['the', 'dday', 'rehearsal', 'that', 'cost', '800', 'life', '2014'],
#  ['ray', 'tracing', 'with', 'ulisp'],
#  ['show', 'hn', 'a', 'few', 'simple', 'game', 'not', 'only', 'for', 'kid'],
#  ['why', 'everyone', 'hate', 'customer', 'service'],
#  ['commodore', '900'],
#  ['qualpwn',
#   '–',
#   'exploiting',
#   'qualcomm',
#   'wlan',
#   'and',
#   'modem',
#   'over',
#   'the',
#   'air'],
#  ['study',
#   'identifies',
#   'main',
#   'culprit',
#   'behind',
#   'lithium',
#   'metal',
#   'battery',
#   'failure'],
#  ['with', 'friend', 'like', 'these'],
#  ['youtube’s', 'lgbtq', 'problem', 'is', 'a', 'businessmodel', 'problem'],
#  ['suburb',
#   'in',
#   'the',
#   'sky',
#   'how',
#   'jakartans',
#   'built',
#   'an',
#   'entire',
#   'village',
#   'on',
#   'top',
#   'of',
#   'a',
#   'mall'],
#  ['circulating',
#   'in',
#   'china’s',
#   'financial',
#   'system',
#   'more',
#   'than',
#   '200b',
#   'in',
#   'iou'],
#  ['the',
#   'death',
#   'of',
#   'alexander',
#   'the',
#   'great',
#   'one',
#   'of',
#   'history',
#   'great',
#   'unsolved',
#   'mystery'],
#  ['the', 'microworkers', 'making', 'digital', 'life', 'possible'],
#  ['keyringless', 'gnupg'],
#  ['the', 'perfect', 'french', 'baguette'],
#  ['shipping', 'wind', 'turbine', 'is', 'not', 'a', 'breeze'],
#  ['iron',
#   'age',
#   'celtic',
#   'woman',
#   'wa',
#   'buried',
#   'in',
#   'a',
#   'hollowedout',
#   'tree',
#   'trunk'],
#  ['the', 'biggest', 'mistake', 'firsttime', 'founder', 'make', 'video'],
#  ['boeing', 'changing', 'max', 'software', 'to', 'use', 'two', 'computer'],
#  ['empty',
#   'train',
#   'on',
#   'the',
#   'modern',
#   'silk',
#   'road',
#   'when',
#   'belt',
#   'and',
#   'road',
#   'interest',
#   'don’t',
#   'align'],
#  ['wavelet', '1994', 'pdf'],
#  ['who', 'did', 'the', 'maya', 'sacrifice'],
#  ['a', 'guide', 'to', 'magnetorquers', 'for', 'satellite'],
#  ['mobile', 'nixos', 'the', 'present', 'and', 'the', 'future'],
#  ['nec', 'show', '‘flying', 'car’', 'hovering', 'steadily', 'for', 'minute'],
#  ['quantum',
#   'radar',
#   'ha',
#   'been',
#   'demonstrated',
#   'for',
#   'the',
#   'first',
#   'time'],
#  ['ear', 'speaker', '–', 'research', 'design', 'and', 'evolution'],
#  ['wasm', 'v', 'pnacl', 'performance', 'benchmark'],
#  ['evolving', 'lindenmayer', 'system'],
#  ['show',
#   'hn',
#   'repository',
#   'of',
#   'open',
#   'source',
#   'spacerelated',
#   'software',
#   'and',
#   'hardware'],
#  ['i', 'love', 'my', 'paper', 'dictionary', '2017'],
#  ['darpa',
#   'want',
#   'help',
#   'cracking',
#   'the',
#   'election',
#   'security',
#   'problem'],
#  ['the',
#   'fed',
#   'is',
#   'getting',
#   'into',
#   'the',
#   'realtime',
#   'payment',
#   'business'],
#  ['woman',
#   'find',
#   'yellow',
#   'diamond',
#   'while',
#   'watching',
#   'youtube',
#   'video',
#   'on',
#   'how',
#   'to',
#   'find',
#   'diamond'],
#  ['amazon', 'will', 'pull', 'the', 'plug', 'on', 'dash', 'button'],
#  ['problem', 'solving', 'and', 'clojure', '19', '2018'],
#  ['a',
#   'new',
#   'book',
#   'asserts',
#   'that',
#   'rich',
#   'country',
#   'grow',
#   'with',
#   'lighter',
#   'environmental',
#   'impact'],
#  ['animal',
#   'movie',
#   'promote',
#   'awareness',
#   'not',
#   'harm',
#   'say',
#   'researcher'],
#  ['2019', 'hyundai', 'kona', 'ev', 'explodes', 'when', 'parked'],
#  ['the',
#   'league',
#   'of',
#   'entropy',
#   'is',
#   'making',
#   'randomness',
#   'truly',
#   'random'],
#  ['a',
#   'transparent',
#   'display',
#   'with',
#   'perpixel',
#   'color',
#   'and',
#   'opacity',
#   'control'],
#  ['the',
#   '“terrascope”',
#   'on',
#   'the',
#   'possibility',
#   'of',
#   'using',
#   'the',
#   'earth',
#   'a',
#   'an',
#   'atmospheric',
#   'lens'],
#  ['human', 'dominated', 'earth', 'earlier', 'than', 'previously', 'thought'],
#  ['fuzzification', 'antifuzzing', 'technique', 'pdf'],
#  ['what',
#   'is',
#   'zoned',
#   'storage',
#   'and',
#   'the',
#   'zoned',
#   'storage',
#   'initiative'],
#  ['webmin', '1890', 'exploit', '–', 'what', 'happened'],
#  ['scaling', 'static', 'analysis', 'at', 'facebook'],
#  ['the', 'death', 'of', 'a', 'weather', 'satellite', 'a', 'seen', 'by', 'sdr'],
#  ['holiday', 'are', 'good', 'for', 'worker', 'and', 'company', 'alike'],
#  ['richard', 'sorge', 'the', 'soviet', 'union’s', 'master', 'spy'],
#  ['debunking', 'the', 'stanford', 'prison', 'experiment', 'pdf'],
#  ['marium',
#   'the',
#   'dugong',
#   'who',
#   'charmed',
#   'thailand',
#   'dy',
#   'after',
#   'ingesting',
#   'plastic'],
#  ['simple',
#   'python',
#   'package',
#   'to',
#   'extract',
#   'deep',
#   'learning',
#   'feature'],
#  ['massive', '‘ocean’', 'discovered', 'towards', 'earth’s', 'core', '2014'],
#  ['def', 'con', '2019', '–', 'ctf', 'retrospective'],
#  ['kdevops',
#   'framework',
#   'for',
#   'setting',
#   'up',
#   'and',
#   'testing',
#   'the',
#   'linux',
#   'kernel',
#   'for',
#   'any',
#   'project'],
#  ['simple',
#   'pure',
#   'and',
#   'total',
#   'functional',
#   'language',
#   'that',
#   'generalizes',
#   'datalog'],
#  ['continuous',
#   '3d',
#   'printing',
#   'possible',
#   'with',
#   'transparent',
#   'polygon',
#   'scanning'],
#  ['could', 'removing', 'social', 'medium', 'metric', 'reduce', 'polarization'],
#  ['roaring',
#   'glacial',
#   'melt',
#   'under',
#   'the',
#   'bridge',
#   'to',
#   'kangerlussiauq',
#   'greenland'],
#  ['the', 'new', 'treasure', 'of', 'pompeii'],
#  ['sec',
#   'investigating',
#   'data',
#   'leak',
#   'at',
#   'first',
#   'american',
#   'financial',
#   'corp'],
#  ['the', 'openbsd', 'ada', 'library'],
#  ['dont', 'say', '“homoiconic”', '2018'],
#  ['u',
#   'air',
#   'force',
#   'pause',
#   'flight',
#   'for',
#   'over',
#   'a',
#   'hundred',
#   'c130s',
#   'over',
#   '‘atypical’',
#   'cracking'],
#  ['i', 'am', 'a', 'horse', 'in', 'the', 'land', 'of', 'booleans'],
#  ['we',
#   'may',
#   'not',
#   'be',
#   'running',
#   'out',
#   'of',
#   'helium',
#   'after',
#   'all',
#   '2015'],
#  ['launch',
#   'hn',
#   'shift',
#   'health',
#   'yc',
#   's19',
#   '–',
#   'understand',
#   'your',
#   'healthcare',
#   'cost',
#   'previsit'],
#  ['smartykit', 'apple', 'i', 'replica'],
#  ['gerbil', '–', 'a', 'metadialect', 'of', 'scheme'],
#  ['hawaii',
#   'extends',
#   'thirty',
#   'meter',
#   'telescope',
#   'permit',
#   'amid',
#   'protest'],
#  ['gm', 'is', 'now', 'detroit’s', 'smallest', 'automaking', 'employer'],
#  ['the',
#   'dipole',
#   'drive',
#   'a',
#   'new',
#   'concept',
#   'in',
#   'space',
#   'propulsion'],
#  ['universal', 'algorithm', 'set', 'to', 'boost', 'microscope'],
#  ['fearing',
#   'data',
#   'privacy',
#   'issue',
#   'google',
#   'cut',
#   'some',
#   'android',
#   'phone',
#   'data',
#   'for',
#   'carrier'],
#  ['robotic',
#   'thread',
#   'is',
#   'designed',
#   'to',
#   'slip',
#   'through',
#   'the',
#   'brain',
#   'blood',
#   'vessel'],
#  ['vickrey–clarke–groves', 'auction'],
#  ['prolog', 'control', 'in', 'six', 'slide'],
#  ['opinion', 'piece', 'on', 'ghc', 'back', 'end'],
#  ['entropic', 'a', 'federated', 'package', 'registry', 'for', 'anything'],
#  ['cbor', '–', 'concise', 'binary', 'object', 'representation'],
#  ['can', 'we', 'survive', 'technology', '1955', 'pdf'],
#  ['cassette', 'are', 'back', 'and', 'it’s', 'not', 'about', 'the', 'music'],
#  ['paul', 'dirac', 'the', 'mozart', 'of', 'science', '2008'],
#  ['in', 'praise', 'of', 'xlogo'],
#  ['show',
#   'hn',
#   'historical',
#   'order',
#   'book',
#   'reconstruction',
#   'api',
#   'for',
#   'crypto',
#   'market'],
#  ['arc', 'of', 'seniority'],
#  ['the', 'long', 'game', 'of', 'research'],
#  ['a', 'look', 'at', 'hs2', 'old', 'oak', 'common', 'station'],
#  ['how',
#   'judy',
#   'array',
#   'work',
#   'and',
#   'why',
#   'they',
#   'are',
#   'so',
#   'fast',
#   '2002'],
#  ['mining', 'bitcoin', 'on', 'an', 'apple', 'ii'],
#  ['unearthing',
#   'a',
#   'masterpiece',
#   'a',
#   'rare',
#   'minoan',
#   'sealstone',
#   '2017'],
#  ['golden', 'ratio'],
#  ['show',
#   'hn',
#   'pgcmd',
#   '–',
#   'an',
#   'alternative',
#   'to',
#   'psql',
#   'with',
#   'json',
#   'output'],
#  ['reviving', 'an', 'hp', '660lx', 'in', '2019'],
#  ['ssb', 'room', 'a', 'new', 'server', 'type', 'for', 'scuttlebutt'],
#  ['implementing', 'poincaré', 'embeddings', '2017'],
#  ['extending', 'ocaml', 'program', 'with', 'lua'],
#  ['container', 'networking', 'with', 'vxlan', 'bgp', 'and', 'wireguard'],
#  ['a', 'fine', 'map', 'from', 'alexander', 'von', 'humboldt', '1851'],
#  ['new', 'research', 'on', 'ptsd', 'in', 'elephant', 'and', 'other', 'animal'],
#  ['“awakenings”',
#   'in',
#   'advanced',
#   'dementia',
#   'patient',
#   'hint',
#   'at',
#   'untapped',
#   'brain',
#   'reserve'],
#  ['recycling',
#   'of',
#   'plastic',
#   'enabled',
#   'by',
#   'dynamic',
#   'covalent',
#   'diketoenamine',
#   'bond',
#   '2018',
#   'pdf'],
#  ['show',
#   'hn',
#   'dataviz',
#   'project',
#   'for',
#   'raytracing',
#   'the',
#   'moon',
#   'model'],
#  ['five',
#   'new',
#   'realtime',
#   'detection',
#   'of',
#   'fast',
#   'radio',
#   'burst',
#   'with',
#   'utmost'],
#  ['lucidscience', '–', 'electronic', 'project', 'and', 'tutorial'],
#  ['what',
#   'are',
#   'child',
#   'dying',
#   'from',
#   'and',
#   'what',
#   'can',
#   'we',
#   'do',
#   'about',
#   'it'],
#  ['a',
#   'conversation',
#   'with',
#   'the',
#   'team',
#   'that',
#   'made',
#   'bread',
#   'with',
#   'ancient',
#   'egyptian',
#   'yeast'],
#  ['air',
#   'force',
#   'reveals',
#   'test',
#   'of',
#   'supposed',
#   'recordsetting',
#   'scramjet',
#   'from',
#   'n',
#   'grumman'],
#  ['the', 'decline', 'of', 'college', 'newspaper'],
#  ['which', 'is', 'the', 'best', 'john', 'le', 'carré', 'novel', '2014'],
#  ['dreaming',
#   'about',
#   'better',
#   'sleep',
#   'dreem',
#   'oura',
#   'and',
#   'the',
#   'rest'],
#  ['penn', 'effect'],
#  ['hall’s',
#   'law',
#   'the',
#   'nineteenth',
#   'century',
#   'prequel',
#   'to',
#   'moore’s',
#   'law',
#   '2012'],
#  ['volcano',
#   'on',
#   'the',
#   'moon',
#   'may',
#   'have',
#   'erupted',
#   'during',
#   'the',
#   'dinosaur',
#   'age',
#   '2014'],
#  ['the', 'world’s', 'smartest', 'chimp', 'ha', 'died'],
#  ['smart',
#   'plastic',
#   'incineration',
#   'posited',
#   'a',
#   'solution',
#   'to',
#   'global',
#   'recycling',
#   'crisis'],
#  ['kei', '–', 'a', 'small', 'and', 'expressive', 'dependent', 'language'],
#  ['freshermeat', '–', 'opensource', 'security', 'software'],
#  ['engineer',
#   'build',
#   'advanced',
#   'microprocessor',
#   'out',
#   'of',
#   'carbon',
#   'nanotube'],
#  ['a',
#   'new',
#   'york',
#   'farm',
#   'stand’s',
#   'success',
#   'an',
#   'eye',
#   'for',
#   'the',
#   'next',
#   'big',
#   'thing'],
#  ['disneyland’s', 'disastrous', 'opening', 'day', '2015'],
#  ['a', 'zmachine', 'in', 'ocaml', '2016'],
#  ['quantum', 'air', 'buy', 'bye', 'electric', 'airplane'],
#  ['famous', 'graphic', 'chip', 'microsoft’s', 'talisman'],
#  ['engineer',
#   'develop',
#   'bonelike',
#   'metal',
#   'foam',
#   'that',
#   'can',
#   'be',
#   'healed',
#   'at',
#   'room',
#   'temperature'],
#  ['using',
#   'the',
#   'golden',
#   'research',
#   'engine',
#   'to',
#   'query',
#   'the',
#   'y',
#   'combinator',
#   's19',
#   'batch'],
#  ['a', 'mosque', 'rebuilt', 'once', 'a', 'year'],
#  ['flying', 'with', 'miniature', 'horse'],
#  ['the', 'oral', 'history', 'of', 'the', 'super', 'soaker'],
#  ['a', 'trailblazing', 'plan', 'to', 'fight', 'california', 'wildfire'],
#  ['show', 'hn', 'firestorm', '–', 'an', 'orm', 'for', 'firestore'],
#  ['programming', 'shape', 'using', 'kirigami', 'tessellation'],
#  ['potosí',
#   'the',
#   'mountain',
#   'of',
#   'silver',
#   'that',
#   'wa',
#   'the',
#   'first',
#   'global',
#   'city'],
#  ['an',
#   'ancient',
#   'egypttoblack',
#   'sea',
#   'route',
#   'adventurer',
#   'to',
#   'test',
#   'theory'],
#  ['exploring', 'the', 'visible', 'spectrum', 'in', 'python'],
#  ['general', 'balanced', 'tree', '1999', 'pdf'],
#  ['using',
#   'wall',
#   'street',
#   'secret',
#   'to',
#   'reduce',
#   'the',
#   'cost',
#   'of',
#   'cloud',
#   'infrastructure'],
#  ['rediscovering', 'rule', 'for', 'ancient', 'board', 'game'],
#  ['on', 'the', 'road', 'in', '1980'],
#  ['the', 'software', 'art'],
#  ['making', 'webworkers', 'async', 'iterables'],
#  ['show',
#   'hn',
#   'quarkide',
#   'and',
#   'a',
#   'javascript',
#   'runtime',
#   'to',
#   'build',
#   'crossplatform',
#   'desktop',
#   'apps'],
#  ['environment', 'and', 'the', 'programming', 'language', 'self', 'part', '4'],
#  ['the', 'lost', 'dove', 'press', 'typeface', 'and', 'it', 'revival', '2015'],
#  ['early',
#   'year',
#   'of',
#   'computer',
#   'gaming',
#   'steve',
#   'russell',
#   'and',
#   'nolan',
#   'bushnell',
#   '2002',
#   'video'],
#  ['the',
#   'quest',
#   'to',
#   'conquer',
#   'earth’s',
#   'space',
#   'junk',
#   'problem',
#   '2018'],
#  ['swadesh', 'list'],
#  ['salvator',
#   'mundi',
#   'and',
#   'the',
#   'unreality',
#   'of',
#   'the',
#   'art',
#   'market']]

# %%
#Join the tokens together
def JoinTokensTogether(val):
    final_token_list = []
    val = " ".join(val)
    return val

link_titles_join = link_titles_lem.map(JoinTokensTogether)
link_titles_join.collect()
# Out:
# ['turning a macbook into a touchscreen with 1 of hardware 2018',
#  'the lonely work of moderating hacker news',
#  'introducing nushell',
#  'google just deleted my nearly 10yearold free and opensource android app',
#  'ebola is now curable',
#  'all the best engineering advice i stole from nontechnical people',
#  'i miss microsoft encarta',
#  'alan kays answer to ‘what are some forgotten book programmer should read’',
#  'information operation directed at hong kong',
#  'terminating service for 8chan',
#  'what happens when you launch google chrome for the first time',
#  'how to build good software',
#  'null license plate not such a bright idea',
#  'what doe a coder do if they cant type',
#  'yelp is replacing restaurants’ phone number so grubhub can take a cut',
#  'japanese anime studio khara moving to blender',
#  'deconstructing google’s excuse on tracking protection',
#  'cloudflare s1',
#  '8chan go dark after hardware provider discontinues service',
#  'please add r support to your site',
#  'no more cheap shipping for chinese seller',
#  'python is eating the world',
#  'verizon to sell tumblr to automattic',
#  'tasty seaweed reduces cows’ methane emission by 99',
#  'hy',
#  'thing i learnt from a senior software engineer',
#  'wewtf',
#  'linux journal cease publication an awkward goodbye',
#  'amd land google twitter a customer with newest server chip',
#  'u navy will replace touchscreen with mechanical control on it destroyer',
#  'standard ebooks free publicdomain ebooks carefully produced',
#  'why is modern web development so complicated',
#  'a man who destroyed his multimillion dollar company in 10 second 2018',
#  'opendrop an open source airdrop implementation',
#  'a deep dive into io exploit chain found in the wild',
#  'software architecture guide',
#  'site using facebook ‘like’ button liable for data eu court rule',
#  'insect apocalypse in u driven by 50x increase in toxic pesticide study',
#  'apple confirms 1m reward for anyone who can hack an iphone',
#  'why all of our game look like crap',
#  'tech interview handbook',
#  'fewer than half of google search now result in a click',
#  'ugly gerry – font created from congressional district',
#  'why ha examinecom disappeared from search result',
#  'a walk in hong kong',
#  'john carmack on the joe rogan experience video',
#  'the baseline interpreter a faster javascript interpreter in firefox 70',
#  'google doesn’t want staff debating politics at work anymore',
#  'build your own text editor',
#  'ive reproduced 130 research paper about “predicting the stock market”',
#  'ask hn how do you read',
#  'how to build a plugin system on the web and also sleep well at night',
#  'europe is edging towards making postcar city a reality',
#  'new york city neighbor build cheaper way to connect to web',
#  'github action now support cicd free for public repository',
#  'consume le create more',
#  'living near tree not just green space improves wellbeing',
#  'kerbal space program 2',
#  'macbook pro keyboard drive me crazy',
#  'why i turned down an aws job offer',
#  'facebook ha been granted patent on shadow banning',
#  'the linux kernel inability to gracefully handle low memory pressure',
#  'show hn cli tool for saving web page a a single file',
#  'start your own isp',
#  'every productivity thought ive ever had a concisely a possible',
#  'preindustrial worker worked fewer hour than today 2009',
#  'milky way’s black hole just flared growing 75 time a bright for a few hour',
#  'amazon ha proven unable or unwilling to effectively police thirdparty seller',
#  'rail 60',
#  'haha wall',
#  'speaking to yourself in the third person make you wiser',
#  'ibm opensources power chip instruction set',
#  'apple expands part access to more independent repair business',
#  'paged out – a new experimental magazine about programming',
#  'let build house for people not car',
#  'we have ruined childhood',
#  'decrement carbon stripe negative emission commitment',
#  '16m american will vote on hackable paperless machine',
#  'home chip fab',
#  'google and mozilla are failing to support browser extension developer',
#  'a mathematician way of converting mile to kilometer',
#  'there is no evil like recaptcha',
#  'kaspersky av injected unique id allowing site to track user in incognito mode',
#  'who owns huawei',
#  'the horror of microsoft team',
#  'hundred of extreme selfciting scientist revealed in new database',
#  'regex for noobs – an illustrated guide',
#  'apple will soon treat online web tracking the same a a security vulnerability',
#  'the it guy v the con artist',
#  'death note l anonymity and eluding entropy 2017',
#  'amd rome second generation epyc review 2x 64core benchmarked',
#  'amazon is a monopoly',
#  'time anxiety is it too late',
#  'wtf – a personal information dashboard for your terminal',
#  'scientist discover a cure for the deadliest strain of tuberculosis',
#  'show hn divjoy – react codebase and ui generator',
#  'protein that may restore damaged sounddetecting cell in the ear',
#  '15 state are trying to make the electoral college obselete',
#  'banned c standard library function in git source code',
#  'pronunciation for hexadecimal number 1968',
#  'turbo an improved rainbow colormap for visualization',
#  'from mac to linux – the setup ive grown to love',
#  'time to get serious about tickborne disease',
#  'pentagon testing mass surveillance balloon across the u',
#  'useless window 10 feature',
#  'some obscure c feature',
#  'mercedesbenz presafe sound',
#  'tsv utility command line tool for large tabular data file',
#  'psytrance guide',
#  'researcher banned on valve bug bounty program publishes second steam 0day',
#  'why do developer at google consider agile development to be nonsense 2016',
#  'planet imaging the entire earth every day',
#  'software made me loathe my car',
#  'dqlite – highavailability sqlite',
#  'cutiepi – allinone raspberry pi tablet',
#  'knuth on huangs sensitivity proof “ive got the proof down to one page” pdf',
#  'supercentenarians are concentrated into region with no birth certificate',
#  'anthony levandowski charged with theft of trade secret',
#  'exfat in the linux kernel',
#  'speed matter why working quickly is more important than it seems 2015',
#  'programmer before you turn 40 get a plan b 2009',
#  'information theory for intelligent people 2018 pdf',
#  'i completed ultimate go took good note and commented directly on source code',
#  'a guide to recording 660fps video on a 6 raspberry pi camera',
#  'super mario 64 ha been decompiled',
#  'yaml probably not so great after all',
#  'rust language cheat sheet',
#  'thought on rust bloat',
#  'google chrome incognito mode can still be detected',
#  'rule for intuitive ux',
#  'iterm2 33',
#  'datadog s1',
#  'the not so hidden cost of sharing code between io and android',
#  'show hn chartxkcd – xkcdstyled chart library',
#  'tell hn danny cohen ha died',
#  'down the rabbithole',
#  'three kind of good tech debt',
#  'facebook scan system library on android and uploads them to their server',
#  'uber post 52b loss and slowest ever growth rate',
#  'the fully remote attack surface of the iphone',
#  'google to offer a best price guarantee on certain flight',
#  'npm ban terminal ad',
#  'the architecture of open source application',
#  'people love working remotely',
#  'berlin’s popular shopping street will go carfree',
#  'toni morrison ha died',
#  'sourcehut welcome bitbucket refugee',
#  'ai startup claim to automate app making but actually just us human',
#  'ask hn recommended resource to learn the linux kernel and o theory',
#  'steam window client local privilege escalation 0day',
#  'hong kong isp association’s statement on selective blocking of internet service',
#  'i wasn’t getting hired a a data scientist so i sought data on who is',
#  'juul philip morris sued under racketeer act for targeting kid',
#  'vmware acquires carbon black for 21b and pivotal for 27b',
#  'zen 2 missive – amd now delivering efficiency that are double that of intel',
#  'write your own excel in f 2018',
#  'performance matter',
#  'is perl 6 being renamed',
#  'people simply empty out 1986',
#  'black hat gdpr privacy law exploited to reveal personal data',
#  'show hn i trained a deep learning model to build site for me',
#  'webkit tracking prevention policy',
#  'removing coordinated inauthentic behavior from china',
#  'calculus for the people',
#  'anxiety look different in men',
#  'yield curve invert in u uk',
#  'amazon offered ‘amazon’s choice’ to vendor who bought ad and lowered price',
#  'cyberchef – cyber swiss army knife',
#  'rust 1370',
#  'a boeing code leak expose security flaw deep in a 787s gut',
#  'ask hn best resource to gain math intuition',
#  'mozilla take action to protect user in kazakhstan',
#  'anime4k real time high quality video upscaling',
#  'wine on window 10',
#  'building a distributed timeseries database on postgresql',
#  'xfce 414',
#  'most startup theory is expost therefore b',
#  'lesson from stripe',
#  'show hn wavebased nonlineofsight computational imaging in julia',
#  '‘they get fired all the time and they have no idea why’',
#  '9th circuit say user can sue facebook over unlawful use of facial recognition',
#  'linux kernel driver in rust might become an option in the future',
#  'moviepass worked out great',
#  'a beginner’s introduction to python web framework 2018',
#  'ask hn who is hiring august 2019',
#  'show hn data structure and algorithm in javascript',
#  'await in rust',
#  'cool but obscure x11 tool',
#  'elsevier threatens others for linking to scihub but doe so itself',
#  'group sex app leak location pic and personal detail',
#  'apple is locking iphone battery to discourage repair',
#  '“i would like to maintain the floppy driver”',
#  'fracking in north america could be partly to blame for methane spike – study',
#  'flawed algorithm are grading million of students’ essay',
#  '35 over 35',
#  'u designates china a currency manipulator',
#  'sunsetting mercurial support in bitbucket',
#  'open letter from an android developer to the google play team',
#  'cue – a language for defining generating and validating data',
#  'how rust optimizes asyncawait',
#  'one city saved 5m by routing school bus with an algorithm',
#  'asyncstd an async port of the rust standard library',
#  'regexr',
#  'the art of warez video',
#  'get your work recognized write a brag document',
#  'one job many role the different skill needed to be a successful cto',
#  'productivity and the workweek 2000',
#  'nigerian teen are making scifi short with slick visual effect',
#  'the most frequent 777 character give 90 coverage of kanji in the wild',
#  'contributing to the mozilla code base',
#  'the lost art of lacing cable 2018',
#  'martini realtime terrain mesh generator',
#  'the impact of meditating every day',
#  'software wa eating the world – now landlord are eating everything',
#  'ibm ha released the power architecture instruction set to the linux foundation',
#  'plastic whats recyclable what becomes trash and why',
#  'uber losing billion freeze engineering hire',
#  'irs budget cut cost 343b in lost revenue from big business',
#  'calculus is deeply irrational',
#  'every noise at once',
#  'att employee were bribed to install phone unlocking malware on company network',
#  'the problem at yale is not free speech',
#  'silk',
#  'beyond meat and kfc partner to test fried plantbased ‘chicken’',
#  'the we company s1',
#  'how to return to the flow faster',
#  'the paxos algorithm or how to win a turing award',
#  'attorney general barr and encryption',
#  'making email more modern with jmap',
#  'ffmpeg 42',
#  'webassembly interface type interoperate with all the thing',
#  'roblox hit 100m monthly active user bigger than minecraft',
#  'word that do handstand',
#  'how men’s body change when they become father',
#  'misconfigured jira instance exposed data of hundred of fortune 500 company',
#  'company use borrowed billion to buy back stock not to invest',
#  'ny state alleges exxonmobil knew risk of climate change and defrauded investor',
#  'new react devtools',
#  'wework get tax rebate meant for it smallbusiness tenant',
#  'administration using the full power of the surveillance state on whistleblower',
#  'a book from alan turing and a mysterious piece of paper',
#  'how to get your first ten customer 2013',
#  'doe the amazon provide 20 of our oxygen',
#  'uber proposes policy that would pay driver a minimum wage of 21 per hour',
#  'the most dangerous writing app',
#  'why did china just devalue the yuan how trade work with freefloating currency',
#  'arend theorem prover based on homotopy type theory by jetbrains',
#  'blazingsql is now open source',
#  'key negotiation of bluetooth attack',
#  'ondevice realtime hand tracking with mediapipe',
#  'dirty trick 6502 programmer use',
#  'insured price 2758 cash price 521',
#  'german grow frustrated with their slowpoke internet',
#  'building a raspberry pi 3b full keyboard handheld',
#  'show hn saag a a service – macronutrientportioned indian spinach curry',
#  'social exclusion fuel extremism in young men',
#  'camscanner a malicious android app with more than 100m downloads in google play',
#  'moscow blockchain voting system cracked a month before election',
#  'anna karenina principle',
#  'qemu vm escape',
#  'inflated bond rating helped spur the financial crisis they’re back',
#  'medieval people bathed regularly',
#  'devilution – a web port of the original diablo game',
#  'cooling a house without air conditioning',
#  '38myearold skull of an early apelike human ancestor discovered in ethiopia',
#  'huawei technician helped african government spy on political opponent',
#  'typescript 36',
#  'the answer to “will you mentor me” is no 2010',
#  'how to measure indoor air quality with a raspberry pi ruuvitags and pms7003',
#  'wework isn’t a tech company',
#  'why const doesnt make c code faster',
#  'verified by twilio',
#  'python v rust for neural network',
#  'big coal plant begin to close',
#  'aussie isv buy ad to wake up google support',
#  'the feynman lecture on physic algebra 1963',
#  'coinbase responding to firefox 0days in the wild',
#  'gamedev tutorial trigonometry basic – sine and cosine',
#  'secretly public domain most book published in the u before 1964',
#  'show hn clojurescript pixel game engine with blender livereloading',
#  'lisp is not based on the lambda calculus',
#  'alphabet overtakes apple to become most cashrich company',
#  'rice university researcher propose a way to boost solar efficiency',
#  'using backblaze b2 and cloudflare worker for free image hosting',
#  'the worst sale promotion in history hoover free flight fiasco',
#  'the door problem of combat design',
#  'wikipedia is now a brave verified publisher',
#  'google plan to deprecate ftp url support in chrome',
#  'killing a process and all of it descendant',
#  'show hn i created postwoman an online opensource api request builder',
#  'the many possibility of imessage file vulnerability',
#  'the design of littlefs a failsafe filesystem designed for microcontrollers',
#  'ask hn whats the best setup for ad blocking and tracker blocking',
#  'rabbit hole the secret to technical expertise',
#  'show hn i made a crm system to make sale fun',
#  'syslog complete system administrator guide',
#  'my sudden trip to hell',
#  'why doe all life use the same 20 amino acid',
#  'toshiba introduces new tiny nvme ssd form factor',
#  'john carmack on parallel implementation 2018',
#  'gnu radio 38',
#  'ask hn how do you handle logging',
#  'the github registry public beta is live',
#  'a practical guide to cs transition and animation',
#  'u farmer stung by tariff now face a 35b corn loss',
#  'facebook hit by apple’s crackdown on messaging feature',
#  'privacy sandbox – open standard to enhance privacy on the web',
#  'transformer from scratch',
#  'we made amiga they fucked it up 2015',
#  'memory management in python',
#  'die with me – a chat app you can only use when you have le than 5 battery',
#  'now bigger than ebay shopify set it sight on amazon',
#  'let build a video card',
#  'pastel a commandline tool to generate analyze convert and manipulate color',
#  'pagemap a mini map for your website',
#  'minify your svgs',
#  'yubico launch it dual usbc and lightning twofactor security key',
#  'a bloomberg reporter’s account of trying to get back his name and credit rating',
#  'opioid crisis johnson and johnson hit by landmark ruling',
#  'big pharma is using faux generic to keep drug price high critic say',
#  'tokyo audiophile venue 2016',
#  'japan surpasses china a largest foreign holder of u treasury',
#  'statement on the purpose of a corporation',
#  'spying on http',
#  'why doesnt mathematics collapse though human often make mistake in proof',
#  'hacker ship their exploit directly to their target’s mailroom',
#  'major book publisher sue amazon’s audible over new speechtotext feature',
#  'hacking the sonos ikea symfonisk into a high quality speaker amp',
#  'kubernetes security assessment pdf',
#  '“culture fit” is a two way street 2018',
#  'what happens when you ach a dead person',
#  'google search take 7 second on certain query',
#  'go module mirror and checksum database launched',
#  'high level of oestrogen in the womb linked to autism',
#  'alone in the dark',
#  'the fungus that devastates the cavendish banana ha now arrived in latin america',
#  'metal shard from boeing 787 taking off over rome rain down on people below',
#  'the “terrible” 3 cent mcu – a short survey of sub 010 microcontrollers',
#  'the order of the json',
#  'in effect seattle is decriminalizing the use of hard drug',
#  'faa ban recalled apple laptop from flight',
#  'salsify – a new architecture for realtime internet video',
#  'walmart sue tesla over fire at store fitted with it solar panel',
#  'danish bank launch negative interest rate mortgage',
#  'opensource firmware',
#  'technical vision for qt 6',
#  'show hn yack – community browser for hacker news reddit youtube and more',
#  'a dream of an ultimate o 1995',
#  'a primer on bézier curve 2013',
#  'bontrager’s wavecel material more effective at preventing concussion than mips',
#  'the death of social reciprocity in the era of digital distraction',
#  'amazon want to control thirdparty sellers’ product pricing',
#  'partiql one query language for all your data',
#  'a bug i wish i hadnt caught',
#  'a mobile phone that respect your freedom video',
#  'cloud run button clicktodeploy your git repos to gcp',
#  'my home lab server with 20 core  40 thread and 128 gb memory',
#  'gcc null pointer check removed',
#  'in the u it cheaper to build and operate wind farm than buy fossil fuel',
#  'wiringpi – deprecated',
#  'credit card have a privacy problem',
#  'starbucks monetary superpower',
#  'building age in the netherlands',
#  'huawei seek independence from the u with riscv and ascend chip',
#  'black hat talk about ‘time ai’ cause uproar is deleted by conference',
#  'the hypersane are among u if only we are prepared to look',
#  'why i like clojure',
#  'cybersecurity pro name their price a hacker attack swell',
#  'gcp to introduce an additional charge for publicly addressed vm instance',
#  'youtube shuts down music companies’ use of manual copyright claim',
#  'poetry dependency management for python',
#  'protocol not platform a technological approach to free speech',
#  'artichoke – a ruby made with rust',
#  'apollo guidance computer switching power supply work after 50 year',
#  'monad a a programming pattern',
#  'denial of h1b visa to india’s largest it service exporter at alltime high',
#  'show hn zeroconfig documentation website for python',
#  'show hn we track reddit google trend twitter etc to find trending topic',
#  'advice to my younger self become allergic to the churn',
#  'show hn sourcery – get a free selfupdating website',
#  'show hn lunch money a personal budgeting tool with multicurrency support',
#  'new life found that life off electricity 2016',
#  'cerebras system unveils a 12t transistor chip for ai',
#  'software architect should be involved in earliest system engineering activity',
#  'using typescript with react',
#  'bmw unveils car sprayed with vantablack',
#  'we shouldn’t take peer review a the ‘gold standard’',
#  'launch hn sanntek yc s19 – breathalyzer for cannabis',
#  'the myth of consumergrade security',
#  'nvidia ceo say google is the only customer building it own silicon at scale',
#  'racket lisp for learning',
#  'ask hn how to be le argumentative online',
#  'insurance company are paying cop to investigate their own customer',
#  'stand out a a speaker',
#  'creeping normality',
#  'nasa said to be investigating first allegation of a crime in space',
#  'germany for first time sell 30year bond offering negative yield',
#  'america’s elderly seem more screenobsessed than the young',
#  'alarming surge in drugresistant hiv uncovered',
#  'levenshtein distance',
#  'punpedia – the online encyclopedia of pun',
#  'legitlooking iphone lightning cable will hijack your computer',
#  'open startup list',
#  'the first solar road ha turned out to be a disappointing failure',
#  'facial recognition school id check lead to gdpr fine',
#  'twitter confesses to more adtech leak',
#  'what ha to happen with unix virtual memory when you have no swap space',
#  'elon musk gambled tesla to save solarcity',
#  'how the new opensource typeface used by github and mozilla came to be',
#  'splunk acquires cloud monitoring service signalfx for 105b',
#  'swap swap swap and bad place to work',
#  'interview with programming language creator 2010 pdf',
#  'activision blizzard ha moved billion of dollar of profit into tax haven',
#  'how to make billion of dollar reducing loneliness',
#  'seashell – pipe output from commandline program to the web in real time',
#  'wework ipo show it the most magical unicorn',
#  'experimental usaf space plane break record for orbital spaceflight',
#  'what i do a a devops consultant',
#  'making container safer',
#  'the erlang rationale',
#  'apple suspends siri response grading in response to privacy concern',
#  'the tragedy of ucs2',
#  'crispr pioneer among university of california researcher boycotting elsevier',
#  '‘no one saw a thing’ when a midwest town banded together to kill the town bully',
#  'what make a good conversation',
#  'ruffle – an adobe flash player written in rust compiled to webassembly',
#  'hedonometer',
#  'github support web authentication webauthn for security key',
#  'twelve latex package to get your paper accepted 2017',
#  'a manager’s guide to kubernetes adoption',
#  'typed property in php 74',
#  'a readable specification of tl 13',
#  'who owns your wireless service crook do',
#  'fed ordered google location dragnet to solve wisconsin bank robbery',
#  'thing to know about gnu readline',
#  'mortgage market reopens to risky borrower',
#  'recognizing the sign of disruption in our urban habitat',
#  'acute effect of electronic cigarette aerosol inhalation on vascular function',
#  'noaa data confirms july wa hottest month ever recorded',
#  'javascript the modern part',
#  'google warns developer that all new android apps require 3 day for approval',
#  'rust gui ecosystem overview',
#  'how doe esperanto sound',
#  'how command and conquer tiberian sun punished the computer of the day video',
#  'what’s the difference between statistic and machine learning',
#  'dropbox no longer follows symlinks to item outside of your dropbox account',
#  'climate change made european heatwave up to 3°c hotter',
#  'unison file synchronizer',
#  'michael cicconetti',
#  'opengpt2 we replicated gpt2 because you can too',
#  'practical tip for facelifting a tech resume',
#  'natural language processing the age of transformer',
#  'the portuguese bank note crisis of 1925',
#  'california farmer are planting solar panel a water supply dry up',
#  'youtube said to be fined up to 200m for children’s privacy violation',
#  'microsoft is killing epub support in edge classic',
#  'ask hn configuration management for personal computer',
#  'intel and rust the future of system programming video',
#  'from 30 to 230 docker container per host',
#  'wireless carrier throttling of online video is pervasive study',
#  'how do black hole destroy information and why is that a problem',
#  'waypipe gsoc project complete',
#  'launch hn quirk yc s19 – opensource cognitive behavioral therapy',
#  'boeings crash expose systemic failing',
#  'goldman sachs is spending 100m to shave millisecond off stock trade',
#  'bad time in tech not if you’re a startup serving other startup',
#  'why did turbo pascal apps fail with a divisionbyzero on faster system',
#  'show hn storytime – create story about your code instead of documentation',
#  'one of the greatest science fiction magazine is now available online 2017',
#  'nixery transparently build and serve container using nix',
#  'most internet service provider are gone – sonic ha survived and thrived',
#  'where do interrupt happen',
#  'ondisk format robustness requirement for new filesystems',
#  'giving up on julia 2016',
#  'the ethic of web performance',
#  'keeping tesla roadster alive is serious work',
#  'oracle director give blessing to shareholder lawsuit against larry ellison',
#  'lf fully decentralized fully replicated keyvalue store',
#  'a quarter of humanity face looming water crisis',
#  'pacvim – pacvim is a game that teach you vim command',
#  'why doe infrastructure cost so much',
#  'law of showrunning 2016 pdf',
#  'possible detection of a black hole with a mass that wa thought to be impossible',
#  'launch hn dex yc s19 – personal crm that reminds you to keep in touch',
#  'a buddhist monk confronts japan suicide culture 2013',
#  'the flawed threecueing system for teaching reading',
#  'home 3d metal printing first result',
#  'são paulo’s outdoor advertising ban 2016',
#  'google forcing nest cameras’ visual indicator light to be on',
#  'the flawed reasoning behind the replication crisis',
#  'sugar opensource software learning platform for child',
#  'open location code an open source standard for address',
#  'it crazy chase forgiving all debt owed by it canada credit card customer',
#  'computer science illustrated 2014',
#  'parsing json is a minefield 2018',
#  'i found an easter egg from 1977',
#  'the interviewer skill ladder for high growth company',
#  'show hn tailwindrun – an online playground for tailwind cs',
#  'what to do once you admit that decentralization never seems to work 2018',
#  'hundred of exposed amazon cloud backup found leaking sensitive data',
#  'removing one maine dam 20 year ago changed everything',
#  'nonplanar printing',
#  'why didnt the roman contribute much to mathematics',
#  'bulk data structure c',
#  'exploring weight agnostic neural network',
#  'have you ever tried to sell a diamond 1982',
#  'big o notation – using notboring math to measure code’s efficiency',
#  'cisco is making it more difficult to use used hardware',
#  'how shrinkflation is playing havoc with economists’ model',
#  'rotten apple right to repair roundup',
#  'tumblr',
#  'doordash buying caviar from square for 410m',
#  'daniel radcliffe and the art of the factcheck 2018',
#  'svalbard is a close a you can get to a place with open border',
#  'dyson tree',
#  'how i finally won my name from domain resellers after nine year of waiting',
#  'fbi tell lawmaker it cant access dayton gunman phone',
#  'child of a thailand tribe who see with clarity beneath the wave 2016',
#  'franky zapata flyboarding frenchman cross english channel',
#  'dignity',
#  'teen hacker find bug in school software that exposed million of record',
#  'a pissedoff tutorial for google wave 2010 video',
#  'i took a pay cut for a more meaningful job',
#  'ibm stop buyback to pay for red hat',
#  'parallelism in postgresql',
#  'tech backlash ha come to stanford',
#  'google’s rival opt out of search engine auction calling it ‘anticompetitive’',
#  'peloton s1',
#  'why a mock doesn’t work',
#  'pattern on good designed to trigger automated license plate reader',
#  'show hn texnique – a latex typesetting game',
#  'upmem put cpu inside memory to allow application to run 20 time faster',
#  'more fire now burning in angola congo than amazon',
#  'telegram introduces feature to prevent user from texting too often in a group',
#  'somehow i became respectable',
#  'how to become a great impostor',
#  'seattle microtransit experiment drive people to light rail',
#  'basic electron framework exploitation',
#  'helsinki central library chosen a the best new public library',
#  'spacex smallsat rideshare program',
#  'personal website for programmer',
#  'startup from y combinator’s s19 demo day 1',
#  'highlight from git 223',
#  'show hn youtube decade – the mostviewed video posted 10 year ago',
#  'standard j npm install funding',
#  'mapped the world’s coal power plant',
#  'kept alive with tube for nearly 17 year',
#  'lesson we learned when debugging a scaling problem',
#  'p idea faq',
#  'show hn scarf – platform to help opensource developer monetize their work',
#  'old paris is no more',
#  'spacebook agis near realtime satellite viewer',
#  'the path to dijkstra’s handwriting 2013',
#  'ted chiang realist of a larger reality',
#  'escape room are big business',
#  'alcohol belt of europe',
#  'dependent haskell is the future 2018',
#  'north american versus european distribution system 2011',
#  'social share button that dont allow the social site to track your user',
#  'nutrient deficiency in rice grown under higher carbon dioxide',
#  'the body is the missing link for truly intelligent machine 2017',
#  'electric motor design claim remarkable improvement',
#  'living off the land in linux',
#  'no son of mine is going to be a benthamite',
#  'extended validation certificate are really dead',
#  'the mobility trap why well never fix congestion by speeding up traffic',
#  'static type checking in common lisp',
#  'interslavic language',
#  'startup from y combinator’s s19 demo day 2',
#  'announcing notqmail',
#  'why the french love to say no',
#  'theory of error backpropagation in the brain',
#  'black beekeeper are transforming detroit’s vacant lot into bee farm 2018',
#  'gpt2 6month followup',
#  'crossword panic of 1944',
#  'libspng – c library for reading and writing png file',
#  'kegans theory of the evolution of consciousness',
#  'hospital checklist are meant to save life so why do they often fail',
#  'understanding sat by implementing a simple sat solver in python 2014',
#  'a deep dive into linux namespaces part 4',
#  'chemist make firstever ring of pure carbon',
#  'datacenter location driven by 19th century politics',
#  'uber is biggest loser a softbank count ipo return',
#  'using bacteria to make selfhealing cement',
#  'better encrypted group chat',
#  'exploring mathematics with matplotlib and python',
#  'moravecs paradox',
#  'vibrationminimizing motion retargeting for robotic character',
#  'website builder webflow yc s13 went from near bankruptcy to 72m series a',
#  'swiss post suspends drone delivery service after second crash',
#  'doityourself openjdk garbage collector',
#  'patagonia philosopher king 2016',
#  'j can look like apl or english',
#  'julias release process',
#  'math in data science',
#  'getting real about distributed system reliability 2012',
#  'dont forget randomness is still just a hypothesis 2006',
#  'history of the broken vertical bar being the ¦ form of ',
#  'show hn i built a “google alerts” for hacker news',
#  'tv detector van',
#  'two brother invented an alphabet for their native language fulfulde',
#  'where will ‘garage orphans’ charge electric car',
#  'how biotech startup funding will change in the next 10 year',
#  'ignition an informal history of liquid rocket propellant 1972 pdf',
#  'winedark sea',
#  '10 year sel4 still the best still getting better',
#  'when to shut down a startup video',
#  'ctvt – a contagious cancer that spread from dog to dog',
#  'ceramic enter a new era with laserwelded joint',
#  'the shady world of repair manual copyrighting for planned obsolescence 2012',
#  'open source hardware hearing aid part 1',
#  'the last working olivetti mainframe sits in a tuscan high school',
#  'in the beginning wa the command line 1999 pdf',
#  'manufacturer want to quit china for vietnam but find it impossible',
#  'microsoft ha first major impact on chrome',
#  'casting glass from 3d printed mold',
#  'def con and stack overflow what our traffic say about cybersecurity',
#  'geocities archive',
#  'nshot learning learning more with le data',
#  'who did the math for general relativity first einstein or hilbert',
#  'the rule of 2',
#  'an exosuit that boost endurance on the trail',
#  'subsurface – an open source scuba dive logging platform',
#  'you may be better off picking stock at random study find',
#  'goal and reward redraw the brain’s map of the world',
#  'fbi delivery driver involved in amazon theft ring',
#  'solar powered raspberry pi camera',
#  'mosquito changed everything',
#  'columnist asked researcher what they could find out from just his cell number',
#  'a commercial path to fusion',
#  'stockx wa hacked exposing million of customers’ data',
#  'waymo’s backseat driver confidential data reveals selfdriving taxi hurdle',
#  'moviepass reportedly changed password to prevent user from seeing film',
#  '“bicycle of the mind”',
#  'what german are reading',
#  'tiny toy totp generator in 18 line of python',
#  'a molecular near miss',
#  'supercomputer will start building a 3d map of the world',
#  'what company are for',
#  'dwindling cpan release',
#  'capital one cyber staff raised concern before hack',
#  'trigger a kernel panic to diagnose unresponsive ec2 instance',
#  'launch hn compound yc s19 – helping employee understand equity compensation',
#  'how we manage a million push notification an hour',
#  'inventing monad',
#  'write fuzzable code',
#  'most software company ignore user behavior',
#  'an afternoon in tokyo with the man who design casio gshock watch 2017',
#  'analyzing the facebook ad placed by the u presidential candidate',
#  'kip500 replace zookeeper with a selfmanaged metadata quorum',
#  'side channel that leaked data from intel cpu patched by silent window update',
#  'chemist discover water microdroplets spontaneously produce hydrogen peroxide',
#  'rendering on the web',
#  'free software network service and web application which can be hosted locally',
#  'phytoplankton population drop 40 percent since 1950 2010',
#  'root cerns scientific data analysis framework for c',
#  'the subversive message hidden in the wizard of oz',
#  'flaw in cellphone evidence prompt review of 10k verdict in denmark',
#  'economist raj chetty ha found a surprising tool to fight housing segregation',
#  'static analysis at scale an instagram story',
#  'camera v lidar',
#  'how digital advertising market really work',
#  'security flaw caused by compiler optimization',
#  'how web content can affect power usage',
#  'music recommendation in hyperbolic space',
#  'a deep dive into amd’s rome epyc architecture',
#  '16bit riscv processor made with carbon nanotube',
#  'show hn real world jupyter notebook embed way to ass data scientist',
#  'launch hn memfault yc w19 – crashlytics for firmware',
#  'a person ha died from a vapingrelated condition',
#  'linux pressure stall information psi by example',
#  'how to write a lisp interpreter in python 2010',
#  'processor design an introduction 1998',
#  'adventure in prolog tutorial 2016',
#  'show hn purely functional scripting',
#  'clever functional design',
#  'google begin penalising domain leasing',
#  'building a programming language pt 3 – interpreting',
#  'sentient classified artificial brain being developed by u intelligence',
#  'live avatar with faceapijs',
#  'india’s messy electric vehicle revolution',
#  'launch hn lang yc s19 – internationalization built for devs',
#  'i tried hiding from big tech in a pile of privacy gadget',
#  'pokemonsay pokemon version of cowsay',
#  'cowrie a mediuminteraction ssh and telnet honeypot',
#  'energy storage investment boom a battery cost halve in the next decade',
#  'effortless elixir release and deployment',
#  'which category of seed startup are thriving which arent',
#  'hydrophilic disc us solar power to separate salt from water',
#  'learning to prove theorem via interacting with proof assistant',
#  'dark matter developer the unseen 99 2012',
#  'urgent11 – zero day vulnerability impacting vxworks',
#  'huntington park’s “robocop” store pedestrians’ face scan license plate',
#  'cern open data portal explore more than 2 pb of open data from particle physic',
#  'getting started with lisp in 2019',
#  'what is null 2010',
#  'misinterpreting hurricane forecast',
#  'scale yc s16 raise 100m from accel and founder fund at 1b valuation',
#  'programming algorithm in lisp data structure',
#  'in pentagon contract fight amazon ha foe in high place',
#  'rome is the fulcrum of amd’s datacenter pivot',
#  'how to get into farming with no money 1980',
#  'phone company ink deal with all 50 state and dc to combat robocalls',
#  'fast tensor in clojure – a sneak peek',
#  'how the great truth dawned',
#  'filekit an open source endtoend encrypted cloud storage service in javascript',
#  'would you accept cheaper rent in exchange for a monthly amazon purchasing quota',
#  'duckling a clojure library that par text into structured data',
#  'mitre system engineering guide 2014 pdf',
#  'texas power price briefly surpass 9k amid scorching heat',
#  'amazon plan to conquer the world of publishing',
#  'toptal sue cofounder breanden beneschott for fraud',
#  'finding amelia earhart’s plane seemed impossible – then came a startling clue',
#  '30 year ago voyager 2 historic neptune flyby',
#  'mesapy a memorysafe python implementation based on pypy 2018',
#  'trail of wind data visualization of the architecture of airport runway',
#  'show hn shapeform – schema driven form for react',
#  'network effect that don’t look like network effect',
#  'germany turn to hydrogen in quest for clean energy economy',
#  'if you want developer to adopt your software make it le risky 2017',
#  'why the u army owns so many fossil',
#  'exploring dna with deep learning',
#  'how the pentagon come up with code word and secret project nickname',
#  'a simulated enigma machine',
#  'on building my own artificial pancreas',
#  'machine learning that’s light enough for an arduino',
#  'unshaky – try to address double key press issue on apple butterfly keyboard',
#  'zrna – softwaredefined analog circuit',
#  'simple rpc framework in 300 line of go',
#  'a codebase is an organism 2014',
#  'the perfect language and why go still isnt it',
#  'hundred of people died over a millennium at “skeleton lake” in the himalaya',
#  'all tridactyl installation might get removed by firefox on aug 21',
#  'diver find remains of ancient temple in sunken egyptian city',
#  'free and opensource tool for analog filmmaking',
#  'api gateway identity crisis – are they replaced by service mesh',
#  'i started an online subscription business from malaysia',
#  'lifehacker tarek loubani on 3dprinting in gaza',
#  'our brain tell story so we can live 2013',
#  'capturing pal video with an sdr and a few dead end',
#  'solving differential equation on a 6502 with wozs floating point code',
#  'computer stupidity 2013',
#  'a look back the bloomberg keyboard 2017',
#  'jupiter riscv assembler and runtime simulator',
#  '42 hour of buckminster fuller might be just the vision we need',
#  'project mu – a modular uefi environment for building modern device',
#  'the high price of multitasking',
#  'curve fitting a linear least square',
#  'handler belief affect scent detection dog outcome 2011',
#  'sipeed longan nano – riscv development board',
#  'the difference between isolation level and consistency level',
#  'detailed 3d map of milky way show warped shape',
#  'map design – a guide to good looking map 2008 pdf',
#  'no silver bullet 1986 pdf',
#  'armoured commander the wwii tank commander roguelike',
#  'how the brain approximates without counting',
#  'softbank plan to lend 20b to it ceo and employee amid volatile market',
#  'the hp way how bill hewlett and i built our company 1960',
#  'how to build a pyramid',
#  'how to get consistent result when benchmarking on linux',
#  'how to teach an iris scanner that the eye it’s looking at is dead',
#  'building a vacuum tube computer',
#  'portugal’s marmelada taste nothing like marmalade 2018',
#  'spacy pytorch transformer',
#  'real world location virtually recreated to scale in minute video',
#  'show hn datkeyserver a distributed pgp keyserver based on the dat protocol',
#  'karel čapeks play rur premiered in january 1921',
#  'apple card restriction include no jailbreaking or cryptocurrency purchase',
#  'the grand c error explosion competition',
#  'turkmenistan on the brink of collapse',
#  'a profile of geoffrey hinton 2018',
#  'scientist reverse aging process in rat brain stem cell',
#  'show hn cordless a discord terminal client written in go',
#  '100 year ago a telephone tower in stockholm connected 5000 phone line 2014',
#  'japanese architect who treated building like living organism',
#  'a recent paper proposes to bring zeppelin back',
#  'jcore open processor',
#  'presidio customizable data protection and pii data anonymization service',
#  'the survival of iggy pop',
#  'bpf portbased firewall for systemd service',
#  'marree man',
#  'the dday rehearsal that cost 800 life 2014',
#  'ray tracing with ulisp',
#  'show hn a few simple game not only for kid',
#  'why everyone hate customer service',
#  'commodore 900',
#  'qualpwn – exploiting qualcomm wlan and modem over the air',
#  'study identifies main culprit behind lithium metal battery failure',
#  'with friend like these',
#  'youtube’s lgbtq problem is a businessmodel problem',
#  'suburb in the sky how jakartans built an entire village on top of a mall',
#  'circulating in china’s financial system more than 200b in iou',
#  'the death of alexander the great one of history great unsolved mystery',
#  'the microworkers making digital life possible',
#  'keyringless gnupg',
#  'the perfect french baguette',
#  'shipping wind turbine is not a breeze',
#  'iron age celtic woman wa buried in a hollowedout tree trunk',
#  'the biggest mistake firsttime founder make video',
#  'boeing changing max software to use two computer',
#  'empty train on the modern silk road when belt and road interest don’t align',
#  'wavelet 1994 pdf',
#  'who did the maya sacrifice',
#  'a guide to magnetorquers for satellite',
#  'mobile nixos the present and the future',
#  'nec show ‘flying car’ hovering steadily for minute',
#  'quantum radar ha been demonstrated for the first time',
#  'ear speaker – research design and evolution',
#  'wasm v pnacl performance benchmark',
#  'evolving lindenmayer system',
#  'show hn repository of open source spacerelated software and hardware',
#  'i love my paper dictionary 2017',
#  'darpa want help cracking the election security problem',
#  'the fed is getting into the realtime payment business',
#  'woman find yellow diamond while watching youtube video on how to find diamond',
#  'amazon will pull the plug on dash button',
#  'problem solving and clojure 19 2018',
#  'a new book asserts that rich country grow with lighter environmental impact',
#  'animal movie promote awareness not harm say researcher',
#  '2019 hyundai kona ev explodes when parked',
#  'the league of entropy is making randomness truly random',
#  'a transparent display with perpixel color and opacity control',
#  'the “terrascope” on the possibility of using the earth a an atmospheric lens',
#  'human dominated earth earlier than previously thought',
#  'fuzzification antifuzzing technique pdf',
#  'what is zoned storage and the zoned storage initiative',
#  'webmin 1890 exploit – what happened',
#  'scaling static analysis at facebook',
#  'the death of a weather satellite a seen by sdr',
#  'holiday are good for worker and company alike',
#  'richard sorge the soviet union’s master spy',
#  'debunking the stanford prison experiment pdf',
#  'marium the dugong who charmed thailand dy after ingesting plastic',
#  'simple python package to extract deep learning feature',
#  'massive ‘ocean’ discovered towards earth’s core 2014',
#  'def con 2019 – ctf retrospective',
#  'kdevops framework for setting up and testing the linux kernel for any project',
#  'simple pure and total functional language that generalizes datalog',
#  'continuous 3d printing possible with transparent polygon scanning',
#  'could removing social medium metric reduce polarization',
#  'roaring glacial melt under the bridge to kangerlussiauq greenland',
#  'the new treasure of pompeii',
#  'sec investigating data leak at first american financial corp',
#  'the openbsd ada library',
#  'dont say “homoiconic” 2018',
#  'u air force pause flight for over a hundred c130s over ‘atypical’ cracking',
#  'i am a horse in the land of booleans',
#  'we may not be running out of helium after all 2015',
#  'launch hn shift health yc s19 – understand your healthcare cost previsit',
#  'smartykit apple i replica',
#  'gerbil – a metadialect of scheme',
#  'hawaii extends thirty meter telescope permit amid protest',
#  'gm is now detroit’s smallest automaking employer',
#  'the dipole drive a new concept in space propulsion',
#  'universal algorithm set to boost microscope',
#  'fearing data privacy issue google cut some android phone data for carrier',
#  'robotic thread is designed to slip through the brain blood vessel',
#  'vickrey–clarke–groves auction',
#  'prolog control in six slide',
#  'opinion piece on ghc back end',
#  'entropic a federated package registry for anything',
#  'cbor – concise binary object representation',
#  'can we survive technology 1955 pdf',
#  'cassette are back and it’s not about the music',
#  'paul dirac the mozart of science 2008',
#  'in praise of xlogo',
#  'show hn historical order book reconstruction api for crypto market',
#  'arc of seniority',
#  'the long game of research',
#  'a look at hs2 old oak common station',
#  'how judy array work and why they are so fast 2002',
#  'mining bitcoin on an apple ii',
#  'unearthing a masterpiece a rare minoan sealstone 2017',
#  'golden ratio',
#  'show hn pgcmd – an alternative to psql with json output',
#  'reviving an hp 660lx in 2019',
#  'ssb room a new server type for scuttlebutt',
#  'implementing poincaré embeddings 2017',
#  'extending ocaml program with lua',
#  'container networking with vxlan bgp and wireguard',
#  'a fine map from alexander von humboldt 1851',
#  'new research on ptsd in elephant and other animal',
#  '“awakenings” in advanced dementia patient hint at untapped brain reserve',
#  'recycling of plastic enabled by dynamic covalent diketoenamine bond 2018 pdf',
#  'show hn dataviz project for raytracing the moon model',
#  'five new realtime detection of fast radio burst with utmost',
#  'lucidscience – electronic project and tutorial',
#  'what are child dying from and what can we do about it',
#  'a conversation with the team that made bread with ancient egyptian yeast',
#  'air force reveals test of supposed recordsetting scramjet from n grumman',
#  'the decline of college newspaper',
#  'which is the best john le carré novel 2014',
#  'dreaming about better sleep dreem oura and the rest',
#  'penn effect',
#  'hall’s law the nineteenth century prequel to moore’s law 2012',
#  'volcano on the moon may have erupted during the dinosaur age 2014',
#  'the world’s smartest chimp ha died',
#  'smart plastic incineration posited a solution to global recycling crisis',
#  'kei – a small and expressive dependent language',
#  'freshermeat – opensource security software',
#  'engineer build advanced microprocessor out of carbon nanotube',
#  'a new york farm stand’s success an eye for the next big thing',
#  'disneyland’s disastrous opening day 2015',
#  'a zmachine in ocaml 2016',
#  'quantum air buy bye electric airplane',
#  'famous graphic chip microsoft’s talisman',
#  'engineer develop bonelike metal foam that can be healed at room temperature',
#  'using the golden research engine to query the y combinator s19 batch',
#  'a mosque rebuilt once a year',
#  'flying with miniature horse',
#  'the oral history of the super soaker',
#  'a trailblazing plan to fight california wildfire',
#  'show hn firestorm – an orm for firestore',
#  'programming shape using kirigami tessellation',
#  'potosí the mountain of silver that wa the first global city',
#  'an ancient egypttoblack sea route adventurer to test theory',
#  'exploring the visible spectrum in python',
#  'general balanced tree 1999 pdf',
#  'using wall street secret to reduce the cost of cloud infrastructure',
#  'rediscovering rule for ancient board game',
#  'on the road in 1980',
#  'the software art',
#  'making webworkers async iterables',
#  'show hn quarkide and a javascript runtime to build crossplatform desktop apps',
#  'environment and the programming language self part 4',
#  'the lost dove press typeface and it revival 2015',
#  'early year of computer gaming steve russell and nolan bushnell 2002 video',
#  'the quest to conquer earth’s space junk problem 2018',
#  'swadesh list',
#  'salvator mundi and the unreality of the art market']

# %%
#Extract all the noun phrases
def ExtractAllPhrases(x):
    from nltk.corpus import stopwords
    stop_words=set(stopwords.words('english'))    
    
    def leaves(tree):
        """Finds NP (nounphrase) leaf nodes of a chunk tree."""
        for subtree in tree.subtrees(filter = lambda t: t.label()=='NP'):
            yield subtree.leaves()
    
    def get_terms(tree):
        for leaf in leaves(tree):
            term = [w for w,t in leaf if not w in stop_words]
            yield term
    
    #Setup regular expression 
    sentence_regexp = r'(?:(?:[A-Z])(?:.[A-Z])+.?)|(?:\w+(?:-\w+)*)|(?:\$?\d+(?:.\d+)?%?)|(?:...|)(?:[][.,;"\'?():-_`])'
   
    #Specify grammar rules
    grammar_rule = r"""
    NBAR:
        {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns
        
    NP:
        {<NBAR>}
        {<NBAR><IN><NBAR>}  # Above, connected with in/of/etc...
    """
    
    #Apply regexp parser
    #Apply shallow parsing in order to give more context to the sentence
    chunker = nltk.RegexpParser(grammar_rule)
    tokens = nltk.regexp_tokenize(x,sentence_regexp)
    
    #Apply part of speech tagging
    #Apply nous, verbs, adjectives, etc. 
    postoks = nltk.tag.pos_tag(tokens)  
    
    # Get a chink from the chunk
    tree = chunker.parse(postoks) 
    terms = get_terms(tree)
    temp_phrases = []
    for term in terms:
        if len(term):
            temp_phrases.append(' '.join(term))
            
    #Get rid of the empty list
    finalPhrase = [w for w in temp_phrases if w]
    return finalPhrase


link_titles_phrases = link_titles_join.map(ExtractAllPhrases)
link_titles_phrases.collect()
# Out:
# [['macbook', 'touchscreen', 'hardware'],
#  ['lonely work', 'hacker news'],
#  ['nushell'],
#  ['google', 'opensource android app'],
#  ['ebola'],
#  ['engineering advice stole', 'nontechnical people'],
#  ['encarta'],
#  ['alan', 'forgotten book programmer'],
#  ['information operation', 'hong kong'],
#  ['service'],
#  ['google chrome', 'first time'],
#  ['good software'],
#  ['null license plate', 'bright idea'],
#  ['coder', 'type'],
#  ['yelp', 'restaurants phone number', 'cut'],
#  ['japanese anime studio khara'],
#  ['google excuse', 'protection'],
#  ['cloudflare s1'],
#  ['go', 'hardware provider discontinues service'],
#  ['r support', 'site'],
#  ['cheap shipping', 'chinese seller'],
#  ['python', 'world'],
#  ['verizon', 'tumblr'],
#  ['tasty seaweed reduces', 'methane emission'],
#  ['hy'],
#  ['thing', 'senior software engineer'],
#  ['wewtf'],
#  ['linux journal cease publication', 'awkward goodbye'],
#  ['amd land google twitter', 'customer', 'newest server chip'],
#  ['u navy', 'mechanical control', 'destroyer'],
#  ['standard ebooks free publicdomain ebooks'],
#  ['modern web development'],
#  ['man', 'multimillion dollar company'],
#  ['opendrop', 'open source airdrop implementation'],
#  ['deep dive', 'io exploit chain', 'wild'],
#  ['software architecture guide'],
#  ['site', 'facebook', 'button liable', 'data eu court rule'],
#  ['insect apocalypse', 'increase', 'toxic pesticide study'],
#  ['apple', 'reward', 'anyone', 'iphone'],
#  ['game look', 'crap'],
#  ['tech interview handbook'],
#  ['half', 'google search', 'click'],
#  ['congressional district'],
#  ['ha examinecom', 'search result'],
#  ['walk', 'hong kong'],
#  ['john carmack', 'joe rogan experience video'],
#  ['baseline interpreter', 'javascript interpreter', 'firefox'],
#  ['google', 'staff', 'politics', 'work'],
#  ['text editor'],
#  ['ive', 'research paper', 'stock market'],
#  [],
#  ['plugin system', 'web', 'night'],
#  ['europe', 'towards', 'postcar city', 'reality'],
#  ['new york city neighbor', 'way'],
#  ['github action', 'cicd', 'public repository'],
#  ['consume le create'],
#  ['green space'],
#  ['kerbal space program'],
#  ['macbook pro keyboard drive'],
#  ['aws job offer'],
#  ['facebook ha', 'patent', 'shadow'],
#  ['linux kernel inability', 'low memory pressure'],
#  ['show', 'cli tool', 'web page', 'single file'],
#  ['isp'],
#  ['productivity'],
#  ['preindustrial worker', 'hour', 'today'],
#  ['milky way black hole', 'time', 'bright', 'hour'],
#  ['amazon ha', 'thirdparty seller'],
#  ['rail'],
#  ['haha wall'],
#  ['third person'],
#  ['ibm opensources power chip instruction set'],
#  ['apple', 'part access', 'independent repair business'],
#  ['new experimental magazine'],
#  ['house', 'people', 'car'],
#  ['childhood'],
#  ['decrement carbon stripe negative emission commitment'],
#  ['hackable paperless machine'],
#  ['home chip fab'],
#  ['google', 'mozilla', 'extension developer'],
#  ['mathematician way', 'mile'],
#  ['recaptcha'],
#  ['kaspersky av', 'unique id', 'site', 'user', 'incognito mode'],
#  ['huawei'],
#  ['horror', 'microsoft team'],
#  ['scientist', 'new database'],
#  ['regex', 'illustrated guide'],
#  ['apple', 'online web', 'security vulnerability'],
#  ['con artist'],
#  ['death note l anonymity', 'entropy'],
#  ['amd rome second generation'],
#  ['amazon', 'monopoly'],
#  ['time anxiety'],
#  ['wtf', 'personal information dashboard', 'terminal'],
#  ['scientist', 'cure', 'strain', 'tuberculosis'],
#  ['show', 'divjoy react codebase', 'ui generator'],
#  ['protein', 'cell', 'ear'],
#  ['state', 'electoral college obselete'],
#  ['c standard library function', 'git source code'],
#  ['pronunciation', 'hexadecimal number'],
#  ['turbo', 'improved rainbow colormap', 'visualization'],
#  ['mac', 'setup ive grown'],
#  ['time', 'tickborne disease'],
#  ['pentagon', 'mass surveillance balloon', 'u'],
#  ['useless window', 'feature'],
#  ['obscure c feature'],
#  ['mercedesbenz presafe sound'],
#  ['tsv utility command line tool', 'large tabular data file'],
#  ['psytrance guide'],
#  ['researcher', 'valve bug bounty program publishes second steam'],
#  ['developer', 'google', 'agile development'],
#  ['planet', 'entire earth', 'day'],
#  ['software', 'car'],
#  ['dqlite highavailability sqlite'],
#  ['cutiepi allinone raspberry pi tablet'],
#  ['knuth', 'huangs sensitivity', 'proof', 'page pdf'],
#  ['supercentenarians', 'region', 'birth certificate'],
#  ['anthony levandowski', 'theft', 'trade secret'],
#  ['exfat', 'linux kernel'],
#  ['speed matter'],
#  ['programmer', 'plan'],
#  ['information theory', 'intelligent people', 'pdf'],
#  ['ultimate go', 'good note', 'source code'],
#  ['guide', 'video', 'raspberry pi camera'],
#  ['super mario', 'ha'],
#  ['yaml'],
#  ['rust language cheat sheet'],
#  ['rust bloat'],
#  ['google chrome incognito mode'],
#  ['rule', 'intuitive ux'],
#  ['iterm2'],
#  ['datadog s1'],
#  ['hidden cost', 'code', 'io', 'android'],
#  ['show', 'chartxkcd', 'chart library'],
#  ['hn', 'cohen ha'],
#  ['rabbithole'],
#  ['kind', 'good tech debt'],
#  ['facebook scan system library', 'android', 'server'],
#  ['uber post', 'loss', 'growth rate'],
#  ['remote attack surface', 'iphone'],
#  ['google', 'price guarantee', 'certain flight'],
#  ['npm ban terminal ad'],
#  ['architecture', 'open source application'],
#  ['people'],
#  ['berlin', 'popular shopping street'],
#  ['toni morrison ha'],
#  ['sourcehut welcome bitbucket refugee'],
#  ['ai startup claim'],
#  ['ask hn', 'resource', 'linux kernel', 'theory'],
#  ['steam window client local privilege escalation'],
#  ['isp association', 'statement', 'selective blocking', 'internet service'],
#  ['data scientist', 'data'],
#  ['juul philip morris', 'racketeer act', 'kid'],
#  ['vmware'],
#  ['missive amd', 'efficiency', 'intel'],
#  ['excel', 'f'],
#  ['performance matter'],
#  [],
#  ['people'],
#  ['privacy law', 'personal data'],
#  ['show hn', 'deep learning model', 'site'],
#  ['webkit', 'prevention policy'],
#  ['inauthentic behavior', 'china'],
#  ['calculus', 'people'],
#  ['anxiety', 'men'],
#  ['yield curve invert', 'u uk'],
#  ['amazon', 'amazon choice', 'vendor', 'ad', 'price'],
#  ['cyberchef cyber swiss army knife'],
#  ['rust'],
#  ['boeing code', 'expose security flaw deep', 'gut'],
#  ['ask hn', 'resource', 'math intuition'],
#  ['mozilla', 'action', 'user', 'kazakhstan'],
#  ['real time high quality video'],
#  ['wine', 'window'],
#  ['distributed timeseries', 'postgresql'],
#  [],
#  ['startup theory', 'b'],
#  ['lesson', 'stripe'],
#  ['show hn', 'nonlineofsight computational imaging', 'julia'],
#  ['time', 'idea'],
#  ['circuit', 'user', 'facebook', 'unlawful use', 'facial recognition'],
#  ['linux kernel driver', 'rust', 'option', 'future'],
#  ['moviepass'],
#  ['beginner introduction', 'web framework'],
#  ['ask hn'],
#  ['show', 'data structure', 'algorithm', 'javascript'],
#  ['await', 'rust'],
#  ['cool', 'obscure x11 tool'],
#  ['elsevier', 'others'],
#  ['group sex', 'leak location pic', 'personal detail'],
#  ['apple', 'battery', 'repair'],
#  ['floppy driver'],
#  ['north america', 'methane spike study'],
#  ['algorithm', 'students'],
#  [],
#  ['currency manipulator'],
#  ['mercurial support', 'bitbucket'],
#  ['open letter', 'android developer', 'google play team'],
#  ['cue', 'language', 'generating', 'validating data'],
#  ['asyncawait'],
#  ['city', 'school bus', 'algorithm'],
#  ['async port', 'rust standard library'],
#  ['regexr'],
#  ['art', 'warez video'],
#  ['work', 'brag document'],
#  ['job many role', 'different skill', 'successful cto'],
#  ['productivity', 'workweek'],
#  ['nigerian teen', 'slick visual effect'],
#  ['character', 'coverage', 'wild'],
#  ['mozilla code base'],
#  ['lost art', 'cable'],
#  ['martini realtime terrain mesh generator'],
#  ['impact', 'day'],
#  ['software', 'world', 'everything'],
#  ['ibm ha', 'power architecture instruction', 'linux foundation'],
#  ['plastic whats', 'trash'],
#  ['freeze engineering hire'],
#  ['irs budget cut cost', 'revenue', 'big business'],
#  ['calculus'],
#  ['noise'],
#  ['att employee', 'phone', 'malware', 'company network'],
#  ['problem', 'yale', 'free speech'],
#  ['silk'],
#  ['meat', 'partner', 'plantbased chicken'],
#  ['company'],
#  ['flow faster'],
#  ['paxos algorithm', 'turing award'],
#  ['attorney general barr', 'encryption'],
#  ['jmap'],
#  ['ffmpeg'],
#  ['interface type interoperate', 'thing'],
#  ['roblox', 'monthly active user', 'minecraft'],
#  ['word'],
#  ['men', 'body change'],
#  ['jira instance', 'data', 'fortune', 'company'],
#  ['company use', 'stock'],
#  ['ny state alleges', 'knew risk', 'climate change', 'investor'],
#  ['new react devtools'],
#  ['wework', 'tax rebate meant', 'smallbusiness tenant'],
#  ['administration', 'full power', 'surveillance state', 'whistleblower'],
#  ['book', 'mysterious piece', 'paper'],
#  ['customer'],
#  ['amazon', 'oxygen'],
#  ['uber proposes policy', 'minimum wage', 'hour'],
#  ['dangerous writing app'],
#  ['trade work', 'freefloating currency'],
#  ['arend theorem prover', 'homotopy type theory', 'jetbrains'],
#  ['blazingsql', 'open source'],
#  ['key negotiation', 'attack'],
#  ['ondevice realtime hand', 'mediapipe'],
#  ['dirty trick', 'programmer use'],
#  ['insured price', 'cash price'],
#  ['german grow', 'slowpoke internet'],
#  ['raspberry pi', 'full keyboard handheld'],
#  ['show', 'service', 'indian spinach curry'],
#  ['social exclusion fuel extremism', 'young men'],
#  ['camscanner', 'malicious android app', 'downloads', 'google play'],
#  ['moscow blockchain voting system', 'month', 'election'],
#  ['principle'],
#  ['qemu vm escape'],
#  ['bond rating', 'financial crisis'],
#  ['medieval people'],
#  ['devilution', 'web port', 'original diablo game'],
#  ['house', 'air conditioning'],
#  ['skull', 'early apelike human ancestor', 'ethiopia'],
#  ['huawei technician', 'african government spy', 'political opponent'],
#  ['typescript'],
#  ['answer'],
#  ['indoor air quality', 'raspberry pi ruuvitags', 'pms7003'],
#  ['wework', 'tech company'],
#  ['const doesnt', 'c code'],
#  ['twilio'],
#  ['python v rust', 'neural network'],
#  ['big coal plant begin'],
#  ['aussie isv', 'ad', 'google support'],
#  ['feynman lecture', 'physic algebra'],
#  ['coinbase', 'wild'],
#  ['gamedev tutorial trigonometry basic sine', 'cosine'],
#  ['public domain', 'book', 'u'],
#  ['show', 'clojurescript pixel game engine', 'blender livereloading'],
#  ['lisp', 'lambda calculus'],
#  ['alphabet overtakes apple', 'cashrich company'],
#  ['rice university researcher', 'way', 'solar efficiency'],
#  ['backblaze b2', 'cloudflare worker', 'free image hosting'],
#  ['sale promotion', 'history', 'free flight fiasco'],
#  ['door problem', 'combat design'],
#  ['wikipedia', 'brave', 'publisher'],
#  ['google plan', 'ftp url support', 'chrome'],
#  ['process'],
#  ['show hn', 'online opensource api request builder'],
#  ['many possibility', 'imessage file vulnerability'],
#  ['design', 'failsafe filesystem', 'microcontrollers'],
#  ['ask hn', 'setup', 'ad blocking', 'tracker blocking'],
#  ['rabbit', 'technical expertise'],
#  ['show hn', 'crm system', 'sale fun'],
#  ['syslog complete system administrator guide'],
#  ['sudden trip'],
#  ['doe', 'life', 'amino acid'],
#  ['toshiba', 'new tiny nvme ssd form factor'],
#  ['john carmack', 'parallel implementation'],
#  ['gnu radio'],
#  [],
#  ['github registry public beta'],
#  ['practical guide', 'transition', 'animation'],
#  ['u farmer stung', 'tariff', 'corn loss'],
#  ['facebook', 'apple', 'messaging feature'],
#  ['privacy sandbox open standard', 'privacy', 'web'],
#  ['transformer', 'scratch'],
#  [],
#  ['memory management', 'python'],
#  ['die', 'battery'],
#  ['ebay shopify', 'amazon'],
#  ['video card'],
#  ['pastel', 'commandline tool', 'analyze convert', 'manipulate color'],
#  ['mini map', 'website'],
#  ['svgs'],
#  ['launch', 'twofactor security key'],
#  ['bloomberg reporter', 'account', 'name', 'credit rating'],
#  ['opioid crisis johnson', 'johnson', 'landmark ruling'],
#  ['big pharma', 'drug price high critic'],
#  ['tokyo audiophile venue'],
#  ['japan', 'foreign holder', 'u treasury'],
#  ['statement', 'purpose', 'corporation'],
#  ['http'],
#  ['doesnt mathematics', 'mistake', 'proof'],
#  ['hacker', 'exploit', 'target mailroom'],
#  ['major book publisher sue amazon', 'new speechtotext feature'],
#  ['sonos ikea symfonisk', 'high quality speaker amp'],
#  ['kubernetes security assessment pdf'],
#  ['culture fit', 'way street'],
#  ['dead person'],
#  ['google search', 'certain query'],
#  ['module mirror', 'checksum database'],
#  ['high level', 'oestrogen', 'womb'],
#  ['dark'],
#  ['fungus', 'cavendish banana ha', 'latin america'],
#  ['metal shard', 'rome', 'people'],
#  ['cent mcu', 'short survey', 'microcontrollers'],
#  ['order', 'json'],
#  ['effect seattle', 'use', 'hard drug'],
#  ['faa ban', 'apple laptop', 'flight'],
#  ['new architecture', 'realtime internet video'],
#  ['walmart sue tesla', 'fire', 'store', 'solar panel'],
#  ['danish bank launch negative interest rate mortgage'],
#  ['opensource firmware'],
#  ['technical vision', 'qt'],
#  ['show', 'community browser', 'hacker news reddit youtube'],
#  ['dream', 'ultimate'],
#  ['primer', 'bézier curve'],
#  ['bontrager wavecel material', 'concussion', 'mips'],
#  ['death', 'social reciprocity', 'era', 'digital distraction'],
#  ['amazon', 'thirdparty sellers product pricing'],
#  ['partiql', 'query language', 'data'],
#  ['bug', 'hadnt'],
#  ['mobile phone', 'freedom video'],
#  ['cloud', 'git repos'],
#  ['home lab server', 'core', 'thread', 'gb memory'],
#  ['gcc null pointer check'],
#  ['u', 'wind farm', 'fossil fuel'],
#  ['wiringpi'],
#  ['credit card', 'privacy problem'],
#  ['starbucks monetary superpower'],
#  ['building age', 'netherlands'],
#  ['huawei seek independence', 'u', 'riscv', 'chip'],
#  ['time ai cause uproar', 'conference'],
#  ['hypersane'],
#  ['clojure'],
#  ['cybersecurity', 'price', 'hacker attack swell'],
#  ['gcp', 'additional charge', 'vm instance'],
#  ['youtube', 'music companies', 'manual copyright claim'],
#  ['poetry dependency management', 'python'],
#  ['protocol', 'technological approach', 'speech'],
#  ['ruby', 'rust'],
#  ['apollo guidance computer', 'power supply work', 'year'],
#  ['programming pattern'],
#  ['denial', 'h1b visa', 'service exporter'],
#  ['show', 'documentation website', 'python'],
#  ['show', 'reddit google trend twitter etc', 'trending topic'],
#  ['advice', 'self', 'churn'],
#  ['show', 'free selfupdating website'],
#  ['show', 'lunch money', 'personal budgeting tool', 'multicurrency support'],
#  ['new life', 'life', 'electricity'],
#  ['cerebras system', 'transistor chip', 'ai'],
#  ['software architect', 'system engineering activity'],
#  ['typescript', 'react'],
#  ['bmw unveils car', 'vantablack'],
#  ['peer review', 'gold standard'],
#  ['launch hn sanntek yc s19 breathalyzer', 'cannabis'],
#  ['myth', 'consumergrade security'],
#  ['nvidia ceo', 'google', 'customer', 'silicon', 'scale'],
#  ['racket lisp'],
#  ['le argumentative online'],
#  ['insurance company', 'cop', 'customer'],
#  ['speaker'],
#  ['normality'],
#  ['nasa', 'first allegation', 'crime', 'space'],
#  ['germany', 'first time', 'bond offering negative yield'],
#  ['america'],
#  ['surge', 'drugresistant hiv'],
#  ['levenshtein distance'],
#  ['online encyclopedia', 'pun'],
#  ['iphone', 'cable', 'computer'],
#  ['open startup list'],
#  ['first solar road ha', 'disappointing failure'],
#  ['facial recognition school', 'lead'],
#  ['twitter', 'adtech leak'],
#  ['ha', 'unix virtual memory', 'swap space'],
#  ['elon musk', 'tesla', 'solarcity'],
#  ['new opensource typeface', 'github', 'mozilla'],
#  ['splunk', 'cloud monitoring service signalfx'],
#  ['swap swap swap', 'bad place'],
#  ['interview', 'programming language creator', 'pdf'],
#  ['activision blizzard', 'dollar', 'profit', 'tax'],
#  ['dollar', 'loneliness'],
#  ['seashell pipe output', 'commandline program', 'web', 'real time'],
#  ['wework ipo show', 'magical unicorn'],
#  ['experimental usaf space plane break record', 'orbital spaceflight'],
#  ['devops consultant'],
#  ['container safer'],
#  ['erlang rationale'],
#  ['apple suspends', 'response grading', 'response', 'privacy concern'],
#  ['tragedy', 'ucs2'],
#  ['crispr', 'university', 'california researcher'],
#  ['one', 'thing', 'midwest town', 'town'],
#  ['good conversation'],
#  ['adobe flash player', 'rust'],
#  ['hedonometer'],
#  ['github support web authentication webauthn', 'security key'],
#  ['twelve latex package', 'paper'],
#  ['manager guide', 'kubernetes adoption'],
#  ['typed property', 'php'],
#  ['readable specification', 'tl'],
#  ['wireless service crook'],
#  ['google location dragnet', 'wisconsin bank robbery'],
#  ['thing', 'gnu readline'],
#  ['mortgage market', 'borrower'],
#  ['sign', 'disruption', 'urban habitat'],
#  ['acute effect',
#   'electronic cigarette aerosol inhalation',
#   'vascular function'],
#  ['data confirms', 'month'],
#  ['javascript', 'modern part'],
#  ['google', 'developer', 'new android apps', 'day', 'approval'],
#  ['rust gui ecosystem overview'],
#  ['doe esperanto sound'],
#  ['command', 'conquer tiberian sun', 'computer', 'day video'],
#  ['difference', 'machine learning'],
#  ['dropbox', 'symlinks', 'dropbox account'],
#  ['climate change', 'c hotter'],
#  ['unison file synchronizer'],
#  ['michael cicconetti'],
#  ['gpt2'],
#  ['practical tip', 'tech resume'],
#  ['natural language', 'age', 'transformer'],
#  ['portuguese bank note crisis'],
#  ['california farmer', 'solar panel', 'water supply'],
#  ['youtube', 'children privacy violation'],
#  ['microsoft', 'epub support', 'edge classic'],
#  ['ask hn configuration management', 'personal computer'],
#  ['intel', 'future', 'system', 'video'],
#  ['docker container', 'host'],
#  ['wireless carrier throttling', 'online video', 'pervasive study'],
#  ['black hole destroy information', 'problem'],
#  ['waypipe gsoc project'],
#  ['launch hn quirk yc s19 opensource cognitive behavioral therapy'],
#  ['boeings', 'expose systemic failing'],
#  ['goldman sachs', 'millisecond', 'stock trade'],
#  ['bad time', 'tech', 'startup', 'startup'],
#  ['pascal apps', 'divisionbyzero', 'faster system'],
#  ['show', 'storytime create story', 'code', 'documentation'],
#  ['science fiction magazine', 'available online'],
#  ['container', 'nix'],
#  ['internet service provider', 'sonic ha'],
#  [],
#  ['ondisk format robustness requirement', 'new filesystems'],
#  ['julia'],
#  ['ethic', 'web performance'],
#  ['tesla roadster', 'serious work'],
#  ['oracle director', 'blessing', 'shareholder lawsuit', 'larry ellison'],
#  ['lf', 'keyvalue store'],
#  ['quarter', 'humanity face', 'water crisis'],
#  ['pacvim pacvim', 'game'],
#  ['doe infrastructure cost'],
#  ['law', 'pdf'],
#  ['possible detection', 'black hole', 'mass'],
#  ['launch hn dex yc', 'personal crm', 'touch'],
#  ['buddhist monk confronts', 'suicide culture'],
#  ['threecueing system', 'reading'],
#  ['home', 'metal printing', 'result'],
#  ['são paulo', 'advertising ban'],
#  ['google', 'cameras visual indicator light'],
#  ['reasoning', 'replication crisis'],
#  ['sugar opensource software', 'platform', 'child'],
#  ['open location code', 'open source standard', 'address'],
#  ['debt', 'credit card customer'],
#  ['computer science'],
#  ['json', 'minefield'],
#  ['easter egg'],
#  ['interviewer skill ladder', 'high growth company'],
#  ['show hn', 'online playground', 'tailwind cs'],
#  ['decentralization'],
#  ['amazon cloud backup', 'sensitive data'],
#  ['maine dam', 'year', 'everything'],
#  ['nonplanar'],
#  ['roman', 'mathematics'],
#  ['bulk data structure c'],
#  ['weight agnostic neural network'],
#  ['diamond'],
#  ['big notation', 'math', 'code efficiency'],
#  ['cisco', 'hardware'],
#  ['shrinkflation', 'havoc', 'economists'],
#  ['rotten apple right', 'roundup'],
#  ['tumblr'],
#  ['doordash', 'caviar', 'square'],
#  ['daniel radcliffe', 'art', 'factcheck'],
#  ['svalbard', 'close', 'place', 'open border'],
#  ['dyson tree'],
#  ['name', 'domain resellers', 'year'],
#  ['fbi tell lawmaker', 'cant access dayton gunman phone'],
#  ['child', 'thailand tribe', 'clarity', 'wave'],
#  ['franky zapata', 'frenchman cross english channel'],
#  ['dignity'],
#  ['teen hacker', 'bug', 'school software', 'record'],
#  ['pissedoff tutorial', 'google wave', 'video'],
#  ['pay cut', 'meaningful job'],
#  ['buyback', 'red hat'],
#  ['parallelism', 'postgresql'],
#  ['tech backlash'],
#  ['google', 'search engine auction'],
#  ['peloton s1'],
#  ['mock work'],
#  ['pattern', 'automated license plate reader'],
#  ['show', 'latex typesetting game'],
#  ['memory', 'application', 'time'],
#  ['fire', 'angola congo', 'amazon'],
#  ['telegram introduces feature', 'user', 'group'],
#  [],
#  ['great impostor'],
#  ['seattle microtransit experiment drive people', 'light rail'],
#  ['basic electron framework exploitation'],
#  ['helsinki central library chosen', 'new public library'],
#  ['spacex smallsat rideshare program'],
#  ['personal website', 'programmer'],
#  ['startup', 'combinator s19 demo day'],
#  ['highlight', 'git'],
#  ['show', 'decade', 'video', 'year'],
#  ['standard j', 'install funding'],
#  ['world coal power plant'],
#  ['kept', 'tube', 'year'],
#  ['lesson', 'scaling problem'],
#  ['p idea faq'],
#  ['show', 'scarf platform', 'developer', 'work'],
#  ['old paris'],
#  ['spacebook agis', 'realtime satellite viewer'],
#  ['path', 'handwriting'],
#  ['chiang realist', 'reality'],
#  ['escape room', 'big business'],
#  ['alcohol belt', 'europe'],
#  ['dependent haskell', 'future'],
#  ['north american versus european distribution system'],
#  ['social share button', 'social site', 'user'],
#  ['nutrient deficiency', 'rice', 'carbon dioxide'],
#  ['body', 'link', 'truly intelligent machine'],
#  ['electric motor design claim remarkable improvement'],
#  ['land', 'linux'],
#  ['son', 'mine', 'benthamite'],
#  ['validation certificate'],
#  ['mobility trap', 'congestion', 'traffic'],
#  ['static type checking', 'common lisp'],
#  ['interslavic language'],
#  ['startup', 'combinator s19 demo day'],
#  ['notqmail'],
#  ['french love'],
#  ['theory', 'error backpropagation', 'brain'],
#  ['black beekeeper', 'detroit vacant lot', 'bee farm'],
#  ['gpt2', 'followup'],
#  ['crossword panic'],
#  ['libspng c', 'reading', 'png file'],
#  ['kegans theory', 'evolution', 'consciousness'],
#  ['hospital checklist', 'life'],
#  ['simple sat solver', 'python'],
#  ['deep dive', 'linux namespaces part'],
#  ['chemist', 'firstever ring', 'pure carbon'],
#  ['datacenter location', '19th century politics'],
#  ['uber', 'softbank count ipo return'],
#  ['bacteria', 'selfhealing cement'],
#  ['group chat'],
#  ['mathematics', 'matplotlib', 'python'],
#  ['moravecs paradox'],
#  ['motion', 'robotic character'],
#  ['website builder webflow yc', 'bankruptcy', 'series'],
#  ['swiss post suspends', 'delivery service', 'second crash'],
#  ['doityourself openjdk garbage collector'],
#  ['patagonia philosopher king'],
#  ['j', 'apl'],
#  ['julias release process'],
#  ['math', 'data science'],
#  ['distributed system reliability'],
#  ['dont forget randomness', 'hypothesis'],
#  ['history', 'broken vertical bar', 'form'],
#  ['show hn', 'google', 'hacker news'],
#  ['tv detector van'],
#  ['brother', 'alphabet', 'native language fulfulde'],
#  ['orphans', 'electric car'],
#  ['biotech startup funding', 'year'],
#  ['ignition', 'informal history', 'liquid rocket propellant', 'pdf'],
#  ['winedark sea'],
#  ['year sel4'],
#  ['startup video'],
#  ['contagious cancer', 'dog'],
#  ['ceramic enter', 'new era', 'laserwelded joint'],
#  ['shady world', 'repair manual copyrighting', 'obsolescence'],
#  ['open source hardware', 'aid part'],
#  ['last working olivetti', 'sits', 'tuscan high school'],
#  ['beginning', 'command line', 'pdf'],
#  ['manufacturer', 'china', 'vietnam'],
#  ['microsoft ha', 'major impact', 'chrome'],
#  ['glass', 'mold'],
#  ['def con', 'stack', 'traffic', 'cybersecurity'],
#  ['geocities'],
#  ['le data'],
#  ['math', 'general relativity'],
#  ['rule'],
#  ['exosuit', 'endurance', 'trail'],
#  ['subsurface', 'open source scuba dive logging platform'],
#  ['stock', 'random study'],
#  ['goal', 'reward', 'brain map', 'world'],
#  ['fbi delivery driver', 'amazon theft ring'],
#  ['raspberry pi camera'],
#  ['everything'],
#  ['columnist', 'cell number'],
#  ['commercial path', 'fusion'],
#  ['stockx wa', 'customers data'],
#  ['waymo backseat driver confidential data reveals', 'taxi hurdle'],
#  ['moviepass', 'password', 'user', 'film'],
#  ['bicycle', 'mind'],
#  [],
#  ['tiny toy totp generator', 'line', 'python'],
#  ['miss'],
#  ['supercomputer', 'map', 'world'],
#  ['company'],
#  ['cpan release'],
#  ['capital', 'cyber staff', 'concern', 'hack'],
#  ['trigger', 'kernel panic', 'unresponsive ec2 instance'],
#  ['launch hn compound yc s19', 'employee understand equity compensation'],
#  ['push notification', 'hour'],
#  ['monad'],
#  ['fuzzable code'],
#  ['software company', 'user behavior'],
#  ['afternoon', 'tokyo', 'man', 'casio gshock watch'],
#  ['facebook ad', 'u presidential candidate'],
#  ['kip500', 'zookeeper', 'metadata quorum'],
#  ['side channel', 'data', 'intel cpu', 'silent window update'],
#  ['chemist discover water microdroplets', 'hydrogen peroxide'],
#  ['web'],
#  ['free software network service', 'web application'],
#  ['phytoplankton population drop', 'percent'],
#  ['root cerns scientific data analysis framework', 'c'],
#  ['subversive message', 'wizard', 'oz'],
#  ['flaw', 'cellphone evidence prompt review', 'verdict', 'denmark'],
#  ['economist raj chetty ha', 'surprising tool', 'housing segregation'],
#  ['static analysis', 'scale', 'instagram story'],
#  ['camera v lidar'],
#  ['digital advertising market'],
#  ['security flaw', 'compiler optimization'],
#  ['web content', 'power usage'],
#  ['music recommendation', 'hyperbolic space'],
#  ['deep dive', 'amd rome epyc architecture'],
#  ['riscv processor', 'carbon nanotube'],
#  ['show hn real world jupyter notebook', 'way', 'data scientist'],
#  ['launch hn memfault yc w19 crashlytics', 'firmware'],
#  ['person ha', 'vapingrelated condition'],
#  ['linux pressure stall information psi', 'example'],
#  ['lisp interpreter', 'python'],
#  ['processor design', 'introduction'],
#  ['adventure', 'prolog'],
#  ['show', 'functional scripting'],
#  ['clever functional design'],
#  ['google begin', 'domain leasing'],
#  ['programming language', 'interpreting'],
#  ['sentient', 'artificial brain', 'u intelligence'],
#  ['live avatar', 'faceapijs'],
#  ['india messy electric vehicle revolution'],
#  ['launch hn', 'yc s19 internationalization', 'devs'],
#  ['big tech', 'pile', 'privacy gadget'],
#  ['pokemonsay pokemon version', 'cowsay'],
#  ['cowrie', 'mediuminteraction ssh', 'telnet honeypot'],
#  ['energy storage investment boom', 'battery cost halve', 'next decade'],
#  ['effortless elixir release', 'deployment'],
#  ['category', 'seed startup', 'arent'],
#  ['solar power', 'salt', 'water'],
#  ['proof assistant'],
#  ['dark matter'],
#  ['day vulnerability', 'vxworks'],
#  ['huntington park robocop store pedestrians', 'scan license plate'],
#  ['cern open data portal', 'pb', 'open data', 'particle physic'],
#  ['lisp'],
#  [],
#  ['hurricane forecast'],
#  ['scale yc s16', 'accel', 'founder fund', 'valuation'],
#  ['algorithm', 'lisp data structure'],
#  ['pentagon contract fight amazon ha foe', 'high place'],
#  ['rome', 'fulcrum', 'amd datacenter pivot'],
#  ['money'],
#  ['phone company', 'deal', 'state', 'dc', 'robocalls'],
#  ['tensor', 'clojure', 'sneak peek'],
#  ['great truth'],
#  ['filekit', 'open source endtoend', 'cloud storage service', 'javascript'],
#  ['rent', 'exchange', 'monthly amazon purchasing quota'],
#  ['clojure library', 'par text', 'data'],
#  ['mitre system engineering guide', 'pdf'],
#  ['texas power price briefly', 'heat'],
#  ['amazon plan', 'world', 'publishing'],
#  ['toptal sue cofounder breanden beneschott', 'fraud'],
#  ['amelia earhart plane', 'startling clue'],
#  ['year', 'historic neptune flyby'],
#  ['mesapy', 'memorysafe python implementation', 'pypy'],
#  ['trail', 'wind data visualization', 'architecture', 'airport runway'],
#  ['show', 'shapeform schema', 'form', 'react'],
#  ['network effect', 'look', 'network effect'],
#  ['germany turn', 'quest', 'clean energy economy'],
#  ['software'],
#  ['u army', 'many fossil'],
#  ['dna', 'deep learning'],
#  ['pentagon', 'code word', 'secret project nickname'],
#  ['simulated enigma machine'],
#  ['artificial pancreas'],
#  ['machine', 'arduino'],
#  ['unshaky try', 'double key press issue', 'apple butterfly keyboard'],
#  ['zrna', 'analog circuit'],
#  ['simple rpc framework', 'line', 'go'],
#  ['codebase', 'organism'],
#  ['perfect language'],
#  ['people', 'millennium', 'skeleton lake', 'himalaya'],
#  ['tridactyl installation', 'firefox', 'aug'],
#  ['remains', 'ancient temple', 'sunken egyptian city'],
#  ['opensource tool', 'analog'],
#  ['api gateway identity crisis', 'service mesh'],
#  ['online subscription business', 'malaysia'],
#  ['lifehacker tarek loubani', 'gaza'],
#  ['brain', 'story'],
#  ['pal video', 'sdr', 'dead end'],
#  ['differential equation', 'point code'],
#  ['computer stupidity'],
#  ['look', 'bloomberg keyboard'],
#  ['jupiter riscv assembler', 'runtime simulator'],
#  ['hour', 'buckminster fuller', 'vision'],
#  ['project', 'modular uefi environment', 'modern device'],
#  ['high price'],
#  ['curve', 'linear least square'],
#  ['handler belief affect scent detection'],
#  ['sipeed longan nano riscv development board'],
#  ['difference', 'isolation level', 'consistency level'],
#  ['map', 'milky way show', 'shape'],
#  ['map design', 'guide', 'map', 'pdf'],
#  ['silver bullet', 'pdf'],
#  ['commander', 'wwii tank commander roguelike'],
#  ['brain'],
#  ['softbank plan', 'ceo', 'employee', 'volatile market'],
#  ['hp way', 'bill hewlett', 'company'],
#  ['pyramid'],
#  ['consistent result', 'benchmarking', 'linux'],
#  ['iris scanner', 'eye'],
#  ['vacuum tube computer'],
#  ['portugal marmelada taste nothing', 'marmalade'],
#  ['spacy pytorch transformer'],
#  ['real world location', 'minute video'],
#  ['show', 'distributed pgp keyserver', 'dat protocol'],
#  ['karel čapeks'],
#  ['apple card restriction', 'jailbreaking', 'cryptocurrency purchase'],
#  ['grand c error explosion competition'],
#  ['turkmenistan', 'brink', 'collapse'],
#  ['profile', 'geoffrey hinton'],
#  ['scientist reverse', 'process', 'rat brain stem cell'],
#  ['show', 'discord terminal client', 'go'],
#  ['year', 'telephone tower', 'stockholm', 'phone line'],
#  ['japanese architect', 'building', 'living organism'],
#  ['recent paper'],
#  ['jcore open processor'],
#  ['presidio customizable data protection', 'pii data anonymization service'],
#  ['survival', 'iggy pop'],
#  ['bpf', 'firewall', 'systemd service'],
#  ['marree man'],
#  ['dday', 'cost', 'life'],
#  ['ray'],
#  ['show', 'simple game', 'kid'],
#  ['everyone hate customer service'],
#  [],
#  ['qualpwn', 'qualcomm wlan', 'modem', 'air'],
#  ['study identifies main culprit', 'lithium metal battery failure'],
#  ['friend'],
#  ['youtube lgbtq problem', 'businessmodel problem'],
#  ['suburb', 'sky', 'jakartans', 'entire village', 'top', 'mall'],
#  ['china', 'financial system', 'iou'],
#  ['death', 'alexander', 'history great unsolved mystery'],
#  ['microworkers', 'digital life'],
#  ['keyringless gnupg'],
#  ['perfect french baguette'],
#  ['wind turbine', 'breeze'],
#  ['iron age celtic woman', 'hollowedout tree trunk'],
#  ['mistake firsttime founder', 'video'],
#  ['max software', 'computer'],
#  ['empty train', 'modern silk road', 'belt', 'road interest align'],
#  ['wavelet', 'pdf'],
#  ['maya sacrifice'],
#  ['guide', 'magnetorquers', 'satellite'],
#  ['future'],
#  ['nec show', 'car', 'minute'],
#  ['quantum radar ha', 'first time'],
#  ['ear speaker research design', 'evolution'],
#  ['wasm v pnacl performance benchmark'],
#  ['lindenmayer system'],
#  ['show', 'repository', 'open source', 'software', 'hardware'],
#  ['paper'],
#  ['darpa', 'help', 'election security problem'],
#  ['fed', 'realtime payment business'],
#  ['woman', 'yellow diamond', 'youtube video', 'diamond'],
#  ['amazon', 'plug', 'dash button'],
#  ['problem solving', 'clojure'],
#  ['new book', 'rich country', 'environmental impact'],
#  ['animal movie promote', 'researcher'],
#  ['hyundai', 'explodes'],
#  ['league', 'entropy'],
#  ['transparent display', 'perpixel color', 'opacity control'],
#  ['terrascope', 'possibility', 'earth', 'atmospheric lens'],
#  ['earth'],
#  ['fuzzification', 'technique pdf'],
#  ['storage', 'zoned storage initiative'],
#  ['webmin'],
#  ['static analysis', 'facebook'],
#  ['death', 'weather satellite', 'sdr'],
#  ['holiday', 'worker', 'company'],
#  ['soviet union master spy'],
#  ['stanford prison experiment pdf'],
#  ['marium', 'dugong', 'thailand dy', 'plastic'],
#  ['simple python package', 'deep learning feature'],
#  ['massive ocean', 'towards', 'core'],
#  ['def con', 'ctf retrospective'],
#  ['kdevops framework', 'linux kernel', 'project'],
#  ['simple pure', 'total functional language', 'datalog'],
#  ['transparent polygon'],
#  ['social medium', 'polarization'],
#  ['glacial melt', 'bridge', 'greenland'],
#  ['new treasure', 'pompeii'],
#  ['sec', 'data leak', 'first american financial corp'],
#  ['openbsd ada library'],
#  ['dont'],
#  ['u air force pause flight', 'hundred c130s', 'atypical cracking'],
#  ['horse', 'land', 'booleans'],
#  ['helium'],
#  ['launch hn shift health yc s19', 'healthcare cost previsit'],
#  ['smartykit apple'],
#  ['metadialect', 'scheme'],
#  ['hawaii', 'thirty meter telescope permit', 'protest'],
#  ['gm', 'detroit', 'employer'],
#  ['dipole drive', 'new concept', 'space propulsion'],
#  ['microscope'],
#  ['data privacy issue google', 'android phone data', 'carrier'],
#  ['robotic thread', 'brain blood vessel'],
#  ['vickrey clarke groves auction'],
#  ['prolog control', 'slide'],
#  ['opinion piece', 'ghc', 'end'],
#  ['federated package registry', 'anything'],
#  ['cbor concise binary object representation'],
#  ['technology', 'pdf'],
#  ['cassette', 'music'],
#  ['paul', 'mozart', 'science'],
#  ['praise', 'xlogo'],
#  ['show', 'historical order book reconstruction api', 'crypto market'],
#  ['arc', 'seniority'],
#  ['long game', 'research'],
#  ['look', 'hs2 old oak common station'],
#  ['judy array work'],
#  ['bitcoin', 'apple ii'],
#  ['masterpiece', 'rare minoan sealstone'],
#  ['golden ratio'],
#  ['show', 'json output'],
#  ['hp'],
#  ['ssb room', 'new server type', 'scuttlebutt'],
#  ['poincaré embeddings'],
#  ['ocaml program', 'lua'],
#  ['container', 'vxlan bgp', 'wireguard'],
#  ['fine map', 'alexander von humboldt'],
#  ['new research', 'ptsd', 'elephant', 'animal'],
#  ['awakenings', 'advanced dementia patient hint', 'untapped brain reserve'],
#  ['recycling', 'plastic', 'dynamic covalent diketoenamine bond', 'pdf'],
#  ['show', 'dataviz project', 'moon model'],
#  ['new realtime detection', 'fast radio burst', 'utmost'],
#  ['lucidscience electronic project'],
#  [],
#  ['conversation', 'team', 'bread', 'ancient egyptian yeast'],
#  ['air force', 'test', 'scramjet', 'n grumman'],
#  ['decline', 'college newspaper'],
#  ['john le carré novel'],
#  ['sleep dreem oura', 'rest'],
#  ['penn effect'],
#  ['hall law', 'nineteenth century prequel', 'law'],
#  ['volcano', 'moon', 'dinosaur age'],
#  ['world', 'chimp ha'],
#  ['smart plastic incineration', 'solution', 'global recycling crisis'],
#  ['expressive dependent language'],
#  ['freshermeat opensource security software'],
#  ['engineer build', 'microprocessor', 'carbon nanotube'],
#  ['new york farm', 'success', 'eye', 'next big thing'],
#  ['disneyland', 'day'],
#  ['zmachine', 'ocaml'],
#  ['quantum air', 'electric airplane'],
#  ['famous graphic chip microsoft talisman'],
#  ['engineer', 'metal foam', 'room temperature'],
#  ['golden research engine', 'combinator s19 batch'],
#  ['mosque rebuilt', 'year'],
#  ['miniature horse'],
#  ['oral history', 'super soaker'],
#  ['trailblazing plan', 'california wildfire'],
#  ['show', 'orm', 'firestore'],
#  ['shape', 'tessellation'],
#  ['mountain', 'silver', 'first global city'],
#  ['ancient egypttoblack sea route adventurer', 'theory'],
#  ['visible spectrum', 'python'],
#  ['pdf'],
#  ['wall street', 'cost', 'cloud infrastructure'],
#  ['rule', 'ancient board game'],
#  ['road'],
#  ['software art'],
#  ['webworkers async iterables'],
#  ['show hn quarkide', 'javascript runtime', 'crossplatform desktop apps'],
#  ['environment', 'programming language', 'part'],
#  ['dove press typeface'],
#  ['early year', 'computer', 'steve russell', 'nolan bushnell', 'video'],
#  ['earth space junk problem'],
#  ['swadesh list'],
#  ['salvator mundi', 'unreality', 'art market']]

# %%
#To determine phrase sentiment values we'll use the “Valence Aware Dictionary and sEntiment Reasoner” - a.k.a VADER.
import nltk
nltk.download('vader_lexicon')

def DetermineWordsSentiment(x):
    from nltk.sentiment.vader import SentimentIntensityAnalyzer
    analyzer = SentimentIntensityAnalyzer() 
    senti_list_temp = []    
    for i in x:
        y = ''.join(i) 
        vs = analyzer.polarity_scores(y)
        senti_list_temp.append((y, vs))
        senti_list_temp = [w for w in senti_list_temp if w]    
    sentiment_list  = []
    for j in senti_list_temp:
        first = j[0]
        second = j[1]
        for (k,v) in second.items():
            if k == 'compound':
                if v < 0.0:
                    sentiment_list.append((first, "Negative"))
                elif v == 0.0:
                    sentiment_list.append((first, "Neutral"))
                else:
                    sentiment_list.append((first, "Positive"))     
    return sentiment_list

sentimentRDD = link_titles_phrases.map(DetermineWordsSentiment)

sentimentRDD.collect()
# Out:
# [nltk_data] Error loading vader_lexicon: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [[('macbook', 'Neutral'), ('touchscreen', 'Neutral'), ('hardware', 'Neutral')],
#  [('lonely work', 'Negative'), ('hacker news', 'Neutral')],
#  [('nushell', 'Neutral')],
#  [('google', 'Neutral'), ('opensource android app', 'Neutral')],
#  [('ebola', 'Neutral')],
#  [('engineering advice stole', 'Neutral'), ('nontechnical people', 'Neutral')],
#  [('encarta', 'Neutral')],
#  [('alan', 'Neutral'), ('forgotten book programmer', 'Negative')],
#  [('information operation', 'Neutral'), ('hong kong', 'Neutral')],
#  [('service', 'Neutral')],
#  [('google chrome', 'Neutral'), ('first time', 'Neutral')],
#  [('good software', 'Positive')],
#  [('null license plate', 'Neutral'), ('bright idea', 'Positive')],
#  [('coder', 'Neutral'), ('type', 'Neutral')],
#  [('yelp', 'Neutral'),
#   ('restaurants phone number', 'Positive'),
#   ('cut', 'Negative')],
#  [('japanese anime studio khara', 'Neutral')],
#  [('google excuse', 'Positive'), ('protection', 'Neutral')],
#  [('cloudflare s1', 'Neutral')],
#  [('go', 'Neutral'), ('hardware provider discontinues service', 'Neutral')],
#  [('r support', 'Positive'), ('site', 'Neutral')],
#  [('cheap shipping', 'Neutral'), ('chinese seller', 'Neutral')],
#  [('python', 'Neutral'), ('world', 'Neutral')],
#  [('verizon', 'Neutral'), ('tumblr', 'Neutral')],
#  [('tasty seaweed reduces', 'Neutral'), ('methane emission', 'Neutral')],
#  [('hy', 'Neutral')],
#  [('thing', 'Neutral'), ('senior software engineer', 'Neutral')],
#  [('wewtf', 'Neutral')],
#  [('linux journal cease publication', 'Neutral'),
#   ('awkward goodbye', 'Negative')],
#  [('amd land google twitter', 'Neutral'),
#   ('customer', 'Neutral'),
#   ('newest server chip', 'Neutral')],
#  [('u navy', 'Neutral'),
#   ('mechanical control', 'Neutral'),
#   ('destroyer', 'Negative')],
#  [('standard ebooks free publicdomain ebooks', 'Positive')],
#  [('modern web development', 'Neutral')],
#  [('man', 'Neutral'), ('multimillion dollar company', 'Neutral')],
#  [('opendrop', 'Neutral'), ('open source airdrop implementation', 'Neutral')],
#  [('deep dive', 'Neutral'),
#   ('io exploit chain', 'Negative'),
#   ('wild', 'Neutral')],
#  [('software architecture guide', 'Neutral')],
#  [('site', 'Neutral'),
#   ('facebook', 'Neutral'),
#   ('button liable', 'Neutral'),
#   ('data eu court rule', 'Neutral')],
#  [('insect apocalypse', 'Neutral'),
#   ('increase', 'Positive'),
#   ('toxic pesticide study', 'Neutral')],
#  [('apple', 'Neutral'),
#   ('reward', 'Positive'),
#   ('anyone', 'Neutral'),
#   ('iphone', 'Neutral')],
#  [('game look', 'Neutral'), ('crap', 'Negative')],
#  [('tech interview handbook', 'Neutral')],
#  [('half', 'Neutral'), ('google search', 'Neutral'), ('click', 'Neutral')],
#  [('congressional district', 'Neutral')],
#  [('ha examinecom', 'Positive'), ('search result', 'Neutral')],
#  [('walk', 'Neutral'), ('hong kong', 'Neutral')],
#  [('john carmack', 'Neutral'), ('joe rogan experience video', 'Neutral')],
#  [('baseline interpreter', 'Neutral'),
#   ('javascript interpreter', 'Neutral'),
#   ('firefox', 'Neutral')],
#  [('google', 'Neutral'),
#   ('staff', 'Neutral'),
#   ('politics', 'Neutral'),
#   ('work', 'Neutral')],
#  [('text editor', 'Neutral')],
#  [('ive', 'Neutral'),
#   ('research paper', 'Neutral'),
#   ('stock market', 'Neutral')],
#  [],
#  [('plugin system', 'Neutral'), ('web', 'Neutral'), ('night', 'Neutral')],
#  [('europe', 'Neutral'),
#   ('towards', 'Neutral'),
#   ('postcar city', 'Neutral'),
#   ('reality', 'Neutral')],
#  [('new york city neighbor', 'Neutral'), ('way', 'Neutral')],
#  [('github action', 'Neutral'),
#   ('cicd', 'Neutral'),
#   ('public repository', 'Neutral')],
#  [('consume le create', 'Positive')],
#  [('green space', 'Neutral')],
#  [('kerbal space program', 'Neutral')],
#  [('macbook pro keyboard drive', 'Neutral')],
#  [('aws job offer', 'Neutral')],
#  [('facebook ha', 'Positive'), ('patent', 'Neutral'), ('shadow', 'Neutral')],
#  [('linux kernel inability', 'Negative'), ('low memory pressure', 'Negative')],
#  [('show', 'Neutral'),
#   ('cli tool', 'Neutral'),
#   ('web page', 'Neutral'),
#   ('single file', 'Neutral')],
#  [('isp', 'Neutral')],
#  [('productivity', 'Neutral')],
#  [('preindustrial worker', 'Neutral'),
#   ('hour', 'Neutral'),
#   ('today', 'Neutral')],
#  [('milky way black hole', 'Neutral'),
#   ('time', 'Neutral'),
#   ('bright', 'Positive'),
#   ('hour', 'Neutral')],
#  [('amazon ha', 'Positive'), ('thirdparty seller', 'Neutral')],
#  [('rail', 'Neutral')],
#  [('haha wall', 'Positive')],
#  [('third person', 'Neutral')],
#  [('ibm opensources power chip instruction set', 'Neutral')],
#  [('apple', 'Neutral'),
#   ('part access', 'Neutral'),
#   ('independent repair business', 'Neutral')],
#  [('new experimental magazine', 'Neutral')],
#  [('house', 'Neutral'), ('people', 'Neutral'), ('car', 'Neutral')],
#  [('childhood', 'Neutral')],
#  [('decrement carbon stripe negative emission commitment', 'Negative')],
#  [('hackable paperless machine', 'Neutral')],
#  [('home chip fab', 'Positive')],
#  [('google', 'Neutral'),
#   ('mozilla', 'Neutral'),
#   ('extension developer', 'Neutral')],
#  [('mathematician way', 'Neutral'), ('mile', 'Neutral')],
#  [('recaptcha', 'Neutral')],
#  [('kaspersky av', 'Neutral'),
#   ('unique id', 'Neutral'),
#   ('site', 'Neutral'),
#   ('user', 'Neutral'),
#   ('incognito mode', 'Neutral')],
#  [('huawei', 'Neutral')],
#  [('horror', 'Negative'), ('microsoft team', 'Neutral')],
#  [('scientist', 'Neutral'), ('new database', 'Neutral')],
#  [('regex', 'Neutral'), ('illustrated guide', 'Neutral')],
#  [('apple', 'Neutral'),
#   ('online web', 'Neutral'),
#   ('security vulnerability', 'Positive')],
#  [('con artist', 'Neutral')],
#  [('death note l anonymity', 'Negative'), ('entropy', 'Neutral')],
#  [('amd rome second generation', 'Neutral')],
#  [('amazon', 'Positive'), ('monopoly', 'Neutral')],
#  [('time anxiety', 'Negative')],
#  [('wtf', 'Negative'),
#   ('personal information dashboard', 'Neutral'),
#   ('terminal', 'Neutral')],
#  [('scientist', 'Neutral'),
#   ('cure', 'Neutral'),
#   ('strain', 'Negative'),
#   ('tuberculosis', 'Neutral')],
#  [('show', 'Neutral'),
#   ('divjoy react codebase', 'Neutral'),
#   ('ui generator', 'Neutral')],
#  [('protein', 'Neutral'), ('cell', 'Neutral'), ('ear', 'Neutral')],
#  [('state', 'Neutral'), ('electoral college obselete', 'Neutral')],
#  [('c standard library function', 'Neutral'), ('git source code', 'Neutral')],
#  [('pronunciation', 'Neutral'), ('hexadecimal number', 'Positive')],
#  [('turbo', 'Neutral'),
#   ('improved rainbow colormap', 'Positive'),
#   ('visualization', 'Neutral')],
#  [('mac', 'Neutral'), ('setup ive grown', 'Neutral')],
#  [('time', 'Neutral'), ('tickborne disease', 'Neutral')],
#  [('pentagon', 'Neutral'),
#   ('mass surveillance balloon', 'Neutral'),
#   ('u', 'Neutral')],
#  [('useless window', 'Negative'), ('feature', 'Neutral')],
#  [('obscure c feature', 'Neutral')],
#  [('mercedesbenz presafe sound', 'Neutral')],
#  [('tsv utility command line tool', 'Neutral'),
#   ('large tabular data file', 'Neutral')],
#  [('psytrance guide', 'Neutral')],
#  [('researcher', 'Neutral'),
#   ('valve bug bounty program publishes second steam', 'Neutral')],
#  [('developer', 'Neutral'),
#   ('google', 'Neutral'),
#   ('agile development', 'Neutral')],
#  [('planet', 'Neutral'), ('entire earth', 'Neutral'), ('day', 'Neutral')],
#  [('software', 'Neutral'), ('car', 'Neutral')],
#  [('dqlite highavailability sqlite', 'Neutral')],
#  [('cutiepi allinone raspberry pi tablet', 'Neutral')],
#  [('knuth', 'Neutral'),
#   ('huangs sensitivity', 'Neutral'),
#   ('proof', 'Neutral'),
#   ('page pdf', 'Neutral')],
#  [('supercentenarians', 'Neutral'),
#   ('region', 'Neutral'),
#   ('birth certificate', 'Neutral')],
#  [('anthony levandowski', 'Neutral'),
#   ('theft', 'Neutral'),
#   ('trade secret', 'Neutral')],
#  [('exfat', 'Neutral'), ('linux kernel', 'Neutral')],
#  [('speed matter', 'Positive')],
#  [('programmer', 'Neutral'), ('plan', 'Neutral')],
#  [('information theory', 'Neutral'),
#   ('intelligent people', 'Positive'),
#   ('pdf', 'Neutral')],
#  [('ultimate go', 'Neutral'),
#   ('good note', 'Positive'),
#   ('source code', 'Neutral')],
#  [('guide', 'Neutral'),
#   ('video', 'Neutral'),
#   ('raspberry pi camera', 'Neutral')],
#  [('super mario', 'Positive'), ('ha', 'Positive')],
#  [('yaml', 'Neutral')],
#  [('rust language cheat sheet', 'Negative')],
#  [('rust bloat', 'Neutral')],
#  [('google chrome incognito mode', 'Neutral')],
#  [('rule', 'Neutral'), ('intuitive ux', 'Neutral')],
#  [('iterm2', 'Neutral')],
#  [('datadog s1', 'Neutral')],
#  [('hidden cost', 'Neutral'),
#   ('code', 'Neutral'),
#   ('io', 'Neutral'),
#   ('android', 'Neutral')],
#  [('show', 'Neutral'), ('chartxkcd', 'Neutral'), ('chart library', 'Neutral')],
#  [('hn', 'Neutral'), ('cohen ha', 'Positive')],
#  [('rabbithole', 'Neutral')],
#  [('kind', 'Positive'), ('good tech debt', 'Positive')],
#  [('facebook scan system library', 'Neutral'),
#   ('android', 'Neutral'),
#   ('server', 'Neutral')],
#  [('uber post', 'Neutral'), ('loss', 'Negative'), ('growth rate', 'Positive')],
#  [('remote attack surface', 'Negative'), ('iphone', 'Neutral')],
#  [('google', 'Neutral'),
#   ('price guarantee', 'Positive'),
#   ('certain flight', 'Positive')],
#  [('npm ban terminal ad', 'Negative')],
#  [('architecture', 'Neutral'), ('open source application', 'Neutral')],
#  [('people', 'Neutral')],
#  [('berlin', 'Neutral'), ('popular shopping street', 'Positive')],
#  [('toni morrison ha', 'Positive')],
#  [('sourcehut welcome bitbucket refugee', 'Positive')],
#  [('ai startup claim', 'Neutral')],
#  [('ask hn', 'Neutral'),
#   ('resource', 'Neutral'),
#   ('linux kernel', 'Neutral'),
#   ('theory', 'Neutral')],
#  [('steam window client local privilege escalation', 'Positive')],
#  [('isp association', 'Neutral'),
#   ('statement', 'Neutral'),
#   ('selective blocking', 'Negative'),
#   ('internet service', 'Neutral')],
#  [('data scientist', 'Neutral'), ('data', 'Neutral')],
#  [('juul philip morris', 'Neutral'),
#   ('racketeer act', 'Neutral'),
#   ('kid', 'Neutral')],
#  [('vmware', 'Neutral')],
#  [('missive amd', 'Neutral'),
#   ('efficiency', 'Positive'),
#   ('intel', 'Neutral')],
#  [('excel', 'Positive'), ('f', 'Neutral')],
#  [('performance matter', 'Positive')],
#  [],
#  [('people', 'Neutral')],
#  [('privacy law', 'Neutral'), ('personal data', 'Neutral')],
#  [('show hn', 'Neutral'),
#   ('deep learning model', 'Neutral'),
#   ('site', 'Neutral')],
#  [('webkit', 'Neutral'), ('prevention policy', 'Neutral')],
#  [('inauthentic behavior', 'Neutral'), ('china', 'Neutral')],
#  [('calculus', 'Neutral'), ('people', 'Neutral')],
#  [('anxiety', 'Negative'), ('men', 'Neutral')],
#  [('yield curve invert', 'Neutral'), ('u uk', 'Neutral')],
#  [('amazon', 'Positive'),
#   ('amazon choice', 'Positive'),
#   ('vendor', 'Neutral'),
#   ('ad', 'Neutral'),
#   ('price', 'Neutral')],
#  [('cyberchef cyber swiss army knife', 'Neutral')],
#  [('rust', 'Neutral')],
#  [('boeing code', 'Neutral'),
#   ('expose security flaw deep', 'Positive'),
#   ('gut', 'Neutral')],
#  [('ask hn', 'Neutral'),
#   ('resource', 'Neutral'),
#   ('math intuition', 'Neutral')],
#  [('mozilla', 'Neutral'),
#   ('action', 'Neutral'),
#   ('user', 'Neutral'),
#   ('kazakhstan', 'Neutral')],
#  [('real time high quality video', 'Neutral')],
#  [('wine', 'Neutral'), ('window', 'Neutral')],
#  [('distributed timeseries', 'Neutral'), ('postgresql', 'Neutral')],
#  [],
#  [('startup theory', 'Neutral'), ('b', 'Neutral')],
#  [('lesson', 'Neutral'), ('stripe', 'Neutral')],
#  [('show hn', 'Neutral'),
#   ('nonlineofsight computational imaging', 'Neutral'),
#   ('julia', 'Neutral')],
#  [('time', 'Neutral'), ('idea', 'Neutral')],
#  [('circuit', 'Neutral'),
#   ('user', 'Neutral'),
#   ('facebook', 'Neutral'),
#   ('unlawful use', 'Neutral'),
#   ('facial recognition', 'Neutral')],
#  [('linux kernel driver', 'Neutral'),
#   ('rust', 'Neutral'),
#   ('option', 'Neutral'),
#   ('future', 'Neutral')],
#  [('moviepass', 'Neutral')],
#  [('beginner introduction', 'Neutral'), ('web framework', 'Neutral')],
#  [('ask hn', 'Neutral')],
#  [('show', 'Neutral'),
#   ('data structure', 'Neutral'),
#   ('algorithm', 'Neutral'),
#   ('javascript', 'Neutral')],
#  [('await', 'Positive'), ('rust', 'Neutral')],
#  [('cool', 'Positive'), ('obscure x11 tool', 'Neutral')],
#  [('elsevier', 'Neutral'), ('others', 'Neutral')],
#  [('group sex', 'Neutral'),
#   ('leak location pic', 'Negative'),
#   ('personal detail', 'Neutral')],
#  [('apple', 'Neutral'), ('battery', 'Neutral'), ('repair', 'Neutral')],
#  [('floppy driver', 'Neutral')],
#  [('north america', 'Neutral'), ('methane spike study', 'Neutral')],
#  [('algorithm', 'Neutral'), ('students', 'Neutral')],
#  [],
#  [('currency manipulator', 'Neutral')],
#  [('mercurial support', 'Positive'), ('bitbucket', 'Neutral')],
#  [('open letter', 'Neutral'),
#   ('android developer', 'Neutral'),
#   ('google play team', 'Positive')],
#  [('cue', 'Neutral'),
#   ('language', 'Neutral'),
#   ('generating', 'Neutral'),
#   ('validating data', 'Positive')],
#  [('asyncawait', 'Neutral')],
#  [('city', 'Neutral'), ('school bus', 'Neutral'), ('algorithm', 'Neutral')],
#  [('async port', 'Neutral'), ('rust standard library', 'Neutral')],
#  [('regexr', 'Neutral')],
#  [('art', 'Neutral'), ('warez video', 'Neutral')],
#  [('work', 'Neutral'), ('brag document', 'Neutral')],
#  [('job many role', 'Neutral'),
#   ('different skill', 'Neutral'),
#   ('successful cto', 'Positive')],
#  [('productivity', 'Neutral'), ('workweek', 'Neutral')],
#  [('nigerian teen', 'Neutral'), ('slick visual effect', 'Neutral')],
#  [('character', 'Neutral'), ('coverage', 'Neutral'), ('wild', 'Neutral')],
#  [('mozilla code base', 'Neutral')],
#  [('lost art', 'Negative'), ('cable', 'Neutral')],
#  [('martini realtime terrain mesh generator', 'Neutral')],
#  [('impact', 'Neutral'), ('day', 'Neutral')],
#  [('software', 'Neutral'), ('world', 'Neutral'), ('everything', 'Neutral')],
#  [('ibm ha', 'Positive'),
#   ('power architecture instruction', 'Neutral'),
#   ('linux foundation', 'Neutral')],
#  [('plastic whats', 'Neutral'), ('trash', 'Neutral')],
#  [('freeze engineering hire', 'Positive')],
#  [('irs budget cut cost', 'Negative'),
#   ('revenue', 'Neutral'),
#   ('big business', 'Neutral')],
#  [('calculus', 'Neutral')],
#  [('noise', 'Neutral')],
#  [('att employee', 'Neutral'),
#   ('phone', 'Neutral'),
#   ('malware', 'Neutral'),
#   ('company network', 'Neutral')],
#  [('problem', 'Negative'), ('yale', 'Neutral'), ('free speech', 'Positive')],
#  [('silk', 'Neutral')],
#  [('meat', 'Neutral'),
#   ('partner', 'Neutral'),
#   ('plantbased chicken', 'Neutral')],
#  [('company', 'Neutral')],
#  [('flow faster', 'Neutral')],
#  [('paxos algorithm', 'Neutral'), ('turing award', 'Positive')],
#  [('attorney general barr', 'Neutral'), ('encryption', 'Neutral')],
#  [('jmap', 'Neutral')],
#  [('ffmpeg', 'Neutral')],
#  [('interface type interoperate', 'Neutral'), ('thing', 'Neutral')],
#  [('roblox', 'Neutral'),
#   ('monthly active user', 'Positive'),
#   ('minecraft', 'Neutral')],
#  [('word', 'Neutral')],
#  [('men', 'Neutral'), ('body change', 'Neutral')],
#  [('jira instance', 'Neutral'),
#   ('data', 'Neutral'),
#   ('fortune', 'Neutral'),
#   ('company', 'Neutral')],
#  [('company use', 'Neutral'), ('stock', 'Neutral')],
#  [('ny state alleges', 'Neutral'),
#   ('knew risk', 'Negative'),
#   ('climate change', 'Neutral'),
#   ('investor', 'Neutral')],
#  [('new react devtools', 'Neutral')],
#  [('wework', 'Neutral'),
#   ('tax rebate meant', 'Neutral'),
#   ('smallbusiness tenant', 'Neutral')],
#  [('administration', 'Neutral'),
#   ('full power', 'Neutral'),
#   ('surveillance state', 'Neutral'),
#   ('whistleblower', 'Neutral')],
#  [('book', 'Neutral'), ('mysterious piece', 'Neutral'), ('paper', 'Neutral')],
#  [('customer', 'Neutral')],
#  [('amazon', 'Positive'), ('oxygen', 'Neutral')],
#  [('uber proposes policy', 'Neutral'),
#   ('minimum wage', 'Neutral'),
#   ('hour', 'Neutral')],
#  [('dangerous writing app', 'Negative')],
#  [('trade work', 'Neutral'), ('freefloating currency', 'Neutral')],
#  [('arend theorem prover', 'Neutral'),
#   ('homotopy type theory', 'Neutral'),
#   ('jetbrains', 'Neutral')],
#  [('blazingsql', 'Neutral'), ('open source', 'Neutral')],
#  [('key negotiation', 'Neutral'), ('attack', 'Negative')],
#  [('ondevice realtime hand', 'Positive'), ('mediapipe', 'Neutral')],
#  [('dirty trick', 'Negative'), ('programmer use', 'Neutral')],
#  [('insured price', 'Neutral'), ('cash price', 'Neutral')],
#  [('german grow', 'Neutral'), ('slowpoke internet', 'Neutral')],
#  [('raspberry pi', 'Neutral'), ('full keyboard handheld', 'Neutral')],
#  [('show', 'Neutral'),
#   ('service', 'Neutral'),
#   ('indian spinach curry', 'Neutral')],
#  [('social exclusion fuel extremism', 'Negative'), ('young men', 'Neutral')],
#  [('camscanner', 'Neutral'),
#   ('malicious android app', 'Neutral'),
#   ('downloads', 'Neutral'),
#   ('google play', 'Positive')],
#  [('moscow blockchain voting system', 'Neutral'),
#   ('month', 'Neutral'),
#   ('election', 'Neutral')],
#  [('principle', 'Neutral')],
#  [('qemu vm escape', 'Positive')],
#  [('bond rating', 'Neutral'), ('financial crisis', 'Negative')],
#  [('medieval people', 'Neutral')],
#  [('devilution', 'Neutral'),
#   ('web port', 'Neutral'),
#   ('original diablo game', 'Positive')],
#  [('house', 'Neutral'), ('air conditioning', 'Neutral')],
#  [('skull', 'Neutral'),
#   ('early apelike human ancestor', 'Neutral'),
#   ('ethiopia', 'Neutral')],
#  [('huawei technician', 'Neutral'),
#   ('african government spy', 'Neutral'),
#   ('political opponent', 'Neutral')],
#  [('typescript', 'Neutral')],
#  [('answer', 'Neutral')],
#  [('indoor air quality', 'Neutral'),
#   ('raspberry pi ruuvitags', 'Neutral'),
#   ('pms7003', 'Neutral')],
#  [('wework', 'Neutral'), ('tech company', 'Neutral')],
#  [('const doesnt', 'Neutral'), ('c code', 'Neutral')],
#  [('twilio', 'Neutral')],
#  [('python v rust', 'Neutral'), ('neural network', 'Neutral')],
#  [('big coal plant begin', 'Neutral')],
#  [('aussie isv', 'Neutral'),
#   ('ad', 'Neutral'),
#   ('google support', 'Positive')],
#  [('feynman lecture', 'Neutral'), ('physic algebra', 'Neutral')],
#  [('coinbase', 'Neutral'), ('wild', 'Neutral')],
#  [('gamedev tutorial trigonometry basic sine', 'Neutral'),
#   ('cosine', 'Neutral')],
#  [('public domain', 'Neutral'), ('book', 'Neutral'), ('u', 'Neutral')],
#  [('show', 'Neutral'),
#   ('clojurescript pixel game engine', 'Neutral'),
#   ('blender livereloading', 'Neutral')],
#  [('lisp', 'Neutral'), ('lambda calculus', 'Neutral')],
#  [('alphabet overtakes apple', 'Neutral'), ('cashrich company', 'Neutral')],
#  [('rice university researcher', 'Neutral'),
#   ('way', 'Neutral'),
#   ('solar efficiency', 'Positive')],
#  [('backblaze b2', 'Neutral'),
#   ('cloudflare worker', 'Neutral'),
#   ('free image hosting', 'Positive')],
#  [('sale promotion', 'Neutral'),
#   ('history', 'Neutral'),
#   ('free flight fiasco', 'Neutral')],
#  [('door problem', 'Negative'), ('combat design', 'Negative')],
#  [('wikipedia', 'Neutral'), ('brave', 'Positive'), ('publisher', 'Neutral')],
#  [('google plan', 'Neutral'),
#   ('ftp url support', 'Positive'),
#   ('chrome', 'Neutral')],
#  [('process', 'Neutral')],
#  [('show hn', 'Neutral'),
#   ('online opensource api request builder', 'Neutral')],
#  [('many possibility', 'Neutral'),
#   ('imessage file vulnerability', 'Negative')],
#  [('design', 'Neutral'),
#   ('failsafe filesystem', 'Neutral'),
#   ('microcontrollers', 'Neutral')],
#  [('ask hn', 'Neutral'),
#   ('setup', 'Neutral'),
#   ('ad blocking', 'Negative'),
#   ('tracker blocking', 'Negative')],
#  [('rabbit', 'Neutral'), ('technical expertise', 'Neutral')],
#  [('show hn', 'Neutral'), ('crm system', 'Neutral'), ('sale fun', 'Positive')],
#  [('syslog complete system administrator guide', 'Neutral')],
#  [('sudden trip', 'Neutral')],
#  [('doe', 'Neutral'), ('life', 'Neutral'), ('amino acid', 'Neutral')],
#  [('toshiba', 'Neutral'), ('new tiny nvme ssd form factor', 'Neutral')],
#  [('john carmack', 'Neutral'), ('parallel implementation', 'Neutral')],
#  [('gnu radio', 'Neutral')],
#  [],
#  [('github registry public beta', 'Neutral')],
#  [('practical guide', 'Neutral'),
#   ('transition', 'Neutral'),
#   ('animation', 'Neutral')],
#  [('u farmer stung', 'Neutral'),
#   ('tariff', 'Neutral'),
#   ('corn loss', 'Negative')],
#  [('facebook', 'Neutral'),
#   ('apple', 'Neutral'),
#   ('messaging feature', 'Neutral')],
#  [('privacy sandbox open standard', 'Neutral'),
#   ('privacy', 'Neutral'),
#   ('web', 'Neutral')],
#  [('transformer', 'Neutral'), ('scratch', 'Neutral')],
#  [],
#  [('memory management', 'Neutral'), ('python', 'Neutral')],
#  [('die', 'Negative'), ('battery', 'Neutral')],
#  [('ebay shopify', 'Neutral'), ('amazon', 'Positive')],
#  [('video card', 'Neutral')],
#  [('pastel', 'Neutral'),
#   ('commandline tool', 'Neutral'),
#   ('analyze convert', 'Neutral'),
#   ('manipulate color', 'Neutral')],
#  [('mini map', 'Neutral'), ('website', 'Neutral')],
#  [('svgs', 'Neutral')],
#  [('launch', 'Neutral'), ('twofactor security key', 'Positive')],
#  [('bloomberg reporter', 'Neutral'),
#   ('account', 'Neutral'),
#   ('name', 'Neutral'),
#   ('credit rating', 'Positive')],
#  [('opioid crisis johnson', 'Negative'),
#   ('johnson', 'Neutral'),
#   ('landmark ruling', 'Positive')],
#  [('big pharma', 'Neutral'), ('drug price high critic', 'Negative')],
#  [('tokyo audiophile venue', 'Neutral')],
#  [('japan', 'Neutral'),
#   ('foreign holder', 'Neutral'),
#   ('u treasury', 'Positive')],
#  [('statement', 'Neutral'),
#   ('purpose', 'Neutral'),
#   ('corporation', 'Neutral')],
#  [('http', 'Neutral')],
#  [('doesnt mathematics', 'Neutral'),
#   ('mistake', 'Negative'),
#   ('proof', 'Neutral')],
#  [('hacker', 'Neutral'),
#   ('exploit', 'Negative'),
#   ('target mailroom', 'Neutral')],
#  [('major book publisher sue amazon', 'Positive'),
#   ('new speechtotext feature', 'Neutral')],
#  [('sonos ikea symfonisk', 'Neutral'),
#   ('high quality speaker amp', 'Neutral')],
#  [('kubernetes security assessment pdf', 'Positive')],
#  [('culture fit', 'Positive'), ('way street', 'Neutral')],
#  [('dead person', 'Negative')],
#  [('google search', 'Neutral'), ('certain query', 'Positive')],
#  [('module mirror', 'Neutral'), ('checksum database', 'Neutral')],
#  [('high level', 'Neutral'), ('oestrogen', 'Neutral'), ('womb', 'Neutral')],
#  [('dark', 'Neutral')],
#  [('fungus', 'Neutral'),
#   ('cavendish banana ha', 'Positive'),
#   ('latin america', 'Neutral')],
#  [('metal shard', 'Neutral'), ('rome', 'Neutral'), ('people', 'Neutral')],
#  [('cent mcu', 'Neutral'),
#   ('short survey', 'Neutral'),
#   ('microcontrollers', 'Neutral')],
#  [('order', 'Neutral'), ('json', 'Neutral')],
#  [('effect seattle', 'Neutral'),
#   ('use', 'Neutral'),
#   ('hard drug', 'Negative')],
#  [('faa ban', 'Negative'), ('apple laptop', 'Neutral'), ('flight', 'Neutral')],
#  [('new architecture', 'Neutral'), ('realtime internet video', 'Neutral')],
#  [('walmart sue tesla', 'Neutral'),
#   ('fire', 'Negative'),
#   ('store', 'Neutral'),
#   ('solar panel', 'Neutral')],
#  [('danish bank launch negative interest rate mortgage', 'Negative')],
#  [('opensource firmware', 'Neutral')],
#  [('technical vision', 'Positive'), ('qt', 'Positive')],
#  [('show', 'Neutral'),
#   ('community browser', 'Neutral'),
#   ('hacker news reddit youtube', 'Neutral')],
#  [('dream', 'Positive'), ('ultimate', 'Neutral')],
#  [('primer', 'Neutral'), ('bézier curve', 'Neutral')],
#  [('bontrager wavecel material', 'Neutral'),
#   ('concussion', 'Neutral'),
#   ('mips', 'Neutral')],
#  [('death', 'Negative'),
#   ('social reciprocity', 'Neutral'),
#   ('era', 'Neutral'),
#   ('digital distraction', 'Negative')],
#  [('amazon', 'Positive'), ('thirdparty sellers product pricing', 'Neutral')],
#  [('partiql', 'Neutral'), ('query language', 'Neutral'), ('data', 'Neutral')],
#  [('bug', 'Neutral'), ('hadnt', 'Neutral')],
#  [('mobile phone', 'Neutral'), ('freedom video', 'Positive')],
#  [('cloud', 'Neutral'), ('git repos', 'Neutral')],
#  [('home lab server', 'Neutral'),
#   ('core', 'Neutral'),
#   ('thread', 'Neutral'),
#   ('gb memory', 'Neutral')],
#  [('gcc null pointer check', 'Neutral')],
#  [('u', 'Neutral'), ('wind farm', 'Neutral'), ('fossil fuel', 'Neutral')],
#  [('wiringpi', 'Neutral')],
#  [('credit card', 'Positive'), ('privacy problem', 'Negative')],
#  [('starbucks monetary superpower', 'Neutral')],
#  [('building age', 'Neutral'), ('netherlands', 'Neutral')],
#  [('huawei seek independence', 'Neutral'),
#   ('u', 'Neutral'),
#   ('riscv', 'Neutral'),
#   ('chip', 'Neutral')],
#  [('time ai cause uproar', 'Neutral'), ('conference', 'Neutral')],
#  [('hypersane', 'Neutral')],
#  [('clojure', 'Neutral')],
#  [('cybersecurity', 'Neutral'),
#   ('price', 'Neutral'),
#   ('hacker attack swell', 'Negative')],
#  [('gcp', 'Neutral'),
#   ('additional charge', 'Neutral'),
#   ('vm instance', 'Neutral')],
#  [('youtube', 'Neutral'),
#   ('music companies', 'Neutral'),
#   ('manual copyright claim', 'Neutral')],
#  [('poetry dependency management', 'Neutral'), ('python', 'Neutral')],
#  [('protocol', 'Neutral'),
#   ('technological approach', 'Neutral'),
#   ('speech', 'Neutral')],
#  [('ruby', 'Neutral'), ('rust', 'Neutral')],
#  [('apollo guidance computer', 'Neutral'),
#   ('power supply work', 'Neutral'),
#   ('year', 'Neutral')],
#  [('programming pattern', 'Neutral')],
#  [('denial', 'Neutral'),
#   ('h1b visa', 'Neutral'),
#   ('service exporter', 'Neutral')],
#  [('show', 'Neutral'),
#   ('documentation website', 'Neutral'),
#   ('python', 'Neutral')],
#  [('show', 'Neutral'),
#   ('reddit google trend twitter etc', 'Neutral'),
#   ('trending topic', 'Neutral')],
#  [('advice', 'Neutral'), ('self', 'Neutral'), ('churn', 'Neutral')],
#  [('show', 'Neutral'), ('free selfupdating website', 'Positive')],
#  [('show', 'Neutral'),
#   ('lunch money', 'Neutral'),
#   ('personal budgeting tool', 'Neutral'),
#   ('multicurrency support', 'Positive')],
#  [('new life', 'Neutral'), ('life', 'Neutral'), ('electricity', 'Neutral')],
#  [('cerebras system', 'Neutral'),
#   ('transistor chip', 'Neutral'),
#   ('ai', 'Neutral')],
#  [('software architect', 'Neutral'),
#   ('system engineering activity', 'Neutral')],
#  [('typescript', 'Neutral'), ('react', 'Neutral')],
#  [('bmw unveils car', 'Neutral'), ('vantablack', 'Neutral')],
#  [('peer review', 'Neutral'), ('gold standard', 'Neutral')],
#  [('launch hn sanntek yc s19 breathalyzer', 'Neutral'),
#   ('cannabis', 'Neutral')],
#  [('myth', 'Neutral'), ('consumergrade security', 'Positive')],
#  [('nvidia ceo', 'Neutral'),
#   ('google', 'Neutral'),
#   ('customer', 'Neutral'),
#   ('silicon', 'Neutral'),
#   ('scale', 'Neutral')],
#  [('racket lisp', 'Neutral')],
#  [('le argumentative online', 'Negative')],
#  [('insurance company', 'Neutral'),
#   ('cop', 'Neutral'),
#   ('customer', 'Neutral')],
#  [('speaker', 'Neutral')],
#  [('normality', 'Neutral')],
#  [('nasa', 'Neutral'),
#   ('first allegation', 'Neutral'),
#   ('crime', 'Negative'),
#   ('space', 'Neutral')],
#  [('germany', 'Neutral'),
#   ('first time', 'Neutral'),
#   ('bond offering negative yield', 'Negative')],
#  [('america', 'Neutral')],
#  [('surge', 'Neutral'), ('drugresistant hiv', 'Neutral')],
#  [('levenshtein distance', 'Neutral')],
#  [('online encyclopedia', 'Neutral'), ('pun', 'Neutral')],
#  [('iphone', 'Neutral'), ('cable', 'Neutral'), ('computer', 'Neutral')],
#  [('open startup list', 'Neutral')],
#  [('first solar road ha', 'Positive'), ('disappointing failure', 'Negative')],
#  [('facial recognition school', 'Neutral'), ('lead', 'Neutral')],
#  [('twitter', 'Neutral'), ('adtech leak', 'Negative')],
#  [('ha', 'Positive'),
#   ('unix virtual memory', 'Neutral'),
#   ('swap space', 'Neutral')],
#  [('elon musk', 'Neutral'), ('tesla', 'Neutral'), ('solarcity', 'Neutral')],
#  [('new opensource typeface', 'Neutral'),
#   ('github', 'Neutral'),
#   ('mozilla', 'Neutral')],
#  [('splunk', 'Neutral'), ('cloud monitoring service signalfx', 'Neutral')],
#  [('swap swap swap', 'Neutral'), ('bad place', 'Negative')],
#  [('interview', 'Neutral'),
#   ('programming language creator', 'Neutral'),
#   ('pdf', 'Neutral')],
#  [('activision blizzard', 'Neutral'),
#   ('dollar', 'Neutral'),
#   ('profit', 'Positive'),
#   ('tax', 'Neutral')],
#  [('dollar', 'Neutral'), ('loneliness', 'Negative')],
#  [('seashell pipe output', 'Neutral'),
#   ('commandline program', 'Neutral'),
#   ('web', 'Neutral'),
#   ('real time', 'Neutral')],
#  [('wework ipo show', 'Neutral'), ('magical unicorn', 'Neutral')],
#  [('experimental usaf space plane break record', 'Neutral'),
#   ('orbital spaceflight', 'Neutral')],
#  [('devops consultant', 'Neutral')],
#  [('container safer', 'Positive')],
#  [('erlang rationale', 'Neutral')],
#  [('apple suspends', 'Neutral'),
#   ('response grading', 'Neutral'),
#   ('response', 'Neutral'),
#   ('privacy concern', 'Neutral')],
#  [('tragedy', 'Negative'), ('ucs2', 'Neutral')],
#  [('crispr', 'Neutral'),
#   ('university', 'Neutral'),
#   ('california researcher', 'Neutral')],
#  [('one', 'Neutral'),
#   ('thing', 'Neutral'),
#   ('midwest town', 'Neutral'),
#   ('town', 'Neutral')],
#  [('good conversation', 'Positive')],
#  [('adobe flash player', 'Neutral'), ('rust', 'Neutral')],
#  [('hedonometer', 'Neutral')],
#  [('github support web authentication webauthn', 'Positive'),
#   ('security key', 'Positive')],
#  [('twelve latex package', 'Neutral'), ('paper', 'Neutral')],
#  [('manager guide', 'Neutral'), ('kubernetes adoption', 'Neutral')],
#  [('typed property', 'Neutral'), ('php', 'Neutral')],
#  [('readable specification', 'Neutral'), ('tl', 'Neutral')],
#  [('wireless service crook', 'Neutral')],
#  [('google location dragnet', 'Neutral'),
#   ('wisconsin bank robbery', 'Neutral')],
#  [('thing', 'Neutral'), ('gnu readline', 'Neutral')],
#  [('mortgage market', 'Neutral'), ('borrower', 'Neutral')],
#  [('sign', 'Neutral'),
#   ('disruption', 'Negative'),
#   ('urban habitat', 'Neutral')],
#  [('acute effect', 'Neutral'),
#   ('electronic cigarette aerosol inhalation', 'Neutral'),
#   ('vascular function', 'Neutral')],
#  [('data confirms', 'Neutral'), ('month', 'Neutral')],
#  [('javascript', 'Neutral'), ('modern part', 'Neutral')],
#  [('google', 'Neutral'),
#   ('developer', 'Neutral'),
#   ('new android apps', 'Neutral'),
#   ('day', 'Neutral'),
#   ('approval', 'Positive')],
#  [('rust gui ecosystem overview', 'Neutral')],
#  [('doe esperanto sound', 'Neutral')],
#  [('command', 'Neutral'),
#   ('conquer tiberian sun', 'Neutral'),
#   ('computer', 'Neutral'),
#   ('day video', 'Neutral')],
#  [('difference', 'Neutral'), ('machine learning', 'Neutral')],
#  [('dropbox', 'Neutral'),
#   ('symlinks', 'Neutral'),
#   ('dropbox account', 'Neutral')],
#  [('climate change', 'Neutral'), ('c hotter', 'Neutral')],
#  [('unison file synchronizer', 'Neutral')],
#  [('michael cicconetti', 'Neutral')],
#  [('gpt2', 'Neutral')],
#  [('practical tip', 'Neutral'), ('tech resume', 'Neutral')],
#  [('natural language', 'Positive'),
#   ('age', 'Neutral'),
#   ('transformer', 'Neutral')],
#  [('portuguese bank note crisis', 'Negative')],
#  [('california farmer', 'Neutral'),
#   ('solar panel', 'Neutral'),
#   ('water supply', 'Neutral')],
#  [('youtube', 'Neutral'), ('children privacy violation', 'Negative')],
#  [('microsoft', 'Neutral'),
#   ('epub support', 'Positive'),
#   ('edge classic', 'Neutral')],
#  [('ask hn configuration management', 'Neutral'),
#   ('personal computer', 'Neutral')],
#  [('intel', 'Neutral'),
#   ('future', 'Neutral'),
#   ('system', 'Neutral'),
#   ('video', 'Neutral')],
#  [('docker container', 'Neutral'), ('host', 'Neutral')],
#  [('wireless carrier throttling', 'Neutral'),
#   ('online video', 'Neutral'),
#   ('pervasive study', 'Neutral')],
#  [('black hole destroy information', 'Negative'), ('problem', 'Negative')],
#  [('waypipe gsoc project', 'Neutral')],
#  [('launch hn quirk yc s19 opensource cognitive behavioral therapy',
#    'Neutral')],
#  [('boeings', 'Neutral'), ('expose systemic failing', 'Negative')],
#  [('goldman sachs', 'Neutral'),
#   ('millisecond', 'Neutral'),
#   ('stock trade', 'Neutral')],
#  [('bad time', 'Negative'),
#   ('tech', 'Neutral'),
#   ('startup', 'Neutral'),
#   ('startup', 'Neutral')],
#  [('pascal apps', 'Neutral'),
#   ('divisionbyzero', 'Neutral'),
#   ('faster system', 'Neutral')],
#  [('show', 'Neutral'),
#   ('storytime create story', 'Positive'),
#   ('code', 'Neutral'),
#   ('documentation', 'Neutral')],
#  [('science fiction magazine', 'Neutral'), ('available online', 'Neutral')],
#  [('container', 'Neutral'), ('nix', 'Neutral')],
#  [('internet service provider', 'Neutral'), ('sonic ha', 'Positive')],
#  [],
#  [('ondisk format robustness requirement', 'Neutral'),
#   ('new filesystems', 'Neutral')],
#  [('julia', 'Neutral')],
#  [('ethic', 'Neutral'), ('web performance', 'Neutral')],
#  [('tesla roadster', 'Neutral'), ('serious work', 'Negative')],
#  [('oracle director', 'Neutral'),
#   ('blessing', 'Positive'),
#   ('shareholder lawsuit', 'Negative'),
#   ('larry ellison', 'Neutral')],
#  [('lf', 'Neutral'), ('keyvalue store', 'Neutral')],
#  [('quarter', 'Neutral'),
#   ('humanity face', 'Neutral'),
#   ('water crisis', 'Negative')],
#  [('pacvim pacvim', 'Neutral'), ('game', 'Neutral')],
#  [('doe infrastructure cost', 'Neutral')],
#  [('law', 'Neutral'), ('pdf', 'Neutral')],
#  [('possible detection', 'Neutral'),
#   ('black hole', 'Neutral'),
#   ('mass', 'Neutral')],
#  [('launch hn dex yc', 'Neutral'),
#   ('personal crm', 'Neutral'),
#   ('touch', 'Neutral')],
#  [('buddhist monk confronts', 'Negative'), ('suicide culture', 'Negative')],
#  [('threecueing system', 'Neutral'), ('reading', 'Neutral')],
#  [('home', 'Neutral'), ('metal printing', 'Neutral'), ('result', 'Neutral')],
#  [('são paulo', 'Neutral'), ('advertising ban', 'Negative')],
#  [('google', 'Neutral'), ('cameras visual indicator light', 'Neutral')],
#  [('reasoning', 'Neutral'), ('replication crisis', 'Negative')],
#  [('sugar opensource software', 'Neutral'),
#   ('platform', 'Neutral'),
#   ('child', 'Neutral')],
#  [('open location code', 'Neutral'),
#   ('open source standard', 'Neutral'),
#   ('address', 'Neutral')],
#  [('debt', 'Negative'), ('credit card customer', 'Positive')],
#  [('computer science', 'Neutral')],
#  [('json', 'Neutral'), ('minefield', 'Neutral')],
#  [('easter egg', 'Neutral')],
#  [('interviewer skill ladder', 'Neutral'),
#   ('high growth company', 'Positive')],
#  [('show hn', 'Neutral'),
#   ('online playground', 'Neutral'),
#   ('tailwind cs', 'Neutral')],
#  [('decentralization', 'Neutral')],
#  [('amazon cloud backup', 'Positive'), ('sensitive data', 'Neutral')],
#  [('maine dam', 'Neutral'), ('year', 'Neutral'), ('everything', 'Neutral')],
#  [('nonplanar', 'Neutral')],
#  [('roman', 'Neutral'), ('mathematics', 'Neutral')],
#  [('bulk data structure c', 'Neutral')],
#  [('weight agnostic neural network', 'Neutral')],
#  [('diamond', 'Positive')],
#  [('big notation', 'Neutral'),
#   ('math', 'Neutral'),
#   ('code efficiency', 'Positive')],
#  [('cisco', 'Neutral'), ('hardware', 'Neutral')],
#  [('shrinkflation', 'Neutral'),
#   ('havoc', 'Negative'),
#   ('economists', 'Neutral')],
#  [('rotten apple right', 'Negative'), ('roundup', 'Neutral')],
#  [('tumblr', 'Neutral')],
#  [('doordash', 'Neutral'), ('caviar', 'Neutral'), ('square', 'Neutral')],
#  [('daniel radcliffe', 'Neutral'),
#   ('art', 'Neutral'),
#   ('factcheck', 'Neutral')],
#  [('svalbard', 'Neutral'),
#   ('close', 'Neutral'),
#   ('place', 'Neutral'),
#   ('open border', 'Neutral')],
#  [('dyson tree', 'Neutral')],
#  [('name', 'Neutral'), ('domain resellers', 'Neutral'), ('year', 'Neutral')],
#  [('fbi tell lawmaker', 'Neutral'),
#   ('cant access dayton gunman phone', 'Neutral')],
#  [('child', 'Neutral'),
#   ('thailand tribe', 'Neutral'),
#   ('clarity', 'Positive'),
#   ('wave', 'Neutral')],
#  [('franky zapata', 'Neutral'),
#   ('frenchman cross english channel', 'Neutral')],
#  [('dignity', 'Positive')],
#  [('teen hacker', 'Neutral'),
#   ('bug', 'Neutral'),
#   ('school software', 'Neutral'),
#   ('record', 'Neutral')],
#  [('pissedoff tutorial', 'Neutral'),
#   ('google wave', 'Neutral'),
#   ('video', 'Neutral')],
#  [('pay cut', 'Negative'), ('meaningful job', 'Positive')],
#  [('buyback', 'Neutral'), ('red hat', 'Neutral')],
#  [('parallelism', 'Neutral'), ('postgresql', 'Neutral')],
#  [('tech backlash', 'Neutral')],
#  [('google', 'Neutral'), ('search engine auction', 'Neutral')],
#  [('peloton s1', 'Neutral')],
#  [('mock work', 'Negative')],
#  [('pattern', 'Neutral'), ('automated license plate reader', 'Neutral')],
#  [('show', 'Neutral'), ('latex typesetting game', 'Neutral')],
#  [('memory', 'Neutral'), ('application', 'Neutral'), ('time', 'Neutral')],
#  [('fire', 'Negative'), ('angola congo', 'Neutral'), ('amazon', 'Positive')],
#  [('telegram introduces feature', 'Neutral'),
#   ('user', 'Neutral'),
#   ('group', 'Neutral')],
#  [],
#  [('great impostor', 'Positive')],
#  [('seattle microtransit experiment drive people', 'Neutral'),
#   ('light rail', 'Neutral')],
#  [('basic electron framework exploitation', 'Neutral')],
#  [('helsinki central library chosen', 'Neutral'),
#   ('new public library', 'Neutral')],
#  [('spacex smallsat rideshare program', 'Neutral')],
#  [('personal website', 'Neutral'), ('programmer', 'Neutral')],
#  [('startup', 'Neutral'), ('combinator s19 demo day', 'Neutral')],
#  [('highlight', 'Positive'), ('git', 'Neutral')],
#  [('show', 'Neutral'),
#   ('decade', 'Neutral'),
#   ('video', 'Neutral'),
#   ('year', 'Neutral')],
#  [('standard j', 'Neutral'), ('install funding', 'Neutral')],
#  [('world coal power plant', 'Neutral')],
#  [('kept', 'Neutral'), ('tube', 'Neutral'), ('year', 'Neutral')],
#  [('lesson', 'Neutral'), ('scaling problem', 'Negative')],
#  [('p idea faq', 'Neutral')],
#  [('show', 'Neutral'),
#   ('scarf platform', 'Neutral'),
#   ('developer', 'Neutral'),
#   ('work', 'Neutral')],
#  [('old paris', 'Neutral')],
#  [('spacebook agis', 'Neutral'), ('realtime satellite viewer', 'Neutral')],
#  [('path', 'Neutral'), ('handwriting', 'Neutral')],
#  [('chiang realist', 'Neutral'), ('reality', 'Neutral')],
#  [('escape room', 'Positive'), ('big business', 'Neutral')],
#  [('alcohol belt', 'Neutral'), ('europe', 'Neutral')],
#  [('dependent haskell', 'Neutral'), ('future', 'Neutral')],
#  [('north american versus european distribution system', 'Neutral')],
#  [('social share button', 'Positive'),
#   ('social site', 'Neutral'),
#   ('user', 'Neutral')],
#  [('nutrient deficiency', 'Neutral'),
#   ('rice', 'Neutral'),
#   ('carbon dioxide', 'Neutral')],
#  [('body', 'Neutral'),
#   ('link', 'Neutral'),
#   ('truly intelligent machine', 'Positive')],
#  [('electric motor design claim remarkable improvement', 'Positive')],
#  [('land', 'Neutral'), ('linux', 'Neutral')],
#  [('son', 'Neutral'), ('mine', 'Neutral'), ('benthamite', 'Neutral')],
#  [('validation certificate', 'Neutral')],
#  [('mobility trap', 'Negative'),
#   ('congestion', 'Neutral'),
#   ('traffic', 'Neutral')],
#  [('static type checking', 'Neutral'), ('common lisp', 'Neutral')],
#  [('interslavic language', 'Neutral')],
#  [('startup', 'Neutral'), ('combinator s19 demo day', 'Neutral')],
#  [('notqmail', 'Neutral')],
#  [('french love', 'Positive')],
#  [('theory', 'Neutral'),
#   ('error backpropagation', 'Negative'),
#   ('brain', 'Neutral')],
#  [('black beekeeper', 'Neutral'),
#   ('detroit vacant lot', 'Neutral'),
#   ('bee farm', 'Neutral')],
#  [('gpt2', 'Neutral'), ('followup', 'Neutral')],
#  [('crossword panic', 'Negative')],
#  [('libspng c', 'Neutral'), ('reading', 'Neutral'), ('png file', 'Neutral')],
#  [('kegans theory', 'Neutral'),
#   ('evolution', 'Neutral'),
#   ('consciousness', 'Neutral')],
#  [('hospital checklist', 'Neutral'), ('life', 'Neutral')],
#  [('simple sat solver', 'Neutral'), ('python', 'Neutral')],
#  [('deep dive', 'Neutral'), ('linux namespaces part', 'Neutral')],
#  [('chemist', 'Neutral'),
#   ('firstever ring', 'Neutral'),
#   ('pure carbon', 'Neutral')],
#  [('datacenter location', 'Neutral'), ('19th century politics', 'Neutral')],
#  [('uber', 'Neutral'), ('softbank count ipo return', 'Neutral')],
#  [('bacteria', 'Neutral'), ('selfhealing cement', 'Neutral')],
#  [('group chat', 'Neutral')],
#  [('mathematics', 'Neutral'),
#   ('matplotlib', 'Neutral'),
#   ('python', 'Neutral')],
#  [('moravecs paradox', 'Negative')],
#  [('motion', 'Neutral'), ('robotic character', 'Neutral')],
#  [('website builder webflow yc', 'Neutral'),
#   ('bankruptcy', 'Neutral'),
#   ('series', 'Neutral')],
#  [('swiss post suspends', 'Neutral'),
#   ('delivery service', 'Neutral'),
#   ('second crash', 'Negative')],
#  [('doityourself openjdk garbage collector', 'Neutral')],
#  [('patagonia philosopher king', 'Neutral')],
#  [('j', 'Neutral'), ('apl', 'Neutral')],
#  [('julias release process', 'Neutral')],
#  [('math', 'Neutral'), ('data science', 'Neutral')],
#  [('distributed system reliability', 'Neutral')],
#  [('dont forget randomness', 'Positive'), ('hypothesis', 'Neutral')],
#  [('history', 'Neutral'),
#   ('broken vertical bar', 'Negative'),
#   ('form', 'Neutral')],
#  [('show hn', 'Neutral'), ('google', 'Neutral'), ('hacker news', 'Neutral')],
#  [('tv detector van', 'Neutral')],
#  [('brother', 'Neutral'),
#   ('alphabet', 'Neutral'),
#   ('native language fulfulde', 'Neutral')],
#  [('orphans', 'Neutral'), ('electric car', 'Neutral')],
#  [('biotech startup funding', 'Neutral'), ('year', 'Neutral')],
#  [('ignition', 'Neutral'),
#   ('informal history', 'Neutral'),
#   ('liquid rocket propellant', 'Neutral'),
#   ('pdf', 'Neutral')],
#  [('winedark sea', 'Neutral')],
#  [('year sel4', 'Neutral')],
#  [('startup video', 'Neutral')],
#  [('contagious cancer', 'Negative'), ('dog', 'Neutral')],
#  [('ceramic enter', 'Neutral'),
#   ('new era', 'Neutral'),
#   ('laserwelded joint', 'Neutral')],
#  [('shady world', 'Neutral'),
#   ('repair manual copyrighting', 'Neutral'),
#   ('obsolescence', 'Neutral')],
#  [('open source hardware', 'Neutral'), ('aid part', 'Neutral')],
#  [('last working olivetti', 'Neutral'),
#   ('sits', 'Neutral'),
#   ('tuscan high school', 'Neutral')],
#  [('beginning', 'Neutral'), ('command line', 'Neutral'), ('pdf', 'Neutral')],
#  [('manufacturer', 'Neutral'), ('china', 'Neutral'), ('vietnam', 'Neutral')],
#  [('microsoft ha', 'Positive'),
#   ('major impact', 'Neutral'),
#   ('chrome', 'Neutral')],
#  [('glass', 'Neutral'), ('mold', 'Neutral')],
#  [('def con', 'Neutral'),
#   ('stack', 'Neutral'),
#   ('traffic', 'Neutral'),
#   ('cybersecurity', 'Neutral')],
#  [('geocities', 'Neutral')],
#  [('le data', 'Neutral')],
#  [('math', 'Neutral'), ('general relativity', 'Neutral')],
#  [('rule', 'Neutral')],
#  [('exosuit', 'Neutral'), ('endurance', 'Neutral'), ('trail', 'Neutral')],
#  [('subsurface', 'Neutral'),
#   ('open source scuba dive logging platform', 'Neutral')],
#  [('stock', 'Neutral'), ('random study', 'Neutral')],
#  [('goal', 'Neutral'),
#   ('reward', 'Positive'),
#   ('brain map', 'Neutral'),
#   ('world', 'Neutral')],
#  [('fbi delivery driver', 'Neutral'), ('amazon theft ring', 'Positive')],
#  [('raspberry pi camera', 'Neutral')],
#  [('everything', 'Neutral')],
#  [('columnist', 'Neutral'), ('cell number', 'Positive')],
#  [('commercial path', 'Neutral'), ('fusion', 'Neutral')],
#  [('stockx wa', 'Neutral'), ('customers data', 'Neutral')],
#  [('waymo backseat driver confidential data reveals', 'Neutral'),
#   ('taxi hurdle', 'Neutral')],
#  [('moviepass', 'Neutral'),
#   ('password', 'Neutral'),
#   ('user', 'Neutral'),
#   ('film', 'Neutral')],
#  [('bicycle', 'Neutral'), ('mind', 'Neutral')],
#  [],
#  [('tiny toy totp generator', 'Neutral'),
#   ('line', 'Neutral'),
#   ('python', 'Neutral')],
#  [('miss', 'Negative')],
#  [('supercomputer', 'Neutral'), ('map', 'Neutral'), ('world', 'Neutral')],
#  [('company', 'Neutral')],
#  [('cpan release', 'Neutral')],
#  [('capital', 'Neutral'),
#   ('cyber staff', 'Neutral'),
#   ('concern', 'Neutral'),
#   ('hack', 'Neutral')],
#  [('trigger', 'Neutral'),
#   ('kernel panic', 'Negative'),
#   ('unresponsive ec2 instance', 'Neutral')],
#  [('launch hn compound yc s19', 'Neutral'),
#   ('employee understand equity compensation', 'Neutral')],
#  [('push notification', 'Neutral'), ('hour', 'Neutral')],
#  [('monad', 'Neutral')],
#  [('fuzzable code', 'Neutral')],
#  [('software company', 'Neutral'), ('user behavior', 'Neutral')],
#  [('afternoon', 'Neutral'),
#   ('tokyo', 'Neutral'),
#   ('man', 'Neutral'),
#   ('casio gshock watch', 'Neutral')],
#  [('facebook ad', 'Neutral'), ('u presidential candidate', 'Neutral')],
#  [('kip500', 'Neutral'),
#   ('zookeeper', 'Neutral'),
#   ('metadata quorum', 'Neutral')],
#  [('side channel', 'Neutral'),
#   ('data', 'Neutral'),
#   ('intel cpu', 'Neutral'),
#   ('silent window update', 'Neutral')],
#  [('chemist discover water microdroplets', 'Neutral'),
#   ('hydrogen peroxide', 'Neutral')],
#  [('web', 'Neutral')],
#  [('free software network service', 'Positive'),
#   ('web application', 'Neutral')],
#  [('phytoplankton population drop', 'Negative'), ('percent', 'Neutral')],
#  [('root cerns scientific data analysis framework', 'Neutral'),
#   ('c', 'Neutral')],
#  [('subversive message', 'Negative'),
#   ('wizard', 'Neutral'),
#   ('oz', 'Neutral')],
#  [('flaw', 'Neutral'),
#   ('cellphone evidence prompt review', 'Neutral'),
#   ('verdict', 'Positive'),
#   ('denmark', 'Neutral')],
#  [('economist raj chetty ha', 'Positive'),
#   ('surprising tool', 'Positive'),
#   ('housing segregation', 'Neutral')],
#  [('static analysis', 'Neutral'),
#   ('scale', 'Neutral'),
#   ('instagram story', 'Neutral')],
#  [('camera v lidar', 'Neutral')],
#  [('digital advertising market', 'Neutral')],
#  [('security flaw', 'Positive'), ('compiler optimization', 'Positive')],
#  [('web content', 'Neutral'), ('power usage', 'Neutral')],
#  [('music recommendation', 'Neutral'), ('hyperbolic space', 'Neutral')],
#  [('deep dive', 'Neutral'), ('amd rome epyc architecture', 'Neutral')],
#  [('riscv processor', 'Neutral'), ('carbon nanotube', 'Neutral')],
#  [('show hn real world jupyter notebook', 'Neutral'),
#   ('way', 'Neutral'),
#   ('data scientist', 'Neutral')],
#  [('launch hn memfault yc w19 crashlytics', 'Neutral'),
#   ('firmware', 'Neutral')],
#  [('person ha', 'Positive'), ('vapingrelated condition', 'Neutral')],
#  [('linux pressure stall information psi', 'Negative'),
#   ('example', 'Neutral')],
#  [('lisp interpreter', 'Neutral'), ('python', 'Neutral')],
#  [('processor design', 'Neutral'), ('introduction', 'Neutral')],
#  [('adventure', 'Positive'), ('prolog', 'Neutral')],
#  [('show', 'Neutral'), ('functional scripting', 'Neutral')],
#  [('clever functional design', 'Positive')],
#  [('google begin', 'Neutral'), ('domain leasing', 'Neutral')],
#  [('programming language', 'Neutral'), ('interpreting', 'Neutral')],
#  [('sentient', 'Neutral'),
#   ('artificial brain', 'Neutral'),
#   ('u intelligence', 'Positive')],
#  [('live avatar', 'Neutral'), ('faceapijs', 'Neutral')],
#  [('india messy electric vehicle revolution', 'Negative')],
#  [('launch hn', 'Neutral'),
#   ('yc s19 internationalization', 'Neutral'),
#   ('devs', 'Neutral')],
#  [('big tech', 'Neutral'), ('pile', 'Neutral'), ('privacy gadget', 'Neutral')],
#  [('pokemonsay pokemon version', 'Neutral'), ('cowsay', 'Neutral')],
#  [('cowrie', 'Neutral'),
#   ('mediuminteraction ssh', 'Neutral'),
#   ('telnet honeypot', 'Neutral')],
#  [('energy storage investment boom', 'Positive'),
#   ('battery cost halve', 'Neutral'),
#   ('next decade', 'Neutral')],
#  [('effortless elixir release', 'Neutral'), ('deployment', 'Neutral')],
#  [('category', 'Neutral'), ('seed startup', 'Neutral'), ('arent', 'Neutral')],
#  [('solar power', 'Neutral'), ('salt', 'Neutral'), ('water', 'Neutral')],
#  [('proof assistant', 'Neutral')],
#  [('dark matter', 'Positive')],
#  [('day vulnerability', 'Negative'), ('vxworks', 'Neutral')],
#  [('huntington park robocop store pedestrians', 'Neutral'),
#   ('scan license plate', 'Neutral')],
#  [('cern open data portal', 'Neutral'),
#   ('pb', 'Neutral'),
#   ('open data', 'Neutral'),
#   ('particle physic', 'Neutral')],
#  [('lisp', 'Neutral')],
#  [],
#  [('hurricane forecast', 'Neutral')],
#  [('scale yc s16', 'Neutral'),
#   ('accel', 'Neutral'),
#   ('founder fund', 'Neutral'),
#   ('valuation', 'Neutral')],
#  [('algorithm', 'Neutral'), ('lisp data structure', 'Neutral')],
#  [('pentagon contract fight amazon ha foe', 'Negative'),
#   ('high place', 'Neutral')],
#  [('rome', 'Neutral'),
#   ('fulcrum', 'Neutral'),
#   ('amd datacenter pivot', 'Neutral')],
#  [('money', 'Neutral')],
#  [('phone company', 'Neutral'),
#   ('deal', 'Neutral'),
#   ('state', 'Neutral'),
#   ('dc', 'Neutral'),
#   ('robocalls', 'Neutral')],
#  [('tensor', 'Neutral'), ('clojure', 'Neutral'), ('sneak peek', 'Neutral')],
#  [('great truth', 'Positive')],
#  [('filekit', 'Neutral'),
#   ('open source endtoend', 'Neutral'),
#   ('cloud storage service', 'Neutral'),
#   ('javascript', 'Neutral')],
#  [('rent', 'Neutral'),
#   ('exchange', 'Neutral'),
#   ('monthly amazon purchasing quota', 'Positive')],
#  [('clojure library', 'Neutral'),
#   ('par text', 'Neutral'),
#   ('data', 'Neutral')],
#  [('mitre system engineering guide', 'Neutral'), ('pdf', 'Neutral')],
#  [('texas power price briefly', 'Neutral'), ('heat', 'Neutral')],
#  [('amazon plan', 'Positive'),
#   ('world', 'Neutral'),
#   ('publishing', 'Neutral')],
#  [('toptal sue cofounder breanden beneschott', 'Neutral'),
#   ('fraud', 'Negative')],
#  [('amelia earhart plane', 'Neutral'), ('startling clue', 'Positive')],
#  [('year', 'Neutral'), ('historic neptune flyby', 'Neutral')],
#  [('mesapy', 'Neutral'),
#   ('memorysafe python implementation', 'Neutral'),
#   ('pypy', 'Neutral')],
#  [('trail', 'Neutral'),
#   ('wind data visualization', 'Neutral'),
#   ('architecture', 'Neutral'),
#   ('airport runway', 'Neutral')],
#  [('show', 'Neutral'),
#   ('shapeform schema', 'Neutral'),
#   ('form', 'Neutral'),
#   ('react', 'Neutral')],
#  [('network effect', 'Neutral'),
#   ('look', 'Neutral'),
#   ('network effect', 'Neutral')],
#  [('germany turn', 'Neutral'),
#   ('quest', 'Neutral'),
#   ('clean energy economy', 'Positive')],
#  [('software', 'Neutral')],
#  [('u army', 'Neutral'), ('many fossil', 'Neutral')],
#  [('dna', 'Neutral'), ('deep learning', 'Neutral')],
#  [('pentagon', 'Neutral'),
#   ('code word', 'Neutral'),
#   ('secret project nickname', 'Neutral')],
#  [('simulated enigma machine', 'Neutral')],
#  [('artificial pancreas', 'Neutral')],
#  [('machine', 'Neutral'), ('arduino', 'Neutral')],
#  [('unshaky try', 'Neutral'),
#   ('double key press issue', 'Neutral'),
#   ('apple butterfly keyboard', 'Neutral')],
#  [('zrna', 'Neutral'), ('analog circuit', 'Neutral')],
#  [('simple rpc framework', 'Neutral'), ('line', 'Neutral'), ('go', 'Neutral')],
#  [('codebase', 'Neutral'), ('organism', 'Neutral')],
#  [('perfect language', 'Positive')],
#  [('people', 'Neutral'),
#   ('millennium', 'Neutral'),
#   ('skeleton lake', 'Neutral'),
#   ('himalaya', 'Neutral')],
#  [('tridactyl installation', 'Neutral'),
#   ('firefox', 'Neutral'),
#   ('aug', 'Neutral')],
#  [('remains', 'Neutral'),
#   ('ancient temple', 'Neutral'),
#   ('sunken egyptian city', 'Neutral')],
#  [('opensource tool', 'Neutral'), ('analog', 'Neutral')],
#  [('api gateway identity crisis', 'Negative'), ('service mesh', 'Neutral')],
#  [('online subscription business', 'Neutral'), ('malaysia', 'Neutral')],
#  [('lifehacker tarek loubani', 'Neutral'), ('gaza', 'Neutral')],
#  [('brain', 'Neutral'), ('story', 'Neutral')],
#  [('pal video', 'Neutral'), ('sdr', 'Neutral'), ('dead end', 'Negative')],
#  [('differential equation', 'Neutral'), ('point code', 'Neutral')],
#  [('computer stupidity', 'Negative')],
#  [('look', 'Neutral'), ('bloomberg keyboard', 'Neutral')],
#  [('jupiter riscv assembler', 'Neutral'), ('runtime simulator', 'Neutral')],
#  [('hour', 'Neutral'),
#   ('buckminster fuller', 'Neutral'),
#   ('vision', 'Positive')],
#  [('project', 'Neutral'),
#   ('modular uefi environment', 'Neutral'),
#   ('modern device', 'Neutral')],
#  [('high price', 'Neutral')],
#  [('curve', 'Neutral'), ('linear least square', 'Neutral')],
#  [('handler belief affect scent detection', 'Neutral')],
#  [('sipeed longan nano riscv development board', 'Neutral')],
#  [('difference', 'Neutral'),
#   ('isolation level', 'Negative'),
#   ('consistency level', 'Neutral')],
#  [('map', 'Neutral'), ('milky way show', 'Neutral'), ('shape', 'Neutral')],
#  [('map design', 'Neutral'),
#   ('guide', 'Neutral'),
#   ('map', 'Neutral'),
#   ('pdf', 'Neutral')],
#  [('silver bullet', 'Neutral'), ('pdf', 'Neutral')],
#  [('commander', 'Neutral'), ('wwii tank commander roguelike', 'Neutral')],
#  [('brain', 'Neutral')],
#  [('softbank plan', 'Neutral'),
#   ('ceo', 'Neutral'),
#   ('employee', 'Neutral'),
#   ('volatile market', 'Neutral')],
#  [('hp way', 'Neutral'), ('bill hewlett', 'Neutral'), ('company', 'Neutral')],
#  [('pyramid', 'Neutral')],
#  [('consistent result', 'Neutral'),
#   ('benchmarking', 'Neutral'),
#   ('linux', 'Neutral')],
#  [('iris scanner', 'Neutral'), ('eye', 'Neutral')],
#  [('vacuum tube computer', 'Neutral')],
#  [('portugal marmelada taste nothing', 'Neutral'), ('marmalade', 'Neutral')],
#  [('spacy pytorch transformer', 'Neutral')],
#  [('real world location', 'Neutral'), ('minute video', 'Neutral')],
#  [('show', 'Neutral'),
#   ('distributed pgp keyserver', 'Neutral'),
#   ('dat protocol', 'Neutral')],
#  [('karel čapeks', 'Neutral')],
#  [('apple card restriction', 'Negative'),
#   ('jailbreaking', 'Neutral'),
#   ('cryptocurrency purchase', 'Neutral')],
#  [('grand c error explosion competition', 'Positive')],
#  [('turkmenistan', 'Neutral'), ('brink', 'Neutral'), ('collapse', 'Negative')],
#  [('profile', 'Neutral'), ('geoffrey hinton', 'Neutral')],
#  [('scientist reverse', 'Neutral'),
#   ('process', 'Neutral'),
#   ('rat brain stem cell', 'Neutral')],
#  [('show', 'Neutral'),
#   ('discord terminal client', 'Negative'),
#   ('go', 'Neutral')],
#  [('year', 'Neutral'),
#   ('telephone tower', 'Neutral'),
#   ('stockholm', 'Neutral'),
#   ('phone line', 'Neutral')],
#  [('japanese architect', 'Neutral'),
#   ('building', 'Neutral'),
#   ('living organism', 'Neutral')],
#  [('recent paper', 'Neutral')],
#  [('jcore open processor', 'Neutral')],
#  [('presidio customizable data protection', 'Neutral'),
#   ('pii data anonymization service', 'Neutral')],
#  [('survival', 'Neutral'), ('iggy pop', 'Neutral')],
#  [('bpf', 'Neutral'), ('firewall', 'Neutral'), ('systemd service', 'Neutral')],
#  [('marree man', 'Neutral')],
#  [('dday', 'Neutral'), ('cost', 'Neutral'), ('life', 'Neutral')],
#  [('ray', 'Neutral')],
#  [('show', 'Neutral'), ('simple game', 'Neutral'), ('kid', 'Neutral')],
#  [('everyone hate customer service', 'Negative')],
#  [],
#  [('qualpwn', 'Neutral'),
#   ('qualcomm wlan', 'Neutral'),
#   ('modem', 'Neutral'),
#   ('air', 'Neutral')],
#  [('study identifies main culprit', 'Neutral'),
#   ('lithium metal battery failure', 'Negative')],
#  [('friend', 'Positive')],
#  [('youtube lgbtq problem', 'Negative'),
#   ('businessmodel problem', 'Negative')],
#  [('suburb', 'Neutral'),
#   ('sky', 'Neutral'),
#   ('jakartans', 'Neutral'),
#   ('entire village', 'Neutral'),
#   ('top', 'Positive'),
#   ('mall', 'Neutral')],
#  [('china', 'Neutral'), ('financial system', 'Neutral'), ('iou', 'Positive')],
#  [('death', 'Negative'),
#   ('alexander', 'Neutral'),
#   ('history great unsolved mystery', 'Positive')],
#  [('microworkers', 'Neutral'), ('digital life', 'Neutral')],
#  [('keyringless gnupg', 'Neutral')],
#  [('perfect french baguette', 'Positive')],
#  [('wind turbine', 'Neutral'), ('breeze', 'Neutral')],
#  [('iron age celtic woman', 'Neutral'), ('hollowedout tree trunk', 'Neutral')],
#  [('mistake firsttime founder', 'Negative'), ('video', 'Neutral')],
#  [('max software', 'Neutral'), ('computer', 'Neutral')],
#  [('empty train', 'Negative'),
#   ('modern silk road', 'Neutral'),
#   ('belt', 'Neutral'),
#   ('road interest align', 'Positive')],
#  [('wavelet', 'Neutral'), ('pdf', 'Neutral')],
#  [('maya sacrifice', 'Neutral')],
#  [('guide', 'Neutral'),
#   ('magnetorquers', 'Neutral'),
#   ('satellite', 'Neutral')],
#  [('future', 'Neutral')],
#  [('nec show', 'Neutral'), ('car', 'Neutral'), ('minute', 'Neutral')],
#  [('quantum radar ha', 'Positive'), ('first time', 'Neutral')],
#  [('ear speaker research design', 'Neutral'), ('evolution', 'Neutral')],
#  [('wasm v pnacl performance benchmark', 'Neutral')],
#  [('lindenmayer system', 'Neutral')],
#  [('show', 'Neutral'),
#   ('repository', 'Neutral'),
#   ('open source', 'Neutral'),
#   ('software', 'Neutral'),
#   ('hardware', 'Neutral')],
#  [('paper', 'Neutral')],
#  [('darpa', 'Neutral'),
#   ('help', 'Positive'),
#   ('election security problem', 'Negative')],
#  [('fed', 'Neutral'), ('realtime payment business', 'Neutral')],
#  [('woman', 'Neutral'),
#   ('yellow diamond', 'Positive'),
#   ('youtube video', 'Neutral'),
#   ('diamond', 'Positive')],
#  [('amazon', 'Positive'), ('plug', 'Neutral'), ('dash button', 'Neutral')],
#  [('problem solving', 'Negative'), ('clojure', 'Neutral')],
#  [('new book', 'Neutral'),
#   ('rich country', 'Positive'),
#   ('environmental impact', 'Neutral')],
#  [('animal movie promote', 'Positive'), ('researcher', 'Neutral')],
#  [('hyundai', 'Neutral'), ('explodes', 'Neutral')],
#  [('league', 'Neutral'), ('entropy', 'Neutral')],
#  [('transparent display', 'Neutral'),
#   ('perpixel color', 'Neutral'),
#   ('opacity control', 'Neutral')],
#  [('terrascope', 'Neutral'),
#   ('possibility', 'Neutral'),
#   ('earth', 'Neutral'),
#   ('atmospheric lens', 'Neutral')],
#  [('earth', 'Neutral')],
#  [('fuzzification', 'Neutral'), ('technique pdf', 'Neutral')],
#  [('storage', 'Neutral'), ('zoned storage initiative', 'Neutral')],
#  [('webmin', 'Neutral')],
#  [('static analysis', 'Neutral'), ('facebook', 'Neutral')],
#  [('death', 'Negative'), ('weather satellite', 'Neutral'), ('sdr', 'Neutral')],
#  [('holiday', 'Positive'), ('worker', 'Neutral'), ('company', 'Neutral')],
#  [('soviet union master spy', 'Neutral')],
#  [('stanford prison experiment pdf', 'Negative')],
#  [('marium', 'Neutral'),
#   ('dugong', 'Neutral'),
#   ('thailand dy', 'Neutral'),
#   ('plastic', 'Neutral')],
#  [('simple python package', 'Neutral'), ('deep learning feature', 'Neutral')],
#  [('massive ocean', 'Neutral'), ('towards', 'Neutral'), ('core', 'Neutral')],
#  [('def con', 'Neutral'), ('ctf retrospective', 'Neutral')],
#  [('kdevops framework', 'Neutral'),
#   ('linux kernel', 'Neutral'),
#   ('project', 'Neutral')],
#  [('simple pure', 'Neutral'),
#   ('total functional language', 'Neutral'),
#   ('datalog', 'Neutral')],
#  [('transparent polygon', 'Neutral')],
#  [('social medium', 'Neutral'), ('polarization', 'Neutral')],
#  [('glacial melt', 'Neutral'),
#   ('bridge', 'Neutral'),
#   ('greenland', 'Neutral')],
#  [('new treasure', 'Positive'), ('pompeii', 'Neutral')],
#  [('sec', 'Neutral'),
#   ('data leak', 'Negative'),
#   ('first american financial corp', 'Neutral')],
#  [('openbsd ada library', 'Neutral')],
#  [('dont', 'Neutral')],
#  [('u air force pause flight', 'Neutral'),
#   ('hundred c130s', 'Neutral'),
#   ('atypical cracking', 'Neutral')],
#  [('horse', 'Neutral'), ('land', 'Neutral'), ('booleans', 'Neutral')],
#  [('helium', 'Neutral')],
#  [('launch hn shift health yc s19', 'Neutral'),
#   ('healthcare cost previsit', 'Neutral')],
#  [('smartykit apple', 'Neutral')],
#  [('metadialect', 'Neutral'), ('scheme', 'Neutral')],
#  [('hawaii', 'Neutral'),
#   ('thirty meter telescope permit', 'Neutral'),
#   ('protest', 'Negative')],
#  [('gm', 'Neutral'), ('detroit', 'Neutral'), ('employer', 'Neutral')],
#  [('dipole drive', 'Neutral'),
#   ('new concept', 'Neutral'),
#   ('space propulsion', 'Neutral')],
#  [('microscope', 'Neutral')],
#  [('data privacy issue google', 'Neutral'),
#   ('android phone data', 'Neutral'),
#   ('carrier', 'Neutral')],
#  [('robotic thread', 'Neutral'), ('brain blood vessel', 'Neutral')],
#  [('vickrey clarke groves auction', 'Neutral')],
#  [('prolog control', 'Neutral'), ('slide', 'Neutral')],
#  [('opinion piece', 'Neutral'), ('ghc', 'Neutral'), ('end', 'Neutral')],
#  [('federated package registry', 'Neutral'), ('anything', 'Neutral')],
#  [('cbor concise binary object representation', 'Neutral')],
#  [('technology', 'Neutral'), ('pdf', 'Neutral')],
#  [('cassette', 'Neutral'), ('music', 'Neutral')],
#  [('paul', 'Neutral'), ('mozart', 'Neutral'), ('science', 'Neutral')],
#  [('praise', 'Positive'), ('xlogo', 'Neutral')],
#  [('show', 'Neutral'),
#   ('historical order book reconstruction api', 'Neutral'),
#   ('crypto market', 'Neutral')],
#  [('arc', 'Neutral'), ('seniority', 'Neutral')],
#  [('long game', 'Neutral'), ('research', 'Neutral')],
#  [('look', 'Neutral'), ('hs2 old oak common station', 'Neutral')],
#  [('judy array work', 'Neutral')],
#  [('bitcoin', 'Neutral'), ('apple ii', 'Neutral')],
#  [('masterpiece', 'Positive'), ('rare minoan sealstone', 'Neutral')],
#  [('golden ratio', 'Neutral')],
#  [('show', 'Neutral'), ('json output', 'Neutral')],
#  [('hp', 'Neutral')],
#  [('ssb room', 'Neutral'),
#   ('new server type', 'Neutral'),
#   ('scuttlebutt', 'Neutral')],
#  [('poincaré embeddings', 'Neutral')],
#  [('ocaml program', 'Neutral'), ('lua', 'Neutral')],
#  [('container', 'Neutral'),
#   ('vxlan bgp', 'Neutral'),
#   ('wireguard', 'Neutral')],
#  [('fine map', 'Positive'), ('alexander von humboldt', 'Neutral')],
#  [('new research', 'Neutral'),
#   ('ptsd', 'Neutral'),
#   ('elephant', 'Neutral'),
#   ('animal', 'Neutral')],
#  [('awakenings', 'Neutral'),
#   ('advanced dementia patient hint', 'Positive'),
#   ('untapped brain reserve', 'Neutral')],
#  [('recycling', 'Neutral'),
#   ('plastic', 'Neutral'),
#   ('dynamic covalent diketoenamine bond', 'Positive'),
#   ('pdf', 'Neutral')],
#  [('show', 'Neutral'),
#   ('dataviz project', 'Neutral'),
#   ('moon model', 'Neutral')],
#  [('new realtime detection', 'Neutral'),
#   ('fast radio burst', 'Neutral'),
#   ('utmost', 'Neutral')],
#  [('lucidscience electronic project', 'Neutral')],
#  [],
#  [('conversation', 'Neutral'),
#   ('team', 'Neutral'),
#   ('bread', 'Neutral'),
#   ('ancient egyptian yeast', 'Neutral')],
#  [('air force', 'Neutral'),
#   ('test', 'Neutral'),
#   ('scramjet', 'Neutral'),
#   ('n grumman', 'Neutral')],
#  [('decline', 'Neutral'), ('college newspaper', 'Neutral')],
#  [('john le carré novel', 'Positive')],
#  [('sleep dreem oura', 'Neutral'), ('rest', 'Neutral')],
#  [('penn effect', 'Neutral')],
#  [('hall law', 'Neutral'),
#   ('nineteenth century prequel', 'Neutral'),
#   ('law', 'Neutral')],
#  [('volcano', 'Neutral'), ('moon', 'Neutral'), ('dinosaur age', 'Neutral')],
#  [('world', 'Neutral'), ('chimp ha', 'Positive')],
#  [('smart plastic incineration', 'Positive'),
#   ('solution', 'Positive'),
#   ('global recycling crisis', 'Negative')],
#  [('expressive dependent language', 'Neutral')],
#  [('freshermeat opensource security software', 'Positive')],
#  [('engineer build', 'Neutral'),
#   ('microprocessor', 'Neutral'),
#   ('carbon nanotube', 'Neutral')],
#  [('new york farm', 'Neutral'),
#   ('success', 'Positive'),
#   ('eye', 'Neutral'),
#   ('next big thing', 'Neutral')],
#  [('disneyland', 'Neutral'), ('day', 'Neutral')],
#  [('zmachine', 'Neutral'), ('ocaml', 'Neutral')],
#  [('quantum air', 'Neutral'), ('electric airplane', 'Neutral')],
#  [('famous graphic chip microsoft talisman', 'Neutral')],
#  [('engineer', 'Neutral'),
#   ('metal foam', 'Neutral'),
#   ('room temperature', 'Neutral')],
#  [('golden research engine', 'Neutral'), ('combinator s19 batch', 'Neutral')],
#  [('mosque rebuilt', 'Neutral'), ('year', 'Neutral')],
#  [('miniature horse', 'Neutral')],
#  [('oral history', 'Neutral'), ('super soaker', 'Positive')],
#  [('trailblazing plan', 'Neutral'), ('california wildfire', 'Neutral')],
#  [('show', 'Neutral'), ('orm', 'Neutral'), ('firestore', 'Neutral')],
#  [('shape', 'Neutral'), ('tessellation', 'Neutral')],
#  [('mountain', 'Neutral'),
#   ('silver', 'Neutral'),
#   ('first global city', 'Neutral')],
#  [('ancient egypttoblack sea route adventurer', 'Positive'),
#   ('theory', 'Neutral')],
#  [('visible spectrum', 'Neutral'), ('python', 'Neutral')],
#  [('pdf', 'Neutral')],
#  [('wall street', 'Neutral'),
#   ('cost', 'Neutral'),
#   ('cloud infrastructure', 'Neutral')],
#  [('rule', 'Neutral'), ('ancient board game', 'Neutral')],
#  [('road', 'Neutral')],
#  [('software art', 'Neutral')],
#  [('webworkers async iterables', 'Neutral')],
#  [('show hn quarkide', 'Neutral'),
#   ('javascript runtime', 'Neutral'),
#   ('crossplatform desktop apps', 'Neutral')],
#  [('environment', 'Neutral'),
#   ('programming language', 'Neutral'),
#   ('part', 'Neutral')],
#  [('dove press typeface', 'Neutral')],
#  [('early year', 'Neutral'),
#   ('computer', 'Neutral'),
#   ('steve russell', 'Neutral'),
#   ('nolan bushnell', 'Neutral'),
#   ('video', 'Neutral')],
#  [('earth space junk problem', 'Negative')],
#  [('swadesh list', 'Neutral')],
#  [('salvator mundi', 'Neutral'),
#   ('unreality', 'Neutral'),
#   ('art market', 'Neutral')]]

# %%
#Seperate out negative and positive sentiments
def ExtractSentimentType(x,sentiment_type):
    target_words = []
    for items in x:
        if len(items)>0:
            if items[len(items)-1]== str(sentiment_type):
                target_words.append(" ".join(items[:len(items)-1]))
    return target_words

neg_sentiments = lambda x: ExtractSentimentType(x, "Negative")
pos_sentiments = lambda x: ExtractSentimentType(x, "Positive")
neg_link_titles_sentiment = sentimentRDD.map(neg_sentiments)
pos_link_titles_sentiment = sentimentRDD.map(pos_sentiments)

# %%
# Now let's extract the top 100 keywords from the extracted key phrases.
freq_pos_link_titles = pos_link_titles_sentiment.flatMap(lambda x : nltk.FreqDist(x)\
                                            .most_common())\
                                            .map(lambda x: x)\
                                            .reduceByKey(lambda x,y : x+y)\
                                            .sortBy(lambda x: x[1], ascending = False)
freq_pos_link_titles.take(100)
# Out:
# [('amazon', 7),
#  ('reward', 2),
#  ('ha', 2),
#  ('diamond', 2),
#  ('good software', 1),
#  ('bright idea', 1),
#  ('restaurants phone number', 1),
#  ('google excuse', 1),
#  ('r support', 1),
#  ('standard ebooks free publicdomain ebooks', 1),
#  ('increase', 1),
#  ('ha examinecom', 1),
#  ('consume le create', 1),
#  ('facebook ha', 1),
#  ('bright', 1),
#  ('amazon ha', 1),
#  ('haha wall', 1),
#  ('home chip fab', 1),
#  ('security vulnerability', 1),
#  ('hexadecimal number', 1),
#  ('improved rainbow colormap', 1),
#  ('speed matter', 1),
#  ('intelligent people', 1),
#  ('good note', 1),
#  ('super mario', 1),
#  ('cohen ha', 1),
#  ('kind', 1),
#  ('good tech debt', 1),
#  ('growth rate', 1),
#  ('price guarantee', 1),
#  ('certain flight', 1),
#  ('popular shopping street', 1),
#  ('toni morrison ha', 1),
#  ('sourcehut welcome bitbucket refugee', 1),
#  ('steam window client local privilege escalation', 1),
#  ('efficiency', 1),
#  ('excel', 1),
#  ('performance matter', 1),
#  ('amazon choice', 1),
#  ('expose security flaw deep', 1),
#  ('await', 1),
#  ('cool', 1),
#  ('mercurial support', 1),
#  ('google play team', 1),
#  ('validating data', 1),
#  ('successful cto', 1),
#  ('ibm ha', 1),
#  ('freeze engineering hire', 1),
#  ('free speech', 1),
#  ('turing award', 1),
#  ('monthly active user', 1),
#  ('ondevice realtime hand', 1),
#  ('google play', 1),
#  ('qemu vm escape', 1),
#  ('original diablo game', 1),
#  ('google support', 1),
#  ('solar efficiency', 1),
#  ('free image hosting', 1),
#  ('brave', 1),
#  ('ftp url support', 1),
#  ('sale fun', 1),
#  ('twofactor security key', 1),
#  ('credit rating', 1),
#  ('landmark ruling', 1),
#  ('u treasury', 1),
#  ('major book publisher sue amazon', 1),
#  ('kubernetes security assessment pdf', 1),
#  ('culture fit', 1),
#  ('certain query', 1),
#  ('cavendish banana ha', 1),
#  ('technical vision', 1),
#  ('qt', 1),
#  ('dream', 1),
#  ('freedom video', 1),
#  ('credit card', 1),
#  ('free selfupdating website', 1),
#  ('multicurrency support', 1),
#  ('consumergrade security', 1),
#  ('first solar road ha', 1),
#  ('profit', 1),
#  ('container safer', 1),
#  ('good conversation', 1),
#  ('github support web authentication webauthn', 1),
#  ('security key', 1),
#  ('approval', 1),
#  ('natural language', 1),
#  ('epub support', 1),
#  ('storytime create story', 1),
#  ('sonic ha', 1),
#  ('blessing', 1),
#  ('credit card customer', 1),
#  ('high growth company', 1),
#  ('amazon cloud backup', 1),
#  ('code efficiency', 1),
#  ('clarity', 1),
#  ('dignity', 1),
#  ('meaningful job', 1),
#  ('great impostor', 1),
#  ('highlight', 1),
#  ('escape room', 1)]

# %%
#converting RDD to spark dataframe
df_fDist = freq_pos_link_titles.toDF()

df_fDist.createOrReplaceTempView("myTable") 

#renaming columns 
df2 = spark.sql("SELECT _1 AS Keywords, _2 as Frequency from myTable limit 1000") 

 #converting spark dataframes to pandas dataframes
pandDPos = df2.toPandas()
pandDPos.plot.barh(x='Keywords', y='Frequency', rot=1, figsize=(10,8))

# %%
# Now let's extract the top 100 keywords from the extracted key phrases.
freq_neg_link_titles = neg_link_titles_sentiment.flatMap(lambda x : nltk.FreqDist(x)\
                                            .most_common())\
                                            .map(lambda x: x)\
                                            .reduceByKey(lambda x,y : x+y)\
                                            .sortBy(lambda x: x[1], ascending = False)
freq_neg_link_titles.take(100)
# Out:
# [('death', 3),
#  ('problem', 2),
#  ('fire', 2),
#  ('lonely work', 1),
#  ('forgotten book programmer', 1),
#  ('cut', 1),
#  ('awkward goodbye', 1),
#  ('destroyer', 1),
#  ('io exploit chain', 1),
#  ('crap', 1),
#  ('linux kernel inability', 1),
#  ('low memory pressure', 1),
#  ('decrement carbon stripe negative emission commitment', 1),
#  ('horror', 1),
#  ('death note l anonymity', 1),
#  ('time anxiety', 1),
#  ('wtf', 1),
#  ('strain', 1),
#  ('useless window', 1),
#  ('rust language cheat sheet', 1),
#  ('loss', 1),
#  ('remote attack surface', 1),
#  ('npm ban terminal ad', 1),
#  ('selective blocking', 1),
#  ('anxiety', 1),
#  ('leak location pic', 1),
#  ('lost art', 1),
#  ('irs budget cut cost', 1),
#  ('knew risk', 1),
#  ('dangerous writing app', 1),
#  ('attack', 1),
#  ('dirty trick', 1),
#  ('social exclusion fuel extremism', 1),
#  ('financial crisis', 1),
#  ('door problem', 1),
#  ('combat design', 1),
#  ('imessage file vulnerability', 1),
#  ('ad blocking', 1),
#  ('tracker blocking', 1),
#  ('corn loss', 1),
#  ('die', 1),
#  ('opioid crisis johnson', 1),
#  ('drug price high critic', 1),
#  ('mistake', 1),
#  ('exploit', 1),
#  ('dead person', 1),
#  ('hard drug', 1),
#  ('faa ban', 1),
#  ('danish bank launch negative interest rate mortgage', 1),
#  ('digital distraction', 1),
#  ('privacy problem', 1),
#  ('hacker attack swell', 1),
#  ('le argumentative online', 1),
#  ('crime', 1),
#  ('bond offering negative yield', 1),
#  ('disappointing failure', 1),
#  ('adtech leak', 1),
#  ('bad place', 1),
#  ('loneliness', 1),
#  ('tragedy', 1),
#  ('disruption', 1),
#  ('portuguese bank note crisis', 1),
#  ('children privacy violation', 1),
#  ('black hole destroy information', 1),
#  ('expose systemic failing', 1),
#  ('bad time', 1),
#  ('serious work', 1),
#  ('shareholder lawsuit', 1),
#  ('water crisis', 1),
#  ('buddhist monk confronts', 1),
#  ('suicide culture', 1),
#  ('advertising ban', 1),
#  ('replication crisis', 1),
#  ('debt', 1),
#  ('havoc', 1),
#  ('rotten apple right', 1),
#  ('pay cut', 1),
#  ('mock work', 1),
#  ('scaling problem', 1),
#  ('mobility trap', 1),
#  ('error backpropagation', 1),
#  ('crossword panic', 1),
#  ('moravecs paradox', 1),
#  ('second crash', 1),
#  ('broken vertical bar', 1),
#  ('contagious cancer', 1),
#  ('miss', 1),
#  ('kernel panic', 1),
#  ('phytoplankton population drop', 1),
#  ('subversive message', 1),
#  ('linux pressure stall information psi', 1),
#  ('india messy electric vehicle revolution', 1),
#  ('day vulnerability', 1),
#  ('pentagon contract fight amazon ha foe', 1),
#  ('fraud', 1),
#  ('api gateway identity crisis', 1),
#  ('dead end', 1),
#  ('computer stupidity', 1),
#  ('isolation level', 1),
#  ('apple card restriction', 1)]

# %%
#converting RDD to spark dataframe
df_fDist = freq_neg_link_titles.toDF()

df_fDist.createOrReplaceTempView("myTable") 

#renaming columns 
df2 = spark.sql("SELECT _1 AS Keywords, _2 as Frequency from myTable limit 1000") 

 #converting spark dataframes to pandas dataframes
pandDNeg = df2.toPandas()
pandDNeg.plot.barh(x='Keywords', y='Frequency', rot=1, figsize=(10,8))

# %%
#Write the top 100 words extracted from keyphrases to file. Both negative and positive
script_dir = os.getcwd()  #<-- absolute dir the script is in
rel_path = "..\data\Top1000KeyPositivePhrasesInTitles.csv"
abs_file_path = os.path.join(script_dir, rel_path)

pandDPos.to_csv(abs_file_path)

script_dir = os.getcwd()  #<-- absolute dir the script is in
rel_path = "..\data\Top1000NegativeKeyPhrasesInTitles.csv"
abs_file_path = os.path.join(script_dir, rel_path)

pandDNeg.to_csv(abs_file_path)
